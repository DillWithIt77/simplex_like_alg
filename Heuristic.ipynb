# %% [markdown]
# # Active Ind Testing

# %%
import numpy as np
import gurobipy as gp
import math
import sympy
import contextlib
import time
import os
from utils import result, METHODS, INF, EPS
from mps_reader_preprocessor import read_mps_preprocess
from polyhedral_model import PolyhedralModel
from polyhedron import Polyhedron

# %% [markdown]
# ## Read in Polyhedron P

# %%
problem_dir = 'netlib_lp_subset'
# problem = 'kb2'
problem = 'adlittle'
# problem = 'angela_test_prob'
# problem = 'network_ex'
# problem = 'gfrd-pnc'
# problem = 'modszk1'
# problem = 'cycle'
# problem = 'cre-c'
mps_fn=os.path.join(problem_dir, problem)
results_dir='results'
max_time=300
sd_method='dual_simplex'
reset=False,
partition_polytope=False
n=0
k=0
spindle=False
spindle_dim=0
n_cone_facets=0
n_parallel_facets=0

# %% [markdown]
# ## Perform SDCA

# %%
### Build Initial Polyhedron from file
print(f'Reading {mps_fn}...')
c, B, d, A, b = read_mps_preprocess(mps_fn)
print('Building polyhedron...')
P = Polyhedron(B, d, A, b, c)
rank_A = np.linalg.matrix_rank(A)

print('Finding feasible solution...')
x_feasible, vbasis, cbasis = P.find_feasible_solution(verbose=False)

x = x_feasible
c=None
verbose=False
method='dual_simplex'
reset=False
max_time=300
first_warm_start=None
save_first_steps=0
problem_name=''

if c is not None:
    P.set_objective(c)

t0 = time.time()
x_current = x
if save_first_steps:
    np.save('solutions/{}_0.npy'.format(problem_name), x_current)      
active_inds, M, omega = P.get_active_constraints(x_current, alt = True)

R = omega/((P.m_B-P.n)*M)
    
pm = P.build_polyhedral_model(active_inds=active_inds, method=method, alt = True)

if first_warm_start is not None:
    print('Using custom warm start')
    pm.set_solution(first_warm_start)
t1 = time.time()
build_time = t1 - t0
print('Polyhedral model build time: {}'.format(build_time))
    
sub_times = {'sd': [], 'step': [], 'solve': [], 'phase_times': []}
active_inds_it = []
descent_circuits = []
obj_values = []
step_sizes = []
iter_times = []
simplex_iters = []
pts_visited = []
iteration = 0
active_inds_it.append(active_inds)
pts_visited.append(x_current)
obj_value = P.c.dot(x_current)
obj_values.append(obj_value)
t2 = time.time()
iter_times.append(t2 - t1)


# compute steepest-descent direction
descent_direction, y_pos, y_neg, steepness, num_steps, solve_time, phase_times = pm.compute_sd_direction(verbose=verbose)
simplex_iters.append(num_steps)
sub_times['solve'].append(solve_time)
sub_times['phase_times'].append(phase_times)
    
t3 = time.time()
sub_times['sd'].append(t3 - t2)
restrict_facets = False
# restrict_facets.append(False)
did_simp = False
first_step = True
G = -float('inf')
s = 1
# T = -float('inf') ##### need to run experiments to figure out what this should be.
while abs(steepness) > EPS:
        
    t3 = time.time()
    if reset:
        pm.reset()
        
    # take maximal step
    if not did_simp:
        x_current, alpha, active_inds = P.take_maximal_step(descent_direction, y_pos, y_neg)
        pts_visited.append(x_current)

    if first_step:
        G_guess = (1/R)*P.c.dot(pts_visited[-1] - pts_visited[-2])
        G = G_guess - P.c.dot(pts_visited[-1] - pts_visited[-2])
        first_step = False
    elif P.c.dot(pts_visited[-2] - pts_visited[-1]) >= (R/s)*G:
        G_old = G
        G = G_old - P.c.dot(pts_visited[-2] - pts_visited[-1])
    else:
        restrict_facets = True

    if P.bfs_soln_chck(x_current) and restrict_facets:
        M = -float('inf')
        omega = float('inf')
        for i in range(P.m_B):
            diff = P.d[i] - P.B_x_current[i]
            if diff > M:
                M = diff
            if diff > 0 and diff < omega:
                omega = diff
        R = omega/((P.m_B-P.n)*M)
        first_step = True
        
    if iteration % 50 == 0 or iteration == 1:
        print('\nIteration {}'.format(iteration))
        print('Objective: {}'.format(obj_value))
        print('Steepness: {}'.format(steepness))
        print('Step length: {}'.format(alpha))
        
    t4 = time.time()
    active_inds_it.append(active_inds)
    obj_value = P.c.dot(x_current)
    obj_values.append(obj_value)
    iter_times.append(t4 - t1)
    sub_times['step'].append(t4 - t3) 
    descent_circuits.append(descent_direction)
    step_sizes.append(alpha)     
                
    if math.isinf(alpha):
        # problem is unbounded
        result(status=1, circuits=descent_circuits, steps=step_sizes)
        
    # compute steepest-descent direction
    # if G <= T:
    #     print('***switched to primal simplex***')
    #     did_simp = True
    #     num_dec_places = Polyhedron.num_aft_dec(obj_value)
    #     x_current = P.second_vert(x_current, obj_value, num_dec_places, verbose=False)
    #     pts_visited.append(x_current)
    #     active_inds = P.get_active_constraints(x_current)
    #     alpha = 0.0
    # elif restrict_facets:
    if restrict_facets:
        pm.set_active_inds(active_inds, inds = active_inds)
        did_simp = False
        descent_direction, y_pos, y_neg, steepness, num_steps, solve_time, phase_times = pm.compute_sd_direction(verbose=verbose)
    else:
        pm.set_active_inds(active_inds)
        did_simp = False
        descent_direction, y_pos, y_neg, steepness, num_steps, solve_time, phase_times = pm.compute_sd_direction(verbose=verbose)
        
    print(f'Number of Active Inds for Iteration {iteration}: {len(active_inds)}')
    print(f'Switch to Facet Restriction for Iteration {iteration}: {restrict_facets}')
    print('---------------------------------------------------------------')
    
        
    t5 = time.time()
    sub_times['sd'].append(t5 - t4)
    sub_times['solve'].append(solve_time)
    sub_times['phase_times'].append(phase_times)
    simplex_iters.append(num_steps)
        
    iteration += 1
    current_time = t5 - t1
    if current_time > max_time:
        result(status=2)
    if iteration <= save_first_steps:
        np.save('solutions/{}_{}.npy'.format(problem_name, iteration), x_current)

t6 = time.time()
total_time = t6 - t1   
print('Total time for steepest-descent scheme: {}'.format(total_time))
# Out:
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.014032125473022461
#
# Iteration 0
# Objective: 671734.1100278501
# Steepness: -1640.0
# Step length: 0.789078446763215
# Number of Active Inds for Iteration 0: 93
# Switch to Facet Restriction for Iteration 0: False
# ---------------------------------------------------------------
#
# Iteration 1
# Objective: 670440.0213751586
# Steepness: -1074.3908969210174
# Step length: 34.370158400267876
# Number of Active Inds for Iteration 1: 92
# Switch to Facet Restriction for Iteration 1: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 2: 89
# Switch to Facet Restriction for Iteration 2: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 3: 89
# Switch to Facet Restriction for Iteration 3: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 4: 88
# Switch to Facet Restriction for Iteration 4: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 5: 89
# Switch to Facet Restriction for Iteration 5: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 6: 89
# Switch to Facet Restriction for Iteration 6: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 7: 87
# Switch to Facet Restriction for Iteration 7: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 8: 80
# Switch to Facet Restriction for Iteration 8: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 9: 78
# Switch to Facet Restriction for Iteration 9: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 10: 78
# Switch to Facet Restriction for Iteration 10: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 11: 78
# Switch to Facet Restriction for Iteration 11: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 12: 78
# Switch to Facet Restriction for Iteration 12: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 13: 79
# Switch to Facet Restriction for Iteration 13: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 14: 80
# Switch to Facet Restriction for Iteration 14: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 15: 80
# Switch to Facet Restriction for Iteration 15: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 16: 81
# Switch to Facet Restriction for Iteration 16: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 17: 79
# Switch to Facet Restriction for Iteration 17: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 18: 79
# Switch to Facet Restriction for Iteration 18: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 19: 78
# Switch to Facet Restriction for Iteration 19: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20: 76
# Switch to Facet Restriction for Iteration 20: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 21: 73
# Switch to Facet Restriction for Iteration 21: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 22: 72
# Switch to Facet Restriction for Iteration 22: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 23: 70
# Switch to Facet Restriction for Iteration 23: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 24: 70
# Switch to Facet Restriction for Iteration 24: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 25: 71
# Switch to Facet Restriction for Iteration 25: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 26: 72
# Switch to Facet Restriction for Iteration 26: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 27: 72
# Switch to Facet Restriction for Iteration 27: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 28: 72
# Switch to Facet Restriction for Iteration 28: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 29: 72
# Switch to Facet Restriction for Iteration 29: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 30: 71
# Switch to Facet Restriction for Iteration 30: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 31: 72
# Switch to Facet Restriction for Iteration 31: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 32: 72
# Switch to Facet Restriction for Iteration 32: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 33: 72
# Switch to Facet Restriction for Iteration 33: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 34: 73
# Switch to Facet Restriction for Iteration 34: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 35: 73
# Switch to Facet Restriction for Iteration 35: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 36: 73
# Switch to Facet Restriction for Iteration 36: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 37: 73
# Switch to Facet Restriction for Iteration 37: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 38: 72
# Switch to Facet Restriction for Iteration 38: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 39: 73
# Switch to Facet Restriction for Iteration 39: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 40: 72
# Switch to Facet Restriction for Iteration 40: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 41: 72
# Switch to Facet Restriction for Iteration 41: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 42: 73
# Switch to Facet Restriction for Iteration 42: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 43: 72
# Switch to Facet Restriction for Iteration 43: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 44: 73
# Switch to Facet Restriction for Iteration 44: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 45: 73
# Switch to Facet Restriction for Iteration 45: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 46: 74
# Switch to Facet Restriction for Iteration 46: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 47: 74
# Switch to Facet Restriction for Iteration 47: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 48: 74
# Switch to Facet Restriction for Iteration 48: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 49: 75
# Switch to Facet Restriction for Iteration 49: False
# ---------------------------------------------------------------
#
# Iteration 50
# Objective: 225732.03531313842
# Steepness: -2.0343141232722095
# Step length: 2.11198353067272
# Number of Active Inds for Iteration 50: 75
# Switch to Facet Restriction for Iteration 50: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 51: 74
# Switch to Facet Restriction for Iteration 51: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 52: 74
# Switch to Facet Restriction for Iteration 52: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 53: 74
# Switch to Facet Restriction for Iteration 53: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 54: 74
# Switch to Facet Restriction for Iteration 54: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 55: 75
# Switch to Facet Restriction for Iteration 55: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 56: 74
# Switch to Facet Restriction for Iteration 56: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 57: 74
# Switch to Facet Restriction for Iteration 57: False
# ---------------------------------------------------------------
# Total time for steepest-descent scheme: 0.2694883346557617

# %%
print(obj_values[-1])
# print(simp_result)
# print(x_current)
# Out:
# 225494.96316238033

# %%
print(f'Reading {mps_fn}...')
c, B, d, A, b = read_mps_preprocess(mps_fn)
print('Building polyhedron...')
P = Polyhedron(B, d, A, b, c)
print('\nSolving with simplex method...')
lp_result = P.solve_lp(verbose=False, record_objs=True)
print('\nSolution using simplex method:')
print(lp_result)
# Out:
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 225494.9631623803
# Total solve time: 0.0
# Number of iterations: 98.0
