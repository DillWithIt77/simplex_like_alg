# %% [markdown]
# # Original SDAC Code

# %%
import numpy as np
import gurobipy as gp
import math
import sympy
import contextlib
import time
import os
from utils import result, METHODS, INF, EPS
from mps_reader_preprocessor import read_mps_preprocess
from polyhedral_model import PolyhedralModel
from polyhedron import Polyhedron

# %% [markdown]
# ## Read in Polyhedron P

# %%
# problems = ['adlittle', 'afiro', 'agg2','agg3','agg', 'bandm',
#  'beaconfd', 'blend', 'bnl1', 'boeing1', 'boeing2', 'bore3d', 'brandy', 'capri',
#  'cre-c', 'cycle', 'degen2', 'degen3', 'e226', 'etamacro', 'fffff800', 'finnis',
#  'fit1d', 'fit1p', 'forplan', 'ganges', 'gfrd-pnc', 'grow15', 'grow22', 'grow7',
#  'israel', 'kb2', 'ken-07', 'lotfi', 'maros', 'modszk1', 'pds-02', 'perold',
#  'pilot4', 'pilotnov', 'qap08', 'recipe', 'sc105', 'sc205', 'sc50a',
#  'sc50b', 'scagr25', 'scagr7', 'scfxm1', 'scfxm2', 'scfxm3', 'scorpion', 'scrs8',
#  'scsd1', 'scsd6', 'scsd8', 'sctap1', 'sctap2', 'sctap3', 'seba', 'share1b',
#  'share2b', 'shell', 'ship04l', 'ship04s', 'ship08l', 'ship08s', 'ship12l', 'ship12s',
#  'sierra', 'stair', 'standata', 'standgub', 'standmps', 'stocfor1', 'stocfor2', 'tuff',
#  'vtp_base', 'wood1p']


# # mps_fn='C:\Users\DillW\OneDrive - The University of Colorado Denver\Documents\GitHub\simplex_like_alg\netlib_lp_subset\kb2'
# for i in problems:
#     problem_dir = 'netlib_lp_subset'
#     # problem = 'afiro'
#     mps_fn=os.path.join(problem_dir, i)
#     results_dir='results'
#     max_time=300
#     sd_method='dual_simplex'
#     reset=False,
#     partition_polytope=False
#     n=0
#     k=0
#     spindle=False
#     spindle_dim=0
#     n_cone_facets=0
#     n_parallel_facets=0

#     ### Build Initial Polyhedron from file
#     print(f'Reading {mps_fn}...')
#     c, B, d, A, b = read_mps_preprocess(mps_fn)
#     print('Building polyhedron...')
#     P = Polyhedron(B, d, A, b, c)

# %%
problem_dir = 'netlib_lp_subset'
# problem = 'kb2'
# problem = 'maros'
# problem = 'pilot4'
# problem = 'adlittle'
# problem = 'angela_test_prob'
# problem = 'network_ex'
# problem = 'gfrd-pnc'
# problem = 'modszk1'
problem = 'cycle'
# problem = 'cre-c'
# problem = 'qap08'
mps_fn=os.path.join(problem_dir, problem)
results_dir='results'
max_time=300
sd_method='dual_simplex'
reset=False,
partition_polytope=False
n=0
k=0
spindle=False
spindle_dim=0
n_cone_facets=0
n_parallel_facets=0

# %% [markdown]
# ## Perform SDCA

# %% [markdown]
# ### Original Code

# %%
### Build Initial Polyhedron from file
print(f'Reading {mps_fn}...')
c, B, d, A, b = read_mps_preprocess(mps_fn)
print('Building polyhedron...')
P = Polyhedron(B, d, A, b, c)

print('Finding feasible solution...')
x_feasible, vbasis, cbasis = P.find_feasible_solution(verbose=False)

x = x_feasible
c=None
verbose=False
method='dual_simplex'
reset=False
max_time=300
first_warm_start=None
save_first_steps=0
problem_name=''

if c is not None:
    P.set_objective(c)

t0 = time.time()
x_current = x
if save_first_steps:
    np.save('solutions/{}_0.npy'.format(problem_name), x_current)      
active_inds = P.get_active_constraints(x_current)
    
pm = P.build_polyhedral_model(active_inds=active_inds, method=method, alt = True)

if first_warm_start is not None:
    print('Using custom warm start')
    pm.set_solution(first_warm_start)
t1 = time.time()
build_time = t1 - t0
print('Polyhedral model build time: {}'.format(build_time))
    
sub_times = {'sd': [], 'step': [], 'solve': [], 'phase_times': []}    
descent_circuits = []
obj_values = []
step_sizes = []
iter_times = []
simplex_iters = []
iteration = 0
obj_value = P.c.dot(x_current)
obj_values.append(obj_value)
t2 = time.time()
iter_times.append(t2 - t1)


# compute steepest-descent direction
descent_direction, y_pos, y_neg, steepness, num_steps, solve_time, phase_times = pm.compute_sd_direction(verbose=verbose)
simplex_iters.append(num_steps)
sub_times['solve'].append(solve_time)
sub_times['phase_times'].append(phase_times)
    
t3 = time.time()
sub_times['sd'].append(t3 - t2)
    
while abs(steepness) > EPS:
        
    t3 = time.time()
    if reset:
        pm.reset()
        
    # take maximal step
    x_current, alpha, active_inds = P.take_maximal_step(descent_direction, y_pos, y_neg) 
        
    if iteration % 50 == 0 or iteration == 1:
        print('\nIteration {}'.format(iteration))
        print('Objective: {}'.format(obj_value))
        print('Steepness: {}'.format(steepness))
        print('Step length: {}'.format(alpha))
        
    t4 = time.time()
    obj_value = P.c.dot(x_current)
    obj_values.append(obj_value)
    iter_times.append(t4 - t1)
    sub_times['step'].append(t4 - t3) 
    descent_circuits.append(descent_direction)
    step_sizes.append(alpha)     
                
    if math.isinf(alpha):
        # problem is unbounded
        result(status=1, circuits=descent_circuits, steps=step_sizes)
        
    pm.set_active_inds(active_inds)
    descent_direction, y_pos, y_neg, steepness, num_steps, solve_time, phase_times = pm.compute_sd_direction(
                                                                                                verbose=verbose)
        
    t5 = time.time()
    sub_times['sd'].append(t5 - t4)
    sub_times['solve'].append(solve_time)
    sub_times['phase_times'].append(phase_times)
    simplex_iters.append(num_steps)
        
    iteration += 1
    current_time = t5 - t1
    if current_time > max_time:
        result(status=2)
    if iteration <= save_first_steps:
        np.save('solutions/{}_{}.npy'.format(problem_name, iteration), x_current)

t6 = time.time()
total_time = t6 - t1   
print('Total time for steepest-descent scheme: {}'.format(total_time))
# Out:
# Reading netlib_lp_subset\cycle...
# removing redundant constraint 'GHF...EB'
# removing redundant constraint 'GHH...EB'
# removing redundant constraint 'GHT...EB'
# removing redundant constraint 'GHX...EB'
# removing redundant constraint 'BGL...AA'
# removing redundant constraint 'BGL...AC'
# removing redundant constraint 'BOA...AC'
# removing redundant constraint 'BOB...AC'
# removing redundant constraint 'BGL...AE'
# removing redundant constraint 'BOA...AE'
# removing redundant constraint 'BOF...BD'
# removing redundant constraint 'BGL...CF'
# removing redundant constraint 'BOB...CF'
# removing redundant constraint 'BOX...CF'
# removing redundant constraint 'BGL...DD'
# removing redundant constraint 'BDN...EF'
# removing redundant constraint 'BOB...EF'
# Building polyhedron...
# Problem size: n = 2857,  m_B = 3437,  m_A = 1376
# Finding feasible solution...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-01
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 9.037283182144165
#
# Iteration 0
# Objective: 0.0
# Steepness: -0.02274333273222677
# Step length: 95.91398436118386
#
# Iteration 1
# Objective: -2.1814036599999995
# Steepness: -0.017055657622435053
# Step length: 114.89277238330612
#
# Iteration 50
# Objective: -4.576975456507307
# Steepness: -0.000484968970578597
# Step length: 0.061230138239927415
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 100
# Objective: -4.69627185224767
# Steepness: -0.00030571120045132775
# Step length: 0.04031049925368381
#
# Iteration 150
# Objective: -4.72632525431214
# Steepness: -0.00019938447973572273
# Step length: 0.8480233236894363
#
# Iteration 200
# Objective: -4.791817884809699
# Steepness: -0.00015225254477404423
# Step length: 1.683855082947827
#
# Iteration 250
# Objective: -4.832442506752199
# Steepness: -9.257459548386447e-05
# Step length: 5.084909027894423
# Degenerate step computed. Changing active facets...
#
# Iteration 300
# Objective: -4.852875931295527
# Steepness: -8.515125936564539e-05
# Step length: 23.260220158661344
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 350
# Objective: -4.955724025373627
# Steepness: -6.84229157193049e-05
# Step length: 30.434658192505154
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 400
# Objective: -5.038918120744013
# Steepness: -6.163896500851828e-05
# Step length: 0.33950100547824524
#
# Iteration 450
# Objective: -5.046016765831611
# Steepness: -4.4902934880688636e-05
# Step length: 85.45635395970545
# Degenerate step computed. Changing active facets...
#
# Iteration 500
# Objective: -5.216083124766313
# Steepness: -1.2043349136341846e-05
# Step length: 0.020508640677643703
# Degenerate step computed. Changing active facets...
#
# Iteration 550
# Objective: -5.2214397781352595
# Steepness: -2.9289635110958017e-06
# Step length: 37.84913312602026
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 600
# Objective: -5.225480778489798
# Steepness: -8.436910080674353e-07
# Step length: 0.009331749097706407
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 650
# Objective: -5.22548320032908
# Steepness: -4.401794595694297e-07
# Step length: -167.5728963268317
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 700
# Objective: -5.22547994088051
# Steepness: -5.622639360975995e-07
# Step length: 2.284173164080868
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 750
# Objective: -5.225481339502366
# Steepness: -4.931983812760234e-07
# Step length: 0.04518610703918758
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 800
# Objective: -5.218321834350119
# Steepness: -4.934467397469588e-07
# Step length: 23.230555070313503
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 850
# Objective: -1.0602118570714083
# Steepness: -5.397915304869665e-07
# Step length: 7512860.165122915
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 900
# Objective: -4.792736076605706
# Steepness: -5.495873285042273e-07
# Step length: -33334500.890046205
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 950
# Objective: 9.635605480747472
# Steepness: -1.0098128783973385e-06
# Step length: -50178.32341649888
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1000
# Objective: 1628.6104765296914
# Steepness: -9.523161405160047e-07
# Step length: 118582812.29744554
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1050
# Objective: 16559.460172833875
# Steepness: -9.530735959750199e-07
# Step length: 7364660117.13611
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1100
# Objective: 108181.65493878722
# Steepness: -9.528685474622608e-07
# Step length: 10985122000.505716
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1150
# Objective: 181719307788.45312
# Steepness: -9.773545820207129e-07
# Step length: 2204695002682036.2
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1200
# Objective: 48036557297.65234
# Steepness: -9.773586133730124e-07
# Step length: -5.771078932867725e+17
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1250
# Objective: 185950939842.34375
# Steepness: -9.77357778080855e-07
# Step length: 639.0674949789601
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1300
# Objective: 128494743708.64062
# Steepness: -9.77358096950209e-07
# Step length: 4.574871900327858e+16
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1350
# Objective: 1608064938471.875
# Steepness: -9.775512245489577e-07
# Step length: -3.2832675756793853e+21
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1400
# Objective: 8485037430007.0
# Steepness: -9.775917639430573e-07
# Step length: 3.304685241722563e+18
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1450
# Objective: 5813063277156.5
# Steepness: -9.775493480902253e-07
# Step length: -2.8916693648776013e+20
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1500
# Objective: 76114105361392.0
# Steepness: -9.775482304425842e-07
# Step length: -3.108492442283904e+19
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1550
# Objective: 3953532489438208.0
# Steepness: -4.971927630781386e-07
# Step length: -9.36630522796528e+18
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1600
# Objective: 2155787060910080.0
# Steepness: -4.971928263331643e-07
# Step length: -0.0
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1650
# Objective: 2564679600038144.0
# Steepness: -4.971927630781391e-07
# Step length: 9.669279526417273e+20
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1700
# Objective: 1.695995882902913e+18
# Steepness: -4.95974349484275e-07
# Step length: -154443938352440.53
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1750
# Objective: 1.1394213187991634e+18
# Steepness: -4.95973507119306e-07
# Step length: 3.204168407112486e+20
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1800
# Objective: 1.1393037227247534e+18
# Steepness: -4.95973507119306e-07
# Step length: 4.702810114121512e+19
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1850
# Objective: 1.139482059702272e+18
# Steepness: -4.95973507119306e-07
# Step length: 189097016.79031214
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1900
# Objective: 1.1397086702192558e+18
# Steepness: -4.959735995090815e-07
# Step length: -1.5134669651599766e+21
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1950
# Objective: 1.1398841176615813e+18
# Steepness: -4.959735071192518e-07
# Step length: 3.2806123454790333e+18
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 2000
# Objective: 1.1500102936542577e+18
# Steepness: -4.95973507119306e-07
# Step length: -2.355812976828931e+21
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 2050
# Objective: 2.102135904081019e+18
# Steepness: -4.962850810039999e-07
# Step length: 1.8492903613496705e+20
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 2100
# Objective: 2.5861298178755133e+18
# Steepness: -4.962850810039999e-07
# Step length: -8.204480303255231e+21
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 2150
# Objective: 2.585853868976374e+18
# Steepness: -4.962850810041625e-07
# Step length: 1.1898369971084823e+19
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 2200
# Objective: 5.487075201553793e+18
# Steepness: -4.962850810041625e-07
# Step length: -3.844606718176632e+22
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 2250
# Objective: 5.509000016376627e+18
# Steepness: -4.962850810041625e-07
# Step length: -45222218247.05265
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 2300
# Objective: 5.666514564842258e+18
# Steepness: -4.962850810041625e-07
# Step length: 3.9211185917055054e+22
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 2350
# Objective: 5.725655629530923e+18
# Steepness: -4.962850810042167e-07
# Step length: 6.370254492459797e+22
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 2400
# Objective: 5.659400971332616e+18
# Steepness: -4.962850810042167e-07
# Step length: -2.399585194211342e+24
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 2450
# Objective: 5.627328905733997e+18
# Steepness: -4.962850810042167e-07
# Step length: 2.250934026258721e+23
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 2500
# Objective: 5.538908199010592e+19
# Steepness: -4.962850810041625e-07
# Step length: 6.962719118554948e+25
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 2550
# Objective: 8.462528899964731e+18
# Steepness: -4.962850810041625e-07
# Step length: 1.0401213618224578e+23
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 2600
# Objective: 1.4589763882661792e+21
# Steepness: -5.980917031795417e-07
# Step length: 1.3107288948894474e+27
# Degenerate step computed. Changing active facets...
# ...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 3750
# Objective: 2.43964809218318e+33
# Steepness: -9.673722680460803e-07
# Step length: 1.282357673031663e+39
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 3800
# Objective: 9.156218571939566e+31
# Steepness: -9.673722680461887e-07
# Step length: -7.10815299046209e+36
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 3850
# Objective: 9.038516512966145e+31
# Steepness: -9.67372268047056e-07
# Step length: -7.60770279197286e+35
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 3900
# Objective: 7.729124751358528e+32
# Steepness: -9.673722680455382e-07
# Step length: -1.0432164914072563e+39
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 3950
# Objective: 8.672921132280907e+32
# Steepness: -9.67372268045972e-07
# Step length: -2.369661778113187e+37
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 4000
# Objective: 6.4942491401602e+34
# Steepness: -9.67372268046514e-07
# Step length: -6.288447503172998e+39
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 4050
# Objective: 5.8112867689415484e+35
# Steepness: -9.673722680455382e-07
# Step length: -7.653986821080183e+41
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 4100
# Objective: 2.2827281898698345e+35
# Steepness: -9.673722680461887e-07
# Step length: 1.4822504654686828e+40
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 4150
# Objective: 1.8251104100600443e+36
# Steepness: -9.673722680461887e-07
# Step length: -0.0
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 4200
# Objective: 1.3688174537921551e+44
# Steepness: -9.41256533481589e-07
# Step length: 3.828354277692749e+49
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 4250
# Objective: 1.8193752107098828e+46
# Steepness: -8.662124599733719e-07
# Step length: 1.3234724566395862e+52
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 4300
# Objective: 8.209871955015848e+45
# Steepness: -8.658093977789795e-07
# Step length: -2.298385694111119e+50
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...

# %%
print(obj_values[-1])
# print(x_current)

# %%
print('\nSolving with simplex method...')
lp_result = P.solve_lp(verbose=False, record_objs=True)
print('\nSolution using simplex method:')
print(lp_result)

# %%
# print(pm)
