# %% [markdown]
# # Warm Start Results

# %% [markdown]
# ## Import Statements

# %%
import os
import pickle
import subprocess

from main import main

from glob import glob
import numpy as np
import random
from matplotlib import pyplot as plt
# %matplotlib inline

from utils import avg

# %% [markdown]
# ## Run Tests

# %%
problems = ['adlittle', 'afiro', 'agg2','agg3','agg', 'bandm',
 'beaconfd', 'blend', 'bnl1', 'boeing1', 'boeing2', 'bore3d', 'brandy', 'capri',
 'cre-c', 'cycle', 'degen2', 'degen3', 'e226', 'etamacro', 'fffff800', 'finnis',
 'fit1d', 'fit1p', 'forplan', 'ganges', 'gfrd-pnc', 'grow15', 'grow22', 'grow7',
 'israel', 'kb2', 'ken-07', 'lotfi', 'maros', 'modszk1', 'pds-02', 'perold',
 'pilot4', 'pilotnov', 'qap08', 'recipe', 'sc105', 'sc205', 'sc50a',
 'sc50b', 'scagr25', 'scagr7', 'scfxm1', 'scfxm2', 'scfxm3', 'scorpion', 'scrs8',
 'scsd1', 'scsd6', 'scsd8', 'sctap1', 'sctap2', 'sctap3', 'seba', 'share1b',
 'share2b', 'shell', 'ship04l', 'ship04s', 'ship08l', 'ship08s', 'ship12l', 'ship12s',
 'sierra', 'stair', 'standata', 'standgub', 'standmps', 'stocfor1', 'stocfor2', 'tuff',
 'vtp_base', 'wood1p']     
        
    
results_dir = 'results'
problem_dir = 'netlib_lp_subset'
max_time = 300
reset = False
sd_method = 'dual_simplex'

for i, problem in enumerate(problems):
    mps_fn = os.path.join(problem_dir, problem)
    print('\n\n\nWorking on problem {} of {}: {}'.format(i+1, len(problems), mps_fn))    
    main(mps_fn=mps_fn, results_dir=results_dir, max_time=max_time, reset=reset, sd_method=sd_method)
# Out:
# Working on problem 1 of 79: netlib_lp_subset\adlittle
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-01
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 225494.96316238024
# Total solve time: 0.0
# Number of iterations: 100.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.014065027236938477
#
# Solution for adlittle using old steepest-descent augmentation:
#
# Optimal objective: 671734.1100278501
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 22.0
# Average num simplex iterations 22.0
# Total simplex iterations: 22.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.00486445426940918
# Feasible solution found with objective 671734.1100278501
#
# Solution for adlittle using new steepest-descent augmentation:
#
# Optimal objective: 671734.1100278501
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 22.0
# Average num simplex iterations 22.0
# Total simplex iterations: 22.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
#
#
# Working on problem 2 of 79: netlib_lp_subset\afiro
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -464.75314285714285
# Total solve time: 0.0
# Number of iterations: 19.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0
#
# Solution for afiro using old steepest-descent augmentation:
#
# Optimal objective: 440.0
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 10.0
# Average num simplex iterations 10.0
# Total simplex iterations: 10.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0068359375
# Feasible solution found with objective 440.0
#
# Solution for afiro using new steepest-descent augmentation:
#
# Optimal objective: 440.0
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 10.0
# Average num simplex iterations 10.0
# Total simplex iterations: 10.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
#
#
# Working on problem 3 of 79: netlib_lp_subset\agg2
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -20239252.355977118
# Total solve time: 0.005010366439819336
# Number of iterations: 158.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0700831413269043
#
# Solution for agg2 using old steepest-descent augmentation:
#
# Optimal objective: 109626646.32852079
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 66.0
# Average num simplex iterations 66.0
# Total simplex iterations: 66.0
# First solve time 0.003999948501586914
# Average solve time 0.003999948501586914
# Total solve time: 0.003999948501586914
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.14127635955810547
# Feasible solution found with objective 109626646.32852075
#
# Solution for agg2 using new steepest-descent augmentation:
#
# Optimal objective: 109626646.32852079
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 66.0
# Average num simplex iterations 66.0
# Total simplex iterations: 66.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
#
#
# Working on problem 4 of 79: netlib_lp_subset\agg3
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 10312115.935089217
# Total solve time: 0.0
# Number of iterations: 156.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.08781647682189941
#
# Solution for agg3 using old steepest-descent augmentation:
#
# Optimal objective: 759202344.1690388
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 105.0
# Average num simplex iterations 105.0
# Total simplex iterations: 105.0
# First solve time 0.009999990463256836
# Average solve time 0.009999990463256836
# Total solve time: 0.009999990463256836
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.08400273323059082
# Feasible solution found with objective 759202344.1690388
#
# Solution for agg3 using new steepest-descent augmentation:
#
# Optimal objective: 759202344.1690388
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 105.0
# Average num simplex iterations 105.0
# Total simplex iterations: 105.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
#
#
# Working on problem 5 of 79: netlib_lp_subset\agg
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -35991767.2865765
# Total solve time: 0.0
# Number of iterations: 75.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.09403705596923828
#
# Solution for agg using old steepest-descent augmentation:
#
# Optimal objective: 703339586.6175559
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 95.0
# Average num simplex iterations 95.0
# Total simplex iterations: 95.0
# First solve time 0.004999876022338867
# Average solve time 0.004999876022338867
# Total solve time: 0.004999876022338867
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.04250955581665039
# Feasible solution found with objective 703339586.6175559
#
# Solution for agg using new steepest-descent augmentation:
#
# Optimal objective: 703339586.6175559
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 95.0
# Average num simplex iterations 95.0
# Total simplex iterations: 95.0
# First solve time 0.0009999275207519531
# Average solve time 0.0009999275207519531
# Total solve time: 0.0009999275207519531
#
#
#
# Working on problem 6 of 79: netlib_lp_subset\bandm
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -158.62801845011555
# Total solve time: 0.0
# Number of iterations: 216.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.12551021575927734
#
# Solution for bandm using old steepest-descent augmentation:
#
# Optimal objective: 35.17554204866987
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 372.0
# Average num simplex iterations 372.0
# Total simplex iterations: 372.0
# First solve time 0.003000020980834961
# Average solve time 0.003000020980834961
# Total solve time: 0.003000020980834961
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.10553789138793945
# Feasible solution found with objective 35.17554204867
#
# Solution for bandm using new steepest-descent augmentation:
#
# Optimal objective: 35.17554204866987
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 372.0
# Average num simplex iterations 372.0
# Total simplex iterations: 372.0
# First solve time 0.002000093460083008
# Average solve time 0.002000093460083008
# Total solve time: 0.002000093460083008
#
#
#
# Working on problem 7 of 79: netlib_lp_subset\beaconfd
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 33592.48580719999
# Total solve time: 0.0
# Number of iterations: 20.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.04200935363769531
#
# Solution for beaconfd using old steepest-descent augmentation:
#
# Optimal objective: 33992.2782842
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 85.0
# Average num simplex iterations 85.0
# Total simplex iterations: 85.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.041312456130981445
# Feasible solution found with objective 33992.278284199994
#
# Solution for beaconfd using new steepest-descent augmentation:
#
# Optimal objective: 33992.2782842
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 85.0
# Average num simplex iterations 85.0
# Total simplex iterations: 85.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
#
#
# Working on problem 8 of 79: netlib_lp_subset\blend
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -30.812149845828237
# Total solve time: 0.0
# Number of iterations: 96.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.008554935455322266
#
# Solution for blend using old steepest-descent augmentation:
#
# Optimal objective: 0.0
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 76.0
# Average num simplex iterations 76.0
# Total simplex iterations: 76.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.01564502716064453
# Feasible solution found with objective 0.0
#
# Solution for blend using new steepest-descent augmentation:
#
# Optimal objective: 0.0
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 76.0
# Average num simplex iterations 76.0
# Total simplex iterations: 76.0
# First solve time 0.0009999275207519531
# Average solve time 0.0009999275207519531
# Total solve time: 0.0009999275207519531
#
#
#
# Working on problem 9 of 79: netlib_lp_subset\bnl1
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 1977.629561522889
# Total solve time: 0.006018161773681641
# Number of iterations: 418.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.6294927597045898
#
# Solution for bnl1 using old steepest-descent augmentation:
#
# Optimal objective: 2108.241973450449
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 682.0
# Average num simplex iterations 682.0
# Total simplex iterations: 682.0
# First solve time 0.006999969482421875
# Average solve time 0.006999969482421875
# Total solve time: 0.006999969482421875
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.6806068420410156
# Feasible solution found with objective 2108.241973450446
#
# Solution for bnl1 using new steepest-descent augmentation:
#
# Optimal objective: 2108.241973450449
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 682.0
# Average num simplex iterations 682.0
# Total simplex iterations: 682.0
# First solve time 0.01399993896484375
# Average solve time 0.01399993896484375
# Total solve time: 0.01399993896484375
#
#
#
# Working on problem 10 of 79: netlib_lp_subset\boeing1
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -335.2135675071269
# Total solve time: 0.008037805557250977
# Number of iterations: 489.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.12619805335998535
#
# Solution for boeing1 using old steepest-descent augmentation:
#
# Optimal objective: 185.3449154488552
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 441.0
# Average num simplex iterations 441.0
# Total simplex iterations: 441.0
# First solve time 0.014999866485595703
# Average solve time 0.014999866485595703
# Total solve time: 0.014999866485595703
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.11746525764465332
# Feasible solution found with objective 185.34491544885563
#
# Solution for boeing1 using new steepest-descent augmentation:
#
# Optimal objective: 185.3449154488552
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 441.0
# Average num simplex iterations 441.0
# Total simplex iterations: 441.0
# First solve time 0.023000001907348633
# Average solve time 0.023000001907348633
# Total solve time: 0.023000001907348633
#
#
#
# Working on problem 11 of 79: netlib_lp_subset\boeing2
# Reading netlib_lp_subset\boeing2...
# removing redundant constraint 'LF1013B1'
# removing redundant constraint 'LF1013B2'
# removing redundant constraint 'LF1015B1'
# removing redundant constraint 'LF1017B1'
# removing redundant constraint 'LF1019B1'
# removing redundant constraint 'LF1019B2'
# removing redundant constraint 'LF1004B1'
# removing redundant constraint 'LF1008B1'
# removing redundant constraint 'LF1008B2'
# removing redundant constraint 'LF1010B1'
# removing redundant constraint 'LF1010B2'
# removing redundant constraint 'LF1010B3'
# removing redundant constraint 'LF1012B1'
# removing redundant constraint 'LF1014B1'
# removing redundant constraint 'LF1014B2'
# removing redundant constraint 'LF1100B1'
# removing redundant constraint 'LF1100B2'
# removing redundant constraint 'LF1100B3'
# removing redundant constraint 'LF1100B4'
# removing redundant constraint 'LF1100B5'
# removing redundant constraint 'LF1102B1'
# removing redundant constraint 'LF1102B2'
# removing redundant constraint 'LF1102B3'
# removing redundant constraint 'LF1102B4'
# removing redundant constraint 'LF1200B1'
# removing redundant constraint 'LF1201B1'
# Building polyhedron...
# Problem size: n = 143,  m_B = 352,  m_A = 4
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -315.01872801520284
# Total solve time: 0.0
# Number of iterations: 72.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\boeing2...
# removing redundant constraint 'LF1013B1'
# removing redundant constraint 'LF1013B2'
# removing redundant constraint 'LF1015B1'
# removing redundant constraint 'LF1017B1'
# removing redundant constraint 'LF1019B1'
# removing redundant constraint 'LF1019B2'
# removing redundant constraint 'LF1004B1'
# removing redundant constraint 'LF1008B1'
# removing redundant constraint 'LF1008B2'
# removing redundant constraint 'LF1010B1'
# removing redundant constraint 'LF1010B2'
# removing redundant constraint 'LF1010B3'
# removing redundant constraint 'LF1012B1'
# removing redundant constraint 'LF1014B1'
# removing redundant constraint 'LF1014B2'
# removing redundant constraint 'LF1100B1'
# removing redundant constraint 'LF1100B2'
# removing redundant constraint 'LF1100B3'
# removing redundant constraint 'LF1100B4'
# removing redundant constraint 'LF1100B5'
# removing redundant constraint 'LF1102B1'
# removing redundant constraint 'LF1102B2'
# removing redundant constraint 'LF1102B3'
# removing redundant constraint 'LF1102B4'
# removing redundant constraint 'LF1200B1'
# removing redundant constraint 'LF1201B1'
# Building polyhedron...
# Problem size: n = 143,  m_B = 352,  m_A = 4
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.01611018180847168
#
# Solution for boeing2 using old steepest-descent augmentation:
#
# Optimal objective: -210.67368152468885
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 305.0
# Average num simplex iterations 305.0
# Total simplex iterations: 305.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\boeing2...
# removing redundant constraint 'LF1013B1'
# removing redundant constraint 'LF1013B2'
# removing redundant constraint 'LF1015B1'
# removing redundant constraint 'LF1017B1'
# removing redundant constraint 'LF1019B1'
# removing redundant constraint 'LF1019B2'
# removing redundant constraint 'LF1004B1'
# removing redundant constraint 'LF1008B1'
# removing redundant constraint 'LF1008B2'
# removing redundant constraint 'LF1010B1'
# removing redundant constraint 'LF1010B2'
# removing redundant constraint 'LF1010B3'
# removing redundant constraint 'LF1012B1'
# removing redundant constraint 'LF1014B1'
# removing redundant constraint 'LF1014B2'
# removing redundant constraint 'LF1100B1'
# removing redundant constraint 'LF1100B2'
# removing redundant constraint 'LF1100B3'
# removing redundant constraint 'LF1100B4'
# removing redundant constraint 'LF1100B5'
# removing redundant constraint 'LF1102B1'
# removing redundant constraint 'LF1102B2'
# removing redundant constraint 'LF1102B3'
# removing redundant constraint 'LF1102B4'
# removing redundant constraint 'LF1200B1'
# removing redundant constraint 'LF1201B1'
# Building polyhedron...
# Problem size: n = 143,  m_B = 352,  m_A = 4
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.011018991470336914
# Feasible solution found with objective -210.6736815246888
#
# Solution for boeing2 using new steepest-descent augmentation:
#
# Optimal objective: -210.67368152468885
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 305.0
# Average num simplex iterations 305.0
# Total simplex iterations: 305.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
#
#
# Working on problem 12 of 79: netlib_lp_subset\bore3d
# Reading netlib_lp_subset\bore3d...
# Building polyhedron...
# Problem size: n = 315,  m_B = 344,  m_A = 215
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 1373.080394208493
# Total solve time: 0.0
# Number of iterations: 53.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\bore3d...
# Building polyhedron...
# Problem size: n = 315,  m_B = 344,  m_A = 215
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.06955265998840332
#
# Solution for bore3d using old steepest-descent augmentation:
#
# Optimal objective: 47483.69385383172
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 77.0
# Average num simplex iterations 77.0
# Total simplex iterations: 77.0
# First solve time 0.002000093460083008
# Average solve time 0.002000093460083008
# Total solve time: 0.002000093460083008
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\bore3d...
# Building polyhedron...
# Problem size: n = 315,  m_B = 344,  m_A = 215
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.06200838088989258
# Feasible solution found with objective 47483.69385383172
#
# Solution for bore3d using new steepest-descent augmentation:
#
# Optimal objective: 47483.69385383172
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 77.0
# Average num simplex iterations 77.0
# Total simplex iterations: 77.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
#
#
# Working on problem 13 of 79: netlib_lp_subset\brandy
# Reading netlib_lp_subset\brandy...
# removing redundant constraint '10178A'
# removing redundant constraint '10179A'
# removing redundant constraint '10180A'
# removing redundant constraint '10181A'
# removing redundant constraint '10182A'
# removing redundant constraint '10184A'
# removing redundant constraint '10185A'
# removing redundant constraint '10186A'
# removing redundant constraint '10187A'
# removing redundant constraint '10188A'
# removing redundant constraint '10189A'
# removing redundant constraint '10002A'
# removing redundant constraint '10003A'
# removing redundant constraint '10004A'
# removing redundant constraint '10067A'
# removing redundant constraint '10077A'
# removing redundant constraint '10079A'
# removing redundant constraint '10088A'
# removing redundant constraint '10099A'
# removing redundant constraint '10103A'
# removing redundant constraint '10109A'
# removing redundant constraint '10111A'
# removing redundant constraint '10112A'
# removing redundant constraint '10113A'
# removing redundant constraint '10114A'
# removing redundant constraint '10115A'
# removing redundant constraint '10155A'
# removing redundant constraint '10157A'
# removing redundant constraint '10161A'
# removing redundant constraint '10165A'
# removing redundant constraint '10166A'
# removing redundant constraint '10174A'
# removing redundant constraint '10205A'
# removing redundant constraint '10206A'
# removing redundant constraint '10212A'
# removing redundant constraint '10213A'
# removing redundant constraint '10214A'
# removing redundant constraint '10221A'
# Building polyhedron...
# Problem size: n = 249,  m_B = 292,  m_A = 139
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 1518.509896488128
# Total solve time: 0.0
# Number of iterations: 170.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\brandy...
# removing redundant constraint '10178A'
# removing redundant constraint '10179A'
# removing redundant constraint '10180A'
# removing redundant constraint '10181A'
# removing redundant constraint '10182A'
# removing redundant constraint '10184A'
# removing redundant constraint '10185A'
# removing redundant constraint '10186A'
# removing redundant constraint '10187A'
# removing redundant constraint '10188A'
# removing redundant constraint '10189A'
# removing redundant constraint '10002A'
# removing redundant constraint '10003A'
# removing redundant constraint '10004A'
# removing redundant constraint '10067A'
# removing redundant constraint '10077A'
# removing redundant constraint '10079A'
# removing redundant constraint '10088A'
# removing redundant constraint '10099A'
# removing redundant constraint '10103A'
# removing redundant constraint '10109A'
# removing redundant constraint '10111A'
# removing redundant constraint '10112A'
# removing redundant constraint '10113A'
# removing redundant constraint '10114A'
# removing redundant constraint '10115A'
# removing redundant constraint '10155A'
# removing redundant constraint '10157A'
# removing redundant constraint '10161A'
# removing redundant constraint '10165A'
# removing redundant constraint '10166A'
# removing redundant constraint '10174A'
# removing redundant constraint '10205A'
# removing redundant constraint '10206A'
# removing redundant constraint '10212A'
# removing redundant constraint '10213A'
# removing redundant constraint '10214A'
# removing redundant constraint '10221A'
# Building polyhedron...
# Problem size: n = 249,  m_B = 292,  m_A = 139
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.04082894325256348
#
# Solution for brandy using old steepest-descent augmentation:
#
# Optimal objective: 7298.656301179384
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 236.0
# Average num simplex iterations 236.0
# Total simplex iterations: 236.0
# First solve time 0.006000041961669922
# Average solve time 0.006000041961669922
# Total solve time: 0.006000041961669922
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\brandy...
# removing redundant constraint '10178A'
# removing redundant constraint '10179A'
# removing redundant constraint '10180A'
# removing redundant constraint '10181A'
# removing redundant constraint '10182A'
# removing redundant constraint '10184A'
# removing redundant constraint '10185A'
# removing redundant constraint '10186A'
# removing redundant constraint '10187A'
# removing redundant constraint '10188A'
# removing redundant constraint '10189A'
# removing redundant constraint '10002A'
# removing redundant constraint '10003A'
# removing redundant constraint '10004A'
# removing redundant constraint '10067A'
# removing redundant constraint '10077A'
# removing redundant constraint '10079A'
# removing redundant constraint '10088A'
# removing redundant constraint '10099A'
# removing redundant constraint '10103A'
# removing redundant constraint '10109A'
# removing redundant constraint '10111A'
# removing redundant constraint '10112A'
# removing redundant constraint '10113A'
# removing redundant constraint '10114A'
# removing redundant constraint '10115A'
# removing redundant constraint '10155A'
# removing redundant constraint '10157A'
# removing redundant constraint '10161A'
# removing redundant constraint '10165A'
# removing redundant constraint '10166A'
# removing redundant constraint '10174A'
# removing redundant constraint '10205A'
# removing redundant constraint '10206A'
# removing redundant constraint '10212A'
# removing redundant constraint '10213A'
# removing redundant constraint '10214A'
# removing redundant constraint '10221A'
# Building polyhedron...
# Problem size: n = 249,  m_B = 292,  m_A = 139
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0425417423248291
# Feasible solution found with objective 7298.656301179384
#
# Solution for brandy using new steepest-descent augmentation:
#
# Optimal objective: 7298.656301179384
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 236.0
# Average num simplex iterations 236.0
# Total simplex iterations: 236.0
# First solve time 0.0029997825622558594
# Average solve time 0.0029997825622558594
# Total solve time: 0.0029997825622558594
#
#
#
# Working on problem 14 of 79: netlib_lp_subset\capri
# Reading netlib_lp_subset\capri...
# Building polyhedron...
# Problem size: n = 353,  m_B = 583,  m_A = 158
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 2690.0129137681606
# Total solve time: 0.0050220489501953125
# Number of iterations: 143.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\capri...
# Building polyhedron...
# Problem size: n = 353,  m_B = 583,  m_A = 158
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.09348511695861816
#
# Solution for capri using old steepest-descent augmentation:
#
# Optimal objective: 5328.851249969662
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 315.0
# Average num simplex iterations 315.0
# Total simplex iterations: 315.0
# First solve time 0.01100015640258789
# Average solve time 0.01100015640258789
# Total solve time: 0.01100015640258789
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\capri...
# Building polyhedron...
# Problem size: n = 353,  m_B = 583,  m_A = 158
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.09443020820617676
# Feasible solution found with objective 5328.851249969662
#
# Solution for capri using new steepest-descent augmentation:
#
# Optimal objective: 5328.851249969662
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 315.0
# Average num simplex iterations 315.0
# Total simplex iterations: 315.0
# First solve time 0.009000062942504883
# Average solve time 0.009000062942504883
# Total solve time: 0.009000062942504883
#
#
#
# Working on problem 15 of 79: netlib_lp_subset\cre-c
# Reading netlib_lp_subset\cre-c...
# removing redundant constraint 'BB013'
# removing redundant constraint 'BB023'
# removing redundant constraint 'BB031'
# removing redundant constraint 'BB032'
# removing redundant constraint 'BB033'
# removing redundant constraint 'BB034'
# removing redundant constraint 'BB035'
# removing redundant constraint 'BB043'
# removing redundant constraint 'BB053'
# removing redundant constraint 'BB063'
# removing redundant constraint 'BB073'
# removing redundant constraint 'BB083'
# removing redundant constraint 'BB093'
# removing redundant constraint 'BB123'
# removing redundant constraint 'BB133'
# removing redundant constraint 'BB141'
# removing redundant constraint 'BB142'
# removing redundant constraint 'BB143'
# removing redundant constraint 'BB144'
# removing redundant constraint 'BB145'
# removing redundant constraint 'BB163'
# removing redundant constraint 'BB173'
# removing redundant constraint 'BB213'
# removing redundant constraint 'BB231'
# removing redundant constraint 'BB232'
# removing redundant constraint 'BB233'
# removing redundant constraint 'BB234'
# removing redundant constraint 'BB235'
# removing redundant constraint 'BB303'
# removing redundant constraint 'BB384'
# removing redundant constraint 'BB414'
# removing redundant constraint 'BB424'
# removing redundant constraint 'BB434'
# removing redundant constraint 'BB444'
# removing redundant constraint 'BB454'
# removing redundant constraint 'BB484'
# removing redundant constraint 'BB551'
# removing redundant constraint 'BB552'
# removing redundant constraint 'BB553'
# removing redundant constraint 'BB554'
# removing redundant constraint 'BB555'
# removing redundant constraint 'BB571'
# removing redundant constraint 'BB572'
# removing redundant constraint 'BB573'
# removing redundant constraint 'BB574'
# removing redundant constraint 'BB575'
# removing redundant constraint 'BB584'
# removing redundant constraint 'BB601'
# removing redundant constraint 'BB602'
# removing redundant constraint 'BB603'
# removing redundant constraint 'BB604'
# removing redundant constraint 'BB605'
# removing redundant constraint 'BB611'
# removing redundant constraint 'BB612'
# removing redundant constraint 'BB613'
# removing redundant constraint 'BB614'
# removing redundant constraint 'BB615'
# removing redundant constraint 'BB621'
# removing redundant constraint 'BB622'
# removing redundant constraint 'BB623'
# removing redundant constraint 'BB624'
# removing redundant constraint 'BB625'
# removing redundant constraint 'BB641'
# removing redundant constraint 'BB642'
# removing redundant constraint 'BB643'
# removing redundant constraint 'BB644'
# removing redundant constraint 'BB645'
# removing redundant constraint 'BB651'
# removing redundant constraint 'BB652'
# removing redundant constraint 'BB653'
# removing redundant constraint 'BB654'
# removing redundant constraint 'BB655'
# removing redundant constraint 'BB661'
# removing redundant constraint 'BB662'
# removing redundant constraint 'BB663'
# removing redundant constraint 'BB664'
# removing redundant constraint 'BB665'
# removing redundant constraint 'BB671'
# removing redundant constraint 'BB672'
# removing redundant constraint 'BB673'
# removing redundant constraint 'BB674'
# removing redundant constraint 'BB675'
# Building polyhedron...
# Problem size: n = 3678,  m_B = 6411,  m_A = 253
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 25275116.140880227
# Total solve time: 0.08012866973876953
# Number of iterations: 2694.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\cre-c...
# removing redundant constraint 'BB013'
# removing redundant constraint 'BB023'
# removing redundant constraint 'BB031'
# removing redundant constraint 'BB032'
# removing redundant constraint 'BB033'
# removing redundant constraint 'BB034'
# removing redundant constraint 'BB035'
# removing redundant constraint 'BB043'
# removing redundant constraint 'BB053'
# removing redundant constraint 'BB063'
# removing redundant constraint 'BB073'
# removing redundant constraint 'BB083'
# removing redundant constraint 'BB093'
# removing redundant constraint 'BB123'
# removing redundant constraint 'BB133'
# removing redundant constraint 'BB141'
# removing redundant constraint 'BB142'
# removing redundant constraint 'BB143'
# removing redundant constraint 'BB144'
# removing redundant constraint 'BB145'
# removing redundant constraint 'BB163'
# removing redundant constraint 'BB173'
# removing redundant constraint 'BB213'
# removing redundant constraint 'BB231'
# removing redundant constraint 'BB232'
# removing redundant constraint 'BB233'
# removing redundant constraint 'BB234'
# removing redundant constraint 'BB235'
# removing redundant constraint 'BB303'
# removing redundant constraint 'BB384'
# removing redundant constraint 'BB414'
# removing redundant constraint 'BB424'
# removing redundant constraint 'BB434'
# removing redundant constraint 'BB444'
# removing redundant constraint 'BB454'
# removing redundant constraint 'BB484'
# removing redundant constraint 'BB551'
# removing redundant constraint 'BB552'
# removing redundant constraint 'BB553'
# removing redundant constraint 'BB554'
# removing redundant constraint 'BB555'
# removing redundant constraint 'BB571'
# removing redundant constraint 'BB572'
# removing redundant constraint 'BB573'
# removing redundant constraint 'BB574'
# removing redundant constraint 'BB575'
# removing redundant constraint 'BB584'
# removing redundant constraint 'BB601'
# removing redundant constraint 'BB602'
# removing redundant constraint 'BB603'
# removing redundant constraint 'BB604'
# removing redundant constraint 'BB605'
# removing redundant constraint 'BB611'
# removing redundant constraint 'BB612'
# removing redundant constraint 'BB613'
# removing redundant constraint 'BB614'
# removing redundant constraint 'BB615'
# removing redundant constraint 'BB621'
# removing redundant constraint 'BB622'
# removing redundant constraint 'BB623'
# removing redundant constraint 'BB624'
# removing redundant constraint 'BB625'
# removing redundant constraint 'BB641'
# removing redundant constraint 'BB642'
# removing redundant constraint 'BB643'
# removing redundant constraint 'BB644'
# removing redundant constraint 'BB645'
# removing redundant constraint 'BB651'
# removing redundant constraint 'BB652'
# removing redundant constraint 'BB653'
# removing redundant constraint 'BB654'
# removing redundant constraint 'BB655'
# removing redundant constraint 'BB661'
# removing redundant constraint 'BB662'
# removing redundant constraint 'BB663'
# removing redundant constraint 'BB664'
# removing redundant constraint 'BB665'
# removing redundant constraint 'BB671'
# removing redundant constraint 'BB672'
# removing redundant constraint 'BB673'
# removing redundant constraint 'BB674'
# removing redundant constraint 'BB675'
# Building polyhedron...
# Problem size: n = 3678,  m_B = 6411,  m_A = 253
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 6.897469520568848
#
# Solution for cre-c using old steepest-descent augmentation:
#
# Optimal objective: 32856322.132818617
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 2756.0
# Average num simplex iterations 2756.0
# Total simplex iterations: 2756.0
# First solve time 0.10700011253356934
# Average solve time 0.10700011253356934
# Total solve time: 0.10700011253356934
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\cre-c...
# removing redundant constraint 'BB013'
# removing redundant constraint 'BB023'
# removing redundant constraint 'BB031'
# removing redundant constraint 'BB032'
# removing redundant constraint 'BB033'
# removing redundant constraint 'BB034'
# removing redundant constraint 'BB035'
# removing redundant constraint 'BB043'
# removing redundant constraint 'BB053'
# removing redundant constraint 'BB063'
# removing redundant constraint 'BB073'
# removing redundant constraint 'BB083'
# removing redundant constraint 'BB093'
# removing redundant constraint 'BB123'
# removing redundant constraint 'BB133'
# removing redundant constraint 'BB141'
# removing redundant constraint 'BB142'
# removing redundant constraint 'BB143'
# removing redundant constraint 'BB144'
# removing redundant constraint 'BB145'
# removing redundant constraint 'BB163'
# removing redundant constraint 'BB173'
# removing redundant constraint 'BB213'
# removing redundant constraint 'BB231'
# removing redundant constraint 'BB232'
# removing redundant constraint 'BB233'
# removing redundant constraint 'BB234'
# removing redundant constraint 'BB235'
# removing redundant constraint 'BB303'
# removing redundant constraint 'BB384'
# removing redundant constraint 'BB414'
# removing redundant constraint 'BB424'
# removing redundant constraint 'BB434'
# removing redundant constraint 'BB444'
# removing redundant constraint 'BB454'
# removing redundant constraint 'BB484'
# removing redundant constraint 'BB551'
# removing redundant constraint 'BB552'
# removing redundant constraint 'BB553'
# removing redundant constraint 'BB554'
# removing redundant constraint 'BB555'
# removing redundant constraint 'BB571'
# removing redundant constraint 'BB572'
# removing redundant constraint 'BB573'
# removing redundant constraint 'BB574'
# removing redundant constraint 'BB575'
# removing redundant constraint 'BB584'
# removing redundant constraint 'BB601'
# removing redundant constraint 'BB602'
# removing redundant constraint 'BB603'
# removing redundant constraint 'BB604'
# removing redundant constraint 'BB605'
# removing redundant constraint 'BB611'
# removing redundant constraint 'BB612'
# removing redundant constraint 'BB613'
# removing redundant constraint 'BB614'
# removing redundant constraint 'BB615'
# removing redundant constraint 'BB621'
# removing redundant constraint 'BB622'
# removing redundant constraint 'BB623'
# removing redundant constraint 'BB624'
# removing redundant constraint 'BB625'
# removing redundant constraint 'BB641'
# removing redundant constraint 'BB642'
# removing redundant constraint 'BB643'
# removing redundant constraint 'BB644'
# removing redundant constraint 'BB645'
# removing redundant constraint 'BB651'
# removing redundant constraint 'BB652'
# removing redundant constraint 'BB653'
# removing redundant constraint 'BB654'
# removing redundant constraint 'BB655'
# removing redundant constraint 'BB661'
# removing redundant constraint 'BB662'
# removing redundant constraint 'BB663'
# removing redundant constraint 'BB664'
# removing redundant constraint 'BB665'
# removing redundant constraint 'BB671'
# removing redundant constraint 'BB672'
# removing redundant constraint 'BB673'
# removing redundant constraint 'BB674'
# removing redundant constraint 'BB675'
# Building polyhedron...
# Problem size: n = 3678,  m_B = 6411,  m_A = 253
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 7.070084571838379
# Feasible solution found with objective 32856322.13281863
#
# Solution for cre-c using new steepest-descent augmentation:
#
# Optimal objective: 32856322.132818617
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 2756.0
# Average num simplex iterations 2756.0
# Total simplex iterations: 2756.0
# First solve time 0.11099982261657715
# Average solve time 0.11099982261657715
# Total solve time: 0.11099982261657715
#
#
#
# Working on problem 16 of 79: netlib_lp_subset\cycle
# Reading netlib_lp_subset\cycle...
# removing redundant constraint 'GHF...EB'
# removing redundant constraint 'GHH...EB'
# removing redundant constraint 'GHT...EB'
# removing redundant constraint 'GHX...EB'
# removing redundant constraint 'BGL...AA'
# removing redundant constraint 'BGL...AC'
# removing redundant constraint 'BOA...AC'
# removing redundant constraint 'BOB...AC'
# removing redundant constraint 'BGL...AE'
# removing redundant constraint 'BOA...AE'
# removing redundant constraint 'BOF...BD'
# removing redundant constraint 'BGL...CF'
# removing redundant constraint 'BOB...CF'
# removing redundant constraint 'BOX...CF'
# removing redundant constraint 'BGL...DD'
# removing redundant constraint 'BDN...EF'
# removing redundant constraint 'BOB...EF'
# Building polyhedron...
# Problem size: n = 2857,  m_B = 3437,  m_A = 1376
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -5.226393024894102
# Total solve time: 0.04761838912963867
# Number of iterations: 1169.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\cycle...
# removing redundant constraint 'GHF...EB'
# removing redundant constraint 'GHH...EB'
# removing redundant constraint 'GHT...EB'
# removing redundant constraint 'GHX...EB'
# removing redundant constraint 'BGL...AA'
# removing redundant constraint 'BGL...AC'
# removing redundant constraint 'BOA...AC'
# removing redundant constraint 'BOB...AC'
# removing redundant constraint 'BGL...AE'
# removing redundant constraint 'BOA...AE'
# removing redundant constraint 'BOF...BD'
# removing redundant constraint 'BGL...CF'
# removing redundant constraint 'BOB...CF'
# removing redundant constraint 'BOX...CF'
# removing redundant constraint 'BGL...DD'
# removing redundant constraint 'BDN...EF'
# removing redundant constraint 'BOB...EF'
# Building polyhedron...
# Problem size: n = 2857,  m_B = 3437,  m_A = 1376
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 3.8697774410247803
#
# Solution for cycle using old steepest-descent augmentation:
#
# Optimal objective: 0.0
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 840.0
# Average num simplex iterations 840.0
# Total simplex iterations: 840.0
# First solve time 0.04799985885620117
# Average solve time 0.04799985885620117
# Total solve time: 0.04799985885620117
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\cycle...
# removing redundant constraint 'GHF...EB'
# removing redundant constraint 'GHH...EB'
# removing redundant constraint 'GHT...EB'
# removing redundant constraint 'GHX...EB'
# removing redundant constraint 'BGL...AA'
# removing redundant constraint 'BGL...AC'
# removing redundant constraint 'BOA...AC'
# removing redundant constraint 'BOB...AC'
# removing redundant constraint 'BGL...AE'
# removing redundant constraint 'BOA...AE'
# removing redundant constraint 'BOF...BD'
# removing redundant constraint 'BGL...CF'
# removing redundant constraint 'BOB...CF'
# removing redundant constraint 'BOX...CF'
# removing redundant constraint 'BGL...DD'
# ...
# Reading netlib_lp_subset\pilot4...
# Building polyhedron...
# Problem size: n = 1000,  m_B = 1252,  m_A = 317
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -2581.139259564279
# Total solve time: 0.03340768814086914
# Number of iterations: 890.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\pilot4...
# Building polyhedron...
# Problem size: n = 1000,  m_B = 1252,  m_A = 317
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.47223639488220215
#
# Solution for pilot4 using old steepest-descent augmentation:
#
# Optimal objective: 0.0
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 513.0
# Average num simplex iterations 513.0
# Total simplex iterations: 513.0
# First solve time 0.03299999237060547
# Average solve time 0.03299999237060547
# Total solve time: 0.03299999237060547
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\pilot4...
# Building polyhedron...
# Problem size: n = 1000,  m_B = 1252,  m_A = 317
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.4609971046447754
# Feasible solution found with objective 0.0
#
# Solution for pilot4 using new steepest-descent augmentation:
#
# Optimal objective: 0.0
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 513.0
# Average num simplex iterations 513.0
# Total simplex iterations: 513.0
# First solve time 0.026000022888183594
# Average solve time 0.026000022888183594
# Total solve time: 0.026000022888183594
#
#
#
# Working on problem 40 of 79: netlib_lp_subset\pilotnov
# Reading netlib_lp_subset\pilotnov...
# Building polyhedron...
# Problem size: n = 2172,  m_B = 2582,  m_A = 905
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -4497.2761882188715
# Total solve time: 0.06339430809020996
# Number of iterations: 717.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\pilotnov...
# Building polyhedron...
# Problem size: n = 2172,  m_B = 2582,  m_A = 905
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 2.1532559394836426
#
# Solution for pilotnov using old steepest-descent augmentation:
#
# Optimal objective: -1374.0854718738688
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 1190.0
# Average num simplex iterations 1190.0
# Total simplex iterations: 1190.0
# First solve time 0.06500005722045898
# Average solve time 0.06500005722045898
# Total solve time: 0.06500005722045898
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\pilotnov...
# Building polyhedron...
# Problem size: n = 2172,  m_B = 2582,  m_A = 905
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 2.203686475753784
# Feasible solution found with objective -1374.0854718738683
#
# Solution for pilotnov using new steepest-descent augmentation:
#
# Optimal objective: -1374.0854718738688
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 1190.0
# Average num simplex iterations 1190.0
# Total simplex iterations: 1190.0
# First solve time 0.06700015068054199
# Average solve time 0.06700015068054199
# Total solve time: 0.06700015068054199
#
#
#
# Working on problem 41 of 79: netlib_lp_subset\qap08
# Reading netlib_lp_subset\qap08...
# Building polyhedron...
# Problem size: n = 1632,  m_B = 1632,  m_A = 912
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 203.50000000000006
# Total solve time: 0.37526607513427734
# Number of iterations: 2841.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\qap08...
# Building polyhedron...
# Problem size: n = 1632,  m_B = 1632,  m_A = 912
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.2082240581512451
#
# Solution for qap08 using old steepest-descent augmentation:
#
# Optimal objective: 303.6065924991011
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 1344.0
# Average num simplex iterations 1344.0
# Total simplex iterations: 1344.0
# First solve time 0.11100006103515625
# Average solve time 0.11100006103515625
# Total solve time: 0.11100006103515625
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\qap08...
# Building polyhedron...
# Problem size: n = 1632,  m_B = 1632,  m_A = 912
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.2041289806365967
# Feasible solution found with objective 303.60659249910015
#
# Solution for qap08 using new steepest-descent augmentation:
#
# Optimal objective: 303.6065924991011
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 1344.0
# Average num simplex iterations 1344.0
# Total simplex iterations: 1344.0
# First solve time 0.1119999885559082
# Average solve time 0.1119999885559082
# Total solve time: 0.1119999885559082
#
#
#
# Working on problem 42 of 79: netlib_lp_subset\recipe
# Reading netlib_lp_subset\recipe...
# Building polyhedron...
# Problem size: n = 180,  m_B = 247,  m_A = 93
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -266.61600000000027
# Total solve time: 0.0020079612731933594
# Number of iterations: 26.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\recipe...
# Building polyhedron...
# Problem size: n = 180,  m_B = 247,  m_A = 93
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.022371530532836914
#
# Solution for recipe using old steepest-descent augmentation:
#
# Optimal objective: -104.83
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 41.0
# Average num simplex iterations 41.0
# Total simplex iterations: 41.0
# First solve time 0.003999948501586914
# Average solve time 0.003999948501586914
# Total solve time: 0.003999948501586914
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\recipe...
# Building polyhedron...
# Problem size: n = 180,  m_B = 247,  m_A = 93
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.016442060470581055
# Feasible solution found with objective -104.83
#
# Solution for recipe using new steepest-descent augmentation:
#
# Optimal objective: -104.83
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 41.0
# Average num simplex iterations 41.0
# Total simplex iterations: 41.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
#
#
# Working on problem 43 of 79: netlib_lp_subset\sc105
# Reading netlib_lp_subset\sc105...
# removing redundant constraint 'ROW00003'
# Building polyhedron...
# Problem size: n = 103,  m_B = 162,  m_A = 45
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -52.202061211707225
# Total solve time: 0.0
# Number of iterations: 96.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\sc105...
# removing redundant constraint 'ROW00003'
# Building polyhedron...
# Problem size: n = 103,  m_B = 162,  m_A = 45
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.004507303237915039
#
# Solution for sc105 using old steepest-descent augmentation:
#
# Optimal objective: 0.0
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 29.0
# Average num simplex iterations 29.0
# Total simplex iterations: 29.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\sc105...
# removing redundant constraint 'ROW00003'
# Building polyhedron...
# Problem size: n = 103,  m_B = 162,  m_A = 45
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0182340145111084
# Feasible solution found with objective 0.0
#
# Solution for sc105 using new steepest-descent augmentation:
#
# Optimal objective: 0.0
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 29.0
# Average num simplex iterations 29.0
# Total simplex iterations: 29.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
#
#
# Working on problem 44 of 79: netlib_lp_subset\sc205
# Reading netlib_lp_subset\sc205...
# removing redundant constraint 'ROW00003'
# Building polyhedron...
# Problem size: n = 203,  m_B = 316,  m_A = 91
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -52.2020612117072
# Total solve time: 0.012305259704589844
# Number of iterations: 219.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\sc205...
# removing redundant constraint 'ROW00003'
# Building polyhedron...
# Problem size: n = 203,  m_B = 316,  m_A = 91
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.03209376335144043
#
# Solution for sc205 using old steepest-descent augmentation:
#
# Optimal objective: 0.0
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 69.0
# Average num simplex iterations 69.0
# Total simplex iterations: 69.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\sc205...
# removing redundant constraint 'ROW00003'
# Building polyhedron...
# Problem size: n = 203,  m_B = 316,  m_A = 91
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.03816556930541992
# Feasible solution found with objective 0.0
#
# Solution for sc205 using new steepest-descent augmentation:
#
# Optimal objective: 0.0
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 69.0
# Average num simplex iterations 69.0
# Total simplex iterations: 69.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
#
#
# Working on problem 45 of 79: netlib_lp_subset\sc50a
# Reading netlib_lp_subset\sc50a...
# removing redundant constraint 'ROW00003'
# Building polyhedron...
# Problem size: n = 48,  m_B = 77,  m_A = 20
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -64.57507705856449
# Total solve time: 0.01402592658996582
# Number of iterations: 49.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\sc50a...
# removing redundant constraint 'ROW00003'
# Building polyhedron...
# Problem size: n = 48,  m_B = 77,  m_A = 20
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.006502866744995117
#
# Solution for sc50a using old steepest-descent augmentation:
#
# Optimal objective: 0.0
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 14.0
# Average num simplex iterations 14.0
# Total simplex iterations: 14.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\sc50a...
# removing redundant constraint 'ROW00003'
# Building polyhedron...
# Problem size: n = 48,  m_B = 77,  m_A = 20
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0
# Feasible solution found with objective 0.0
#
# Solution for sc50a using new steepest-descent augmentation:
#
# Optimal objective: 0.0
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 14.0
# Average num simplex iterations 14.0
# Total simplex iterations: 14.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
#
#
# Working on problem 46 of 79: netlib_lp_subset\sc50b
# Reading netlib_lp_subset\sc50b...
# removing redundant constraint 'ROW00002'
# removing redundant constraint 'ROW00003'
# Building polyhedron...
# Problem size: n = 48,  m_B = 76,  m_A = 20
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -69.99999999999999
# Total solve time: 0.0
# Number of iterations: 52.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\sc50b...
# removing redundant constraint 'ROW00002'
# removing redundant constraint 'ROW00003'
# Building polyhedron...
# Problem size: n = 48,  m_B = 76,  m_A = 20
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0040130615234375
#
# Solution for sc50b using old steepest-descent augmentation:
#
# Optimal objective: 0.0
# Total solve time: None
# Number of iterations: 0
# First simplex iterations 16.0
# Average num simplex iterations 16.0
# Total simplex iterations: 16.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\sc50b...
# removing redundant constraint 'ROW00002'
# removing redundant constraint 'ROW00003'
# Building polyhedron...
# Problem size: n = 48,  m_B = 76,  m_A = 20
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0
# Feasible solution found with objective 0.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 23
#      21 mps_fn = os.path.join(problem_dir, problem)
#      22 print('\n\n\nWorking on problem {} of {}: {}'.format(i+1, len(problems), mps_fn))
# ---> 23 main(mps_fn=mps_fn, results_dir=results_dir, max_time=max_time, reset=reset, sd_method=sd_method)
#
# File ~\OneDrive - The University of Colorado Denver\Documents\GitHub\simplex_like_alg\main.py:31, in main(mps_fn, results_dir, max_time, sd_method, reset)
#      28 print(old_sd_result)
#      30 print('\nSolving with new steepest descent...')
# ---> 31 new_sd_result = init_sdac.new_sdac(mps_fn,results_dir, max_time, reset,sd_method)
#      32 print('\nSolution for {} using new steepest-descent augmentation:'.format(os.path.basename(mps_fn)))
#      33 print(new_sd_result)
#
# File ~\OneDrive - The University of Colorado Denver\Documents\GitHub\simplex_like_alg\init_sdac.py:136, in new_sdac(mps_fn, results_dir, max_time, reset, sd_method)
#     132 init_edge = np.array(x_feasible_2) - np.array(x_current)
#     133 ########################################################
#     134
#     135 # compute steepest-descent direction
# --> 136 descent_direction, y_pos, y_neg, steepness, num_steps, solve_time, phase_times = pm.compute_sd_direction(edge=init_edge, verbose=verbose)
#     137 simplex_iters.append(num_steps)
#     138 sub_times['solve'].append(solve_time)
#
# File ~\OneDrive - The University of Colorado Denver\Documents\GitHub\simplex_like_alg\polyhedral_model.py:207, in PolyhedralModel.compute_sd_direction(self, verbose, **kwargs)
#     205 t0 = time.time()
#     206 if np.all(init_edge != 0):
# --> 207     self.model.set_solution(init_edge)
#     208 self.model._phase1_time = None
#     209 self.model._is_dualinf = True
#
# File src\\gurobipy\\model.pxi:368, in gurobipy.Model.__getattr__()
#
# File src\\gurobipy\\model.pxi:1880, in gurobipy.Model.getAttr()
#
# File src\\gurobipy\\attrutil.pxi:26, in gurobipy._getattrinfo()
#
# AttributeError: 'gurobipy.Model' object has no attribute 'set_solution'

# %% [markdown]
# ## View Results

# %%
results_dir = 'results'
problems = ['adlittle', 'afiro', 'agg2','agg3','agg', 'bandm',
 'beaconfd', 'blend', 'bnl1', 'boeing1', 'boeing2', 'bore3d', 'brandy', 'capri',
 'cre-c', 'cycle', 'degen2', 'degen3', 'e226', 'etamacro', 'fffff800', 'finnis',
 'fit1d', 'fit1p', 'forplan', 'ganges', 'gfrd-pnc', 'grow15', 'grow22', 'grow7',
 'israel', 'kb2', 'ken-07', 'lotfi', 'maros', 'modszk1', 'pds-02', 'perold',
 'pilot4', 'pilotnov', 'pilot', 'qap08', 'recipe', 'sc105', 'sc205', 'sc50a',
 'sc50b', 'scagr25', 'scagr7', 'scfxm1', 'scfxm2', 'scfxm3', 'scorpion', 'scrs8',
 'scsd1', 'scsd6', 'scsd8', 'sctap1', 'sctap2', 'sctap3', 'seba', 'share1b',
 'share2b', 'shell', 'ship04l', 'ship04s', 'ship08l', 'ship08s', 'ship12l', 'ship12s',
 'sierra', 'stair', 'standata', 'standgub', 'standmps', 'stocfor1', 'stocfor2', 'tuff',
 'vtp_base', 'wood1p']     


avgs = {'lp_time': [], 'old_sd_time': [], 'old_first_sd': [], 'old_avg_sd': [],
        'new_sd_time': [], 'new_first_sd': [], 'new_avg_sd': [],
        'lp_iters': [], 'old_sd_iters': []}
from statistics import median

figure_dir = 'figures'
if not os.path.exists(figure_dir): os.mkdir(figure_dir)
for problem in problems:
    lp_fn = os.path.join(results_dir, problem + '_lp.p')
    old_sd_fn = os.path.join(results_dir, problem + '_old_sd.p')
    if not os.path.exists(old_sd_fn): continue
    new_sd_fn = os.path.join(results_dir, problem + '_new_sd.p')
    if not os.path.exists(new_sd_fn): continue
    
    
    with open(lp_fn, 'rb') as f:
        lp_results = pickle.load(f)
    with open(old_sd_fn, 'rb') as f:
        old_sd_results = pickle.load(f)
    with open(new_sd_fn, 'rb') as f:
        new_sd_results = pickle.load(f)
        
    try: 
        avgs['old_first_sd'].append(old_sd_results['solve_times'][0])
        avgs['old_avg_sd'].append(avg(old_sd_results['solve_times'][1:]))
        avgs['new_first_sd'].append(new_sd_results['solve_times'][0])
        avgs['new_avg_sd'].append(avg(new_sd_results['solve_times'][1:]))
        avgs['lp_time'].append(lp_results['solve_time_total'])
        avgs['old_sd_time'].append(old_sd_results['solve_time_total'])
        avgs['new_sd_time'].append(new_sd_results['solve_time_total'])
        avgs['lp_iters'].append(lp_results['n_iters'])
        avgs['old_sd_iters'].append(old_sd_results['n_iters'])
        avgs['new_sd_iters'].append(new_sd_results['n_iters'])
    except KeyError:
        print('skipping {}'.format(problem))
        continue
        
for metric in avgs:
    print('Average {}: {}'.format(metric, avg(avgs[metric])))
    print('Median {}: {}'.format(metric, median(avgs[metric])))

# %%
problems = ['stocfor2', 'cycle', 'modszk1', 'standmps', 'shell',
            'scagr25', 'scfxm2', 'etamacro', 'qap08', 'share1b',
            'grow15', 'grow22', 'grow7', 'cre-c', 'degen3']
problems = ['cycle', 'modszk1', 'degen3']


results_dir = 'results_dual_simplex_phase1'
figure_dir = 'figs_final'
save_figs = True

if not os.path.exists(figure_dir): os.mkdir(figure_dir)
for problem in problems:
    lp_fn = os.path.join(results_dir, problem + '_lp.p')
    old_sd_fn = os.path.join(results_dir, problem + '_old_sd.p')
    if not os.path.exists(old_sd_fn): continue
    new_sd_fn = os.path.join(results_dir, problem + '_new_sd.p')
    if not os.path.exists(new_sd_fn): continue
    problem_name = problem
    
    with open(lp_fn, 'rb') as f:
        lp_results = pickle.load(f)
    with open(old_sd_fn, 'rb') as f:
        old_sd_results = pickle.load(f)
    with open(new_sd_fn, 'rb') as f:
        new_sd_results = pickle.load(f)
        
    lp_results['obj_values'].append(lp_results['obj'])  
    lp_results['iter_times'].append(lp_results['solve_time_total'])  
    plt.figure(figsize=(10,5))
    plt.title('Simplex Objective for {}'.format(problem_name))
    plt.xlabel('Iteration')
    plt.ylabel('Obj. Value')
    plt.plot(list(range(len(lp_results['obj_values']))), lp_results['obj_values'], 'go-')
    fn = os.path.join(figure_dir, '{}_{}_lp_iter.png'.format(problem, results_dir))
    if save_figs: plt.savefig(fname=fn)
    plt.show()
    
    plt.figure(figsize=(10,5))
    plt.title('SD Objective for {}'.format(problem_name))
    plt.xlabel('Iteration')
    plt.ylabel('Obj. Value')
    plt.plot(list(range(len(old_sd_results['obj_values']))), old_sd_results['obj_values'], 'bo-')
    fn = os.path.join(figure_dir, '{}_{}_sd_iter.png'.format(problem, results_dir))
    if save_figs: plt.savefig(fname=fn)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('SD Objective for {}'.format(problem_name))
    plt.xlabel('Iteration')
    plt.ylabel('Obj. Value')
    plt.plot(list(range(len(new_sd_results['obj_values']))), new_sd_results['obj_values'], 'bo-')
    fn = os.path.join(figure_dir, '{}_{}_sd_iter.png'.format(problem, results_dir))
    if save_figs: plt.savefig(fname=fn)
    plt.show()
    
    times = {}
    #times['sd total'] = sd_results['solve_time_total']
    times['simplex total'] = lp_results['solve_time_total']
    times['first old SD step time'] = old_sd_results['solve_times'][0]
    times['average old SD step time'] = avg(old_sd_results['solve_times'][1:])
    times['first old SD step time'] = new_sd_results['solve_times'][0]
    times['average old SD step time'] = avg(new_sd_results['solve_times'][1:])
    #times['first SD Phase1 time'] = sd_results['sub_times']['phase1_times'][0]
    old_phase1_time = old_sd_results['sub_times']['phase1_times'][0]
    old_phase1_times = [0, old_phase1_time, 0]
    new_phase1_time = new_sd_results['sub_times']['phase1_times'][0]
    new_phase1_times = [0, new_phase1_time, 0]
    times['first old SD step time'] -= old_phase1_time
    times['first new SD step time'] -= new_phase1_time
    
    time_types = [key for key in times]

    #f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,5))
    plt.figure(figsize=(6,5))
    plt.title('Time breakdown for {}'.format(problem_name))
    plt.ylabel('Time (s)')
    x_pos = np.arange(len(time_types))
    plt.xticks(x_pos, time_types)
    values = [times[key] for key in times]
    p2 = plt.bar(x_pos, values, align='center', alpha=0.8)
    p1 = plt.bar(x_pos, phase1_times, bottom=values, align='center', alpha=0.8)
    fn = os.path.join(figure_dir, '{}_{}_time_breakdown.png'.format(problem, results_dir))
    plt.legend((p1[0], p2[0]), ('Phase I', 'Phase II'))
    plt.ylim(top=times['simplex total']*1.05)
    if save_figs: plt.savefig(fname=fn)
    plt.show()

    #ax2.set_title('Step breakdown for {}'.format(problem_name))
    #ax2.set_ylabel('Time (s)')
    #x_pos = np.arange(len(subtime_types))
    #ax2.set_xticks(x_pos)
    #ax2.set_xticklabels(subtime_types)
    #values = [subtimes[key] for key in subtimes]
    #ax2.bar(x_pos, values, align='center', alpha=0.8, color='m')
    #f.show()  
    
    plt.figure(figsize=(10,5))
    plt.title('Time comparison for {}'.format(problem_name))
    plt.xlabel('Time (s)')
    plt.ylabel('Obj. Value')
    plt.plot(lp_results['iter_times'], lp_results['obj_values'], 'go-', label='simplex')
    plt.plot(old_sd_results['iter_times'], old_sd_results['obj_values'], 'bo-', label='steepest-descent')
    plt.plot(new_sd_results['iter_times'], new_sd_results['obj_values'], 'bo-', label='steepest-descent')
    plt.legend(loc='upper right')
    fn = os.path.join(figure_dir, '{}_{}_time_comp.png'.format(problem, results_dir))
    if save_figs: plt.savefig(fname=fn)
    plt.show()
