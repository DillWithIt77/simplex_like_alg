# %% [markdown]
# # Active Ind Testing

# %%
import numpy as np
import gurobipy as gp
import math
import sympy
import contextlib
import time
import os
from utils import result, METHODS, INF, EPS
from mps_reader_preprocessor import read_mps_preprocess
from polyhedral_model import PolyhedralModel
from polyhedron import Polyhedron

# %% [markdown]
# ## Read in Polyhedron P

# %%
problem_dir = 'netlib_lp_subset'
# problem = 'kb2'
# problem = 'adlittle'
# problem = 'angela_test_prob'
# problem = 'network_ex'
# problem = 'gfrd-pnc'
# problem = 'modszk1'
# problem = 'cycle'
# problem = 'cre-c'
# problem = 'scsd8'
# problem = 'bandm'
# problem = 'qap08'
# problem = 'scsd1'
problem = 'scsd6'
mps_fn=os.path.join(problem_dir, problem)
results_dir='results'
max_time=300
sd_method='dual_simplex'
reset=False,
partition_polytope=False
n=0
k=0
spindle=False
spindle_dim=0
n_cone_facets=0
n_parallel_facets=0

# %% [markdown]
# ## Perform SDCA

# %%
### Build Initial Polyhedron from file
print(f'Reading {mps_fn}...')
c, B, d, A, b = read_mps_preprocess(mps_fn)
print('Building polyhedron...')
P = Polyhedron(B, d, A, b, c)
rank_A = np.linalg.matrix_rank(A)

print('Finding feasible solution...')
x_feasible, vbasis, cbasis = P.find_feasible_solution(verbose=False)

x = x_feasible
c=None
verbose=False
method='dual_simplex'
reset=False
max_time=300
first_warm_start=None
save_first_steps=0
problem_name=''

if c is not None:
    P.set_objective(c)

t0 = time.time()
x_current = x
if save_first_steps:
    np.save('solutions/{}_0.npy'.format(problem_name), x_current)      
active_inds = P.get_active_constraints(x_current)
    
pm = P.build_polyhedral_model(active_inds=active_inds, method=method)

if first_warm_start is not None:
    print('Using custom warm start')
    pm.set_solution(first_warm_start)
t1 = time.time()
build_time = t1 - t0
print('Polyhedral model build time: {}'.format(build_time))
    
sub_times = {'sd': [], 'step': [], 'solve': [], 'phase_times': []}
active_inds_it = []
descent_circuits = []
obj_values = []
step_sizes = []
iter_times = []
simplex_iters = []
iteration = 0
active_inds_it.append(active_inds)
obj_value = P.c.dot(x_current)
obj_values.append(obj_value)
t2 = time.time()
iter_times.append(t2 - t1)


# compute steepest-descent direction
descent_direction, y_pos, y_neg, steepness, num_steps, solve_time, phase_times = pm.compute_sd_direction(verbose=verbose)
simplex_iters.append(num_steps)
sub_times['solve'].append(solve_time)
sub_times['phase_times'].append(phase_times)
    
t3 = time.time()
sub_times['sd'].append(t3 - t2)
simp_switches = []
simp_switches.append(False)
    
while abs(steepness) > EPS:
        
    t3 = time.time()
    if reset:
        pm.reset()
        
    # take maximal step
    x_current, alpha, active_inds = P.take_maximal_step(descent_direction, y_pos, y_neg)

    if len(active_inds) < (P.n - rank_A):
        simp_switches.append(True)
    else:
        simp_switches.append(False)
        
    if iteration % 50 == 0 or iteration == 1:
        print('\nIteration {}'.format(iteration))
        print('Objective: {}'.format(obj_value))
        print('Steepness: {}'.format(steepness))
        print('Step length: {}'.format(alpha))
        # print('Descent Direction: {}'.format(descent_direction))
        
    t4 = time.time()
    active_inds_it.append(active_inds)
    obj_value = P.c.dot(x_current)
    obj_values.append(obj_value)
    iter_times.append(t4 - t1)
    sub_times['step'].append(t4 - t3) 
    descent_circuits.append(descent_direction)
    step_sizes.append(alpha)     
                
    if math.isinf(alpha):
        # problem is unbounded
        result(status=1, circuits=descent_circuits, steps=step_sizes)

    print(f'Number of Active Inds for Iteration {iteration}: {len(active_inds)}')
    print(f'Switch to Facet Restriction for Iteration {iteration}: {simp_switches[-1]}')
        
    # compute steepest-descent direction
    if simp_switches[-1] and not simp_switches[-2]:
        init_inds = active_inds
        print(f'initial inds for switch: {init_inds}')

    if simp_switches[-1]:
        print('using init_inds')
        pm.set_active_inds(init_inds, simp_switch = simp_switches[-1])
    elif simp_switches[-2] and not simp_switches[-1]:
        ##### finish using primal simplex 
        # not to self: when I used the set_solution method, it said that the x_current at the time of the switch was not feasible
        print('switched to primal simplex')
        simp_result = P.solve_lp_ws(x_current,verbose=False, record_objs=True)
        print(simp_result)
        break
    else:
        print('using active_inds')
        pm.set_active_inds(active_inds, simp_switch = simp_switches[-1])
    
    print('---------------------------------------------------------------')
    
    descent_direction, y_pos, y_neg, steepness, num_steps, solve_time, phase_times = pm.compute_sd_direction(verbose=verbose)
        
    t5 = time.time()
    sub_times['sd'].append(t5 - t4)
    sub_times['solve'].append(solve_time)
    sub_times['phase_times'].append(phase_times)
    simplex_iters.append(num_steps)
        
    iteration += 1
    current_time = t5 - t1
    if current_time > max_time:
        result(status=2)
    if iteration <= save_first_steps:
        np.save('solutions/{}_{}.npy'.format(problem_name, iteration), x_current)

t6 = time.time()
total_time = t6 - t1   
print('Total time for steepest-descent scheme: {}'.format(total_time))
# Out:
# Reading netlib_lp_subset\scsd6...
# Building polyhedron...
# Problem size: n = 1350,  m_B = 1350,  m_A = 147
# Finding feasible solution...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-01
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.5890417098999023
#
# Iteration 0
# Objective: 291.2499979658468
# Steepness: -3.344423207158696
# Step length: 11.949529965689111
# Number of Active Inds for Iteration 0: 1305
# Switch to Facet Restriction for Iteration 0: False
# using active_inds
# ---------------------------------------------------------------
#
# Iteration 1
# Objective: 251.28571263395787
# Steepness: -3.167184265575473
# Step length: 4.73606799117992
# Number of Active Inds for Iteration 1: 1305
# Switch to Facet Restriction for Iteration 1: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 2: 1304
# Switch to Facet Restriction for Iteration 2: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 3: 1304
# Switch to Facet Restriction for Iteration 3: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 4: 1304
# Switch to Facet Restriction for Iteration 4: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 5: 1303
# Switch to Facet Restriction for Iteration 5: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 6: 1303
# Switch to Facet Restriction for Iteration 6: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 7: 1304
# Switch to Facet Restriction for Iteration 7: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 8: 1304
# Switch to Facet Restriction for Iteration 8: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 9: 1304
# Switch to Facet Restriction for Iteration 9: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 10: 1304
# Switch to Facet Restriction for Iteration 10: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 11: 1304
# Switch to Facet Restriction for Iteration 11: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 12: 1304
# Switch to Facet Restriction for Iteration 12: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 13: 1299
# Switch to Facet Restriction for Iteration 13: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 14: 1298
# Switch to Facet Restriction for Iteration 14: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 15: 1298
# Switch to Facet Restriction for Iteration 15: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 16: 1299
# Switch to Facet Restriction for Iteration 16: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 17: 1300
# Switch to Facet Restriction for Iteration 17: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 18: 1300
# Switch to Facet Restriction for Iteration 18: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 19: 1299
# Switch to Facet Restriction for Iteration 19: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20: 1298
# Switch to Facet Restriction for Iteration 20: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 21: 1295
# Switch to Facet Restriction for Iteration 21: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 22: 1294
# Switch to Facet Restriction for Iteration 22: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 23: 1290
# Switch to Facet Restriction for Iteration 23: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 24: 1289
# Switch to Facet Restriction for Iteration 24: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 25: 1290
# Switch to Facet Restriction for Iteration 25: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 26: 1288
# Switch to Facet Restriction for Iteration 26: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 27: 1286
# Switch to Facet Restriction for Iteration 27: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 28: 1287
# Switch to Facet Restriction for Iteration 28: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 29: 1283
# Switch to Facet Restriction for Iteration 29: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 30: 1282
# Switch to Facet Restriction for Iteration 30: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 31: 1282
# Switch to Facet Restriction for Iteration 31: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 32: 1281
# Switch to Facet Restriction for Iteration 32: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 33: 1281
# Switch to Facet Restriction for Iteration 33: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 34: 1282
# Switch to Facet Restriction for Iteration 34: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 35: 1283
# Switch to Facet Restriction for Iteration 35: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 36: 1284
# Switch to Facet Restriction for Iteration 36: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 37: 1283
# Switch to Facet Restriction for Iteration 37: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 38: 1283
# Switch to Facet Restriction for Iteration 38: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 39: 1284
# Switch to Facet Restriction for Iteration 39: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 40: 1287
# Switch to Facet Restriction for Iteration 40: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 41: 1286
# Switch to Facet Restriction for Iteration 41: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 42: 1289
# Switch to Facet Restriction for Iteration 42: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 43: 1292
# Switch to Facet Restriction for Iteration 43: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 44: 1291
# Switch to Facet Restriction for Iteration 44: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 45: 1292
# Switch to Facet Restriction for Iteration 45: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 46: 1285
# Switch to Facet Restriction for Iteration 46: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 47: 1284
# Switch to Facet Restriction for Iteration 47: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 48: 1286
# Switch to Facet Restriction for Iteration 48: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 49: 1286
# Switch to Facet Restriction for Iteration 49: False
# using active_inds
# ---------------------------------------------------------------
#
# Iteration 50
# Objective: 50.75027592884256
# Steepness: -0.028808902378936366
# Step length: 0.003072650158305131
# Number of Active Inds for Iteration 50: 1280
# Switch to Facet Restriction for Iteration 50: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 51: 1281
# Switch to Facet Restriction for Iteration 51: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 52: 1282
# Switch to Facet Restriction for Iteration 52: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 53: 1283
# Switch to Facet Restriction for Iteration 53: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 54: 1284
# Switch to Facet Restriction for Iteration 54: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 55: 1285
# Switch to Facet Restriction for Iteration 55: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 56: 1287
# Switch to Facet Restriction for Iteration 56: False
# using active_inds
# ---------------------------------------------------------------
# Total time for steepest-descent scheme: 0.6554927825927734

# %%
print(P.n)
print(rank_A)
print(P.m_B)
print(math.floor(P.n/10))
# Out:
# 1350
# 147
# 1350
# 135

# %%
print(obj_values[-1])
# print(x_current)
# print(simp_result)
# Out:
# 50.500000069035536

# %%
print(f'Reading {mps_fn}...')
c, B, d, A, b = read_mps_preprocess(mps_fn)
print('Building polyhedron...')
P = Polyhedron(B, d, A, b, c)
print('\nSolving with simplex method...')
lp_result = P.solve_lp(verbose=False, record_objs=True)
print('\nSolution using simplex method:')
print(lp_result)
# Out:
# Reading netlib_lp_subset\scsd6...
# Building polyhedron...
# Problem size: n = 1350,  m_B = 1350,  m_A = 147
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 50.50000007714435
# Total solve time: 0.0
# Number of iterations: 402.0

# %%
equality = np.all(np.isclose(np.dot(A, np.array(x_current)), b))
inequality = np.all(np.dot(B, np.array(x_current)) <= d)
print(equality)
print(inequality)
# Out:
# True
# False

# %%
# P.bfs_soln_chck(x_current)
P.set_solution(x_current)
# Out:
# Feasible solution found with objective 50.50000007921082
