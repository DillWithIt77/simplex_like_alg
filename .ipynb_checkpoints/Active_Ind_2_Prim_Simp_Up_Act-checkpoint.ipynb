# %% [markdown]
# # Active Ind Testing

# %%
import numpy as np
import gurobipy as gp
import math
import sympy
import contextlib
import time
import os
from utils import result, METHODS, INF, EPS
from mps_reader_preprocessor import read_mps_preprocess
from polyhedral_model import PolyhedralModel
from polyhedron import Polyhedron

# %% [markdown]
# ## Read in Polyhedron P

# %%
problem_dir = 'netlib_lp_subset'
# problem = 'kb2'
problem = 'adlittle'
# problem = 'angela_test_prob'
# problem = 'network_ex'
# problem = 'gfrd-pnc'
# problem = 'modszk1'
# problem = 'cycle'
# problem = 'cre-c'
mps_fn=os.path.join(problem_dir, problem)
results_dir='results'
max_time=300
sd_method='dual_simplex'
reset=False,
partition_polytope=False
n=0
k=0
spindle=False
spindle_dim=0
n_cone_facets=0
n_parallel_facets=0

# %% [markdown]
# ## Perform SDCA

# %%
### Build Initial Polyhedron from file
print(f'Reading {mps_fn}...')
c, B, d, A, b = read_mps_preprocess(mps_fn)
print('Building polyhedron...')
P = Polyhedron(B, d, A, b, c)
rank_A = np.linalg.matrix_rank(A)

print('Finding feasible solution...')
x_feasible, vbasis, cbasis = P.find_feasible_solution(verbose=False)

x = x_feasible
c=None
verbose=False
method='dual_simplex'
reset=False
max_time=300
first_warm_start=None
save_first_steps=0
problem_name=''

if c is not None:
    P.set_objective(c)

t0 = time.time()
x_current = x
if save_first_steps:
    np.save('solutions/{}_0.npy'.format(problem_name), x_current)      
active_inds = P.get_active_constraints(x_current)
    
pm = P.build_polyhedral_model(active_inds=active_inds, method=method)

if first_warm_start is not None:
    print('Using custom warm start')
    pm.set_solution(first_warm_start)
t1 = time.time()
build_time = t1 - t0
print('Polyhedral model build time: {}'.format(build_time))
    
sub_times = {'sd': [], 'step': [], 'solve': [], 'phase_times': []}
active_inds_it = []
descent_circuits = []
obj_values = []
step_sizes = []
iter_times = []
simplex_iters = []
iteration = 0
active_inds_it.append(active_inds)
obj_value = P.c.dot(x_current)
obj_values.append(obj_value)
t2 = time.time()
iter_times.append(t2 - t1)


# compute steepest-descent direction
descent_direction, y_pos, y_neg, steepness, num_steps, solve_time, phase_times = pm.compute_sd_direction(verbose=verbose)
simplex_iters.append(num_steps)
sub_times['solve'].append(solve_time)
sub_times['phase_times'].append(phase_times)
    
t3 = time.time()
sub_times['sd'].append(t3 - t2)
simp_switches = []
simp_switches.append(False)

while abs(steepness) > EPS:
        
    t3 = time.time()
    if reset:
        pm.reset()
        
    # take maximal step
    if not simp_switches[-1]:
        x_current, alpha, active_inds = P.take_maximal_step(descent_direction, y_pos, y_neg)

    if len(active_inds) < (P.n - rank_A):
        simp_switches.append(True)
    else:
        simp_switches.append(False)
        
    if iteration % 50 == 0 or iteration == 1:
        print('\nIteration {}'.format(iteration))
        print('Objective: {}'.format(obj_value))
        print('Steepness: {}'.format(steepness))
        print('Step length: {}'.format(alpha))
        
    t4 = time.time()
    active_inds_it.append(active_inds)
    obj_value = P.c.dot(x_current)
    obj_values.append(obj_value)
    iter_times.append(t4 - t1)
    sub_times['step'].append(t4 - t3) 
    descent_circuits.append(descent_direction)
    step_sizes.append(alpha)     
                
    if math.isinf(alpha):
        # problem is unbounded
        result(status=1, circuits=descent_circuits, steps=step_sizes)
        
    # compute steepest-descent direction
    if simp_switches[-2] and not simp_switches[-1]:
        print('switched to primal simplex')
        num_dec_places = Polyhedron.num_aft_dec(obj_value)
        print(f'before simp: {x_current}')
        x_current = P.second_vert(x_current, obj_value, num_dec_places, verbose=False)
        print(f'after simp: {x_current}')
        active_inds = P.get_active_constraints(x_current)
    else:
        pm.set_active_inds(active_inds, simp_switch = simp_switches[-1])
        descent_direction, y_pos, y_neg, steepness, num_steps, solve_time, phase_times = pm.compute_sd_direction(verbose=verbose)
        
    print(f'Number of Active Inds for Iteration {iteration}: {len(active_inds)}')
    print(f'Switch to Facet Restriction for Iteration {iteration}: {simp_switches[-1]}')
    print('---------------------------------------------------------------')
    
        
    t5 = time.time()
    sub_times['sd'].append(t5 - t4)
    sub_times['solve'].append(solve_time)
    sub_times['phase_times'].append(phase_times)
    simplex_iters.append(num_steps)
        
    iteration += 1
    current_time = t5 - t1
    if current_time > max_time:
        result(status=2)
    if iteration <= save_first_steps:
        np.save('solutions/{}_{}.npy'.format(problem_name, iteration), x_current)

t6 = time.time()
total_time = t6 - t1   
print('Total time for steepest-descent scheme: {}'.format(total_time))
# Out:
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-01
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.00689387321472168
#
# Iteration 0
# Objective: 671734.1100278501
# Steepness: -1093.3333333333335
# Step length: 1.492387497139124
# Number of Active Inds for Iteration 0: 93
# Switch to Facet Restriction for Iteration 0: False
# ---------------------------------------------------------------
#
# Iteration 1
# Objective: 670102.4330309781
# Steepness: -608.695652173913
# Step length: 14.047128014198497
# Number of Active Inds for Iteration 1: 90
# Switch to Facet Restriction for Iteration 1: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 2: 90
# Switch to Facet Restriction for Iteration 2: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 3: 90
# Switch to Facet Restriction for Iteration 3: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 4: 90
# Switch to Facet Restriction for Iteration 4: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 5: 88
# Switch to Facet Restriction for Iteration 5: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 6: 88
# Switch to Facet Restriction for Iteration 6: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 7: 84
# Switch to Facet Restriction for Iteration 7: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 8: 84
# Switch to Facet Restriction for Iteration 8: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 9: 85
# Switch to Facet Restriction for Iteration 9: False
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 10: 80
# Switch to Facet Restriction for Iteration 10: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 11: 80
# Switch to Facet Restriction for Iteration 11: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 12: 80
# Switch to Facet Restriction for Iteration 12: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 13: 80
# Switch to Facet Restriction for Iteration 13: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 14: 80
# Switch to Facet Restriction for Iteration 14: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 15: 80
# Switch to Facet Restriction for Iteration 15: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 16: 80
# Switch to Facet Restriction for Iteration 16: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 17: 80
# Switch to Facet Restriction for Iteration 17: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 18: 80
# Switch to Facet Restriction for Iteration 18: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 19: 80
# Switch to Facet Restriction for Iteration 19: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20: 80
# Switch to Facet Restriction for Iteration 20: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 21: 80
# Switch to Facet Restriction for Iteration 21: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 22: 80
# Switch to Facet Restriction for Iteration 22: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 23: 80
# Switch to Facet Restriction for Iteration 23: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 24: 80
# Switch to Facet Restriction for Iteration 24: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 25: 80
# Switch to Facet Restriction for Iteration 25: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 26: 80
# Switch to Facet Restriction for Iteration 26: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration
True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20630: 80
# Switch to Facet Restriction for Iteration 20630: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20631: 80
# Switch to Facet Restriction for Iteration 20631: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20632: 80
# Switch to Facet Restriction for Iteration 20632: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20633: 80
# Switch to Facet Restriction for Iteration 20633: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20634: 80
# Switch to Facet Restriction for Iteration 20634: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20635: 80
# Switch to Facet Restriction for Iteration 20635: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20636: 80
# Switch to Facet Restriction for Iteration 20636: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20637: 80
# Switch to Facet Restriction for Iteration 20637: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20638: 80
# Switch to Facet Restriction for Iteration 20638: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20639: 80
# Switch to Facet Restriction for Iteration 20639: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20640: 80
# Switch to Facet Restriction for Iteration 20640: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20641: 80
# Switch to Facet Restriction for Iteration 20641: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20642: 80
# Switch to Facet Restriction for Iteration 20642: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20643: 80
# Switch to Facet Restriction for Iteration 20643: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20644: 80
# Switch to Facet Restriction for Iteration 20644: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20645: 80
# Switch to Facet Restriction for Iteration 20645: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20646: 80
# Switch to Facet Restriction for Iteration 20646: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20647: 80
# Switch to Facet Restriction for Iteration 20647: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20648: 80
# Switch to Facet Restriction for Iteration 20648: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20649: 80
# Switch to Facet Restriction for Iteration 20649: True
# ---------------------------------------------------------------
#
# Iteration 20650
# Objective: 598014.8545205264
# Steepness: -155.65818553368214
# Step length: 4.321933057485882
# Number of Active Inds for Iteration 20650: 80
# Switch to Facet Restriction for Iteration 20650: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20651: 80
# Switch to Facet Restriction for Iteration 20651: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20652: 80
# Switch to Facet Restriction for Iteration 20652: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20653: 80
# Switch to Facet Restriction for Iteration 20653: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20654: 80
# Switch to Facet Restriction for Iteration 20654: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20655: 80
# Switch to Facet Restriction for Iteration 20655: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20656: 80
# Switch to Facet Restriction for Iteration 20656: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20657: 80
# Switch to Facet Restriction for Iteration 20657: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20658: 80
# Switch to Facet Restriction for Iteration 20658: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20659: 80
# Switch to Facet Restriction for Iteration 20659: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20660: 80
# Switch to Facet Restriction for Iteration 20660: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20661: 80
# Switch to Facet Restriction for Iteration 20661: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20662: 80
# Switch to Facet Restriction for Iteration 20662: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20663: 80
# Switch to Facet Restriction for Iteration 20663: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20664: 80
# Switch to Facet Restriction for Iteration 20664: True
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 20665: 80
# Switch to Facet Restriction for Iteration 20665: True
# ---------------------------------------------------------------

# %%
print(P.n)
print(rank_A)
print(P.m_B)
print(math.floor(P.n/10))
# Out:
# 41
# 16
# 77
# 4

# %%
# print(obj_values[-1])
print(simp_result)
# print(x_current)
# Out:
# Optimal objective: -1749.9001299062058
# Total solve time: 0.0
# Number of iterations: 57.0

# %%
print(f'Reading {mps_fn}...')
c, B, d, A, b = read_mps_preprocess(mps_fn)
print('Building polyhedron...')
P = Polyhedron(B, d, A, b, c)
print('\nSolving with simplex method...')
lp_result = P.solve_lp(verbose=False, record_objs=True)
print('\nSolution using simplex method:')
print(lp_result)
# Out:
# Reading netlib_lp_subset\kb2...
# Building polyhedron...
# Problem size: n = 41,  m_B = 77,  m_A = 16
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -1749.9001299062058
# Total solve time: 0.0
# Number of iterations: 39.0

# %%
equality = np.all(np.isclose(np.dot(A, np.array(x_feasible)), b))
inequality = np.all(np.dot(B, np.array(x_feasible))<= d)
print(equality)
print(inequality)
# Out:
# True
# True
