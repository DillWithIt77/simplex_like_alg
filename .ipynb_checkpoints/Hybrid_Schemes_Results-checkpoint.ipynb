# %% [markdown]
# # Warm Start Results

# %% [markdown]
# ## Import Statements

# %%
import os
import pickle
import subprocess

from hybrid_main import hybrid_main

from glob import glob
import numpy as np
import random
from matplotlib import pyplot as plt
# %matplotlib inline

from utils import avg

# %% [markdown]
# ## Run Tests

# %%
problems = ['adlittle', 'afiro', 'agg2','agg3','agg', 'bandm',
 'beaconfd', 'blend', 'bnl1', 'boeing1', 'boeing2', 'bore3d', 'brandy', 'capri',
 'degen2', 'degen3', 'e226', 'etamacro', 'fffff800', 'finnis',
 'fit1d', 'fit1p', 'forplan', 'ganges', 'gfrd-pnc', 'grow15', 'grow22', 'grow7',
  'kb2', 'ken-07', 'lotfi', 'maros', 'pds-02', 'perold',
 'pilotnov', 'qap08', 'recipe', 'sc105', 'sc205', 'sc50a',
 'sc50b', 'scagr25', 'scagr7', 'scfxm1', 'scfxm2', 'scfxm3', 'scorpion', 'scrs8',
 'scsd1', 'scsd6', 'scsd8', 'sctap1', 'sctap2', 'sctap3', 'seba', 'share1b',
 'share2b', 'shell', 'ship04l', 'ship04s', 'ship08l', 'ship08s', 'ship12l', 'ship12s',
 'sierra', 'stair', 'standata', 'standgub', 'standmps', 'stocfor1', 'stocfor2', 'tuff',
 'vtp_base', 'wood1p', 'cre-c', 'modszk1']     
# 'pilot4',
# 'cycle', 'israel', 

# problems = ['adlittle']
    
results_dir = 'results'
problem_dir = 'netlib_lp_subset'
max_time = 300
reset = False
sd_method = 'dual_simplex'

for i, problem in enumerate(problems):
    mps_fn = os.path.join(problem_dir, problem)
    print('\n\n\nWorking on problem {} of {}: {}'.format(i+1, len(problems), mps_fn))    
    hybrid_main(mps_fn=mps_fn, results_dir=results_dir, max_time=max_time, reset=reset, sd_method=sd_method)
# Out:
# Working on problem 1 of 76: netlib_lp_subset\adlittle
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-01
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 225494.96316238024
# Total solve time: 0.003000020980834961
# Number of iterations: 100.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0035772323608398438
#
# Iteration 0
# Objective: 671734.1100278501
# Steepness: -1093.3333333333335
# Step length: 1.492387497139124
#
# Iteration 1
# Objective: 670102.4330309781
# Steepness: -608.695652173913
# Step length: 14.047128014198497
#
# Iteration 50
# Objective: 225785.31769628634
# Steepness: -1.1566308634677132
# Step length: 10.69303715265792
# Total time for steepest-descent scheme: 0.0760948657989502
#
# Solving with hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.012200593948364258
#
# Iteration 0
# Objective: 671734.1100278501
# Steepness: -1093.3333333333335
# Step length: 1.492387497139124
#
# Iteration 1
# Objective: 670102.4330309781
# Steepness: -608.695652173913
# Step length: 14.047128014198497
# Total time for steepest-descent scheme: 0.04164600372314453
#
# Solving with hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.009166955947875977
#
# Iteration 0
# Objective: 671734.1100278501
# Steepness: -1093.3333333333335
# Step length: 1.492387497139124
#
# Iteration 1
# Objective: 670102.4330309781
# Steepness: -608.695652173913
# Step length: 14.047128014198497
# Total time for steepest-descent scheme: 0.04139065742492676
#
# Solving with alt hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.009273290634155273
#
# Iteration 0
# Objective: 671734.1100278501
# Steepness: -1640.0
# Step length: 0.789078446763215
#
# Iteration 1
# Objective: 670440.0213751586
# Steepness: -1074.3908969210174
# Step length: 34.370158400267876
# Total time for steepest-descent scheme: 0.034717559814453125
#
# Solving with alt hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.003548145294189453
#
# Iteration 0
# Objective: 671734.1100278501
# Steepness: -1640.0
# Step length: 0.789078446763215
#
# Iteration 1
# Objective: 670440.0213751586
# Steepness: -1074.3908969210174
# Step length: 34.370158400267876
# Total time for steepest-descent scheme: 0.04177594184875488
#
#
#
# Working on problem 2 of 76: netlib_lp_subset\afiro
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -464.75314285714285
# Total solve time: 0.0
# Number of iterations: 19.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0
#
# Iteration 0
# Objective: 440.0
# Steepness: -3.333333333333334
# Step length: 131.99999999999997
#
# Iteration 1
# Objective: 7.105427357601002e-14
# Steepness: -0.14049832478346544
# Step length: 3245.3160714285714
# Total time for steepest-descent scheme: 0.01136469841003418
#
# Solving with hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0
#
# Iteration 0
# Objective: 440.0
# Steepness: -3.333333333333334
# Step length: 131.99999999999997
#
# Iteration 1
# Objective: 7.105427357601002e-14
# Steepness: -0.14049832478346544
# Step length: 3245.3160714285714
# Total time for steepest-descent scheme: 0.00928187370300293
#
# Solving with hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0005037784576416016
#
# Iteration 0
# Objective: 440.0
# Steepness: -3.333333333333334
# Step length: 131.99999999999997
#
# Iteration 1
# Objective: 7.105427357601002e-14
# Steepness: -0.14049832478346544
# Step length: 3245.3160714285714
# Total time for steepest-descent scheme: 0.0025146007537841797
#
# Solving with alt hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0033369064331054688
#
# Iteration 0
# Objective: 440.0
# Steepness: -10.0
# Step length: 44.0
#
# Iteration 1
# Objective: 0.0
# Steepness: -0.5511640352346532
# Step length: 827.27
# Total time for steepest-descent scheme: 0.003166675567626953
#
# Solving with alt hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0
#
# Iteration 0
# Objective: 440.0
# Steepness: -10.0
# Step length: 44.0
#
# Iteration 1
# Objective: 0.0
# Steepness: -0.5511640352346532
# Step length: 827.27
# Total time for steepest-descent scheme: 0.005633115768432617
#
#
#
# Working on problem 3 of 76: netlib_lp_subset\agg2
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -20239252.355977118
# Total solve time: 0.0
# Number of iterations: 158.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.09276628494262695
#
# Iteration 0
# Objective: 109626646.32852079
# Steepness: -83.04516320666386
# Step length: 742.8174157224255
#
# Iteration 1
# Objective: 109564958.93499938
# Steepness: -58.894049681906935
# Step length: 2062.9421267070884
#
# Iteration 50
# Objective: -17812065.089391712
# Steepness: -1.1416934370415128
# Step length: 236890.10620872286
# Total time for steepest-descent scheme: 0.5696995258331299
#
# Solving with hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.07935905456542969
#
# Iteration 0
# Objective: 109626646.32852079
# Steepness: -83.04516320666386
# Step length: 742.8174157224255
#
# Iteration 1
# Objective: 109564958.93499938
# Steepness: -58.894049681906935
# Step length: 2062.9421267070884
#
# Iteration 50
# Objective: -17812065.089391712
# Steepness: -1.1416934370415128
# Step length: 236890.10620872286
# Total time for steepest-descent scheme: 0.5880353450775146
#
# Solving with hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.09039187431335449
#
# Iteration 0
# Objective: 109626646.32852079
# Steepness: -83.04516320666386
# Step length: 742.8174157224255
#
# Iteration 1
# Objective: 109564958.93499938
# Steepness: -58.894049681906935
# Step length: 2062.9421267070884
#
# Iteration 50
# Objective: -17812065.089391712
# Steepness: -1.1416934370415128
# Step length: 236890.10620872286
# Total time for steepest-descent scheme: 0.6284918785095215
#
# Solving with alt hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0864408016204834
#
# Iteration 0
# Objective: 109626646.32852079
# Steepness: -95.36046565083602
# Step length: 646.8864544694084
#
# Iteration 1
# Objective: 109564958.93499938
# Steepness: -69.07276802119921
# Step length: 166247.28621455768
#
# Iteration 50
# Objective: -12062153.818650587
# Steepness: -3.1196373399077557
# Step length: 240519.90770596656
#
# Iteration 100
# Objective: -20208016.257038515
# Steepness: -0.08233096269574358
# Step length: 201625.23862797202
# Total time for steepest-descent scheme: 0.6423389911651611
#
# Solving with alt hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0948324203491211
#
# Iteration 0
# Objective: 109626646.32852079
# Steepness: -95.36046565083602
# Step length: 646.8864544694084
#
# Iteration 1
# Objective: 109564958.93499938
# Steepness: -69.07276802119921
# Step length: 166247.28621455768
#
# Iteration 50
# Objective: -12062153.818650587
# Steepness: -3.1196373399077557
# Step length: 240519.90770596656
#
# Iteration 100
# Objective: -20208016.257038515
# Steepness: -0.08233096269574358
# Step length: 201625.23862797202
# Total time for steepest-descent scheme: 0.7710287570953369
#
#
#
# Working on problem 4 of 76: netlib_lp_subset\agg3
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 10312115.935089217
# Total solve time: 0.013000011444091797
# Number of iterations: 156.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0999138355255127
#
# Iteration 0
# Objective: 759202344.1690388
# Steepness: -99.87397600792033
# Step length: 6779195.16351643
#
# Iteration 1
# Objective: 82137169.05498938
# Steepness: -73.94169151062248
# Step length: 2650.7530877042677
#
# Iteration 50
# Objective: 11402989.186213307
# Steepness: -1.0241476605354012
# Step length: 186189.46206288485
# Total time for steepest-descent scheme: 0.5452964305877686
#
# Solving with hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.09479784965515137
#
# Iteration 0
# Objective: 759202344.1690388
# Steepness: -99.87397600792033
# Step length: 6779195.16351643
#
# Iteration 1
# Objective: 82137169.05498938
# Steepness: -73.94169151062248
# Step length: 2650.7530877042677
#
# Iteration 50
# Objective: 11402989.186213307
# Steepness: -1.0241476605354012
# Step length: 186189.46206288485
# Total time for steepest-descent scheme: 0.5508108139038086
#
# Solving with hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.09888005256652832
#
# Iteration 0
# Objective: 759202344.1690388
# Steepness: -99.87397600792033
# Step length: 6779195.16351643
#
# Iteration 1
# Objective: 82137169.05498938
# Steepness: -73.94169151062248
# Step length: 2650.7530877042677
#
# Iteration 50
# Objective: 11402989.186213307
# Steepness: -1.0241476605354012
# Step length: 186189.46206288485
# Total time for steepest-descent scheme: 0.5516471862792969
#
# Solving with alt hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.10062837600708008
#
# Iteration 0
# Objective: 759202344.1690388
# Steepness: -99.94022343440434
# Step length: 6774701.434987689
#
# Iteration 1
# Objective: 82137169.05498938
# Steepness: -86.58110244457778
# Step length: 2263.786918251856
#
# Iteration 50
# Objective: 14775184.059586516
# Steepness: -1.8142513145226056
# Step length: 332109.4406394084
# Total time for steepest-descent scheme: 0.6140358448028564
#
# Solving with alt hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0959465503692627
#
# Iteration 0
# Objective: 759202344.1690388
# Steepness: -99.94022343440434
# Step length: 6774701.434987689
#
# Iteration 1
# Objective: 82137169.05498938
# Steepness: -86.58110244457778
# Step length: 2263.786918251856
#
# Iteration 50
# Objective: 14775184.059586516
# Steepness: -1.8142513145226056
# Step length: 332109.4406394084
# Total time for steepest-descent scheme: 0.7434036731719971
#
#
#
# Working on problem 5 of 76: netlib_lp_subset\agg
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -35991767.2865765
# Total solve time: 0.002000093460083008
# Number of iterations: 75.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.043372392654418945
#
# Iteration 0
# Objective: 703339586.6175559
# Steepness: -99.956349594957
# Step length: 2544092.712901022
#
# Iteration 1
# Objective: 449041366.0048387
# Steepness: -99.63098617323385
# Step length: 622821.068708921
# Total time for steepest-descent scheme: 0.18874049186706543
#
# Solving with hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.03570890426635742
#
# Iteration 0
# Objective: 703339586.6175559
# Steepness: -99.956349594957
# Step length: 2544092.712901022
#
# Iteration 1
# Objective: 449041366.0048387
# Steepness: -99.63098617323385
# Step length: 622821.068708921
# Total time for steepest-descent scheme: 0.219651460647583
#
# Solving with hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.05338001251220703
#
# Iteration 0
# Objective: 703339586.6175559
# Steepness: -99.956349594957
# Step length: 2544092.712901022
#
# Iteration 1
# Objective: 449041366.0048387
# Steepness: -99.63098617323385
# Step length: 622821.068708921
# Total time for steepest-descent scheme: 0.21149134635925293
#
# Solving with alt hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.04708099365234375
#
# Iteration 0
# Objective: 703339586.6175559
# Steepness: -100.0013825608798
# Step length: 2542947.0483360873
#
# Iteration 1
# Objective: 449041366.0048387
# Steepness: -99.84451764705882
# Step length: 621489.0786921954
# Total time for steepest-descent scheme: 0.18696975708007812
#
# Solving with alt hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.03353166580200195
#
# Iteration 0
# Objective: 703339586.6175559
# Steepness: -100.0013825608798
# Step length: 2542947.0483360873
#
# Iteration 1
# Objective: 449041366.0048387
# Steepness: -99.84451764705882
# Step length: 621489.0786921954
# Total time for steepest-descent scheme: 0.19991183280944824
#
#
#
# Working on problem 6 of 76: netlib_lp_subset\bandm
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -158.62801845011555
# Total solve time: 0.0
# Number of iterations: 216.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.12118697166442871
#
# Iteration 0
# Objective: 35.17554204866987
# Steepness: -3.0233333333333334
# Step length: 5.4910125
#
# Iteration 1
# Objective: 18.574380923669892
# Steepness: -1.6666666666666665
# Step length: 2.919
#
# Iteration 50
# Objective: -83.89061670032704
# Steepness: -0.10222001817147731
# Step length: 7.878452745717247
#
# Iteration 100
# Objective: -150.8447534442673
# Steepness: -0.022664555281095882
# Step length: 2.8725769410157787
#
# Iteration 150
# Objective: -158.3352099434993
# Steepness: -0.003824671795482795
# Step length: 2.8753848724163946
# Total time for steepest-descent scheme: 0.962705135345459
#
# Solving with hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.16685891151428223
#
# Iteration 0
# Objective: 35.17554204866987
# Steepness: -3.0233333333333334
# Step length: 5.4910125
#
# Iteration 1
# Objective: 18.574380923669892
# Steepness: -1.6666666666666665
# Step length: 2.919
#
# Iteration 50
# Objective: -83.89061670032704
# Steepness: -0.10222001817147731
# Step length: 7.878452745717247
#
# Iteration 100
# Objective: -150.8447534442673
# Steepness: -0.022664555281095882
# Step length: 2.8725769410157787
#
# Iteration 150
# Objective: -158.3352099434993
# Steepness: -0.003824671795482795
# Step length: 2.8753848724163946
# Total time for steepest-descent scheme: 0.9074559211730957
#
# Solving with hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.11856842041015625
#
# Iteration 0
# Objective: 35.17554204866987
# Steepness: -3.0233333333333334
# Step length: 5.4910125
#
# Iteration 1
# Objective: 18.574380923669892
# Steepness: -1.6666666666666665
# Step length: 2.919
#
# Iteration 50
# Objective: -83.89061670032704
# Steepness: -0.10222001817147731
# Step length: 7.878452745717247
#
# Iteration 100
# Objective: -150.8447534442673
# Steepness: -0.022664555281095882
# Step length: 2.8725769410157787
#
# Iteration 150
# Objective: -158.3352099434993
# Steepness: -0.003824671795482795
# Step length: 2.8753848724163946
# Total time for steepest-descent scheme: 0.9395434856414795
#
# Solving with alt hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.1382286548614502
#
# Iteration 0
# Objective: 35.17554204866987
# Steepness: -4.535
# Step length: 3.660675
#
# Iteration 1
# Objective: 18.574380923669892
# Steepness: -3.2716999121539905
# Step length: 3.1920764323842126
# Total time for steepest-descent scheme: 0.39470410346984863
#
# Solving with alt hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.14119815826416016
#
# Iteration 0
# Objective: 35.17554204866987
# Steepness: -4.535
# Step length: 3.660675
#
# Iteration 1
# Objective: 18.574380923669892
# Steepness: -3.2716999121539905
# Step length: 3.1920764323842126
# Total time for steepest-descent scheme: 0.39743494987487793
#
#
#
# Working on problem 7 of 76: netlib_lp_subset\beaconfd
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 33592.48580719999
# Total solve time: 0.0
# Number of iterations: 20.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.09121847152709961
#
# Iteration 0
# Objective: 33992.2782842
# Steepness: -0.07985710632678573
# Step length: 1074.2533000000003
#
# Iteration 1
# Objective: 33906.4915242
# Steepness: -0.06030063441259438
# Step length: 10.890871063301619
# Total time for steepest-descent scheme: 0.06422090530395508
#
# Solving with hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.04849672317504883
#
# Iteration 0
# Objective: 33992.2782842
# Steepness: -0.07985710632678573
# Step length: 1074.2533000000003
#
# Iteration 1
# Objective: 33906.4915242
# Steepness: -0.06030063441259438
# Step length: 10.890871063301619
# Total time for steepest-descent scheme: 0.06671547889709473
#
# Solving with hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0419154167175293
#
# Iteration 0
# Objective: 33992.2782842
# Steepness: -0.07985710632678573
# Step length: 1074.2533000000003
#
# Iteration 1
# Objective: 33906.4915242
# Steepness: -0.06030063441259438
# Step length: 10.890871063301619
# Total time for steepest-descent scheme: 0.07210040092468262
#
# Solving with alt hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.04844164848327637
#
# Iteration 0
# Objective: 33992.2782842
# Steepness: -0.15971421265357094
# Step length: 537.1266499999999
#
# Iteration 1
# Objective: 33906.4915242
# Steepness: -0.12242091693385798
# Step length: 4.840480000000002
# Total time for steepest-descent scheme: 0.06394362449645996
#
# Solving with alt hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.044408559799194336
#
# Iteration 0
# Objective: 33992.2782842
# Steepness: -0.15971421265357094
# Step length: 537.1266499999999
#
# Iteration 1
# Objective: 33906.4915242
# Steepness: -0.12242091693385798
# Step length: 4.840480000000002
# Total time for steepest-descent scheme: 0.06347894668579102
#
#
#
# Working on problem 8 of 76: netlib_lp_subset\blend
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -30.812149845828237
# Total solve time: 0.0
# Number of iterations: 96.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.010570764541625977
#
# Iteration 0
# Objective: 0.0
# Steepness: -0.07995096139551053
# Step length: 204.46220784365894
#
# Iteration 1
# Objective: -16.346950086149228
# Steepness: -0.07507855792833903
# Step length: 11.700432388455038
# Total time for steepest-descent scheme: 0.03360128402709961
#
# Solving with hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0
#
# Iteration 0
# Objective: 0.0
# Steepness: -0.07995096139551053
# Step length: 204.46220784365894
#
# Iteration 1
# Objective: -16.346950086149228
# Steepness: -0.07507855792833903
# Step length: 11.700432388455038
# Total time for steepest-descent scheme: 0.031697988510131836
#
# Solving with hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0022144317626953125
#
# Iteration 0
# Objective: 0.0
# Steepness: -0.07995096139551053
# Step length: 204.46220784365894
#
# Iteration 1
# Objective: -16.346950086149228
# Steepness: -0.07507855792833903
# Step length: 11.700432388455038
# Total time for steepest-descent scheme: 0.03240323066711426
#
# Solving with alt hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.011522769927978516
#
# Iteration 0
# Objective: 0.0
# Steepness: -0.3848458175993066
# Step length: 53.238512352921944
#
# Iteration 1
# Objective: -20.488618814231025
# Steepness: -0.28835601916583664
# Step length: 6.615784235933553
# Total time for steepest-descent scheme: 0.008829832077026367
#
# Solving with alt hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.023665428161621094
#
# Iteration 0
# Objective: 0.0
# Steepness: -0.3848458175993066
# Step length: 53.238512352921944
#
# Iteration 1
# Objective: -20.488618814231025
# Steepness: -0.28835601916583664
# Step length: 6.615784235933553
# Total time for steepest-descent scheme: 0.012892007827758789
#
#
#
# Working on problem 9 of 76: netlib_lp_subset\bnl1
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 1977.629561522889
# Total solve time: 0.010999917984008789
# Number of iterations: 418.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.633751392364502
#
# Iteration 0
# Objective: 2108.241973450449
# Steepness: -0.7838325324871562
# Step length: 4.856190808556725
#
# Iteration 1
# Objective: 2104.4355331107377
# Steepness: -0.6354513698630138
# Step length: 2.99269911829352
#
# Iteration 50
# Objective: 2043.545568881475
# Steepness: -0.08612423856809902
# Step length: 5.70826107383492
#
# Iteration 100
# Objective: 2022.0571831451566
# Steepness: -0.020279165658631113
# Step length: 1.4363708520740728
#
# Iteration 150
# Objective: 1995.7276129810098
# Steepness: -0.004485204050821907
# Step length: 20.53110302270434
#
# Iteration 200
# Objective: 1977.641840780525
# Steepness: -0.00019217177943730638
# Step length: 64.24983037808491
# Total time for steepest-descent scheme: 2.8127317428588867
#
# Solving with hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.6479263305664062
#
# Iteration 0
# Objective: 2108.241973450449
# Steepness: -0.7838325324871562
# Step length: 4.856190808556725
#
# Iteration 1
# Objective: 2104.4355331107377
# Steepness: -0.6354513698630138
# Step length: 2.99269911829352
#
# Iteration 50
# Objective: 2043.545568881475
# Steepness: -0.08612423856809902
# Step length: 5.70826107383492
#
# Iteration 100
# Objective: 2022.0571831451566
# Steepness: -0.020279165658631113
# Step length: 1.4363708520740728
#
# Iteration 150
# Objective: 1995.7276129810098
# Steepness: -0.004485204050821907
# Step length: 20.53110302270434
#
# Iteration 200
# Objective: 1977.641840780525
# Steepness: -0.00019217177943730638
# Step length: 64.24983037808491
# Total time for steepest-descent scheme: 2.8207037448883057
#
# Solving with hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.6975204944610596
#
# Iteration 0
# Objective: 2108.241973450449
# Steepness: -0.7838325324871562
# Step length: 4.856190808556725
#
# Iteration 1
# Objective: 2104.4355331107377
# Steepness: -0.6354513698630138
# Step length: 2.99269911829352
#
# Iteration 50
# Objective: 2043.545568881475
# Steepness: -0.08612423856809902
# Step length: 5.70826107383492
#
# Iteration 100
# Objective: 2022.0571831451566
# Steepness: -0.020279165658631113
# Step length: 1.4363708520740728
#
# Iteration 150
# Objective: 1995.7276129810098
# Steepness: -0.004485204050821907
# Step length: 20.53110302270434
#
# Iteration 200
# Objective: 1977.641840780525
# Steepness: -0.00019217177943730638
# Step length: 64.24983037808491
# Total time for steepest-descent scheme: 2.84786319732666
#
# Solving with alt hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.6487898826599121
#
# Iteration 0
# Objective: 2108.241973450449
# Steepness: -0.834255982631071
# Step length: 4.562676707102708
#
# Iteration 1
# Objective: 2104.4355331107377
# Steepness: -0.7363166666666666
# Step length: 2.5827403349656404
#
# Iteration 50
# Objective: 2046.9595283631202
# Steepness: -0.14675959223224488
# Step length: 3.5187556191869325
#
# Iteration 100
# Objective: 2017.915815058945
# Steepness: -0.039278187767867616
# Step length: 0.6111300405518976
#
# Iteration 150
# Objective: 1987.2054123872244
# Steepness: -0.006778671423944415
# Step length: 45.16393909596076
# Degenerate step computed. Changing active facets...
# Total time for steepest-descent scheme: 2.8044495582580566
#
# Solving with alt hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.659496545791626
#
# Iteration 0
# Objective: 2108.241973450449
# Steepness: -0.834255982631071
# Step length: 4.562676707102708
#
# Iteration 1
# Objective: 2104.4355331107377
# Steepness: -0.7363166666666666
# Step length: 2.5827403349656404
#
# Iteration 50
# Objective: 2046.9595283631202
# Steepness: -0.14675959223224488
# Step length: 3.5187556191869325
#
# Iteration 100
# Objective: 2017.915815058945
# Steepness: -0.039278187767867616
# Step length: 0.6111300405518976
#
# Iteration 150
# Objective: 1987.2054123872244
# Steepness: -0.006778671423944415
# Step length: 45.16393909596076
# Degenerate step computed. Changing active facets...
# Total time for steepest-descent scheme: 2.8002259731292725
#
#
#
# Working on problem 10 of 76: netlib_lp_subset\boeing1
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -335.2135675071269
# Total solve time: 0.01699995994567871
# Number of iterations: 489.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.1268165111541748
#
# Iteration 0
# Objective: 185.3449154488552
# Steepness: -0.04583250627946371
# Step length: 25.020530715655763
#
# Iteration 1
# Objective: 184.19816181771438
# Steepness: -0.04562063710694408
# Step length: 2.6145797978557512
#
# Iteration 50
# Objective: 139.54470532839713
# Steepness: -0.011809188377272494
# Step length: 18.347500606060603
#
# Iteration 100
# Objective: 44.144078111970586
# Steepness: -0.007734463866938159
# Step length: 16.87172322888511
#
# Iteration 150
# Objective: -181.3181480752378
# Steepness: -0.005574989948692791
# Step length: 205.30346449428785
#
# Iteration 200
# Objective: -282.48169717286777
# Steepness: -0.002848129479120891
# Step length: 282.23204812842454
#
# Iteration 250
# Objective: -322.4790636131133
# Steepness: -0.0013605947055824793
# Step length: 253.98658316440697
#
# Iteration 300
# Objective: -330.6687738769457
# Steepness: -0.0006404787701682962
# Step length: 108.82814413224426
#
# Iteration 350
# Objective: -335.0442400516968
# Steepness: -5.897976000898025e-05
# Step length: 49.10070024957276
# Total time for steepest-descent scheme: 2.883906126022339
#
# Solving with hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.17021775245666504
#
# Iteration 0
# Objective: 185.3449154488552
# Steepness: -0.04583250627946371
# Step length: 25.020530715655763
#
# Iteration 1
# Objective: 184.19816181771438
# Steepness: -0.04562063710694408
# Step length: 2.6145797978557512
#
# Iteration 50
# Objective: 139.54470532839713
# Steepness: -0.011809188377272494
# Step length: 18.347500606060603
#
# Iteration 100
# Objective: 44.144078111970586
# Steepness: -0.007734463866938159
# Step length: 16.87172322888511
#
# Iteration 150
# Objective: -181.3181480752378
# Steepness: -0.005574989948692791
# Step length: 205.30346449428785
#
# Iteration 200
# Objective: -282.48169717286777
# Steepness: -0.002848129479120891
# Step length: 282.23204812842454
#
# Iteration 250
# Objective: -322.4790636131133
# Steepness: -0.0013605947055824793
# Step length: 253.98658316440697
#
# Iteration 300
# Objective: -330.6687738769457
# Steepness: -0.0006404787701682962
# Step length: 108.82814413224426
#
# Iteration 350
# Objective: -335.0442400516968
# Steepness: -5.897976000898025e-05
# Step length: 49.10070024957276
# Total time for steepest-descent scheme: 2.887399435043335
#
# Solving with hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.12640142440795898
#
# Iteration 0
# Objective: 185.3449154488552
# Steepness: -0.04583250627946371
# Step length: 25.020530715655763
#
# Iteration 1
# Objective: 184.19816181771438
# Steepness: -0.04562063710694408
# Step length: 2.6145797978557512
#
# Iteration 50
# Objective: 139.54470532839713
# Steepness: -0.011809188377272494
# Step length: 18.347500606060603
#
# Iteration 100
# Objective: 44.144078111970586
# Steepness: -0.007734463866938159
# Step length: 16.87172322888511
#
# Iteration 150
# Objective: -181.3181480752378
# Steepness: -0.005574989948692791
# Step length: 205.30346449428785
#
# Iteration 200
# Objective: -282.48169717286777
# Steepness: -0.002848129479120891
# Step length: 282.23204812842454
#
# Iteration 250
# Objective: -322.4790636131133
# Steepness: -0.0013605947055824793
# Step length: 253.98658316440697
#
# Iteration 300
# Objective: -330.6687738769457
# Steepness: -0.0006404787701682962
# Step length: 108.82814413224426
#
# Iteration 350
# Objective: -335.0442400516968
# Steepness: -5.897976000898025e-05
# Step length: 49.10070024957276
# Total time for steepest-descent scheme: 2.8998613357543945
#
# Solving with alt hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.15906620025634766
#
# Iteration 0
# Objective: 185.3449154488552
# Steepness: -0.08395087429574756
# Step length: 11.392164163294307
#
# Iteration 1
# Objective: 184.38853330722594
# Steepness: -0.08343918454051315
# Step length: 6.971598637593853
#
# Iteration 50
# Objective: 151.96623567358856
# Steepness: -0.030360443778581145
# Step length: 2.666356685376954
# Total time for steepest-descent scheme: 0.6345694065093994
#
# Solving with alt hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.16969609260559082
#
# Iteration 0
# Objective: 185.3449154488552
# Steepness: -0.08395087429574756
# Step length: 11.392164163294307
#
# Iteration 1
# Objective: 184.38853330722594
# Steepness: -0.08343918454051315
# Step length: 6.971598637593853
#
# Iteration 50
# Objective: 151.96623567358856
# Steepness: -0.030360443778581145
# Step length: 2.666356685376954
# Total time for steepest-descent scheme: 0.7471556663513184
#
#
#
# Working on problem 11 of 76: netlib_lp_subset\boeing2
# Reading netlib_lp_subset\boeing2...
# removing redundant constraint 'LF1013B1'
# removing redundant constraint 'LF1013B2'
# removing redundant constraint 'LF1015B1'
# removing redundant constraint 'LF1017B1'
# removing redundant constraint 'LF1019B1'
# removing redundant constraint 'LF1019B2'
# removing redundant constraint 'LF1004B1'
# removing redundant constraint 'LF1008B1'
# removing redundant constraint 'LF1008B2'
# removing redundant constraint 'LF1010B1'
# removing redundant constraint 'LF1010B2'
# removing redundant constraint 'LF1010B3'
# removing redundant constraint 'LF1012B1'
# removing redundant constraint 'LF1014B1'
# removing redundant constraint 'LF1014B2'
# removing redundant constraint 'LF1100B1'
# removing redundant constraint 'LF1100B2'
# removing redundant constraint 'LF1100B3'
# removing redundant constraint 'LF1100B4'
# removing redundant constraint 'LF1100B5'
# removing redundant constraint 'LF1102B1'
# removing redundant constraint 'LF1102B2'
# removing redundant constraint 'LF1102B3'
# removing redundant constraint 'LF1102B4'
# removing redundant constraint 'LF1200B1'
# removing redundant constraint 'LF1201B1'
# Building polyhedron...
# Problem size: n = 143,  m_B = 352,  m_A = 4
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -315.01872801520284
# Total solve time: 0.002000093460083008
# Number of iterations: 72.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\boeing2...
# removing redundant constraint 'LF1013B1'
# removing redundant constraint 'LF1013B2'
# removing redundant constraint 'LF1015B1'
# removing redundant constraint 'LF1017B1'
# removing redundant constraint 'LF1019B1'
# removing redundant constraint 'LF1019B2'
# removing redundant constraint 'LF1004B1'
# removing redundant constraint 'LF1008B1'
# removing redundant constraint 'LF1008B2'
# removing redundant constraint 'LF1010B1'
# removing redundant constraint 'LF1010B2'
# removing redundant constraint 'LF1010B3'
# removing redundant constraint 'LF1012B1'
# removing redundant constraint 'LF1014B1'
# removing redundant constraint 'LF1014B2'
# removing redundant constraint 'LF1100B1'
# removing redundant constraint 'LF1100B2'
# removing redundant constraint 'LF1100B3'
# removing redundant constraint 'LF1100B4'
# removing redundant constraint 'LF1100B5'
# removing redundant constraint 'LF1102B1'
# removing redundant constraint 'LF1102B2'
# removing redundant constraint 'LF1102B3'
# removing redundant constraint 'LF1102B4'
# removing redundant constraint 'LF1200B1'
# removing redundant constraint 'LF1201B1'
# Building polyhedron...
# Problem size: n = 143,  m_B = 352,  m_A = 4
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.02727675437927246
#
# Iteration 0
# Objective: -210.67368152468885
# Steepness: -0.2182553844586359
# Step length: 189.77319990648823
#
# Iteration 1
# Objective: -252.09270423022505
# Steepness: -0.18371391049959032
# ...
# removing redundant constraint 'BB625'
# removing redundant constraint 'BB641'
# removing redundant constraint 'BB642'
# removing redundant constraint 'BB643'
# removing redundant constraint 'BB644'
# removing redundant constraint 'BB645'
# removing redundant constraint 'BB651'
# removing redundant constraint 'BB652'
# removing redundant constraint 'BB653'
# removing redundant constraint 'BB654'
# removing redundant constraint 'BB655'
# removing redundant constraint 'BB661'
# removing redundant constraint 'BB662'
# removing redundant constraint 'BB663'
# removing redundant constraint 'BB664'
# removing redundant constraint 'BB665'
# removing redundant constraint 'BB671'
# removing redundant constraint 'BB672'
# removing redundant constraint 'BB673'
# removing redundant constraint 'BB674'
# removing redundant constraint 'BB675'
# Building polyhedron...
# Problem size: n = 3678,  m_B = 6411,  m_A = 253
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 7.882047176361084
#
# Iteration 0
# Objective: 32856322.132818617
# Steepness: -641.175149629028
# Step length: 76.52537363399388
#
# Iteration 1
# Objective: 32807255.964928426
# Steepness: -425.13585916570986
# Step length: 31.949427744533757
#
# Iteration 50
# Objective: 30093658.59119859
# Steepness: -153.99039199416424
# Step length: 707.2010738974151
#
# Iteration 100
# Objective: 28579870.42759521
# Steepness: -119.88397964970855
# Step length: 554.6582535296625
#
# Iteration 150
# Objective: 27339468.62048316
# Steepness: -79.0705638779644
# Step length: 0.9113640963276649
#
# Iteration 200
# Objective: 26384897.9552865
# Steepness: -58.666666666666664
# Step length: 282.00000000000017
#
# Iteration 250
# Objective: 25678050.533281334
# Steepness: -58.666666666666664
# Step length: 35.40673286690165
#
# Iteration 300
# Objective: 25437168.35141155
# Steepness: -32.29501974765054
# Step length: 107.46591511778134
#
# Iteration 350
# Objective: 25365491.157584675
# Steepness: -12.328980785735567
# Step length: 255.16314424810633
#
# Iteration 400
# Objective: 25296082.478848033
# Steepness: -5.500405611759259
# Step length: 248.9160454896174
#
# Iteration 450
# Objective: 25276214.568782903
# Steepness: -0.6719805377749887
# Step length: 1060.3974416869762
# Total time for steepest-descent scheme: 32.07662487030029
#
# Solving with alt hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\cre-c...
# removing redundant constraint 'BB013'
# removing redundant constraint 'BB023'
# removing redundant constraint 'BB031'
# removing redundant constraint 'BB032'
# removing redundant constraint 'BB033'
# removing redundant constraint 'BB034'
# removing redundant constraint 'BB035'
# removing redundant constraint 'BB043'
# removing redundant constraint 'BB053'
# removing redundant constraint 'BB063'
# removing redundant constraint 'BB073'
# removing redundant constraint 'BB083'
# removing redundant constraint 'BB093'
# removing redundant constraint 'BB123'
# removing redundant constraint 'BB133'
# removing redundant constraint 'BB141'
# removing redundant constraint 'BB142'
# removing redundant constraint 'BB143'
# removing redundant constraint 'BB144'
# removing redundant constraint 'BB145'
# removing redundant constraint 'BB163'
# removing redundant constraint 'BB173'
# removing redundant constraint 'BB213'
# removing redundant constraint 'BB231'
# removing redundant constraint 'BB232'
# removing redundant constraint 'BB233'
# removing redundant constraint 'BB234'
# removing redundant constraint 'BB235'
# removing redundant constraint 'BB303'
# removing redundant constraint 'BB384'
# removing redundant constraint 'BB414'
# removing redundant constraint 'BB424'
# removing redundant constraint 'BB434'
# removing redundant constraint 'BB444'
# removing redundant constraint 'BB454'
# removing redundant constraint 'BB484'
# removing redundant constraint 'BB551'
# removing redundant constraint 'BB552'
# removing redundant constraint 'BB553'
# removing redundant constraint 'BB554'
# removing redundant constraint 'BB555'
# removing redundant constraint 'BB571'
# removing redundant constraint 'BB572'
# removing redundant constraint 'BB573'
# removing redundant constraint 'BB574'
# removing redundant constraint 'BB575'
# removing redundant constraint 'BB584'
# removing redundant constraint 'BB601'
# removing redundant constraint 'BB602'
# removing redundant constraint 'BB603'
# removing redundant constraint 'BB604'
# removing redundant constraint 'BB605'
# removing redundant constraint 'BB611'
# removing redundant constraint 'BB612'
# removing redundant constraint 'BB613'
# removing redundant constraint 'BB614'
# removing redundant constraint 'BB615'
# removing redundant constraint 'BB621'
# removing redundant constraint 'BB622'
# removing redundant constraint 'BB623'
# removing redundant constraint 'BB624'
# removing redundant constraint 'BB625'
# removing redundant constraint 'BB641'
# removing redundant constraint 'BB642'
# removing redundant constraint 'BB643'
# removing redundant constraint 'BB644'
# removing redundant constraint 'BB645'
# removing redundant constraint 'BB651'
# removing redundant constraint 'BB652'
# removing redundant constraint 'BB653'
# removing redundant constraint 'BB654'
# removing redundant constraint 'BB655'
# removing redundant constraint 'BB661'
# removing redundant constraint 'BB662'
# removing redundant constraint 'BB663'
# removing redundant constraint 'BB664'
# removing redundant constraint 'BB665'
# removing redundant constraint 'BB671'
# removing redundant constraint 'BB672'
# removing redundant constraint 'BB673'
# removing redundant constraint 'BB674'
# removing redundant constraint 'BB675'
# Building polyhedron...
# Problem size: n = 3678,  m_B = 6411,  m_A = 253
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 7.857381343841553
#
# Iteration 0
# Objective: 32856322.132818617
# Steepness: -1032.1460423381989
# Step length: 47.53800903895344
#
# Iteration 1
# Objective: 32807255.964928426
# Steepness: -709.0303038100808
# Step length: 30.058137022175952
#
# Iteration 50
# Objective: 29742913.83430299
# Steepness: -230.0983788652862
# Step length: 188.716550744641
#
# Iteration 100
# Objective: 28406010.878465068
# Steepness: -156.99928102159714
# Step length: 23.426685828084338
#
# Iteration 150
# Objective: 27225355.924276996
# Steepness: -119.72463946133016
# Step length: 6.595946295034787
#
# Iteration 200
# Objective: 26994207.862161517
# Steepness: -91.79634706270255
# Step length: 22.473643292062036
#
# Iteration 250
# Objective: 26346843.071963076
# Steepness: -88.0
# Step length: 638.0000000000002
#
# Iteration 300
# Objective: 25473623.574906282
# Steepness: -77.27809558597116
# Step length: 92.65557567076775
#
# Iteration 350
# Objective: 25396106.384085342
# Steepness: -23.16383435199323
# Step length: 41.45142573371747
#
# Iteration 400
# Objective: 25300069.461953506
# Steepness: -11.105743128595869
# Step length: 39.99860396958375
#
# Iteration 450
# Objective: 25275404.99193652
# Steepness: -1.2679926236742745
# Step length: 51.36721844762146
# Total time for steepest-descent scheme: 27.743664503097534
#
# Solving with alt hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\cre-c...
# removing redundant constraint 'BB013'
# removing redundant constraint 'BB023'
# removing redundant constraint 'BB031'
# removing redundant constraint 'BB032'
# removing redundant constraint 'BB033'
# removing redundant constraint 'BB034'
# removing redundant constraint 'BB035'
# removing redundant constraint 'BB043'
# removing redundant constraint 'BB053'
# removing redundant constraint 'BB063'
# removing redundant constraint 'BB073'
# removing redundant constraint 'BB083'
# removing redundant constraint 'BB093'
# removing redundant constraint 'BB123'
# removing redundant constraint 'BB133'
# removing redundant constraint 'BB141'
# removing redundant constraint 'BB142'
# removing redundant constraint 'BB143'
# removing redundant constraint 'BB144'
# removing redundant constraint 'BB145'
# removing redundant constraint 'BB163'
# removing redundant constraint 'BB173'
# removing redundant constraint 'BB213'
# removing redundant constraint 'BB231'
# removing redundant constraint 'BB232'
# removing redundant constraint 'BB233'
# removing redundant constraint 'BB234'
# removing redundant constraint 'BB235'
# removing redundant constraint 'BB303'
# removing redundant constraint 'BB384'
# removing redundant constraint 'BB414'
# removing redundant constraint 'BB424'
# removing redundant constraint 'BB434'
# removing redundant constraint 'BB444'
# removing redundant constraint 'BB454'
# removing redundant constraint 'BB484'
# removing redundant constraint 'BB551'
# removing redundant constraint 'BB552'
# removing redundant constraint 'BB553'
# removing redundant constraint 'BB554'
# removing redundant constraint 'BB555'
# removing redundant constraint 'BB571'
# removing redundant constraint 'BB572'
# removing redundant constraint 'BB573'
# removing redundant constraint 'BB574'
# removing redundant constraint 'BB575'
# removing redundant constraint 'BB584'
# removing redundant constraint 'BB601'
# removing redundant constraint 'BB602'
# removing redundant constraint 'BB603'
# removing redundant constraint 'BB604'
# removing redundant constraint 'BB605'
# removing redundant constraint 'BB611'
# removing redundant constraint 'BB612'
# removing redundant constraint 'BB613'
# removing redundant constraint 'BB614'
# removing redundant constraint 'BB615'
# removing redundant constraint 'BB621'
# removing redundant constraint 'BB622'
# removing redundant constraint 'BB623'
# removing redundant constraint 'BB624'
# removing redundant constraint 'BB625'
# removing redundant constraint 'BB641'
# removing redundant constraint 'BB642'
# removing redundant constraint 'BB643'
# removing redundant constraint 'BB644'
# removing redundant constraint 'BB645'
# removing redundant constraint 'BB651'
# removing redundant constraint 'BB652'
# removing redundant constraint 'BB653'
# removing redundant constraint 'BB654'
# removing redundant constraint 'BB655'
# removing redundant constraint 'BB661'
# removing redundant constraint 'BB662'
# removing redundant constraint 'BB663'
# removing redundant constraint 'BB664'
# removing redundant constraint 'BB665'
# removing redundant constraint 'BB671'
# removing redundant constraint 'BB672'
# removing redundant constraint 'BB673'
# removing redundant constraint 'BB674'
# removing redundant constraint 'BB675'
# Building polyhedron...
# Problem size: n = 3678,  m_B = 6411,  m_A = 253
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 7.91113018989563
#
# Iteration 0
# Objective: 32856322.132818617
# Steepness: -1032.1460423381989
# Step length: 47.53800903895344
#
# Iteration 1
# Objective: 32807255.964928426
# Steepness: -709.0303038100808
# Step length: 30.058137022175952
#
# Iteration 50
# Objective: 29742913.83430299
# Steepness: -230.0983788652862
# Step length: 188.716550744641
#
# Iteration 100
# Objective: 28406010.878465068
# Steepness: -156.99928102159714
# Step length: 23.426685828084338
#
# Iteration 150
# Objective: 27225355.924276996
# Steepness: -119.72463946133016
# Step length: 6.595946295034787
#
# Iteration 200
# Objective: 26994207.862161517
# Steepness: -91.79634706270255
# Step length: 22.473643292062036
#
# Iteration 250
# Objective: 26346843.071963076
# Steepness: -88.0
# Step length: 638.0000000000002
#
# Iteration 300
# Objective: 25473623.574906282
# Steepness: -77.27809558597116
# Step length: 92.65557567076775
#
# Iteration 350
# Objective: 25396106.384085342
# Steepness: -23.16383435199323
# Step length: 41.45142573371747
#
# Iteration 400
# Objective: 25300069.461953506
# Steepness: -11.105743128595869
# Step length: 39.99860396958375
#
# Iteration 450
# Objective: 25275404.99193652
# Steepness: -1.2679926236742745
# Step length: 51.36721844762146
# Total time for steepest-descent scheme: 28.29122757911682
#
#
#
# Working on problem 76 of 76: netlib_lp_subset\modszk1
# Reading netlib_lp_subset\modszk1...
# removing redundant constraint 'ROW0147'
# Building polyhedron...
# Problem size: n = 1620,  m_B = 1618,  m_A = 686
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 320.6197290648233
# Total solve time: 0.05200004577636719
# Number of iterations: 1233.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\modszk1...
# removing redundant constraint 'ROW0147'
# Building polyhedron...
# Problem size: n = 1620,  m_B = 1618,  m_A = 686
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.1586720943450928
#
# Iteration 0
# Objective: 699998.447478
# Steepness: -0.07001241293244018
# Step length: 3143467.2427973496
#
# Iteration 1
# Objective: 479916.7208356728
# Steepness: -0.06813450045722237
# Step length: 994453.6074015652
#
# Iteration 50
# Objective: 546.1423394468627
# Steepness: -0.01625016448093732
# Step length: 2617.1582900835015
# Total time for steepest-descent scheme: 1.196345567703247
#
# Solving with hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\modszk1...
# removing redundant constraint 'ROW0147'
# Building polyhedron...
# Problem size: n = 1620,  m_B = 1618,  m_A = 686
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.2662017345428467
#
# Iteration 0
# Objective: 699998.447478
# Steepness: -0.07001241293244018
# Step length: 3143467.2427973496
#
# Iteration 1
# Objective: 479916.7208356728
# Steepness: -0.06813450045722237
# Step length: 994453.6074015652
#
# Iteration 50
# Objective: 546.1423394468627
# Steepness: -0.01625016448093732
# Step length: 2617.1582900835015
# Total time for steepest-descent scheme: 1.2065637111663818
#
# Solving with hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\modszk1...
# removing redundant constraint 'ROW0147'
# Building polyhedron...
# Problem size: n = 1620,  m_B = 1618,  m_A = 686
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.2339200973510742
#
# Iteration 0
# Objective: 699998.447478
# Steepness: -0.07001241293244018
# Step length: 3143467.2427973496
#
# Iteration 1
# Objective: 479916.7208356728
# Steepness: -0.06813450045722237
# Step length: 994453.6074015652
#
# Iteration 50
# Objective: 546.1423394468627
# Steepness: -0.01625016448093732
# Step length: 2617.1582900835015
# Total time for steepest-descent scheme: 1.2386653423309326
#
# Solving with alt hybrid steepest descent with init active inds...
# Reading netlib_lp_subset\modszk1...
# removing redundant constraint 'ROW0147'
# Building polyhedron...
# Problem size: n = 1620,  m_B = 1618,  m_A = 686
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.225731372833252
#
# Iteration 0
# Objective: 699998.447478
# Steepness: -0.6967017914293044
# Step length: 362332.074856989
#
# Iteration 1
# Objective: 447561.0418328388
# Steepness: -0.6718624717182093
# Step length: 305729.23112444277
#
# Iteration 50
# Objective: 11515.785480467177
# Steepness: -0.04870901421853333
# Step length: 16995.28868063986
# Total time for steepest-descent scheme: 1.8110618591308594
#
# Solving with alt hybrid steepest descent with updated active inds...
# Reading netlib_lp_subset\modszk1...
# removing redundant constraint 'ROW0147'
# Building polyhedron...
# Problem size: n = 1620,  m_B = 1618,  m_A = 686
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# added alt constraints
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.2464005947113037
#
# Iteration 0
# Objective: 699998.447478
# Steepness: -0.6967017914293044
# Step length: 362332.074856989
#
# Iteration 1
# Objective: 447561.0418328388
# Steepness: -0.6718624717182093
# Step length: 305729.23112444277
#
# Iteration 50
# Objective: 11515.785480467177
# Steepness: -0.04870901421853333
# Step length: 16995.28868063986
# Total time for steepest-descent scheme: 1.8418571949005127

# %%
### note to self, look at alt_steepest_descent for cycle and israel problem. Figure out why this is getting stuck/having a crazy number of iterations

# %% [markdown]
# ## View Results

# %%
results_dir = 'results'
problems = ['adlittle', 'afiro', 'agg2','agg3','agg', 'bandm',
 'beaconfd', 'blend', 'bnl1', 'boeing1', 'boeing2', 'bore3d', 'brandy', 'capri',
 'cycle', 'degen2', 'degen3', 'e226', 'etamacro', 'fffff800', 'finnis',
 'fit1d', 'fit1p', 'forplan', 'ganges', 'gfrd-pnc', 'grow15', 'grow22', 'grow7',
 'israel', 'kb2', 'ken-07', 'lotfi', 'maros', 'pds-02', 'perold',
 'pilotnov', 'qap08', 'recipe', 'sc105', 'sc205', 'sc50a',
 'sc50b', 'scagr25', 'scagr7', 'scfxm1', 'scfxm2', 'scfxm3', 'scorpion', 'scrs8',
 'scsd1', 'scsd6', 'scsd8', 'sctap1', 'sctap2', 'sctap3', 'seba', 'share1b',
 'share2b', 'shell', 'ship04l', 'ship04s', 'ship08l', 'ship08s', 'ship12l', 'ship12s',
 'sierra', 'stair', 'standata', 'standgub', 'standmps', 'stocfor1', 'stocfor2', 'tuff',
 'vtp_base', 'wood1p', 'cre-c', 'modszk1']
 # 'pilot4',

avgs = {'lp_time': [], 
        'old_sd_time': [], 'old_avg_sd': [],
        # 'alt_sd_time': [], 'avg_alt_sd': [],
        'alt_hybrid_up_act_sd_time': [], 'alt_hybrid_up_act_avg_sd': [], 
        'alt_hybrid_init_act_sd_time': [],'alt_hybrid_init_act_avg_sd': [],
        'reg_hybrid_up_act_sd_time': [], 'reg_hybrid_up_act_avg_sd': [], 
        'reg_hybrid_init_act_sd_time': [],'reg_hybrid_init_act_avg_sd': [],
        'lp_iters': [], 'old_sd_iters': [],
        # 'alt_sd_iters': [],
        'alt_hybrid_up_act_sd_iters': [], 'alt_hybrid_init_act_sd_iters': [],
       'reg_hybrid_up_act_sd_iters': [], 'reg_hybrid_init_act_sd_iters': []}
from statistics import median

figure_dir = 'figures'
if not os.path.exists(figure_dir): os.mkdir(figure_dir)
for problem in problems:
    lp_fn = os.path.join(results_dir, problem + '_lp.p')
    old_sd_fn = os.path.join(results_dir, problem + '_old_sd.p')
    if not os.path.exists(old_sd_fn): continue
    # alt_sd_fn = os.path.join(results_dir, problem + '_alt_sd.p')
    # if not os.path.exists(alt_sd_fn): continue
    alt_hybrid_up_act_sd_fn = os.path.join(results_dir, problem + '_alt_hybrid_up_act_sd.p')
    if not os.path.exists(alt_hybrid_up_act_sd_fn): continue
    alt_hybrid_init_act_sd_fn = os.path.join(results_dir, problem + '_alt_hybrid_init_act_sd.p')
    if not os.path.exists(alt_hybrid_init_act_sd_fn): continue
    reg_hybrid_up_act_sd_fn = os.path.join(results_dir, problem + '_reg_hybrid_up_act_sd.p')
    if not os.path.exists(reg_hybrid_up_act_sd_fn): continue
    reg_hybrid_init_act_sd_fn = os.path.join(results_dir, problem + '_reg_hybrid_init_act_sd.p')
    if not os.path.exists(reg_hybrid_init_act_sd_fn): continue
    
    
    with open(lp_fn, 'rb') as f:
        lp_results = pickle.load(f)
    with open(old_sd_fn, 'rb') as f:
        old_sd_results = pickle.load(f)
    # with open(alt_sd_fn, 'rb') as f:
    #     alt_sd_results = pickle.load(f)
    with open(alt_hybrid_up_act_sd_fn, 'rb') as f:
        alt_hybrid_up_act_sd_result = pickle.load(f)
    with open(alt_hybrid_init_act_sd_fn, 'rb') as f:
        alt_hybrid_init_act_sd_result = pickle.load(f)
    with open(reg_hybrid_up_act_sd_fn, 'rb') as f:
        reg_hybrid_up_act_sd_result = pickle.load(f)
    with open(reg_hybrid_init_act_sd_fn, 'rb') as f:
        reg_hybrid_init_act_sd_result = pickle.load(f)
        
    try: 
        avgs['old_avg_sd'].append(avg(old_sd_results['solve_times'][1:]))
        # avgs['alt_avg_sd'].append(avg(alt_sd_results['solve_times'][1:]))
        avgs['alt_hybrid_up_act_avg_sd'].append(avg(alt_hybrid_up_act_sd_result['solve_times'][1:]))
        avgs['alt_hybrid_init_act_avg_sd'].append(avg(alt_hybrid_init_act_sd_result['solve_times'][1:]))
        avgs['reg_hybrid_up_act_avg_sd'].append(avg(reg_hybrid_up_act_sd_result['solve_times'][1:]))
        avgs['reg_hybrid_init_act_avg_sd'].append(avg(reg_hybrid_init_act_sd_result['solve_times'][1:]))
        avgs['lp_time'].append(lp_results['solve_time_total'])
        avgs['old_sd_time'].append(old_sd_results['solve_time_total'])
        # avgs['alt_sd_time'].append(alt_sd_results['solve_time_total'])
        avgs['alt_hybrid_up_act_sd_time'].append(alt_hybrid_up_act_sd_result['solve_time_total'])
        avgs['alt_hybrid_init_act_sd_time'].append(alt_hybrid_init_act_sd_result['solve_time_total'])
        avgs['reg_hybrid_up_act_sd_time'].append(reg_hybrid_up_act_sd_result['solve_time_total'])
        avgs['reg_hybrid_init_act_sd_time'].append(reg_hybrid_init_act_sd_result['solve_time_total'])
        avgs['lp_iters'].append(lp_results['n_iters'])
        avgs['old_sd_iters'].append(old_sd_results['n_iters'])
        # avgs['alt_sd_iters'].append(alt_sd_results['n_iters'])
        avgs['alt_hybrid_up_act_sd_iters'].append(alt_hybrid_up_act_sd_result['n_iters'])
        avgs['alt_hybrid_init_act_sd_iters'].append(alt_hybrid_init_act_sd_result['n_iters'])
        avgs['reg_hybrid_up_act_sd_iters'].append(reg_hybrid_up_act_sd_result['n_iters'])
        avgs['reg_hybrid_init_act_sd_iters'].append(reg_hybrid_init_act_sd_result['n_iters'])
    except KeyError:
        print('skipping {}'.format(problem))
        continue
        
for metric in avgs:
    print(metric)
    print('Average {}: {}'.format(metric, avg(avgs[metric])))
    print('Median {}: {}'.format(metric, median(avgs[metric])))
# Out:
# lp_time
# Average lp_time: 0.01693420033705862
# Median lp_time: 0.003000020980834961
# old_sd_time
# Average old_sd_time: 4.802901929930637
# Median old_sd_time: 1.0351659059524536
# old_avg_sd
# Average old_avg_sd: 0.0028250303658362377
# Median old_avg_sd: 0.0015646849359784807
# alt_hybrid_up_act_sd_time
# Average alt_hybrid_up_act_sd_time: 3.9560107808364067
# Median alt_hybrid_up_act_sd_time: 0.8576550483703613
# alt_hybrid_up_act_avg_sd
# Average alt_hybrid_up_act_avg_sd: 0.009792192923526755
# Median alt_hybrid_up_act_avg_sd: 0.0018722641652155108
# alt_hybrid_init_act_sd_time
# Average alt_hybrid_init_act_sd_time: 4.027691354877071
# Median alt_hybrid_init_act_sd_time: 0.8948072195053101
# alt_hybrid_init_act_avg_sd
# Average alt_hybrid_init_act_avg_sd: 0.009743856451581828
# Median alt_hybrid_init_act_avg_sd: 0.0019452789398364241
# reg_hybrid_up_act_sd_time
# Average reg_hybrid_up_act_sd_time: 4.410045153216312
# Median reg_hybrid_up_act_sd_time: 1.0990147590637207
# reg_hybrid_up_act_avg_sd
# Average reg_hybrid_up_act_avg_sd: 0.01033631835824221
# Median reg_hybrid_up_act_avg_sd: 0.0016336965381650997
# reg_hybrid_init_act_sd_time
# Average reg_hybrid_init_act_sd_time: 4.340113172405644
# Median reg_hybrid_init_act_sd_time: 1.0642457008361816
# reg_hybrid_init_act_avg_sd
# Average reg_hybrid_init_act_avg_sd: 0.010083655122143752
# Median reg_hybrid_init_act_avg_sd: 0.0017916718999288054
# lp_iters
# Average lp_iters: 457.32894736842104
# Median lp_iters: 284.0
# old_sd_iters
# Average old_sd_iters: 212.31578947368422
# Median old_sd_iters: 114.5
# alt_hybrid_up_act_sd_iters
# Average alt_hybrid_up_act_sd_iters: 165.35526315789474
# Median alt_hybrid_up_act_sd_iters: 86.5
# alt_hybrid_init_act_sd_iters
# Average alt_hybrid_init_act_sd_iters: 165.35526315789474
# Median alt_hybrid_init_act_sd_iters: 86.5
# reg_hybrid_up_act_sd_iters
# Average reg_hybrid_up_act_sd_iters: 192.28947368421052
# Median reg_hybrid_up_act_sd_iters: 108.0
# reg_hybrid_init_act_sd_iters
# Average reg_hybrid_init_act_sd_iters: 192.28947368421052
# Median reg_hybrid_init_act_sd_iters: 108.0
