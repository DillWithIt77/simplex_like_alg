# %% [markdown]
# # Active Ind Testing

# %%
import numpy as np
import gurobipy as gp
import math
import sympy
import contextlib
import time
import os
from utils import result, METHODS, INF, EPS
from mps_reader_preprocessor import read_mps_preprocess
from polyhedral_model import PolyhedralModel
from polyhedron import Polyhedron

# %% [markdown]
# ## Read in Polyhedron P

# %%
problem_dir = 'netlib_lp_subset'
# problem = 'kb2'
# problem = 'adlittle'
# problem = 'angela_test_prob'
# problem = 'network_ex'
# problem = 'gfrd-pnc'
# problem = 'modszk1'
# problem = 'cycle'
# problem = 'cre-c'
problem = 'qap08'
mps_fn=os.path.join(problem_dir, problem)
results_dir='results'
max_time=300
sd_method='dual_simplex'
reset=False,
partition_polytope=False
n=0
k=0
spindle=False
spindle_dim=0
n_cone_facets=0
n_parallel_facets=0

# %% [markdown]
# ## Perform SDCA

# %%
### Build Initial Polyhedron from file
print(f'Reading {mps_fn}...')
c, B, d, A, b = read_mps_preprocess(mps_fn)
print('Building polyhedron...')
P = Polyhedron(B, d, A, b, c)
rank_A = np.linalg.matrix_rank(A)

print('Finding feasible solution...')
x_feasible, vbasis, cbasis = P.find_feasible_solution(verbose=False)

x = x_feasible
c=None
verbose=False
method='dual_simplex'
reset=False
max_time=300
first_warm_start=None
save_first_steps=0
problem_name=''

if c is not None:
    P.set_objective(c)

t0 = time.time()
x_current = x
if save_first_steps:
    np.save('solutions/{}_0.npy'.format(problem_name), x_current)      
active_inds = P.get_active_constraints(x_current)
    
pm = P.build_polyhedral_model(active_inds=active_inds, method=method)

if first_warm_start is not None:
    print('Using custom warm start')
    pm.set_solution(first_warm_start)
t1 = time.time()
build_time = t1 - t0
print('Polyhedral model build time: {}'.format(build_time))
    
sub_times = {'sd': [], 'step': [], 'solve': [], 'phase_times': []}
active_inds_it = []
descent_circuits = []
obj_values = []
step_sizes = []
iter_times = []
simplex_iters = []
iteration = 0
active_inds_it.append(active_inds)
obj_value = P.c.dot(x_current)
obj_values.append(obj_value)
t2 = time.time()
iter_times.append(t2 - t1)


# compute steepest-descent direction
descent_direction, y_pos, y_neg, steepness, num_steps, solve_time, phase_times = pm.compute_sd_direction(verbose=verbose)
# orig_test_dir = descent_direction
# print(descent_direction)
# print(np.count_nonzero(np.array(descent_direction)))
simplex_iters.append(num_steps)
sub_times['solve'].append(solve_time)
sub_times['phase_times'].append(phase_times)
    
t3 = time.time()
sub_times['sd'].append(t3 - t2)
restrict_switches = []
restrict_switches.append(False)
init_inds = None
while abs(steepness) > EPS:
        
    t3 = time.time()
    if reset:
        pm.reset()
        
    # take maximal step
    x_current, alpha, active_inds = P.take_maximal_step(descent_direction, y_pos, y_neg)

        # -math.floor(P.n/10)
    if len(active_inds) < (P.n - rank_A):
        restrict_switches.append(True)
    else:
        restrict_switches.append(False)
    
    if iteration % 50 == 0 or iteration == 1:
        print('\nIteration {}'.format(iteration))
        print('Objective: {}'.format(obj_value))
        print('Steepness: {}'.format(steepness))
        print('Step length: {}'.format(alpha))
        
    t4 = time.time()
    active_inds_it.append(active_inds)
    obj_value = P.c.dot(x_current)
    obj_values.append(obj_value)
    iter_times.append(t4 - t1)
    sub_times['step'].append(t4 - t3) 
    descent_circuits.append(descent_direction)
    step_sizes.append(alpha)     
                
    if math.isinf(alpha):
        # problem is unbounded
        result(status=1, circuits=descent_circuits, steps=step_sizes)
        
    # compute steepest-descent direction
    print(f'Number of Active Inds for Iteration {iteration}: {len(active_inds)}')
    print(f'Switch to Facet Restriction for Iteration {iteration}: {restrict_switches[-1]}')
    
    if restrict_switches[-1] and not restrict_switches[-2]:
        init_inds = active_inds

    if restrict_switches[-1]:
        print('using init_inds')
        pm.set_active_inds(active_inds, init = init_inds, simp_switch = restrict_switches[-1])
    else:
        print('using active_inds')
        pm.set_active_inds(active_inds, simp_switch = restrict_switches[-1])

    print('---------------------------------------------------------------')

    descent_direction, y_pos, y_neg, steepness, num_steps, solve_time, phase_times = pm.compute_sd_direction(verbose=verbose)
        
    t5 = time.time()
    sub_times['sd'].append(t5 - t4)
    sub_times['solve'].append(solve_time)
    sub_times['phase_times'].append(phase_times)
    simplex_iters.append(num_steps)
        
    iteration += 1
    current_time = t5 - t1
    if current_time > max_time:
        result(status=2)
    if iteration <= save_first_steps:
        np.save('solutions/{}_{}.npy'.format(problem_name, iteration), x_current)

t6 = time.time()
total_time = t6 - t1 
print(f'final iteration steepness: {steepness}')
print('Total time for steepest-descent scheme: {}'.format(total_time))
# Out:
# Reading netlib_lp_subset\qap08...
# Building polyhedron...
# Problem size: n = 1632,  m_B = 1632,  m_A = 912
# Finding feasible solution...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-01
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 2.7766122817993164
#
# Iteration 0
# Objective: 303.6065924991011
# Steepness: -7.500000000000017
# Step length: 0.42444896301039126
# Number of Active Inds for Iteration 0: 878
# Switch to Facet Restriction for Iteration 0: False
# using active_inds
# ---------------------------------------------------------------
#
# Iteration 1
# Objective: 300.4232252765232
# Steepness: -7.161270236647989
# Step length: 0.33806047545422946
# Number of Active Inds for Iteration 1: 748
# Switch to Facet Restriction for Iteration 1: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 2: 727
# Switch to Facet Restriction for Iteration 2: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 3: 660
# Switch to Facet Restriction for Iteration 3: True
# initial inds for switch: [66, 68, 70, 71, 72, 75, 76, 79, 81, 83, 84, 87, 88, 89, 90, 94, 99, 100, 102, 103, 107, 108, 111, 114, 116, 118, 119, 122, 123, 124, 125, 128, 129, 132, 135, 137, 138, 140, 142, 143, 145, 148, 151, 156, 159, 161, 163, 171, 172, 173, 175, 177, 180, 181, 182, 183, 184, 185, 188, 190, 192, 194, 195, 197, 198, 201, 203, 205, 206, 207, 209, 215, 219, 222, 223, 225, 226, 228, 233, 234, 235, 236, 239, 240, 243, 244, 245, 246, 248, 249, 251, 252, 253, 254, 256, 257, 258, 261, 262, 264, 267, 271, 274, 278, 279, 283, 286, 288, 292, 294, 303, 305, 308, 311, 312, 316, 317, 318, 319, 324, 327, 329, 330, 332, 334, 337, 338, 341, 342, 345, 350, 352, 353, 
 1544, 1545, 1546, 1547, 1548, 1549, 1550, 1553, 1557, 1558, 1561, 1567, 1568, 1572, 1574, 1578, 1582, 1584, 1588, 1589, 1592, 1593, 1594, 1596, 1599, 1600, 1601, 1606, 1607, 1609, 1612, 1613, 1614, 1618, 1619, 1622, 1623, 1626, 1627, 1629]
# using init_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 4: 661
# Switch to Facet Restriction for Iteration 4: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 5: 662
# Switch to Facet Restriction for Iteration 5: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 6: 663
# Switch to Facet Restriction for Iteration 6: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 7: 664
# Switch to Facet Restriction for Iteration 7: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 8: 665
# Switch to Facet Restriction for Iteration 8: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 9: 666
# Switch to Facet Restriction for Iteration 9: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 10: 667
# Switch to Facet Restriction for Iteration 10: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 11: 668
# Switch to Facet Restriction for Iteration 11: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 12: 669
# Switch to Facet Restriction for Iteration 12: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 13: 670
# Switch to Facet Restriction for Iteration 13: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 14: 671
# Switch to Facet Restriction for Iteration 14: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 15: 672
# Switch to Facet Restriction for Iteration 15: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 16: 673
# Switch to Facet Restriction for Iteration 16: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 17: 674
# Switch to Facet Restriction for Iteration 17: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1180
#  B_g_i: 0.008032536858159193
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 18: 675
# Switch to Facet Restriction for Iteration 18: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 95
#  B_g_i: 0.01637010676156618
# active ind: True
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1180
#  B_g_i: 0.008032536858159193
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 19: 676
# Switch to Facet Restriction for Iteration 19: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 95
#  B_g_i: 0.01637010676156618
# active ind: True
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 646
#  B_g_i: 0.001118454499235224
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1180
#  B_g_i: 0.008032536858159193
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 20: 677
# Switch to Facet Restriction for Iteration 20: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 95
#  B_g_i: 0.01637010676156618
# active ind: True
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 646
#  B_g_i: 0.001118454499235224
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1180
#  B_g_i: 0.008032536858159193
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1443
#  B_g_i: 0.008845958312148981
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 21: 678
# Switch to Facet Restriction for Iteration 21: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 95
#  B_g_i: 0.01637010676156618
# active ind: True
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 646
#  B_g_i: 0.001118454499235224
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1180
#  B_g_i: 0.008032536858159193
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1389
#  B_g_i: 0.0012201321809867521
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1443
#  B_g_i: 0.008845958312148981
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 22: 679
# Switch to Facet Restriction for Iteration 22: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 95
#  B_g_i: 0.01637010676156618
# active ind: True
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 646
#  B_g_i: 0.001118454499235224
# active ind: True
# i in init_inds: False
# i: 659
#  B_g_i: 0.011387900355872425
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1180
#  B_g_i: 0.008032536858159193
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1389
#  B_g_i: 0.0012201321809867521
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1443
#  B_g_i: 0.008845958312148981
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 23: 680
# Switch to Facet Restriction for Iteration 23: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 95
#  B_g_i: 0.01637010676156618
# active ind: True
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 241
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 646
#  B_g_i: 0.001118454499235224
# active ind: True
# i in init_inds: False
# i: 659
#  B_g_i: 0.011387900355872425
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1180
#  B_g_i: 0.008032536858159193
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1389
#  B_g_i: 0.0012201321809867521
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1443
#  B_g_i: 0.008845958312148981
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# Number of Active Inds for Iteration 24: 681
# Switch to Facet Restriction for Iteration 24: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 95
#  B_g_i: 0.01637010676156618
# active ind: True
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 241
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 646
#  B_g_i: 0.001118454499235224
# active ind: True
# i in init_inds: False
# i: 659
#  B_g_i: 0.011387900355872425
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1180
#  B_g_i: 0.008032536858159193
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1389
#  B_g_i: 0.0012201321809867521
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1443
#  B_g_i: 0.008845958312148981
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# i in init_inds: False
# i: 1610
#  B_g_i: 0.007981698017281524
# active ind: True
# Number of Active Inds for Iteration 25: 682
# Switch to Facet Restriction for Iteration 25: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 95
#  B_g_i: 0.01637010676156618
# active ind: True
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 241
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 646
#  B_g_i: 0.001118454499235224
# active ind: True
# i in init_inds: False
# i: 659
#  B_g_i: 0.011387900355872425
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1180
#  B_g_i: 0.008032536858159193
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1389
#  B_g_i: 0.0012201321809867521
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1443
#  B_g_i: 0.008845958312148981
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# i in init_inds: False
# i: 1474
#  B_g_i: 0.007473309608538021
# active ind: True
# i in init_inds: False
# i: 1610
#  B_g_i: 0.007981698017281524
# active ind: True
# Number of Active Inds for Iteration 26: 683
# Switch to Facet Restriction for Iteration 26: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 65
#  B_g_i: 0.007778342653787395
# active ind: True
# i in init_inds: False
# i: 95
#  B_g_i: 0.01637010676156618
# active ind: True
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 241
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 646
#  B_g_i: 0.001118454499235224
# active ind: True
# i in init_inds: False
# i: 659
#  B_g_i: 0.011387900355872425
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1180
#  B_g_i: 0.008032536858159193
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1389
#  B_g_i: 0.0012201321809867521
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1443
#  B_g_i: 0.008845958312148981
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# i in init_inds: False
# i: 1474
#  B_g_i: 0.007473309608538021
# active ind: True
# i in init_inds: False
# i: 1610
#  B_g_i: 0.007981698017281524
# active ind: True
# Number of Active Inds for Iteration 27: 684
# Switch to Facet Restriction for Iteration 27: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 65
#  B_g_i: 0.007778342653787395
# active ind: True
# i in init_inds: False
# i: 95
#  B_g_i: 0.01637010676156618
# active ind: True
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 241
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 646
#  B_g_i: 0.001118454499235224
# active ind: True
# i in init_inds: False
# i: 659
#  B_g_i: 0.011387900355872425
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1180
#  B_g_i: 0.008032536858159193
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1389
#  B_g_i: 0.0012201321809867521
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1443
#  B_g_i: 0.008845958312148981
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# i in init_inds: False
# i: 1474
#  B_g_i: 0.007473309608538021
# active ind: True
# i in init_inds: False
# i: 1610
#  B_g_i: 0.007981698017281524
# active ind: True
# i in init_inds: False
# i: 1625
#  B_g_i: 0.010879511947126856
# active ind: True
# Number of Active Inds for Iteration 28: 685
# Switch to Facet Restriction for Iteration 28: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 65
#  B_g_i: 0.007778342653787395
# active ind: True
# i in init_inds: False
# i: 95
#  B_g_i: 0.01637010676156618
# active ind: True
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 241
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 556
#  B_g_i: 0.007778342653787395
# active ind: True
# i in init_inds: False
# i: 646
#  B_g_i: 0.001118454499235224
# active ind: True
# i in init_inds: False
# i: 659
#  B_g_i: 0.011387900355872425
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1180
#  B_g_i: 0.008032536858159193
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1389
#  B_g_i: 0.0012201321809867521
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1443
#  B_g_i: 0.008845958312148981
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# i in init_inds: False
# i: 1474
#  B_g_i: 0.007473309608538021
# active ind: True
# i in init_inds: False
# i: 1610
#  B_g_i: 0.007981698017281524
# active ind: True
# i in init_inds: False
# i: 1625
#  B_g_i: 0.010879511947126856
# active ind: True
# Number of Active Inds for Iteration 29: 686
# Switch to Facet Restriction for Iteration 29: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 65
#  B_g_i: 0.007778342653787395
# active ind: True
# i in init_inds: False
# i: 95
#  B_g_i: 0.01637010676156618
# active ind: True
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 241
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 556
#  B_g_i: 0.007778342653787395
# active ind: True
# i in init_inds: False
# i: 646
#  B_g_i: 0.001118454499235224
# active ind: True
# i in init_inds: False
# i: 659
#  B_g_i: 0.011387900355872425
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1008
#  B_g_i: 0.0033553634977125683
# active ind: True
# i in init_inds: False
# i: 1180
#  B_g_i: 0.008032536858159193
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1389
#  B_g_i: 0.0012201321809867521
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1443
#  B_g_i: 0.008845958312148981
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# i in init_inds: False
# i: 1474
#  B_g_i: 0.007473309608538021
# active ind: True
# i in init_inds: False
# i: 1610
#  B_g_i: 0.007981698017281524
# active ind: True
# i in init_inds: False
# i: 1625
#  B_g_i: 0.010879511947126856
# active ind: True
# Number of Active Inds for Iteration 30: 687
# Switch to Facet Restriction for Iteration 30: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 65
#  B_g_i: 0.007778342653787395
# active ind: True
# i in init_inds: False
# i: 95
#  B_g_i: 0.01637010676156618
# active ind: True
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 241
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 556
#  B_g_i: 0.007778342653787395
# active ind: True
# i in init_inds: False
# i: 646
#  B_g_i: 0.001118454499235224
# active ind: True
# i in init_inds: False
# i: 659
#  B_g_i: 0.011387900355872425
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1008
#  B_g_i: 0.0033553634977125683
# active ind: True
# i in init_inds: False
# i: 1180
#  B_g_i: 0.008032536858159193
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1389
#  B_g_i: 0.0012201321809867521
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1443
#  B_g_i: 0.008845958312148981
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# i in init_inds: False
# i: 1474
#  B_g_i: 0.007473309608538021
# active ind: True
# i in init_inds: False
# i: 1533
#  B_g_i: 0.0021860701576012723
# active ind: True
# i in init_inds: False
# i: 1610
#  B_g_i: 0.007981698017281524
# active ind: True
# i in init_inds: False
# i: 1625
#  B_g_i: 0.010879511947126856
# active ind: True
# Number of Active Inds for Iteration 31: 688
# Switch to Facet Restriction for Iteration 31: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 65
#  B_g_i: 0.007778342653787395
# active ind: True
# i in init_inds: False
# i: 95
#  B_g_i: 0.01637010676156618
# active ind: True
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 241
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 556
#  B_g_i: 0.007778342653787395
# active ind: True
# i in init_inds: False
# i: 646
#  B_g_i: 0.001118454499235224
# active ind: True
# i in init_inds: False
# i: 659
#  B_g_i: 0.011387900355872425
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1008
#  B_g_i: 0.0033553634977125683
# active ind: True
# i in init_inds: False
# i: 1180
#  B_g_i: 0.008032536858159193
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1389
#  B_g_i: 0.0012201321809867521
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1443
#  B_g_i: 0.008845958312148981
# active ind: True
# i in init_inds: False
# i: 1453
#  B_g_i: 0.004219623792575838
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# i in init_inds: False
# i: 1474
#  B_g_i: 0.007473309608538021
# active ind: True
# i in init_inds: False
# i: 1533
#  B_g_i: 0.0021860701576012723
# active ind: True
# i in init_inds: False
# i: 1610
#  B_g_i: 0.007981698017281524
# active ind: True
# i in init_inds: False
# i: 1625
#  B_g_i: 0.010879511947126856
# active ind: True
# Number of Active Inds for Iteration 32: 689
# Switch to Facet Restriction for Iteration 32: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 65
#  B_g_i: 0.007778342653787395
# active ind: True
# i in init_inds: False
# i: 95
#  B_g_i: 0.01637010676156618
# active ind: True
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 224
#  B_g_i: 0.002796136248093381
# active ind: True
# i in init_inds: False
# i: 241
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 556
#  B_g_i: 0.007778342653787395
# active ind: True
# i in init_inds: False
# i: 646
#  B_g_i: 0.001118454499235224
# active ind: True
# i in init_inds: False
# i: 659
#  B_g_i: 0.011387900355872425
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1008
#  B_g_i: 0.0033553634977125683
# active ind: True
# i in init_inds: False
# i: 1180
#  B_g_i: 0.008032536858159193
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1389
#  B_g_i: 0.0012201321809867521
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1443
#  B_g_i: 0.008845958312148981
# active ind: True
# i in init_inds: False
# i: 1453
#  B_g_i: 0.004219623792575838
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# i in init_inds: False
# i: 1474
#  B_g_i: 0.007473309608538021
# active ind: True
# i in init_inds: False
# i: 1533
#  B_g_i: 0.0021860701576012723
# active ind: True
# i in init_inds: False
# i: 1610
#  B_g_i: 0.007981698017281524
# active ind: True
# i in init_inds: False
# i: 1625
#  B_g_i: 0.010879511947126856
# active ind: True
# Number of Active Inds for Iteration 33: 690
# Switch to Facet Restriction for Iteration 33: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 65
#  B_g_i: 0.007778342653787395
# active ind: True
# i in init_inds: False
# i: 95
#  B_g_i: 0.01637010676156618
# active ind: True
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 224
#  B_g_i: 0.002796136248093381
# active ind: True
# i in init_inds: False
# i: 241
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 556
#  B_g_i: 0.007778342653787395
# active ind: True
# i in init_inds: False
# i: 646
#  B_g_i: 0.001118454499235224
# active ind: True
# i in init_inds: False
# i: 659
#  B_g_i: 0.011387900355872425
# active ind: True
# i in init_inds: False
# i: 826
#  B_g_i: 0.005643111337061513
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1008
#  B_g_i: 0.0033553634977125683
# active ind: True
# i in init_inds: False
# i: 1180
#  B_g_i: 0.008032536858159193
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1389
#  B_g_i: 0.0012201321809867521
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1443
#  B_g_i: 0.008845958312148981
# active ind: True
# i in init_inds: False
# i: 1453
#  B_g_i: 0.004219623792575838
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# i in init_inds: False
# i: 1474
#  B_g_i: 0.007473309608538021
# active ind: True
# i in init_inds: False
# i: 1533
#  B_g_i: 0.0021860701576012723
# active ind: True
# i in init_inds: False
# i: 1610
#  B_g_i: 0.007981698017281524
# active ind: True
# i in init_inds: False
# i: 1625
#  B_g_i: 0.010879511947126856
# active ind: True
# Number of Active Inds for Iteration 34: 691
# Switch to Facet Restriction for Iteration 34: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i: 65
#  B_g_i: 0.007778342653787395
# active ind: True
# i in init_inds: False
# i: 95
#  B_g_i: 0.01637010676156618
# active ind: True
# i in init_inds: False
# i: 214
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 224
#  B_g_i: 0.002796136248093381
# active ind: True
# i in init_inds: False
# i: 241
#  B_g_i: 0.01138790035587087
# active ind: True
# i in init_inds: False
# i: 441
#  B_g_i: 0.007320793085918377
# active ind: True
# i in init_inds: False
# i: 556
#  B_g_i: 0.007778342653787395
# active ind: True
# i in init_inds: False
# i: 646
#  B_g_i: 0.001118454499235224
# active ind: True
# i in init_inds: False
# i: 659
#  B_g_i: 0.011387900355872425
# active ind: True
# i in init_inds: False
# i: 826
#  B_g_i: 0.005643111337061513
# active ind: True
# i in init_inds: False
# i: 950
#  B_g_i: 0.0005592272496184442
# active ind: True
# i in init_inds: False
# i: 963
#  B_g_i: 0.007066598881544915
# active ind: True
# i in init_inds: False
# i: 1008
#  B_g_i: 0.0033553634977125683
# active ind: True
# i in init_inds: False
# i: 1180
#  B_g_i: 0.008032536858159193
# active ind: True
# i in init_inds: False
# i: 1297
#  B_g_i: 0.007778342653786262
# active ind: True
# i in init_inds: False
# i: 1301
#  B_g_i: 0.009405185561767379
# active ind: True
# i in init_inds: False
# i: 1306
#  B_g_i: 0.0064056939501780435
# active ind: True
# i in init_inds: False
# i: 1313
#  B_g_i: 0.006202338586674196
# active ind: True
# i in init_inds: False
# i: 1362
#  B_g_i: 0.014234875444832974
# active ind: True
# i in init_inds: False
# i: 1379
#  B_g_i: 0.012760549059476647
# active ind: True
# i in init_inds: False
# i: 1389
#  B_g_i: 0.0012201321809867521
# active ind: True
# i in init_inds: False
# i: 1394
#  B_g_i: 0.008490086426027377
# active ind: True
# i in init_inds: False
# i: 1425
#  B_g_i: 0.003101169293340614
# active ind: True
# i in init_inds: False
# i: 1435
#  B_g_i: 0.007066598881546635
# active ind: True
# i in init_inds: False
# i: 1443
#  B_g_i: 0.008845958312148981
# active ind: True
# i in init_inds: False
# i: 1453
#  B_g_i: 0.004219623792575838
# active ind: True
# i in init_inds: False
# i: 1463
#  B_g_i: 0.008185053380780493
# active ind: True
# i in init_inds: False
# i: 1474
#  B_g_i: 0.007473309608538021
# active ind: True
# i in init_inds: False
# i: 1533
#  B_g_i: 0.0021860701576012723
# active ind: True
# i in init_inds: False
# i: 1610
#  B_g_i: 0.007981698017281524
# active ind: True
# i in init_inds: False
# i: 1625
#  B_g_i: 0.010879511947126856
# active ind: True
# Number of Active Inds for Iteration 35: 692
# Switch to Facet Restriction for Iteration 35: True
# using init_inds
# ---------------------------------------------------------------
# i in init_inds: False
# i:
False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1077: 853
# Switch to Facet Restriction for Iteration 1077: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1078: 853
# Switch to Facet Restriction for Iteration 1078: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1079: 853
# Switch to Facet Restriction for Iteration 1079: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1080: 854
# Switch to Facet Restriction for Iteration 1080: False
# using active_inds
# ---------------------------------------------------------------
# Degenerate step computed. Changing active facets...
# Number of Active Inds for Iteration 1081: 855
# Switch to Facet Restriction for Iteration 1081: False
# using active_inds
# ---------------------------------------------------------------
# Degenerate step computed. Changing active facets...
# Number of Active Inds for Iteration 1082: 855
# Switch to Facet Restriction for Iteration 1082: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1083: 856
# Switch to Facet Restriction for Iteration 1083: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1084: 857
# Switch to Facet Restriction for Iteration 1084: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1085: 858
# Switch to Facet Restriction for Iteration 1085: False
# using active_inds
# ---------------------------------------------------------------
# Degenerate step computed. Changing active facets...
# Number of Active Inds for Iteration 1086: 857
# Switch to Facet Restriction for Iteration 1086: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1087: 858
# Switch to Facet Restriction for Iteration 1087: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1088: 858
# Switch to Facet Restriction for Iteration 1088: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1089: 858
# Switch to Facet Restriction for Iteration 1089: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1090: 858
# Switch to Facet Restriction for Iteration 1090: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1091: 855
# Switch to Facet Restriction for Iteration 1091: False
# using active_inds
# ---------------------------------------------------------------
# Degenerate step computed. Changing active facets...
# Number of Active Inds for Iteration 1092: 856
# Switch to Facet Restriction for Iteration 1092: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1093: 857
# Switch to Facet Restriction for Iteration 1093: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1094: 858
# Switch to Facet Restriction for Iteration 1094: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1095: 857
# Switch to Facet Restriction for Iteration 1095: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1096: 855
# Switch to Facet Restriction for Iteration 1096: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1097: 855
# Switch to Facet Restriction for Iteration 1097: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1098: 855
# Switch to Facet Restriction for Iteration 1098: False
# using active_inds
# ---------------------------------------------------------------
# Degenerate step computed. Changing active facets...
# Number of Active Inds for Iteration 1099: 855
# Switch to Facet Restriction for Iteration 1099: False
# using active_inds
# ---------------------------------------------------------------
#
# Iteration 1100
# Objective: 149.02393559150508
# Steepness: -0.19460433331678073
# Step length: 272.3046457977726
# Number of Active Inds for Iteration 1100: 855
# Switch to Facet Restriction for Iteration 1100: False
# using active_inds
# ---------------------------------------------------------------
# Degenerate step computed. Changing active facets...
# Number of Active Inds for Iteration 1101: 852
# Switch to Facet Restriction for Iteration 1101: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1102: 852
# Switch to Facet Restriction for Iteration 1102: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1103: 853
# Switch to Facet Restriction for Iteration 1103: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1104: 853
# Switch to Facet Restriction for Iteration 1104: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1105: 854
# Switch to Facet Restriction for Iteration 1105: False
# using active_inds
# ---------------------------------------------------------------
# Degenerate step computed. Changing active facets...
# Number of Active Inds for Iteration 1106: 854
# Switch to Facet Restriction for Iteration 1106: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1107: 855
# Switch to Facet Restriction for Iteration 1107: False
# using active_inds
# ---------------------------------------------------------------
# Degenerate step computed. Changing active facets...
# Number of Active Inds for Iteration 1108: 852
# Switch to Facet Restriction for Iteration 1108: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1109: 853
# Switch to Facet Restriction for Iteration 1109: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1110: 852
# Switch to Facet Restriction for Iteration 1110: False
# using active_inds
# ---------------------------------------------------------------
# Degenerate step computed. Changing active facets...
# Number of Active Inds for Iteration 1111: 850
# Switch to Facet Restriction for Iteration 1111: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1112: 850
# Switch to Facet Restriction for Iteration 1112: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1113: 851
# Switch to Facet Restriction for Iteration 1113: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1114: 852
# Switch to Facet Restriction for Iteration 1114: False
# using active_inds
# ---------------------------------------------------------------
# Number of Active Inds for Iteration 1115: 852
# Switch to Facet Restriction for Iteration 1115: False
# using active_inds
# ---------------------------------------------------------------

# %%
print(P.n)
print(rank_A)
print(P.m_B)
print(math.floor(P.n/10))

# %%
print(obj_values[-1])
# print(x_current)

# %%
print('\nSolving with simplex method...')
lp_result = P.solve_lp(verbose=False, record_objs=True)
print('\nSolution using simplex method:')
print(lp_result)

# %%
equality = np.all(np.isclose(np.dot(A, np.array(x_feasible)), b))
inequality = np.all(np.dot(B, np.array(x_feasible))<= d)
print(equality)
print(inequality)
