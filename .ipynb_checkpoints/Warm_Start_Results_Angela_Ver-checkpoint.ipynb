# %% [markdown]
# # Warm Start Results (Angela Version)

# %% [markdown]
# ## Import Statements

# %%
import os
import pickle
import subprocess

from main import main

from glob import glob
import numpy as np
import random
from matplotlib import pyplot as plt
# %matplotlib inline

from utils import avg

# %% [markdown]
# ## Run Tests

# %%
# problems = ['adlittle', 'afiro', 'agg2','agg3','agg', 'bandm',
#  'beaconfd', 'blend', 'bnl1', 'boeing1', 'boeing2', 'bore3d', 'brandy', 'capri',
#  'cycle', 'degen2', 'degen3', 'e226', 'etamacro', 'fffff800', 'finnis',
#  'fit1d', 'fit1p', 'forplan', 'ganges', 'gfrd-pnc', 'grow15', 'grow22', 'grow7',
#  'israel', 'kb2', 'ken-07', 'lotfi', 'maros', 'pds-02', 'perold',
#  'pilot4', 'pilotnov', 'qap08', 'recipe', 'sc105', 'sc205', 'sc50a',
#  'sc50b', 'scagr25', 'scagr7', 'scfxm1', 'scfxm2', 'scfxm3', 'scorpion', 'scrs8',
#  'scsd1', 'scsd6', 'scsd8', 'sctap1', 'sctap2', 'sctap3', 'seba', 'share1b',
#  'share2b', 'shell', 'ship04l', 'ship04s', 'ship08l', 'ship08s', 'ship12l', 'ship12s',
#  'sierra', 'stair', 'standata', 'standgub', 'standmps', 'stocfor1', 'stocfor2', 'tuff',
#  'vtp_base', 'wood1p', 'cre-c', 'modszk1']  
problems = ['bandm', 'qap08', 'scsd1', 'scsd6', 'scsd8']

# 'cre-c', 'modszk1',
    
results_dir = 'results'
problem_dir = 'netlib_lp_subset'
max_time = 300
reset = False
sd_method = 'dual_simplex'
old_sd_sub = []
old_sd_solve = []
old_sd_phase = []
new_sd_sub = []
new_sd_solve = []
new_sd_phase = []

for i, problem in enumerate(problems):
    mps_fn = os.path.join(problem_dir, problem)
    print('\n\n\nWorking on problem {} of {}: {}'.format(i+1, len(problems), mps_fn)) 
    old_sub, old_solve, old_phase, new_sub, new_solve, new_phase = main(mps_fn=mps_fn, results_dir=results_dir, max_time=max_time, reset=reset, 
                                                                        sd_method=sd_method)
    old_sd_sub.append(old_sub)
    old_sd_solve.append(old_solve)
    old_sd_phase.append(old_phase[0])
    new_sd_sub.append(new_sub)
    new_sd_solve.append(new_solve)
    new_sd_phase.append(new_phase[0])
# Out:
# Working on problem 1 of 5: netlib_lp_subset\bandm
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-01
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -158.62801845011555
# Total solve time: 0.015885591506958008
# Number of iterations: 216.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.28177857398986816
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.2833137512207031
# standard form warm start
#
#
#
# Working on problem 2 of 5: netlib_lp_subset\qap08
# Reading netlib_lp_subset\qap08...
# Building polyhedron...
# Problem size: n = 1632,  m_B = 1632,  m_A = 912
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 203.50000000000006
# Total solve time: 0.8493709564208984
# Number of iterations: 2841.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\qap08...
# Building polyhedron...
# Problem size: n = 1632,  m_B = 1632,  m_A = 912
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 2.75490140914917
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\qap08...
# Building polyhedron...
# Problem size: n = 1632,  m_B = 1632,  m_A = 912
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 2.734189748764038
# standard form warm start
#
#
#
# Working on problem 3 of 5: netlib_lp_subset\scsd1
# Reading netlib_lp_subset\scsd1...
# Building polyhedron...
# Problem size: n = 760,  m_B = 760,  m_A = 77
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 8.666666674333364
# Total solve time: 0.015674591064453125
# Number of iterations: 160.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\scsd1...
# Building polyhedron...
# Problem size: n = 760,  m_B = 760,  m_A = 77
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.47313356399536133
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\scsd1...
# Building polyhedron...
# Problem size: n = 760,  m_B = 760,  m_A = 77
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.5347836017608643
# standard form warm start
#
#
#
# Working on problem 4 of 5: netlib_lp_subset\scsd6
# Reading netlib_lp_subset\scsd6...
# Building polyhedron...
# Problem size: n = 1350,  m_B = 1350,  m_A = 147
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 50.50000007826237
# Total solve time: 0.03201556205749512
# Number of iterations: 491.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\scsd6...
# Building polyhedron...
# Problem size: n = 1350,  m_B = 1350,  m_A = 147
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.4142861366271973
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\scsd6...
# Building polyhedron...
# Problem size: n = 1350,  m_B = 1350,  m_A = 147
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.3672277927398682
# standard form warm start
#
#
#
# Working on problem 5 of 5: netlib_lp_subset\scsd8
# Reading netlib_lp_subset\scsd8...
# Building polyhedron...
# Problem size: n = 2750,  m_B = 2750,  m_A = 397
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 904.9999999254637
# Total solve time: 0.046916961669921875
# Number of iterations: 965.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\scsd8...
# Building polyhedron...
# Problem size: n = 2750,  m_B = 2750,  m_A = 397
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 6.264296054840088
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\scsd8...
# Building polyhedron...
# Problem size: n = 2750,  m_B = 2750,  m_A = 397
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 5.685465574264526
# standard form warm start

# %% [markdown]
# ## View Results

# %%
print(f'Average old sd time: {np.mean(np.array(old_sd_sub))}')
print(f'Average new sd time: {np.mean(np.array(new_sd_sub))}')
print(f'Average old solve time: {np.mean(np.array(old_sd_solve))}')
print(f'Average new solve time: {np.mean(np.array(new_sd_solve))}')
print(f'Average old phase 1 time: {np.mean(np.array(old_sd_phase))}')
print(f'Average new phase 1 time: {np.mean(np.array(new_sd_phase))}')
# Out:
# Average old sd time: 0.08544001579284669
# Average new sd time: 0.08224077224731445
# Average old solve time: 0.07039999961853027
# Average new solve time: 0.06879992485046386
# Average old phase 1 time: 0.014996099472045898
# Average new phase 1 time: 0.01732635498046875

# %%
print(f'Median old sd time: {np.median(np.array(old_sd_sub))}')
print(f'Median new sd time: {np.median(np.array(new_sd_sub))}')
print(f'Median old solve time: {np.median(np.array(old_sd_solve))}')
print(f'Median new solve time: {np.median(np.array(new_sd_solve))}')
print(f'Median old phase 1 time: {np.median(np.array(old_sd_phase))}')
print(f'Median new phase 1 time: {np.median(np.array(new_sd_phase))}')
# Out:
# Median old sd time: 0.03135061264038086
# Median new sd time: 0.031252384185791016
# Median old solve time: 0.03099989891052246
# Median new solve time: 0.016000032424926758
# Median old phase 1 time: 0.013142585754394531
# Median new phase 1 time: 0.015343189239501953

# %%
# print(np.array(old_sd_sub))
# print(np.array(new_sd_sub))
print(np.array(old_sd_phase))
print(np.array(new_sd_phase))
# Out:
# [0.01314259 0.03086615 0.         0.         0.03097177]
# [0.         0.03786993 0.         0.01534319 0.03341866]
