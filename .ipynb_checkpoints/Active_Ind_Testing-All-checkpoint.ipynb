# %% [markdown]
# # Active Ind Testing

# %%
import numpy as np
import gurobipy as gp
import math
import sympy
import contextlib
import time
import os
from utils import result, METHODS, INF, EPS
from mps_reader_preprocessor import read_mps_preprocess
from polyhedral_model import PolyhedralModel
from polyhedron import Polyhedron

# %%
def active_ind_switch(mps_fn):
    ### Build Initial Polyhedron from file
    print(f'Reading {mps_fn}...')
    c, B, d, A, b = read_mps_preprocess(mps_fn)
    print('Building polyhedron...')
    P = Polyhedron(B, d, A, b, c)
    if A.size == 0:
        rank_A = 0
    else:
        rank_A = np.linalg.matrix_rank(A)

    print('Finding feasible solution...')
    x_feasible, vbasis, cbasis = P.find_feasible_solution(verbose=False)

    x = x_feasible
    c=None
    verbose=False
    method='dual_simplex'
    reset=False
    max_time=300
    first_warm_start=None
    save_first_steps=0
    problem_name=''

    if c is not None:
        P.set_objective(c)

    t0 = time.time()
    x_current = x
    if save_first_steps:
        np.save('solutions/{}_0.npy'.format(problem_name), x_current)      
    active_inds = P.get_active_constraints(x_current)
    
    pm = P.build_polyhedral_model(active_inds=active_inds, method=method)

    if first_warm_start is not None:
        print('Using custom warm start')
        pm.set_solution(first_warm_start)
    t1 = time.time()
    build_time = t1 - t0
    print('Polyhedral model build time: {}'.format(build_time))
    
    sub_times = {'sd': [], 'step': [], 'solve': [], 'phase_times': []}
    active_inds_it = []
    descent_circuits = []
    obj_values = []
    step_sizes = []
    iter_times = []
    simplex_iters = []
    iteration = 0
    active_inds_it.append(active_inds)
    obj_value = P.c.dot(x_current)
    obj_values.append(obj_value)
    t2 = time.time()
    iter_times.append(t2 - t1)


    # compute steepest-descent direction
    descent_direction, y_pos, y_neg, steepness, num_steps, solve_time, phase_times = pm.compute_sd_direction(verbose=verbose)
    print(np.count_nonzero(np.array(descent_direction)))
    simplex_iters.append(num_steps)
    sub_times['solve'].append(solve_time)
    sub_times['phase_times'].append(phase_times)
    
    t3 = time.time()
    sub_times['sd'].append(t3 - t2)
    
    while abs(steepness) > EPS:
        
        t3 = time.time()
        if reset:
            pm.reset()
        
        # take maximal step
        x_current, alpha, active_inds = P.take_maximal_step(descent_direction, y_pos, y_neg)  
        
        if iteration % 50 == 0 or iteration == 1:
            print('\nIteration {}'.format(iteration))
            print('Objective: {}'.format(obj_value))
            print('Steepness: {}'.format(steepness))
            print('Step length: {}'.format(alpha))
            # print('Descent Direction: {}'.format(descent_direction))
        
        t4 = time.time()
        active_inds_it.append(active_inds)
        obj_value = P.c.dot(x_current)
        obj_values.append(obj_value)
        iter_times.append(t4 - t1)
        sub_times['step'].append(t4 - t3) 
        descent_circuits.append(descent_direction)
        step_sizes.append(alpha)     
                
        if math.isinf(alpha):
            # problem is unbounded
            result(status=1, circuits=descent_circuits, steps=step_sizes)
        
        # compute steepest-descent direction
        # print(f'number of active inds for iteration {iteration}: {len(active_inds)}')
        # for ind in active_inds:
        #     if abs(P.B_x_current[ind]-P.d[ind]) > EPS:
        #         print(f'Not truly active inds for inex {ind}: {P.B_x_current[ind]} != {P.d[ind]}')
            # print(f'check that (Bx)_i = d_i for index {ind}: {P.B_x_current[ind]} = {P.d[ind]}; {abs(P.B_x_current[ind]-P.d[ind])<= EPS}')
        if len(active_inds) <= math.floor((P.n - rank_A)) and np.count_nonzero(np.array(descent_direction)) != 0:
            print('simp_switch')
            pm.set_active_inds(active_inds, simp_switch = True)
        else:
            print('regular')
            pm.set_active_inds(active_inds)
        descent_direction, y_pos, y_neg, steepness, num_steps, solve_time, phase_times = pm.compute_sd_direction(verbose=verbose)
        
        t5 = time.time()
        sub_times['sd'].append(t5 - t4)
        sub_times['solve'].append(solve_time)
        sub_times['phase_times'].append(phase_times)
        simplex_iters.append(num_steps)
        
        iteration += 1
        current_time = t5 - t1
        if current_time > max_time:
            result(status=2)
        if iteration <= save_first_steps:
            np.save('solutions/{}_{}.npy'.format(problem_name, iteration), x_current)

    t6 = time.time()
    total_time = t6 - t1   
    print('Total time for steepest-descent scheme: {}'.format(total_time))
    print(f'Objective Value: {obj_values[-1]}')

# %%
def simplex_ver(mps_fn):
    print(f'Reading {mps_fn}...')
    c, B, d, A, b = read_mps_preprocess(mps_fn)
    print('Building polyhedron...')
    P = Polyhedron(B, d, A, b, c)
    if A.size == 0:
        rank_A = 0
    else:
        rank_A = np.linalg.matrix_rank(A)

    print('Finding feasible solution...')
    x_feasible, vbasis, cbasis = P.find_feasible_solution(verbose=False)
    
    print('\nSolving with simplex method...')
    lp_result = P.solve_lp(verbose=False, record_objs=True)
    print('\nSolution using simplex method:')
    print(lp_result)

# %%
problem_dir = 'netlib_lp_subset'
# problem = 'kb2'
# problem = 'adlittle'
# problem = 'angela_test_prob'
# problem = 'network_ex'
# problem = 'gfrd-pnc'
# problem = 'modszk1'
# problem = 'cycle'
# problem = 'cre-c'
# mps_fn=os.path.join(problem_dir, problem)
# results_dir='results'
# max_time=300
# sd_method='dual_simplex'
# reset=False,
# partition_polytope=False
# n=0
# k=0
# spindle=False
# spindle_dim=0
# n_cone_facets=0
# n_parallel_facets=0

problems = ['adlittle', 'afiro', 'agg2','agg3','agg', 'bandm',
 'beaconfd', 'blend', 'bnl1', 'boeing1', 'boeing2', 'bore3d', 'brandy', 'capri',
 'cycle', 'degen2', 'degen3', 'e226', 'etamacro', 'fffff800', 'finnis',
 'fit1d', 'fit1p', 'forplan', 'ganges', 'gfrd-pnc', 'grow15', 'grow22', 'grow7',
 'israel', 'kb2', 'ken-07', 'lotfi', 'maros', 'pds-02', 'perold',
 'pilot4', 'pilotnov', 'qap08', 'recipe', 'sc105', 'sc205', 'sc50a',
 'sc50b', 'scagr25', 'scagr7', 'scfxm1', 'scfxm2', 'scfxm3', 'scorpion', 'scrs8',
 'scsd1', 'scsd6', 'scsd8', 'sctap1', 'sctap2', 'sctap3', 'seba', 'share1b',
 'share2b', 'shell', 'ship04l', 'ship04s', 'ship08l', 'ship08s', 'ship12l', 'ship12s',
 'sierra', 'stair', 'standata', 'standgub', 'standmps', 'stocfor1', 'stocfor2', 'tuff',
 'vtp_base', 'wood1p', 'cre-c', 'modszk1']

for problem in problems:
    mps_fn=os.path.join(problem_dir, problem)
    active_ind_switch(mps_fn)
    simplex_ver(mps_fn)
# Out:
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-01
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0
# 1
#
# Iteration 0
# Objective: 671734.1100278501
# Steepness: -1093.3333333333335
# Step length: 1.492387497139124
# regular
#
# Iteration 1
# Objective: 670102.4330309781
# Steepness: -608.695652173913
# Step length: 14.047128014198497
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# regular
# regular
# simp_switch
# regular
# simp_switch
# regular
# simp_switch
#
# Iteration 50
# Objective: 237024.02418761735
# Steepness: -32.89239796024481
# Step length: 236.0920277609726
# regular
# simp_switch
# regular
# simp_switch
# regular
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# regular
# regular
# regular
# Total time for steepest-descent scheme: 0.11130905151367188
# Objective Value: 225494.9631623802
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 225494.96316238024
# Total solve time: 0.0
# Number of iterations: 100.0
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0
# 2
#
# Iteration 0
# Objective: 440.0
# Steepness: -3.333333333333334
# Step length: 131.99999999999997
# regular
#
# Iteration 1
# Objective: 7.105427357601002e-14
# Steepness: -0.14049832478346544
# Step length: 3245.3160714285714
# regular
# regular
# Total time for steepest-descent scheme: 0.014019250869750977
# Objective Value: -464.7531428571429
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -464.75314285714285
# Total solve time: 0.0
# Number of iterations: 19.0
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0747687816619873
# 4
#
# Iteration 0
# Objective: 109626646.32852079
# Steepness: -83.04516320666386
# Step length: 742.8174157224255
# regular
#
# Iteration 1
# Objective: 109564958.93499938
# Steepness: -58.894049681906935
# Step length: 2062.9421267070884
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 50
# Objective: -17812065.089391712
# Steepness: -1.1416934370415128
# Step length: 236890.10620872286
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# simp_switch
# regular
# regular
# simp_switch
# regular
# simp_switch
# regular
# regular
# simp_switch
# simp_switch
# Total time for steepest-descent scheme: 0.4194517135620117
# Objective Value: -19949969.534534935
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -20239252.355977118
# Total solve time: 0.0
# Number of iterations: 158.0
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0974423885345459
# 11
#
# Iteration 0
# Objective: 759202344.1690388
# Steepness: -99.87397600792033
# Step length: 6779195.16351643
# regular
#
# Iteration 1
# Objective: 82137169.05498938
# Steepness: -73.94169151062248
# Step length: 2650.7530877042677
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 50
# Objective: 11402989.186213307
# Steepness: -1.0241476605354012
# Step length: 186189.46206288485
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# simp_switch
# regular
# simp_switch
# simp_switch
# Total time for steepest-descent scheme: 0.37746214866638184
# Objective Value: 10561146.714119254
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 10312115.935089217
# Total solve time: 0.007018327713012695
# Number of iterations: 156.0
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.04734516143798828
# 4
#
# Iteration 0
# Objective: 703339586.6175559
# Steepness: -99.956349594957
# Step length: 2544092.712901022
# regular
#
# Iteration 1
# Objective: 449041366.0048387
# Steepness: -99.63098617323385
# Step length: 622821.068708921
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Total time for steepest-descent scheme: 0.1915757656097412
# Objective Value: -35991767.28657648
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -35991767.2865765
# Total solve time: 0.0
# Number of iterations: 75.0
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.11485719680786133
# 3
#
# Iteration 0
# Objective: 35.17554204866987
# Steepness: -3.0233333333333334
# Step length: 5.4910125
# regular
#
# Iteration 1
# Objective: 18.574380923669892
# Steepness: -1.6666666666666665
# Step length: 2.919
# regular
# regular
# regular
# regular
# simp_switch
# simp_switch
# regular
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
#
# Iteration 50
# Objective: -69.66008327742693
# Steepness: -0.05489248285398931
# Step length: 0.6525426905774232
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
#
# Iteration 100
# Objective: -138.9409963362623
# Steepness: -0.081093268055299
# Step length: 0.6951091816047593
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
#
# Iteration 150
# Objective: -156.23621186901218
# Steepness: -0.011055251644261839
# Step length: 9.051783830678723
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# regular
# regular
# simp_switch
# simp_switch
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 200
# Objective: -158.58308614590734
# Steepness: -0.0005116732372467128
# Step length: 16.859226280463876
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Total time for steepest-descent scheme: 1.1598753929138184
# Objective Value: -158.6280185856463
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -158.62801845011555
# Total solve time: 0.006580829620361328
# Number of iterations: 216.0
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.03129315376281738
# 13
#
# Iteration 0
# Objective: 33992.2782842
# Steepness: -0.07985710632678573
# Step length: 1074.2533000000003
# regular
#
# Iteration 1
# Objective: 33906.4915242
# Steepness: -0.06030063441259438
# Step length: 10.890871063301619
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Total time for steepest-descent scheme: 0.06809425354003906
# Objective Value: 33592.4858072
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 33592.48580719999
# Total solve time: 0.0
# Number of iterations: 20.0
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.012235403060913086
# 47
#
# Iteration 0
# Objective: 0.0
# Steepness: -0.07995096139551053
# Step length: 204.46220784365894
# regular
#
# Iteration 1
# Objective: -16.346950086149228
# Steepness: -0.07507855792833903
# Step length: 11.700432388455038
# simp_switch
# regular
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# regular
# regular
# regular
# regular
# regular
# Total time for steepest-descent scheme: 0.018507003784179688
# Objective Value: -30.81214984582821
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -30.812149845828237
# Total solve time: 0.0
# Number of iterations: 96.0
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.6640982627868652
# 6
#
# Iteration 0
# Objective: 2108.241973450449
# Steepness: -0.7838325324871562
# Step length: 4.856190808556725
# regular
#
# Iteration 1
# Objective: 2104.4355331107377
# Steepness: -0.6354513698630138
# Step length: 2.99269911829352
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 50
# Objective: 2043.545568881475
# Steepness: -0.08612423856809902
# Step length: 5.70826107383492
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 100
# Objective: 2022.0571831451566
# Steepness: -0.020279165658631113
# Step length: 1.4363708520740728
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 150
# Objective: 1995.7276129810098
# Steepness: -0.004485204050821907
# Step length: 20.53110302270434
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# regular
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# regular
# regular
# regular
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
#
# Iteration 200
# Objective: 1977.6483281963415
# Steepness: -5.375063697109145e-06
# Step length: 10.19862375481255
# regular
# regular
# regular
# regular
# Total time for steepest-descent scheme: 3.0447468757629395
# Objective Value: 1977.6288922585754
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 1977.629561522889
# Total solve time: 0.011714935302734375
# Number of iterations: 418.0
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.12270879745483398
# 16
#
# Iteration 0
# Objective: 185.3449154488552
# Steepness: -0.04583250627946371
# Step length: 25.020530715655763
# regular
#
# Iteration 1
# Objective: 184.19816181771438
# Steepness: -0.04562063710694408
# Step length: 2.6145797978557512
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 50
# Objective: 139.54470532839713
# Steepness: -0.011809188377272494
# Step length: 18.347500606060603
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# simp_switch
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# simp_switch
# regular
# simp_switch
# simp_switch
# regular
# simp_switch
# regular
# simp_switch
# simp_switch
# regular
#
# Iteration 100
# Objective: 45.361136013657365
# Steepness: -0.007768210833897633
# Step length: 148.54408883631578
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 150
# Objective: -182.54956612745062
# Steepness: -0.005555470094343022
# Step length: 56.12296661331926
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 200
# Objective: -283.28553058909495
# Steepness: -0.002769595166153462
# Step length: 201.44521888900604
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 250
# Objective: -323.834377463054
# Steepness: -0.0013444465893503806
# Step length: 0.4909995721596531
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 300
# Objective: -332.44792186654706
# Steepness: -0.0006241746850089223
# Step length: 14.77928801137112
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 350
# Objective: -335.1203884647163
# Steepness: -4.797309235902731e-05
# Step length: 1066.424966050186
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Total time for steepest-descent scheme: 2.9503183364868164
# Objective Value: -335.2135675071265
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -335.2135675071269
# Total solve time: 0.0
# Number of iterations: 489.0
# Reading netlib_lp_subset\boeing2...
# removing redundant constraint 'LF1013B1'
# removing redundant constraint 'LF1013B2'
# removing redundant constraint 'LF1015B1'
# removing redundant constraint 'LF1017B1'
# removing redundant constraint 'LF1019B1'
# removing redundant constraint 'LF1019B2'
# removing redundant constraint 'LF1004B1'
# removing redundant constraint 'LF1008B1'
# removing redundant constraint 'LF1008B2'
# removing redundant constraint 'LF1010B1'
# removing redundant constraint 'LF1010B2'
# removing redundant constraint 'LF1010B3'
# removing redundant constraint 'LF1012B1'
# removing redundant constraint 'LF1014B1'
# removing redundant constraint 'LF1014B2'
# removing redundant constraint 'LF1100B1'
# removing redundant constraint 'LF1100B2'
# removing redundant constraint 'LF1100B3'
# removing redundant constraint 'LF1100B4'
# removing redundant constraint 'LF1100B5'
# removing redundant constraint 'LF1102B1'
# removing redundant constraint 'LF1102B2'
# removing redundant constraint 'LF1102B3'
# removing redundant constraint 'LF1102B4'
# removing redundant constraint 'LF1200B1'
# removing redundant constraint 'LF1201B1'
# Building polyhedron...
# Problem size: n = 143,  m_B = 352,  m_A = 4
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.01401662826538086
# 8
#
# Iteration 0
# Objective: -210.67368152468885
# Steepness: -0.2182553844586359
# Step length: 189.77319990648823
# regular
#
# Iteration 1
# Objective: -252.09270423022505
# Steepness: -0.18371391049959032
# Step length: 1.9636084368406919
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 50
# Objective: -314.6785100011729
# Steepness: -0.00034898749272091706
# Step length: 975.1455699574111
# regular
# Total time for steepest-descent scheme: 0.17337632179260254
# Objective Value: -315.0188236086702
# Reading netlib_lp_subset\boeing2...
# removing redundant constraint 'LF1013B1'
# removing redundant constraint 'LF1013B2'
# removing redundant constraint 'LF1015B1'
# removing redundant constraint 'LF1017B1'
# removing redundant constraint 'LF1019B1'
# removing redundant constraint 'LF1019B2'
# removing redundant constraint 'LF1004B1'
# removing redundant constraint 'LF1008B1'
# removing redundant constraint 'LF1008B2'
# removing redundant constraint 'LF1010B1'
# removing redundant constraint 'LF1010B2'
# removing redundant constraint 'LF1010B3'
# removing redundant constraint 'LF1012B1'
# removing redundant constraint 'LF1014B1'
# removing redundant constraint 'LF1014B2'
# removing redundant constraint 'LF1100B1'
# removing redundant constraint 'LF1100B2'
# removing redundant constraint 'LF1100B3'
# removing redundant constraint 'LF1100B4'
# removing redundant constraint 'LF1100B5'
# removing redundant constraint 'LF1102B1'
# removing redundant constraint 'LF1102B2'
# removing redundant constraint 'LF1102B3'
# removing redundant constraint 'LF1102B4'
# removing redundant constraint 'LF1200B1'
# removing redundant constraint 'LF1201B1'
# Building polyhedron...
# Problem size: n = 143,  m_B = 352,  m_A = 4
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -315.01872801520284
# Total solve time: 0.0069751739501953125
# Number of iterations: 72.0
# Reading netlib_lp_subset\bore3d...
# Building polyhedron...
# Problem size: n = 315,  m_B = 344,  m_A = 215
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0530390739440918
# 5
#
# Iteration 0
# Objective: 47483.69385383172
# Steepness: -65.70256647058824
# Step length: 55.10885274207872
# regular
#
# Iteration 1
# Objective: 43862.90079342743
# Steepness: -5.609429770571782
# Step length: 295.8725622557921
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Total time for steepest-descent scheme: 0.10555005073547363
# Objective Value: 1373.0803942084908
# Reading netlib_lp_subset\bore3d...
# Building polyhedron...
# Problem size: n = 315,  m_B = 344,  m_A = 215
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 1373.080394208493
# Total solve time: 0.0
# Number of iterations: 53.0
# Reading netlib_lp_subset\brandy...
# removing redundant constraint '10178A'
# removing redundant constraint '10179A'
# removing redundant constraint '10180A'
# removing redundant constraint '10181A'
# removing redundant constraint '10182A'
# removing redundant constraint '10184A'
# removing redundant constraint '10185A'
# removing redundant constraint '10186A'
# removing redundant constraint '10187A'
# removing redundant constraint '10188A'
# removing redundant constraint '10189A'
# removing redundant constraint '10002A'
# removing redundant constraint '10003A'
# removing redundant constraint '10004A'
# removing redundant constraint '10067A'
# removing redundant constraint '10077A'
# removing redundant constraint '10079A'
# removing redundant constraint '10088A'
# removing redundant constraint '10099A'
# removing redundant constraint '10103A'
# removing redundant constraint '10109A'
# removing redundant constraint '10111A'
# removing redundant constraint '10112A'
# removing redundant constraint '10113A'
# removing redundant constraint '10114A'
# removing redundant constraint '10115A'
# removing redundant constraint '10155A'
# removing redundant constraint '10157A'
# removing redundant constraint '10161A'
# removing redundant constraint '10165A'
# removing redundant constraint '10166A'
# removing redundant constraint '10174A'
# removing redundant constraint '10205A'
# removing redundant constraint '10206A'
# removing redundant constraint '10212A'
# removing redundant constraint '10213A'
# removing redundant constraint '10214A'
# removing redundant constraint '10221A'
# Building polyhedron...
# Problem size: n = 249,  m_B = 292,  m_A = 139
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.05548524856567383
# 4
#
# Iteration 0
# Objective: 7298.656301179384
# Steepness: -0.9407337723424272
# Step length: 1575.1442626192616
# regular
#
# Iteration 1
# Objective: 5816.864897022036
# Steepness: -0.9398631887544163
# Step length: 1199.9841252002025
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# simp_switch
# regular
# regular
# regular
# regular
# regular
# simp_switch
# simp_switch
# simp_switch
# regular
# regular
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# regular
# regular
# regular
#
# Iteration 50
# Objective: 1987.6298518708518
# Steepness: -0.35451489631169064
# Step length: 17.007047645631705
# regular
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# regular
# simp_switch
# regular
# regular
# regular
#
# Iteration 100
# Objective: 1540.4204705617626
# Steepness: -0.049573101019715085
# Step length: 65.46554180250702
# regular
# regular
# regular
# simp_switch
# regular
# regular
# simp_switch
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 150
# Objective: 1519.6973521664106
# Steepness: -0.002556025557371001
# Step length: 11.631240657587215
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Total time for steepest-descent scheme: 0.5998878479003906
# Objective Value: 1518.50989648813
# Reading netlib_lp_subset\brandy...
# removing redundant constraint '10178A'
# removing redundant constraint '10179A'
# removing redundant constraint '10180A'
# removing redundant constraint '10181A'
# removing redundant constraint '10182A'
# removing redundant constraint '10184A'
# removing redundant constraint '10185A'
# removing redundant constraint '10186A'
# removing redundant constraint '10187A'
# removing redundant constraint '10188A'
# removing redundant constraint '10189A'
# removing redundant constraint '10002A'
# removing redundant constraint '10003A'
# removing redundant constraint '10004A'
# removing redundant constraint '10067A'
# removing redundant constraint '10077A'
# removing redundant constraint '10079A'
# removing redundant constraint '10088A'
# removing redundant constraint '10099A'
# removing redundant constraint '10103A'
# removing redundant constraint '10109A'
# removing redundant constraint '10111A'
# removing redundant constraint '10112A'
# removing redundant constraint '10113A'
# removing redundant constraint '10114A'
# removing redundant constraint '10115A'
# removing redundant constraint '10155A'
# removing redundant constraint '10157A'
# removing redundant constraint '10161A'
# removing redundant constraint '10165A'
# removing redundant constraint '10166A'
# removing redundant constraint '10174A'
# removing redundant constraint '10205A'
# removing redundant constraint '10206A'
# removing redundant constraint '10212A'
# removing redundant constraint '10213A'
# removing redundant constraint '10214A'
# removing redundant constraint '10221A'
# Building polyhedron...
# Problem size: n = 249,  m_B = 292,  m_A = 139
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 1518.509896488128
# Total solve time: 0.0005202293395996094
# Number of iterations: 170.0
# Reading netlib_lp_subset\capri...
# Building polyhedron...
# Problem size: n = 353,  m_B = 583,  m_A = 158
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.10201644897460938
# 6
#
# Iteration 0
# Objective: 5328.851249969662
# Steepness: -1.3053567196652693
# Step length: 44.31498070782584
# simp_switch
#
# Iteration 1
# Objective: 5271.004392120864
# Steepness: -1.123619613919928
# Step length: 4.542441182465511
# regular
# simp_switch
# regular
# simp_switch
# Total time for steepest-descent scheme: 0.04857993125915527
# Objective Value: 5227.025234448415
# Reading netlib_lp_subset\capri...
# Building polyhedron...
# Problem size: n = 353,  m_B = 583,  m_A = 158
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 2690.0129137681606
# Total solve time: 0.0
# Number of iterations: 143.0
# Reading netlib_lp_subset\cycle...
# removing redundant constraint 'GHF...EB'
# removing redundant constraint 'GHH...EB'
# removing redundant constraint 'GHT...EB'
# removing redundant constraint 'GHX...EB'
# removing redundant constraint 'BGL...AA'
# removing redundant constraint 'BGL...AC'
# removing redundant constraint 'BOA...AC'
# removing redundant constraint 'BOB...AC'
# removing redundant constraint 'BGL...AE'
# removing redundant constraint 'BOA...AE'
# removing redundant constraint 'BOF...BD'
# removing redundant constraint 'BGL...CF'
# removing redundant constraint 'BOB...CF'
# removing redundant constraint 'BOX...CF'
# removing redundant constraint 'BGL...DD'
# removing redundant constraint 'BDN...EF'
# removing redundant constraint 'BOB...EF'
# Building polyhedron...
# Problem size: n = 2857,  m_B = 3437,  m_A = 1376
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 3.9980368614196777
# 42
#
# Iteration 0
# Objective: 0.0
# Steepness: -0.0020448422461391267
# Step length: 696.875346911834
# regular
#
# Iteration 1
# Objective: -1.4250001496581777
# Steepness: -0.0018861745610514319
# Step length: 641.0281747197395
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 50
# Objective: -4.7551258104120215
# Steepness: -2.225065066121837e-05
# Step length: 0.0054431731768228185
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# regular
#
# Iteration 100
# Objective: -4.869080181218497
# Steepness: -1.380114745130213e-05
# Step length: 0.3737790262285603
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
#
# Iteration 150
# Objective: -5.022229269980018
# Steepness: -9.830128054408513e-06
# Step length: 0.0002283117993612506
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 200
# Objective: -5.099857214742819
# Steepness: -7.3771283631571e-06
# Step length: 12.946942726574902
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# Total time for steepest-descent scheme: 9.339106798171997
# Objective Value: -5.224931332631746
# Reading netlib_lp_subset\cycle...
# removing redundant constraint 'GHF...EB'
# removing redundant constraint 'GHH...EB'
# removing redundant constraint 'GHT...EB'
# removing redundant constraint 'GHX...EB'
# removing redundant constraint 'BGL...AA'
# removing redundant constraint 'BGL...AC'
# removing redundant constraint 'BOA...AC'
# removing redundant constraint 'BOB...AC'
# removing redundant constraint 'BGL...AE'
# removing redundant constraint 'BOA...AE'
# removing redundant constraint 'BOF...BD'
# removing redundant constraint 'BGL...CF'
# removing redundant constraint 'BOB...CF'
# removing redundant constraint 'BOX...CF'
# removing redundant constraint 'BGL...DD'
# removing redundant constraint 'BDN...EF'
# removing redundant constraint 'BOB...EF'
# Building polyhedron...
# Problem size: n = 2857,  m_B = 3437,  m_A = 1376
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -5.226393024894102
# Total solve time: 0.04584336280822754
# Number of iterations: 1169.0
# Reading netlib_lp_subset\degen2...
# Building polyhedron...
# Problem size: n = 534,  m_B = 757,  m_A = 221
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.16672754287719727
# 10
#
# Iteration 0
# Objective: -1291.02
# Steepness: -1.6785714285714284
# Step length: 7.0
# regular
#
# Iteration 1
# Objective: -1302.77
# Steepness: -1.6660000000000006
# Step length: 5.0
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 50
# Objective: -1433.7629570833333
# Steepness: -0.06375000000000008
# Step length: 6.322888888888928
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Total time for steepest-descent scheme: 0.4790823459625244
# Objective Value: -1435.1779999999999
# Reading netlib_lp_subset\degen2...
# Building polyhedron...
# Problem size: n = 534,  m_B = 757,  m_A = 221
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -1435.178
# Total solve time: 0.012017250061035156
# Number of iterations: 536.0
# Reading netlib_lp_subset\degen3...
# Building polyhedron...
# Problem size: n = 1818,  m_B = 2604,  m_A = 717
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.7925543785095215
# 10
#
# Iteration 0
# Objective: -930.6566666666666
# Steepness: -0.25299999999999984
# Step length: 10.0
# regular
#
# Iteration 1
# Objective: -933.1866666666667
# Steepness: -0.2233333333333333
# Step length: 35.99999999999992
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 50
# Objective: -980.7158993055556
# Steepness: -0.045692307692307685
# Step length: 1.670138888887733
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 100
# Objective: -987.0890635499338
# Steepness: -0.003376623376623397
# Step length: 15.121944444444507
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Total time for steepest-descent scheme: 3.5283279418945312
# Objective Value: -987.294
# Reading netlib_lp_subset\degen3...
# Building polyhedron...
# Problem size: n = 1818,  m_B = 2604,  m_A = 717
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -987.2940000000006
# Total solve time: 0.12710118293762207
# Number of iterations: 1668.0
# Reading netlib_lp_subset\e226...
# Building polyhedron...
# Problem size: n = 282,  m_B = 472,  m_A = 33
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.047724008560180664
# 1
#
# Iteration 0
# Objective: 44.76682239406883
# Steepness: -1.3398333333333332
# Step length: 1.9032
# regular
#
# Iteration 1
# Objective: 42.21685159406883
# Steepness: -1.2733999999999999
# Step length: 1.4071147426927355
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 50
# Objective: 8.568429154313801
# Steepness: -0.12640771160434752
# Step length: 0.002694966144692191
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# regular
# regular
# regular
# simp_switch
# simp_switch
# regular
# simp_switch
# regular
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# regular
# regular
# regular
# regular
# regular
# regular
# simp_switch
# regular
# regular
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# regular
# regular
# Degenerate step computed. Changing active facets...
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# regular
#
# Iteration 100
# Objective: -8.196815212243465
# Steepness: -0.05127147086798842
# Step length: 4.182232062149539
# regular
# simp_switch
# simp_switch
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# simp_switch
# regular
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# regular
# simp_switch
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# simp_switch
# regular
# regular
# regular
# regular
# regular
# regular
# simp_switch
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
#
# Iteration 150
# Objective: -16.498548371586352
# Steepness: -0.015279154744347977
# Step length: 17.472967258132527
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# regular
# simp_switch
# simp_switch
# simp_switch
# regular
# regular
# regular
# simp_switch
# simp_switch
# simp_switch
# simp_switch
# regular
# regular
# regular
# simp_switch
# regular
# simp_switch
# regular
# simp_switch
# regular
# regular
# regular
# simp_switch
# regular
# simp_switch
# regular
# regular
# simp_switch
# regular
# simp_switch
# simp_switch
# regular
# simp_switch
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 200
# Objective: -18.477613387952857
# Steepness: -0.00195
# Step length: 5.627083453829033
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Total time for steepest-descent scheme: 1.1120691299438477
# Objective Value: -18.751943289883187
# Reading netlib_lp_subset\e226...
# Building polyhedron...
# Problem size: n = 282,  m_B = 472,  m_A = 33
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -18.75192906637051
# Total solve time: 0.0
# Number of iterations: 298.0
# Reading netlib_lp_subset\etamacro...
# Building polyhedron...
# Problem size: n = 688,  m_B = 869,  m_A = 354
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.26069045066833496
# 2
#
# Iteration 0
# Objective: 258.7190233697029
# Steepness: -141.74356363636363
# Step length: 2.7559474579999987
# regular
#
# Iteration 1
# Objective: -131.9187905217946
# Steepness: -118.80627054202671
# Step length: 0.0786860649600003
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 50
# Objective: -744.8297180420711
# Steepness: -0.025386195028298527
# Step length: 0.11179183082580323
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 100
# Objective: -752.4604391560533
# Steepness: -0.006594729560653592
# Step length: 46.514112378739526
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 150
# Objective: -755.3312416394745
# Steepness: -0.001032243766124312
# Step length: 19.1984018822811
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# ...
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 129831.46246136139
# Total solve time: 0.0
# Number of iterations: 78.0
# Reading netlib_lp_subset\wood1p...
# Building polyhedron...
# Problem size: n = 2594,  m_B = 2595,  m_A = 243
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 2.204923629760742
# 88
#
# Iteration 0
# Objective: 5.244599208289261
# Steepness: -0.7498808982937437
# Step length: 0.030064203529038554
# regular
#
# Iteration 1
# Objective: 5.22205463634042
# Steepness: -0.7498785598237437
# Step length: 0.5633929633571945
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 50
# Objective: 2.6331615675187585
# Steepness: -0.6290916221770007
# Step length: 0.014867402774170382
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# regular
# regular
# regular
#
# Iteration 100
# Objective: 1.4451271784243485
# Steepness: -0.1420947605214332
# Step length: 0.01125206264022415
# regular
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# regular
# Degenerate step computed. Changing active facets...
# regular
# Total time for steepest-descent scheme: 3.235645055770874
# Objective Value: 1.4429024191088287
# Reading netlib_lp_subset\wood1p...
# Building polyhedron...
# Problem size: n = 2594,  m_B = 2595,  m_A = 243
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 1.442902411573409
# Total solve time: 0.026215553283691406
# Number of iterations: 319.0
# Reading netlib_lp_subset\cre-c...
# removing redundant constraint 'BB013'
# removing redundant constraint 'BB023'
# removing redundant constraint 'BB031'
# removing redundant constraint 'BB032'
# removing redundant constraint 'BB033'
# removing redundant constraint 'BB034'
# removing redundant constraint 'BB035'
# removing redundant constraint 'BB043'
# removing redundant constraint 'BB053'
# removing redundant constraint 'BB063'
# removing redundant constraint 'BB073'
# removing redundant constraint 'BB083'
# removing redundant constraint 'BB093'
# removing redundant constraint 'BB123'
# removing redundant constraint 'BB133'
# removing redundant constraint 'BB141'
# removing redundant constraint 'BB142'
# removing redundant constraint 'BB143'
# removing redundant constraint 'BB144'
# removing redundant constraint 'BB145'
# removing redundant constraint 'BB163'
# removing redundant constraint 'BB173'
# removing redundant constraint 'BB213'
# removing redundant constraint 'BB231'
# removing redundant constraint 'BB232'
# removing redundant constraint 'BB233'
# removing redundant constraint 'BB234'
# removing redundant constraint 'BB235'
# removing redundant constraint 'BB303'
# removing redundant constraint 'BB384'
# removing redundant constraint 'BB414'
# removing redundant constraint 'BB424'
# removing redundant constraint 'BB434'
# removing redundant constraint 'BB444'
# removing redundant constraint 'BB454'
# removing redundant constraint 'BB484'
# removing redundant constraint 'BB551'
# removing redundant constraint 'BB552'
# removing redundant constraint 'BB553'
# removing redundant constraint 'BB554'
# removing redundant constraint 'BB555'
# removing redundant constraint 'BB571'
# removing redundant constraint 'BB572'
# removing redundant constraint 'BB573'
# removing redundant constraint 'BB574'
# removing redundant constraint 'BB575'
# removing redundant constraint 'BB584'
# removing redundant constraint 'BB601'
# removing redundant constraint 'BB602'
# removing redundant constraint 'BB603'
# removing redundant constraint 'BB604'
# removing redundant constraint 'BB605'
# removing redundant constraint 'BB611'
# removing redundant constraint 'BB612'
# removing redundant constraint 'BB613'
# removing redundant constraint 'BB614'
# removing redundant constraint 'BB615'
# removing redundant constraint 'BB621'
# removing redundant constraint 'BB622'
# removing redundant constraint 'BB623'
# removing redundant constraint 'BB624'
# removing redundant constraint 'BB625'
# removing redundant constraint 'BB641'
# removing redundant constraint 'BB642'
# removing redundant constraint 'BB643'
# removing redundant constraint 'BB644'
# removing redundant constraint 'BB645'
# removing redundant constraint 'BB651'
# removing redundant constraint 'BB652'
# removing redundant constraint 'BB653'
# removing redundant constraint 'BB654'
# removing redundant constraint 'BB655'
# removing redundant constraint 'BB661'
# removing redundant constraint 'BB662'
# removing redundant constraint 'BB663'
# removing redundant constraint 'BB664'
# removing redundant constraint 'BB665'
# removing redundant constraint 'BB671'
# removing redundant constraint 'BB672'
# removing redundant constraint 'BB673'
# removing redundant constraint 'BB674'
# removing redundant constraint 'BB675'
# Building polyhedron...
# Problem size: n = 3678,  m_B = 6411,  m_A = 253
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 7.232925891876221
# 15
#
# Iteration 0
# Objective: 32856322.132818617
# Steepness: -641.175149629028
# Step length: 76.52537363399388
# regular
#
# Iteration 1
# Objective: 32807255.964928426
# Steepness: -425.13585916570986
# Step length: 31.949427744533757
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 50
# Objective: 30093658.59119859
# Steepness: -153.99039199416424
# Step length: 707.2010738974151
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 100
# Objective: 28579870.42759521
# Steepness: -119.88397964970855
# Step length: 554.6582535296625
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 150
# Objective: 27339468.62048316
# Steepness: -79.0705638779644
# Step length: 0.9113640963276649
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 200
# Objective: 26384897.9552865
# Steepness: -58.666666666666664
# Step length: 282.00000000000017
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 250
# Objective: 25678050.533281334
# Steepness: -58.666666666666664
# Step length: 35.40673286690165
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 300
# Objective: 25437168.35141155
# Steepness: -32.29501974765054
# Step length: 107.46591511778134
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 350
# Objective: 25365491.157584675
# Steepness: -12.328980785735567
# Step length: 255.16314424810633
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 400
# Objective: 25296082.478848033
# Steepness: -5.500405611759259
# Step length: 248.9160454896174
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 450
# Objective: 25276214.568782903
# Steepness: -0.6719805377749887
# Step length: 1060.3974416869762
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Total time for steepest-descent scheme: 28.74918270111084
# Objective Value: 25275116.14088022
# Reading netlib_lp_subset\cre-c...
# removing redundant constraint 'BB013'
# removing redundant constraint 'BB023'
# removing redundant constraint 'BB031'
# removing redundant constraint 'BB032'
# removing redundant constraint 'BB033'
# removing redundant constraint 'BB034'
# removing redundant constraint 'BB035'
# removing redundant constraint 'BB043'
# removing redundant constraint 'BB053'
# removing redundant constraint 'BB063'
# removing redundant constraint 'BB073'
# removing redundant constraint 'BB083'
# removing redundant constraint 'BB093'
# removing redundant constraint 'BB123'
# removing redundant constraint 'BB133'
# removing redundant constraint 'BB141'
# removing redundant constraint 'BB142'
# removing redundant constraint 'BB143'
# removing redundant constraint 'BB144'
# removing redundant constraint 'BB145'
# removing redundant constraint 'BB163'
# removing redundant constraint 'BB173'
# removing redundant constraint 'BB213'
# removing redundant constraint 'BB231'
# removing redundant constraint 'BB232'
# removing redundant constraint 'BB233'
# removing redundant constraint 'BB234'
# removing redundant constraint 'BB235'
# removing redundant constraint 'BB303'
# removing redundant constraint 'BB384'
# removing redundant constraint 'BB414'
# removing redundant constraint 'BB424'
# removing redundant constraint 'BB434'
# removing redundant constraint 'BB444'
# removing redundant constraint 'BB454'
# removing redundant constraint 'BB484'
# removing redundant constraint 'BB551'
# removing redundant constraint 'BB552'
# removing redundant constraint 'BB553'
# removing redundant constraint 'BB554'
# removing redundant constraint 'BB555'
# removing redundant constraint 'BB571'
# removing redundant constraint 'BB572'
# removing redundant constraint 'BB573'
# removing redundant constraint 'BB574'
# removing redundant constraint 'BB575'
# removing redundant constraint 'BB584'
# removing redundant constraint 'BB601'
# removing redundant constraint 'BB602'
# removing redundant constraint 'BB603'
# removing redundant constraint 'BB604'
# removing redundant constraint 'BB605'
# removing redundant constraint 'BB611'
# removing redundant constraint 'BB612'
# removing redundant constraint 'BB613'
# removing redundant constraint 'BB614'
# removing redundant constraint 'BB615'
# removing redundant constraint 'BB621'
# removing redundant constraint 'BB622'
# removing redundant constraint 'BB623'
# removing redundant constraint 'BB624'
# removing redundant constraint 'BB625'
# removing redundant constraint 'BB641'
# removing redundant constraint 'BB642'
# removing redundant constraint 'BB643'
# removing redundant constraint 'BB644'
# removing redundant constraint 'BB645'
# removing redundant constraint 'BB651'
# removing redundant constraint 'BB652'
# removing redundant constraint 'BB653'
# removing redundant constraint 'BB654'
# removing redundant constraint 'BB655'
# removing redundant constraint 'BB661'
# removing redundant constraint 'BB662'
# removing redundant constraint 'BB663'
# removing redundant constraint 'BB664'
# removing redundant constraint 'BB665'
# removing redundant constraint 'BB671'
# removing redundant constraint 'BB672'
# removing redundant constraint 'BB673'
# removing redundant constraint 'BB674'
# removing redundant constraint 'BB675'
# Building polyhedron...
# Problem size: n = 3678,  m_B = 6411,  m_A = 253
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 25275116.140880227
# Total solve time: 0.07705497741699219
# Number of iterations: 2694.0
# Reading netlib_lp_subset\modszk1...
# removing redundant constraint 'ROW0147'
# Building polyhedron...
# Problem size: n = 1620,  m_B = 1618,  m_A = 686
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.075066089630127
# 599
#
# Iteration 0
# Objective: 699998.447478
# Steepness: -0.07001241293244018
# Step length: 3143467.2427973496
# regular
#
# Iteration 1
# Objective: 479916.7208356728
# Steepness: -0.06813450045722237
# Step length: 994453.6074015652
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
#
# Iteration 50
# Objective: 546.1423394468627
# Steepness: -0.01625016448093732
# Step length: 2617.1582900835015
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# regular
# Total time for steepest-descent scheme: 1.0856900215148926
# Objective Value: 305.0545144922107
# Reading netlib_lp_subset\modszk1...
# removing redundant constraint 'ROW0147'
# Building polyhedron...
# Problem size: n = 1620,  m_B = 1618,  m_A = 686
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 320.6197290648233
# Total solve time: 0.044055938720703125
# Number of iterations: 1233.0
