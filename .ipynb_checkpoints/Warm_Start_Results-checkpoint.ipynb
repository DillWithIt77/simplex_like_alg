# %% [markdown]
# # Warm Start Results

# %% [markdown]
# ## Import Statements

# %%
import os
import pickle
import subprocess

from main import main

from glob import glob
import numpy as np
import random
from matplotlib import pyplot as plt
# %matplotlib inline

from utils import avg

# %% [markdown]
# ## Run Tests

# %%
# problems = ['adlittle', 'afiro', 'agg2','agg3','agg', 'bandm',
#  'beaconfd', 'blend', 'bnl1', 'boeing1', 'boeing2', 'bore3d', 'brandy', 'capri',
#  'cycle', 'degen2', 'degen3', 'e226', 'etamacro', 'fffff800', 'finnis',
#  'fit1d', 'fit1p', 'forplan', 'ganges', 'gfrd-pnc', 'grow15', 'grow22', 'grow7']
            # ,
# problems = ['maros']
problems = ['israel', 'kb2', 'ken-07', 'lotfi', 'pds-02', 'perold',
  'pilotnov', 'qap08', 'recipe', 'sc105', 'sc205', 'sc50a',
 'sc50b', 'scagr25', 'scagr7', 'scfxm1', 'scfxm2', 'scfxm3', 'scorpion', 'scrs8',
 'scsd1', 'scsd6', 'scsd8', 'sctap1', 'sctap2', 'sctap3', 'seba', 'share1b']
 #             ,
 # problems = ['share2b', 'shell', 'ship04l', 'ship04s', 'ship08l', 'ship08s', 'ship12l', 'ship12s',
 # 'sierra', 'stair', 'standata', 'standgub', 'standmps', 'stocfor1', 'stocfor2', 'tuff',
 # 'vtp_base', 'wood1p', 'cre-c', 'modszk1']     

# 'cre-c', 'modszk1',
    
results_dir = 'results'
problem_dir = 'netlib_lp_subset'
max_time = 300
reset = False
sd_method = 'dual_simplex'

for i, problem in enumerate(problems):
    mps_fn = os.path.join(problem_dir, problem)
    print('\n\n\nWorking on problem {} of {}: {}'.format(i+1, len(problems), mps_fn))    
    main(mps_fn=mps_fn, results_dir=results_dir, max_time=max_time, reset=reset, sd_method=sd_method)
# Out:
# Working on problem 1 of 29: netlib_lp_subset\israel
# Reading netlib_lp_subset\israel...
# Building polyhedron...
# Problem size: n = 142,  m_B = 316,  m_A = 0
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -896644.8218630459
# Total solve time: 0.0
# Number of iterations: 198.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\israel...
# Building polyhedron...
# Problem size: n = 142,  m_B = 316,  m_A = 0
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.024148941040039062
#
# Iteration 0
# Objective: 330581.13
# Steepness: -1002.3333333333333
# Step length: 90.0
#
# Iteration 1
# Objective: 240371.13
# Steepness: -1001.6666666666666
# Step length: 150.0
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 50
# Objective: -549157.6454514507
# Steepness: -0.22335422837996546
# Step length: 8.52419212530159
# Degenerate step computed. Changing active facets...
#
# Iteration 100
# Objective: -868548.1497242879
# Steepness: -0.062138744361619994
# Step length: 43.57170347058289
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 150
# Objective: -888634.6720398816
# Steepness: -0.018186160897363905
# Step length: 56043.435305978135
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Total time for steepest-descent scheme: 0.5664699077606201
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\israel...
# Building polyhedron...
# Problem size: n = 142,  m_B = 316,  m_A = 0
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.023430347442626953
# standard form warm start
#
# Iteration 0
# Objective: 330581.13
# Steepness: -1002.3333333333333
# Step length: 90.0
#
# Iteration 1
# Objective: 240371.13
# Steepness: -1001.6666666666666
# Step length: 150.0
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 50
# Objective: -549157.6454514507
# Steepness: -0.22335422837996546
# Step length: 8.52419212530159
# Degenerate step computed. Changing active facets...
#
# Iteration 100
# Objective: -868548.1497242879
# Steepness: -0.062138744361619994
# Step length: 43.57170347058289
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 150
# Objective: -888634.6720398816
# Steepness: -0.018186160897363905
# Step length: 56043.435305978135
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Total time for steepest-descent scheme: 0.5528151988983154
#
#
#
# Working on problem 2 of 29: netlib_lp_subset\kb2
# Reading netlib_lp_subset\kb2...
# Building polyhedron...
# Problem size: n = 41,  m_B = 77,  m_A = 16
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -1749.9001299062058
# Total solve time: 0.0
# Number of iterations: 57.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\kb2...
# Building polyhedron...
# Problem size: n = 41,  m_B = 77,  m_A = 16
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0
#
# Iteration 0
# Objective: 0.0
# Steepness: -0.0792808268654455
# Step length: 6258.741180973611
#
# Iteration 1
# Objective: -496.1981759644028
# Steepness: -0.07772243885478054
# Step length: 2117.1975229708805
# Total time for steepest-descent scheme: 0.029668807983398438
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\kb2...
# Building polyhedron...
# Problem size: n = 41,  m_B = 77,  m_A = 16
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0
# standard form warm start
#
# Iteration 0
# Objective: 0.0
# Steepness: -0.0792808268654455
# Step length: 6258.741180973611
#
# Iteration 1
# Objective: -496.1981759644028
# Steepness: -0.07772243885478054
# Step length: 2117.1975229708805
# Total time for steepest-descent scheme: 0.03349494934082031
#
#
#
# Working on problem 3 of 29: netlib_lp_subset\ken-07
# Reading netlib_lp_subset\ken-07...
# Building polyhedron...
# Problem size: n = 3602,  m_B = 7204,  m_A = 2426
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -679520443.3816886
# Total solve time: 0.001990079879760742
# Number of iterations: 1285.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\ken-07...
# Building polyhedron...
# Problem size: n = 3602,  m_B = 7204,  m_A = 2426
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 9.764652252197266
#
# Iteration 0
# Objective: -575077381.51734
# Steepness: -5000.0
# Step length: 56.0
#
# Iteration 1
# Objective: -575357381.51734
# Steepness: -5000.0
# Step length: 136.0
#
# Iteration 50
# Objective: -599132575.151887
# Steepness: -3300.308731125
# Step length: 88.0
#
# Iteration 100
# Objective: -616770328.4358441
# Steepness: -2550.655004
# Step length: 47.99999999999999
#
# Iteration 150
# Objective: -631501736.936895
# Steepness: -1916.006456642857
# Step length: 112.0
#
# Iteration 200
# Objective: -641492498.8746719
# Steepness: -1624.0500217222223
# Step length: 342.0
#
# Iteration 250
# Objective: -650636279.0972517
# Steepness: -1393.9926601333332
# Step length: 30.00000000000003
#
# Iteration 300
# Objective: -657522468.6275555
# Steepness: -1141.8700033461537
# Step length: 26.0
#
# Iteration 350
# Objective: -663110720.8052545
# Steepness: -935.2904184594596
# Step length: 443.9999999999999
#
# Iteration 400
# Objective: -667735454.4619645
# Steepness: -763.3588926944444
# Step length: 341.99999999999983
#
# Iteration 450
# Objective: -671662125.2677355
# Steepness: -617.2114159999999
# Step length: 84.0
#
# Iteration 500
# Objective: -674324083.013861
# Steepness: -449.32292179166666
# Step length: 48.0
#
# Iteration 550
# Objective: -676773416.1338887
# Steepness: -306.82486350000005
# Step length: 78.00000000000009
#
# Iteration 600
# Objective: -678057323.9930015
# Steepness: -221.17070228571436
# Step length: 83.99999999999999
#
# Iteration 650
# Objective: -679125884.8520664
# Steepness: -123.63999311363645
# Step length: 139.33333333333292
#
# Iteration 700
# Objective: -679498025.7030039
# Steepness: -28.20318045454539
# Step length: 22.000000000000004
# Total time for steepest-descent scheme: 38.6346480846405
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\ken-07...
# Building polyhedron...
# Problem size: n = 3602,  m_B = 7204,  m_A = 2426
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 10.030791997909546
# standard form warm start
#
# Iteration 0
# Objective: -575077381.51734
# Steepness: -5000.0
# Step length: 56.0
#
# Iteration 1
# Objective: -575357381.51734
# Steepness: -5000.0
# Step length: 136.0
#
# Iteration 50
# Objective: -599132575.151887
# Steepness: -3300.308731125
# Step length: 88.0
#
# Iteration 100
# Objective: -616770328.4358441
# Steepness: -2550.655004
# Step length: 47.99999999999999
#
# Iteration 150
# Objective: -631501736.936895
# Steepness: -1916.006456642857
# Step length: 112.0
#
# Iteration 200
# Objective: -641492498.8746719
# Steepness: -1624.0500217222223
# Step length: 342.0
#
# Iteration 250
# Objective: -650636279.0972517
# Steepness: -1393.9926601333332
# Step length: 30.00000000000003
#
# Iteration 300
# Objective: -657522468.6275555
# Steepness: -1141.8700033461537
# Step length: 26.0
#
# Iteration 350
# Objective: -663110720.8052545
# Steepness: -935.2904184594596
# Step length: 443.9999999999999
#
# Iteration 400
# Objective: -667735454.4619645
# Steepness: -763.3588926944444
# Step length: 341.99999999999983
#
# Iteration 450
# Objective: -671662125.2677355
# Steepness: -617.2114159999999
# Step length: 84.0
#
# Iteration 500
# Objective: -674324083.013861
# Steepness: -449.32292179166666
# Step length: 48.0
#
# Iteration 550
# Objective: -676773416.1338887
# Steepness: -306.82486350000005
# Step length: 78.00000000000009
#
# Iteration 600
# Objective: -678057323.9930015
# Steepness: -221.17070228571436
# Step length: 83.99999999999999
#
# Iteration 650
# Objective: -679125884.8520664
# Steepness: -123.63999311363645
# Step length: 139.33333333333292
#
# Iteration 700
# Objective: -679498025.7030039
# Steepness: -28.20318045454539
# Step length: 22.000000000000004
# Total time for steepest-descent scheme: 38.883066177368164
#
#
#
# Working on problem 4 of 29: netlib_lp_subset\lotfi
# Reading netlib_lp_subset\lotfi...
# Building polyhedron...
# Problem size: n = 308,  m_B = 366,  m_A = 95
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -25.264706061880013
# Total solve time: 0.0
# Number of iterations: 270.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\lotfi...
# Building polyhedron...
# Problem size: n = 308,  m_B = 366,  m_A = 95
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.04573202133178711
#
# Iteration 0
# Objective: 241.27149999
# Steepness: -0.003639973527465255
# Step length: 362.64
#
# Iteration 1
# Objective: 239.95149999
# Steepness: -0.003639973527465255
# Step length: 120.88000000000004
#
# Iteration 50
# Objective: -24.643977176174744
# Steepness: -0.0001428163381890888
# Step length: 356.42693599321626
# Total time for steepest-descent scheme: 0.19718551635742188
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\lotfi...
# Building polyhedron...
# Problem size: n = 308,  m_B = 366,  m_A = 95
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.04837536811828613
# standard form warm start
#
# Iteration 0
# Objective: 241.27149999
# Steepness: -0.003639973527465255
# Step length: 362.64
#
# Iteration 1
# Objective: 239.95149999
# Steepness: -0.003639973527465255
# Step length: 120.88000000000004
#
# Iteration 50
# Objective: -24.643977176174744
# Steepness: -0.0001428163381890888
# Step length: 356.42693599321626
# Total time for steepest-descent scheme: 0.19546890258789062
#
#
#
# Working on problem 5 of 29: netlib_lp_subset\pds-02
# Reading netlib_lp_subset\pds-02...
# Building polyhedron...
# Problem size: n = 7535,  m_B = 9850,  m_A = 2772
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 28857862010.0
# Total solve time: 0.023190736770629883
# Number of iterations: 1626.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\pds-02...
# Building polyhedron...
# Problem size: n = 7535,  m_B = 9850,  m_A = 2772
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 27.1339008808136
#
# Iteration 0
# Objective: 29313633510.0
# Steepness: -7644.923076923077
# Step length: 1170.0
#
# Iteration 1
# Objective: 29304688950.0
# Steepness: -7644.923076923076
# Step length: 1248.0
#
# Iteration 50
# Objective: 28923260657.0
# Steepness: -4166.625
# Step length: 1600.0
#
# Iteration 100
# Objective: 28857878942.0
# Steepness: -4.25
# Step length: 664.0
# Total time for steepest-descent scheme: 10.133833169937134
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\pds-02...
# Building polyhedron...
# Problem size: n = 7535,  m_B = 9850,  m_A = 2772
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 29.283151149749756
# standard form warm start
#
# Iteration 0
# Objective: 29313633510.0
# Steepness: -7644.923076923077
# Step length: 1170.0
#
# Iteration 1
# Objective: 29304688950.0
# Steepness: -7644.923076923076
# Step length: 1248.0
#
# Iteration 50
# Objective: 28923260657.0
# Steepness: -4166.625
# Step length: 1600.0
#
# Iteration 100
# Objective: 28857878942.0
# Steepness: -4.25
# Step length: 664.0
# Total time for steepest-descent scheme: 14.632773399353027
#
#
#
# Working on problem 6 of 29: netlib_lp_subset\perold
# Reading netlib_lp_subset\perold...
# Building polyhedron...
# Problem size: n = 1376,  m_B = 1620,  m_A = 559
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -9380.75527823477
# Total solve time: 0.0793759822845459
# Number of iterations: 1343.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\perold...
# Building polyhedron...
# Problem size: n = 1376,  m_B = 1620,  m_A = 559
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.9312746524810791
#
# Iteration 0
# Objective: -5878.539464724801
# Steepness: -0.1298021494076112
# Step length: 16.51812373752404
#
# Iteration 1
# Objective: -5880.683552690113
# Steepness: -0.12967917588992592
# Step length: 4.810617745574795
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 50
# Objective: -5891.497608320888
# Steepness: -0.11339056912359134
# Step length: 1.6093280663778555
#
# Iteration 100
# Objective: -5921.233456902385
# Steepness: -0.10624875027895286
# Step length: 64.48081582976096
# Degenerate step computed. Changing active facets...
#
# Iteration 150
# Objective: -6346.768023927732
# Steepness: -0.1027068482553756
# Step length: 384.0238129721613
#
# Iteration 200
# Objective: -6602.120138686976
# Steepness: -0.060415581576635284
# Step length: 3.9146302549717475
#
# Iteration 250
# Objective: -6658.540326597856
# Steepness: -0.04890735650494484
# Step length: 41.66356325718628
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 300
# Objective: -6701.36296068084
# Steepness: -0.036871697084774904
# Step length: 6.42813966670168
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 350
# Objective: -6715.974585659811
# Steepness: -0.027442703066384133
# Step length: 0.7943674001001994
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 400
# Objective: -6797.3569330928785
# Steepness: -0.019739448966650957
# Step length: 1.6502035914866762
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 450
# Objective: -7352.565435397062
# Steepness: -0.0157183009325452
# Step length: 716.3069774146052
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 500
# Objective: -7517.674565033803
# Steepness: -0.012743991149546205
# Step length: 562.8530317238473
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 550
# Objective: -7940.418536664971
# Steepness: -0.011682490735456501
# Step length: 2637.3794505692076
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 600
# Objective: -8660.52343559625
# Steepness: -0.008976153738445264
# Step length: 173.92168582388976
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 650
# Objective: -9102.321190297034
# Steepness: -0.005743917830198199
# Step length: 6.27983563721356
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 700
# Objective: -9132.488536822828
# Steepness: -0.003942689888491498
# Step length: -6.063445650691375e-12
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 750
# Objective: -9143.660853293477
# Steepness: -0.0016639791978986735
# Step length: 25.2594434204877
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 800
# Objective: -9150.934414761054
# Steepness: -0.0009959558868248585
# Step length: 1.343365584531387
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 850
# Objective: -9277.28907376299
# Steepness: -0.0007804747002427
# Step length: -30773.75511615914
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 900
# Objective: -9290.527347696694
# Steepness: -0.0005368385213139727
# Step length: 575.5259015651894
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 950
# Objective: -9310.671208319796
# Steepness: -0.00035684896387698235
# Step length: 90.89264108387654
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1000
# Objective: -9323.275819767892
# Steepness: -0.0002148572483903692
# Step length: -0.0
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1050
# Objective: -9335.870429867391
# Steepness: -0.00012356915907066313
# Step length: 3352.2368035763916
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1100
# Objective: -9357.588041701061
# Steepness: -8.76837470052083e-05
# Step length: 640.6415028817962
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1150
# Objective: -9365.861297982628
# Steepness: -5.159662582534341e-05
# Step length: 6417.056396853218
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1200
# Objective: -9380.262479909832
# Steepness: -1.1131150082931853e-05
# Step length: 3030.0662069944883
# Degenerate step computed. Changing active facets...
# Total time for steepest-descent scheme: 20.50045108795166
#
# Solving with new steepest descent...
# Reading netlib_lp_subset\perold...
# Building polyhedron...
# Problem size: n = 1376,  m_B = 1620,  m_A = 559
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.8734521865844727
# standard form warm start
#
# Iteration 0
# Objective: -5878.539464724801
# Steepness: -0.1298021494076112
# Step length: 16.51812373752404
#
# Iteration 1
# Objective: -5880.683552690113
# Steepness: -0.12967917588992592
# Step length: 4.810617745574795
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 50
# Objective: -5891.497608320888
# Steepness: -0.11339056912359134
# Step length: 1.6093280663778555
#
# Iteration 100
# Objective: -5921.233456902385
# Steepness: -0.10624875027895286
# Step length: 64.48081582976096
# Degenerate step computed. Changing active facets...
#
# Iteration 150
# Objective: -6346.768023927732
# Steepness: -0.1027068482553756
# Step length: 384.0238129721613
#
# Iteration 200
# Objective: -6602.120138686976
# Steepness: -0.060415581576635284
# Step length: 3.9146302549717475
#
# Iteration 250
# Objective: -6658.540326597856
# Steepness: -0.04890735650494484
# Step length: 41.66356325718628
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 300
# Objective: -6701.36296068084
# Steepness: -0.036871697084774904
# Step length: 6.42813966670168
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 350
# Objective: -6715.974585659811
# Steepness: -0.027442703066384133
# Step length: 0.7943674001001994
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 400
# Objective: -6797.3569330928785
# Steepness: -0.019739448966650957
# Step length: 1.6502035914866762
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 450
# Objective: -7352.565435397062
# Steepness: -0.0157183009325452
# Step length: 716.3069774146052
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 500
# Objective: -7517.674565033803
# Steepness: -0.012743991149546205
# Step length: 562.8530317238473
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 550
# Objective: -7940.418536664971
# Steepness: -0.011682490735456501
# Step length: 2637.3794505692076
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 600
# Objective: -8660.52343559625
# Steepness: -0.008976153738445264
# Step length: 173.92168582388976
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 650
# Objective: -9102.321190297034
# Steepness: -0.005743917830198199
# Step length: 6.27983563721356
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 700
# Objective: -9132.488536822828
# Steepness: -0.003942689888491498
# Step length: -6.063445650691375e-12
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 750
# Objective: -9143.660853293477
# Steepness: -0.0016639791978986735
# Step length: 25.2594434204877
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 800
# Objective: -9150.934414761054
# Steepness: -0.0009959558868248585
# Step length: 1.343365584531387
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 850
# Objective: -9277.28907376299
# Steepness: -0.0007804747002427
# Step length: -30773.75511615914
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 900
# Objective: -9290.527347696694
# Steepness: -0.0005368385213139727
# Step length: 575.5259015651894
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 950
# Objective: -9310.671208319796
# Steepness: -0.00035684896387698235
# Step length: 90.89264108387654
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1000
# Objective: -9323.275819767892
# Steepness: -0.0002148572483903692
# Step length: -0.0
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1050
# Objective: -9335.870429867391
# Steepness: -0.00012356915907066313
# Step length: 3352.2368035763916
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1100
# Objective: -9357.588041701061
# Steepness: -8.76837470052083e-05
# Step length: 640.6415028817962
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1150
# Objective: -9365.861297982628
# Steepness: -5.159662582534341e-05
# Step length: 6417.056396853218
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 1200
# Objective: -9380.262479909832
# Steepness: -1.1131150082931853e-05
# Step length: 3030.0662069944883
# Degenerate step computed. Changing active facets...
# Total time for steepest-descent scheme: 20.527731895446777
#
#
#
# Working on problem 7 of 29: netlib_lp_subset\pilot4
# Reading netlib_lp_subset\pilot4...
# Building polyhedron...
# Problem size: n = 1000,  m_B = 1252,  m_A = 317
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -2581.139259564279
# Total solve time: 0.041753530502319336
# Number of iterations: 890.0
#
# Solving with old steepest descent...
# Reading netlib_lp_subset\pilot4...
# Building polyhedron...
# Problem size: n = 1000,  m_B = 1252,  m_A = 317
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.49574828147888184
#
# Iteration 0
# Objective: 0.0
# Steepness: -0.08230652911645721
# Step length: 0.4021046639769739
#
# Iteration 1
# Objective: -0.033095839233484046
# Steepness: -0.0823063170345791
# Step length: 0.1005264805540184
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 50
# Objective: -25.038034983105405
# Steepness: -0.02116945150833488
# Step length: 56.20736799701429
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 100
# Objective: -138.7969383159167
# Steepness: -0.016434873915179272
# Step length: 489.9363911228062
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 150
# Objective: -295.2965892651142
# Steepness: -0.012324895074237886
# Step length: 12.851087706647212
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 200
# Objective: -711.6099239846869
# Steepness: -0.01212523661466369
# Step length: -992.2186329540141
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 250
# Objective: -829.3477332685413
# Steepness: -0.01145747338794195
# Step length: 16.742148302423136
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 300
# Objective: -916.4515834620815
# Steepness: -0.00678813875401999
# Step length: 1364.8896572802466
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 350
# Objective: -1033.8677753473125
# Steepness: -0.006161602002518772
# Step length: 107.55663664330115
# Degenerate step computed. Changing active facets...
#
# Iteration 400
# Objective: -1161.6700761619154
# Steepness: -0.004171684554937614
# Step length: 56.19114322853301
#
# Iteration 450
# Objective: -1350.6028291124753
# Steepness: -0.0029273559614163237
# Step length: 115.35416655422046
# Degenerate step computed. Changing active facets...
#
# Iteration 500
# Objective: -1801.2688562589342
# Steepness: -0.002209013508318869
# Step length: 3671.61628043202
#
# Iteration 550
# Objective: -1915.5407481285988
# Steepness: -0.0018946759816960003
# Step length: 41.067538983290945
#
# Iteration 600
# Objective: -2221.8075173873503
# Steepness: -0.0013665335260569923
# Step length: 12070.292479119134
#
# Iteration 650
# Objective: -2467.0423745238318
# Steepness: -0.0009056448897678953
# Step length: 1818.1688797600436
# Degenerate step computed. Changing active facets...
#
# Iteration 700
# Objective: -2522.7118707487175
# Steepness: -0.0004931915247199533
# Step length: 5.429883390970784
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 750
# Objective: -2550.1268805001
# Steepness: -0.0002026458903408476
# Step length: 6833.000736231112
#
# Iteration 800
# Objective: -2572.485986025145
# Steepness: -0.00010314933457770828
# Step length: 6.002779098766597
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 850
# Objective: -2580.7520991032725
# Steepness: -3.719936295190218e-05
# Step length: 21.672720226738992
#
# Iteration 900
# Objective: -2582.480861672215
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 950
# Objective: -2582.4810076085023
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 1000
# Objective: -2582.4798173306212
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780666258577
#
# Iteration 1050
# Objective: -2582.4808616679484
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766395994
#
# Iteration 1100
# Objective: -2582.48086167222
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 1150
# Objective: -2582.4810076085078
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 1200
# Objective: -2582.4798173306267
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780666257091
#
# Iteration 1250
# Objective: -2582.4808616679547
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766351516
#
# Iteration 1300
# Objective: -2582.4808616722257
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 1350
# Objective: -2582.481007608514
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 1400
# Objective: -2582.4798173306335
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780666255594
#
# Iteration 1450
# Objective: -2582.480861667961
# Steepness: -3.3979110265375255e-07
# Step length: 0.01236796776621808
#
# Iteration 1500
# Objective: -2582.480861672231
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 1550
# Objective: -2582.4810076085187
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 1600
# Objective: -2582.479817330638
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780666254097
#
# Iteration 1650
# Objective: -2582.480861667965
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766351516
#
# Iteration 1700
# Objective: -2582.4808616722353
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 1750
# Objective: -2582.4810076085228
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 1800
# Objective: -2582.4798173306426
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780666252613
#
# Iteration 1850
# Objective: -2582.480861667971
# Steepness: -3.3979110265375255e-07
# Step length: 0.01236796776626256
#
# Iteration 1900
# Objective: -2582.480861672242
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 1950
# Objective: -2582.48100760853
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 2000
# Objective: -2582.47981733065
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780666251116
#
# Iteration 2050
# Objective: -2582.4808616679775
# Steepness: -3.3979110265375255e-07
# Step length: 0.01236796776626256
#
# Iteration 2100
# Objective: -2582.4808616722476
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 2150
# Objective: -2582.4810076085355
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 2200
# Objective: -2582.4798173306544
# Steepness: -1.2674682173797778e-07
# Step length: 8238.78066624963
#
# Iteration 2250
# Objective: -2582.480861667981
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766395994
#
# Iteration 2300
# Objective: -2582.480861672251
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 2350
# Objective: -2582.4810076085387
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 2400
# Objective: -2582.479817330658
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780666248143
#
# Iteration 2450
# Objective: -2582.4808616679866
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766329278
#
# Iteration 2500
# Objective: -2582.4808616722576
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 2550
# Objective: -2582.481007608546
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 2600
# Objective: -2582.4798173306663
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780666246636
#
# Iteration 2650
# Objective: -2582.4808616679948
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766329278
#
# Iteration 2700
# Objective: -2582.4808616722657
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 2750
# Objective: -2582.4810076085528
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 2800
# Objective: -2582.4798173306713
# Steepness: -1.2674682173797778e-07
# Step length: 8238.78066624514
#
# Iteration 2850
# Objective: -2582.4808616679984
# Steepness: -3.3979110265375255e-07
# Step length: 0.01236796776621808
#
# Iteration 2900
# Objective: -2582.4808616722694
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 2950
# Objective: -2582.481007608557
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 3000
# Objective: -2582.479817330677
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780666243643
#
# Iteration 3050
# Objective: -2582.4808616680057
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766351516
#
# Iteration 3100
# Objective: -2582.4808616722767
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 3150
# Objective: -2582.4810076085655
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 3200
# Objective: -2582.4798173306854
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780666242157
#
# Iteration 3250
# Objective: -2582.480861668014
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766395994
#
# Iteration 3300
# Objective: -2582.480861672285
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 3350
# Objective: -2582.4810076085723
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 3400
# Objective: -2582.4798173306917
# Steepness: -1.2674682173797778e-07
# Step length: 8238.78066624066
#
# Iteration 3450
# Objective: -2582.4808616680198
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766373755
#
# Iteration 3500
# Objective: -2582.4808616722903
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 3550
# Objective: -2582.481007608578
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 3600
# Objective: -2582.4798173306976
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780666239152
#
# Iteration 3650
# Objective: -2582.4808616680257
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766329278
#
# Iteration 3700
# Objective: -2582.480861672297
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 3750
# Objective: -2582.4810076085855
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 3800
# Objective: -2582.479817330706
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780666237655
#
# Iteration 3850
# Objective: -2582.480861668034
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766307037
#
# Iteration 3900
# Objective: -2582.4808616723044
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 3950
# Objective: -2582.4810076085923
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 4000
# Objective: -2582.4798173307117
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780666236158
#
# Iteration 4050
# Objective: -2582.4808616680393
# Steepness: -3.3979110265375255e-07
# Step length: 0.01236796776626256
#
# Iteration 4100
# Objective: -2582.4808616723094
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 4150
# Objective: -2582.481007608597
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 4200
# Objective: -2582.4798173307163
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780666234663
#
# Iteration 4250
# Objective: -2582.480861668044
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766240322
#
# Iteration 4300
# Objective: -2582.480861672314
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 4350
# Objective: -2582.481007608602
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 4400
# ...
# Step length: 0.01236796776626256
#
# Iteration 42300
# Objective: -2582.4808616734463
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 42350
# Objective: -2582.4810076097347
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 42400
# Objective: -2582.479817331855
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665949029
#
# Iteration 42450
# Objective: -2582.480861669184
# Steepness: -3.3979110265375255e-07
# Step length: 0.01236796776626256
#
# Iteration 42500
# Objective: -2582.4808616734554
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 42550
# Objective: -2582.481007609743
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 42600
# Objective: -2582.4798173318627
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665947534
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File src\\gurobipy\\callback.pxi:208, in gurobipy.CallbackClass.callback()
#
# File ~\OneDrive - The University of Colorado Denver\Documents\GitHub\simplex_like_alg\polyhedral_model.py:199, in PolyhedralModel.compute_sd_direction.<locals>.dualinf_callback(model, where)
#     197 self.model._phase1_time = 0 #None
#     198 self.model._is_dualinf = True
# --> 199 def dualinf_callback(model, where):
#     200     if where == gp.GRB.Callback.SIMPLEX:
#     201         if model._is_dualinf:
#
# KeyboardInterrupt:
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "src\\gurobipy\\callback.pxi", line 208, in gurobipy.CallbackClass.callback
#   File "C:\Users\DillW\OneDrive - The University of Colorado Denver\Documents\GitHub\simplex_like_alg\polyhedral_model.py", line 199, in dualinf_callback
#     def dualinf_callback(model, where):
#
# KeyboardInterrupt:
# Iteration 42650
# Objective: -2582.4808616691907
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766329278
#
# Iteration 42700
# Objective: -2582.480861673461
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File src\\gurobipy\\callback.pxi:208, in gurobipy.CallbackClass.callback()
#
# File ~\OneDrive - The University of Colorado Denver\Documents\GitHub\simplex_like_alg\polyhedral_model.py:199, in PolyhedralModel.compute_sd_direction.<locals>.dualinf_callback(model, where)
#     197 self.model._phase1_time = 0 #None
#     198 self.model._is_dualinf = True
# --> 199 def dualinf_callback(model, where):
#     200     if where == gp.GRB.Callback.SIMPLEX:
#     201         if model._is_dualinf:
#
# KeyboardInterrupt:
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "src\\gurobipy\\callback.pxi", line 208, in gurobipy.CallbackClass.callback
#   File "C:\Users\DillW\OneDrive - The University of Colorado Denver\Documents\GitHub\simplex_like_alg\polyhedral_model.py", line 199, in dualinf_callback
#     def dualinf_callback(model, where):
#
# KeyboardInterrupt:
# Iteration 42750
# Objective: -2582.4810076097483
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 42800
# Objective: -2582.4798173318677
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665946037
#
# Iteration 42850
# Objective: -2582.4808616691953
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766307037
#
# Iteration 42900
# Objective: -2582.4808616734654
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 42950
# Objective: -2582.481007609753
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 43000
# Objective: -2582.4798173318723
# Steepness: -1.2674682173797778e-07
# Step length: 8238.78066594455
#
# Iteration 43050
# Objective: -2582.4808616692
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766240322
#
# Iteration 43100
# Objective: -2582.480861673471
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 43150
# Objective: -2582.4810076097588
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 43200
# Objective: -2582.4798173318786
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665943053
#
# Iteration 43250
# Objective: -2582.4808616692067
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766373755
#
# Iteration 43300
# Objective: -2582.4808616734776
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 43350
# Objective: -2582.4810076097647
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 43400
# Objective: -2582.479817331884
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665941556
#
# Iteration 43450
# Objective: -2582.4808616692117
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766240322
#
# Iteration 43500
# Objective: -2582.4808616734817
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 43550
# Objective: -2582.481007609769
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 43600
# Objective: -2582.4798173318877
# Steepness: -1.2674682173797778e-07
# Step length: 8238.78066594006
#
# Iteration 43650
# Objective: -2582.4808616692153
# Steepness: -3.3979110265375255e-07
# Step length: 0.0123679677662848
#
# Iteration 43700
# Objective: -2582.4808616734863
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 43750
# Objective: -2582.4810076097747
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 43800
# Objective: -2582.4798173318945
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665938564
#
# Iteration 43850
# Objective: -2582.4808616692226
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766240322
#
# Iteration 43900
# Objective: -2582.4808616734936
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 43950
# Objective: -2582.481007609782
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 44000
# Objective: -2582.4798173319004
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665937056
#
# Iteration 44050
# Objective: -2582.480861669228
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766240322
#
# Iteration 44100
# Objective: -2582.480861673498
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 44150
# Objective: -2582.4810076097847
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 44200
# Objective: -2582.479817331904
# Steepness: -1.2674682173797778e-07
# Step length: 8238.78066593557
#
# Iteration 44250
# Objective: -2582.480861669231
# Steepness: -3.3979110265375255e-07
# Step length: 0.0123679677662848
#
# Iteration 44300
# Objective: -2582.4808616735027
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 44350
# Objective: -2582.4810076097906
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 44400
# Objective: -2582.4798173319105
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665934062
#
# Iteration 44450
# Objective: -2582.480861669239
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766395994
#
# Iteration 44500
# Objective: -2582.48086167351
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 44550
# Objective: -2582.481007609799
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 44600
# Objective: -2582.4798173319186
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665932576
#
# Iteration 44650
# Objective: -2582.480861669246
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766240322
#
# Iteration 44700
# Objective: -2582.4808616735163
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 44750
# Objective: -2582.481007609804
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 44800
# Objective: -2582.4798173319236
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665931079
#
# Iteration 44850
# Objective: -2582.480861669251
# Steepness: -3.3979110265375255e-07
# Step length: 0.01236796776626256
#
# Iteration 44900
# Objective: -2582.4808616735218
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 44950
# Objective: -2582.48100760981
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 45000
# Objective: -2582.4798173319305
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665929584
#
# Iteration 45050
# Objective: -2582.480861669259
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766329278
#
# Iteration 45100
# Objective: -2582.480861673531
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 45150
# Objective: -2582.481007609819
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 45200
# Objective: -2582.4798173319386
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665928076
#
# Iteration 45250
# Objective: -2582.480861669267
# Steepness: -3.3979110265375255e-07
# Step length: 0.01236796776626256
#
# Iteration 45300
# Objective: -2582.4808616735377
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 45350
# Objective: -2582.481007609826
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 45400
# Objective: -2582.479817331946
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665926568
#
# Iteration 45450
# Objective: -2582.4808616692735
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766240322
#
# Iteration 45500
# Objective: -2582.4808616735436
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 45550
# Objective: -2582.481007609831
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 45600
# Objective: -2582.479817331951
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665925071
#
# Iteration 45650
# Objective: -2582.480861669279
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766307037
#
# Iteration 45700
# Objective: -2582.48086167355
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 45750
# Objective: -2582.4810076098374
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 45800
# Objective: -2582.479817331957
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665923574
#
# Iteration 45850
# Objective: -2582.4808616692853
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766373755
#
# Iteration 45900
# Objective: -2582.480861673556
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 45950
# Objective: -2582.4810076098433
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 46000
# Objective: -2582.4798173319623
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665922066
#
# Iteration 46050
# Objective: -2582.48086166929
# Steepness: -3.3979110265375255e-07
# Step length: 0.01236796776621808
#
# Iteration 46100
# Objective: -2582.48086167356
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 46150
# Objective: -2582.4810076098474
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 46200
# Objective: -2582.479817331967
# Steepness: -1.2674682173797778e-07
# Step length: 8238.78066592058
#
# Iteration 46250
# Objective: -2582.480861669294
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766329278
#
# Iteration 46300
# Objective: -2582.480861673565
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 46350
# Objective: -2582.481007609853
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 46400
# Objective: -2582.479817331973
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665919096
#
# Iteration 46450
# Objective: -2582.480861669301
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766240322
#
# Iteration 46500
# Objective: -2582.4808616735722
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 46550
# Objective: -2582.4810076098597
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 46600
# Objective: -2582.4798173319787
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665917588
#
# Iteration 46650
# Objective: -2582.4808616693063
# Steepness: -3.3979110265375255e-07
# Step length: 0.01236796776626256
#
# Iteration 46700
# Objective: -2582.480861673577
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 46750
# Objective: -2582.481007609864
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 46800
# Objective: -2582.4798173319823
# Steepness: -1.2674682173797778e-07
# Step length: 8238.78066591609
#
# Iteration 46850
# Objective: -2582.48086166931
# Steepness: -3.3979110265375255e-07
# Step length: 0.0123679677662848
#
# Iteration 46900
# Objective: -2582.480861673581
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 46950
# Objective: -2582.4810076098693
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 47000
# Objective: -2582.4798173319887
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665914594
#
# Iteration 47050
# Objective: -2582.480861669317
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766373755
#
# Iteration 47100
# Objective: -2582.480861673588
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 47150
# Objective: -2582.481007609876
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 47200
# Objective: -2582.4798173319955
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665913097
#
# Iteration 47250
# Objective: -2582.4808616693226
# Steepness: -3.3979110265375255e-07
# Step length: 0.01236796776626256
#
# Iteration 47300
# Objective: -2582.4808616735922
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 47350
# Objective: -2582.4810076098797
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 47400
# Objective: -2582.4798173319987
# Steepness: -1.2674682173797778e-07
# Step length: 8238.7806659116
#
# Iteration 47450
# Objective: -2582.4808616693267
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766351516
#
# Iteration 47500
# Objective: -2582.4808616735977
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 47550
# Objective: -2582.481007609886
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 47600
# Objective: -2582.4798173320064
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665910102
#
# Iteration 47650
# Objective: -2582.480861669335
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766351516
#
# Iteration 47700
# Objective: -2582.4808616736063
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 47750
# Objective: -2582.4810076098947
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 47800
# Objective: -2582.479817332015
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665908595
#
# Iteration 47850
# Objective: -2582.4808616693417
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766307037
#
# Iteration 47900
# Objective: -2582.4808616736127
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 47950
# Objective: -2582.4810076099
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 48000
# Objective: -2582.4798173320196
# Steepness: -1.2674682173797778e-07
# Step length: 8238.780665907098
#
# Iteration 48050
# Objective: -2582.480861669348
# Steepness: -3.3979110265375255e-07
# Step length: 0.01236796776626256
#
# Iteration 48100
# Objective: -2582.4808616736186
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 48150
# Objective: -2582.4810076099075
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357
#
# Iteration 48200
# Objective: -2582.479817332028
# Steepness: -1.2674682173797778e-07
# Step length: 8238.78066590559
#
# Iteration 48250
# Objective: -2582.4808616693563
# Steepness: -3.3979110265375255e-07
# Step length: 0.012367967766418233
#
# Iteration 48300
# Objective: -2582.4808616736277
# Steepness: -1.3055529809868793e-07
# Step length: 1117.5067222785824
#
# Iteration 48350
# Objective: -2582.4810076099157
# Steepness: 1.306438974683952e-07
# Step length: 1117.8372692890357

# %% [markdown]
# ## View Results

# %%
results_dir = 'results'
problems = ['adlittle', 'afiro', 'agg2','agg3','agg', 'bandm',
 'beaconfd', 'blend', 'bnl1', 'boeing1', 'boeing2', 'bore3d', 'brandy', 'capri',
'cycle', 'degen2', 'degen3', 'e226', 'etamacro', 'fffff800', 'finnis',
 'fit1d', 'fit1p', 'forplan', 'ganges', 'gfrd-pnc', 'grow15', 'grow22', 'grow7',
 'israel', 'kb2', 'ken-07', 'lotfi', 'maros', 'pds-02', 'perold',
 'pilot4', 'pilotnov', 'pilot', 'qap08', 'recipe', 'sc105', 'sc205', 'sc50a',
 'sc50b', 'scagr25', 'scagr7', 'scfxm1', 'scfxm2', 'scfxm3', 'scorpion', 'scrs8',
 'scsd1', 'scsd6', 'scsd8', 'sctap1', 'sctap2', 'sctap3', 'seba', 'share1b',
 'share2b', 'shell', 'ship04l', 'ship04s', 'ship08l', 'ship08s', 'ship12l', 'ship12s',
 'sierra', 'stair', 'standata', 'standgub', 'standmps', 'stocfor1', 'stocfor2', 'tuff',
 'vtp_base', 'wood1p', 'cre-c', 'modszk1']     

# 'cre-c','modszk1',
avgs = {'lp_time': [], 'old_sd_time': [], 'new_sd_time': [], 'old_first_sd': [], 'new_first_sd': [], 'old_avg_sd': [], 'new_avg_sd': [],
        'lp_iters': [], 'old_sd_iters': [], 'new_sd_iters': []}
from statistics import median

figure_dir = 'figures'
if not os.path.exists(figure_dir): os.mkdir(figure_dir)
for problem in problems:
    lp_fn = os.path.join(results_dir, problem + '_lp.p')
    old_sd_fn = os.path.join(results_dir, problem + '_old_sd.p')
    if not os.path.exists(old_sd_fn): continue
    new_sd_fn = os.path.join(results_dir, problem + '_new_sd.p')
    if not os.path.exists(new_sd_fn): continue
    
    
    with open(lp_fn, 'rb') as f:
        lp_results = pickle.load(f)
    with open(old_sd_fn, 'rb') as f:
        old_sd_results = pickle.load(f)
    with open(new_sd_fn, 'rb') as f:
        new_sd_results = pickle.load(f)
        
    try: 
        avgs['old_first_sd'].append(old_sd_results['solve_times'][0])
        avgs['old_avg_sd'].append(avg(old_sd_results['solve_times'][1:]))
        avgs['new_first_sd'].append(new_sd_results['solve_times'][0])
        avgs['new_avg_sd'].append(avg(new_sd_results['solve_times'][1:]))
        avgs['lp_time'].append(lp_results['solve_time_total'])
        avgs['old_sd_time'].append(old_sd_results['solve_time_total'])
        avgs['new_sd_time'].append(new_sd_results['solve_time_total'])
        avgs['lp_iters'].append(lp_results['n_iters'])
        avgs['old_sd_iters'].append(old_sd_results['n_iters'])
        avgs['new_sd_iters'].append(new_sd_results['n_iters'])
    except KeyError:
        print('skipping {}'.format(problem))
        continue
        
for metric in avgs:
    print(metric)
    print('Average {}: {}'.format(metric, avg(avgs[metric])))
    print('Median {}: {}'.format(metric, median(avgs[metric])))

# %%
problems = ['stocfor2', 'cycle', 'standmps', 'shell',
            'scagr25', 'scfxm2', 'etamacro', 'qap08', 'share1b',
            'grow15', 'grow22', 'grow7', 'degen3', 'cycle']
# 'modszk1', 'cre-c',
problems = ['cycle', 'degen3', 'modszk1']
# 'modszk1',


results_dir = 'results_dual_simplex_phase1'
figure_dir = 'figs_final'
save_figs = True

if not os.path.exists(figure_dir): os.mkdir(figure_dir)
for problem in problems:
    lp_fn = os.path.join(results_dir, problem + '_lp.p')
    old_sd_fn = os.path.join(results_dir, problem + '_old_sd.p')
    if not os.path.exists(old_sd_fn): continue
    new_sd_fn = os.path.join(results_dir, problem + '_new_sd.p')
    if not os.path.exists(new_sd_fn): continue
    problem_name = problem
    
    with open(lp_fn, 'rb') as f:
        lp_results = pickle.load(f)
    with open(old_sd_fn, 'rb') as f:
        old_sd_results = pickle.load(f)
    with open(new_sd_fn, 'rb') as f:
        new_sd_results = pickle.load(f)
        
    lp_results['obj_values'].append(lp_results['obj'])  
    lp_results['iter_times'].append(lp_results['solve_time_total'])  
    plt.figure(figsize=(10,5))
    plt.title('Simplex Objective for {}'.format(problem_name))
    plt.xlabel('Iteration')
    plt.ylabel('Obj. Value')
    plt.plot(list(range(len(lp_results['obj_values']))), lp_results['obj_values'], 'go-')
    fn = os.path.join(figure_dir, '{}_{}_lp_iter.png'.format(problem, results_dir))
    if save_figs: plt.savefig(fname=fn)
    plt.show()
    
    plt.figure(figsize=(10,5))
    plt.title('SD Objective for {}'.format(problem_name))
    plt.xlabel('Iteration')
    plt.ylabel('Obj. Value')
    plt.plot(list(range(len(old_sd_results['obj_values']))), old_sd_results['obj_values'], 'bo-')
    fn = os.path.join(figure_dir, '{}_{}_sd_iter.png'.format(problem, results_dir))
    if save_figs: plt.savefig(fname=fn)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('SD Objective for {}'.format(problem_name))
    plt.xlabel('Iteration')
    plt.ylabel('Obj. Value')
    plt.plot(list(range(len(new_sd_results['obj_values']))), new_sd_results['obj_values'], 'bo-')
    fn = os.path.join(figure_dir, '{}_{}_sd_iter.png'.format(problem, results_dir))
    if save_figs: plt.savefig(fname=fn)
    plt.show()
    
    times = {}
    times['sd total'] = sd_results['solve_time_total']
    times['simplex total'] = lp_results['solve_time_total']
    times['first old SD step time'] = old_sd_results['solve_times'][0]
    times['average old SD step time'] = avg(old_sd_results['solve_times'][1:])
    times['first old SD step time'] = new_sd_results['solve_times'][0]
    times['average old SD step time'] = avg(new_sd_results['solve_times'][1:])
    times['first SD Phase1 time'] = sd_results['sub_times']['phase1_times'][0]
    old_phase1_time = old_sd_results['sub_times']['phase1_times'][0]
    old_phase1_times = [0, old_phase1_time, 0]
    new_phase1_time = new_sd_results['sub_times']['phase1_times'][0]
    new_phase1_times = [0, new_phase1_time, 0]
    times['first old SD step time'] -= old_phase1_time
    times['first new SD step time'] -= new_phase1_time
    
    time_types = [key for key in times]

    #f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,5))
    plt.figure(figsize=(6,5))
    plt.title('Time breakdown for {}'.format(problem_name))
    plt.ylabel('Time (s)')
    x_pos = np.arange(len(time_types))
    plt.xticks(x_pos, time_types)
    values = [times[key] for key in times]
    p2 = plt.bar(x_pos, values, align='center', alpha=0.8)
    p1 = plt.bar(x_pos, phase1_times, bottom=values, align='center', alpha=0.8)
    fn = os.path.join(figure_dir, '{}_{}_time_breakdown.png'.format(problem, results_dir))
    plt.legend((p1[0], p2[0]), ('Phase I', 'Phase II'))
    plt.ylim(top=times['simplex total']*1.05)
    if save_figs: plt.savefig(fname=fn)
    plt.show()

    #ax2.set_title('Step breakdown for {}'.format(problem_name))
    #ax2.set_ylabel('Time (s)')
    #x_pos = np.arange(len(subtime_types))
    #ax2.set_xticks(x_pos)
    #ax2.set_xticklabels(subtime_types)
    #values = [subtimes[key] for key in subtimes]
    #ax2.bar(x_pos, values, align='center', alpha=0.8, color='m')
    #f.show()  
    
    plt.figure(figsize=(10,5))
    plt.title('Time comparison for {}'.format(problem_name))
    plt.xlabel('Time (s)')
    plt.ylabel('Obj. Value')
    plt.plot(lp_results['iter_times'], lp_results['obj_values'], 'go-', label='simplex')
    plt.plot(old_sd_results['iter_times'], old_sd_results['obj_values'], 'bo-', label='steepest-descent')
    plt.plot(new_sd_results['iter_times'], new_sd_results['obj_values'], 'bo-', label='steepest-descent')
    plt.legend(loc='upper right')
    fn = os.path.join(figure_dir, '{}_{}_time_comp.png'.format(problem, results_dir))
    if save_figs: plt.savefig(fname=fn)
    plt.show()
