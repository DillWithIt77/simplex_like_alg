# %% [markdown]
# # Warm Start Results

# %% [markdown]
# ## Import Statements

# %%
import os
import pickle
import subprocess

from facet_main import facet_main

from glob import glob
import numpy as np
import random
from matplotlib import pyplot as plt
# %matplotlib inline

from utils import avg

# %% [markdown]
# ## Run Tests

# %%
problems = ['adlittle', 'afiro', 'agg2','agg3','agg', 'bandm',
 'beaconfd', 'blend', 'bnl1', 'boeing1', 'boeing2', 'bore3d', 'brandy', 'capri',
 'cycle', 'degen2', 'degen3', 'e226', 'etamacro', 'fffff800', 'finnis',
 'fit1d', 'fit1p', 'forplan', 'ganges', 'gfrd-pnc', 'grow15', 'grow22', 'grow7',
 'israel', 'kb2', 'ken-07', 'lotfi', 'maros', 'pds-02', 'perold',
 'pilotnov', 'qap08', 'recipe', 'sc105', 'sc205', 'sc50a',
 'sc50b', 'scagr25', 'scagr7', 'scfxm1', 'scfxm2', 'scfxm3', 'scorpion', 'scrs8',
 'scsd1', 'scsd6', 'scsd8', 'sctap1', 'sctap2', 'sctap3', 'seba', 'share1b',
 'share2b', 'shell', 'ship04l', 'ship04s', 'ship08l', 'ship08s', 'ship12l', 'ship12s',
 'sierra', 'stair', 'standata', 'standgub', 'standmps', 'stocfor1', 'stocfor2', 'tuff',
 'vtp_base', 'wood1p', 'cre-c', 'modszk1']     
# 'shell','modszk1'
# 'cre-c', 'modszk1',
# 'pilot4',
    
results_dir = 'results'
problem_dir = 'netlib_lp_subset'
max_time = 300
reset = False
sd_method = 'dual_simplex'

for i, problem in enumerate(problems):
    mps_fn = os.path.join(problem_dir, problem)
    print('\n\n\nWorking on problem {} of {}: {}'.format(i+1, len(problems), mps_fn))    
    facet_main(mps_fn=mps_fn, results_dir=results_dir, max_time=max_time, reset=reset, sd_method=sd_method)
# Out:
# Working on problem 1 of 78: netlib_lp_subset\adlittle
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-01
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 225494.96316238024
# Total solve time: 0.006999969482421875
# Number of iterations: 100.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0065076351165771484
#
# Iteration 0
# Objective: 671734.1100278501
# Steepness: -1093.3333333333335
# Step length: 1.492387497139124
#
# Iteration 1
# Objective: 670102.4330309781
# Steepness: -608.695652173913
# Step length: 14.047128014198497
#
# Iteration 50
# Objective: 225785.31769628634
# Steepness: -1.1566308634677132
# Step length: 10.69303715265792
# Total time for steepest-descent scheme: 0.07938289642333984
#
# Solving with circuit aug with updated active inds steepest descent...
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.008610963821411133
#
# Iteration 0
# Objective: 671734.1100278501
# Steepness: -1093.3333333333335
# Step length: 1.492387497139124
#
# Iteration 1
# Objective: 670102.4330309781
# Steepness: -608.695652173913
# Step length: 14.047128014198497
#
# Iteration 50
# Objective: 225785.31769628634
# Steepness: -1.1566308634677132
# Step length: 10.69303715265792
# Total time for steepest-descent scheme: 0.0894613265991211
#
# Solving with circuit aug with initial active inds steepest descent...
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0
#
# Iteration 0
# Objective: 671734.1100278501
# Steepness: -1093.3333333333335
# Step length: 1.492387497139124
#
# Iteration 1
# Objective: 670102.4330309781
# Steepness: -608.695652173913
# Step length: 14.047128014198497
#
# Iteration 50
# Objective: 225785.31769628634
# Steepness: -1.1566308634677132
# Step length: 10.69303715265792
# Total time for steepest-descent scheme: 0.09040141105651855
#
# Finish solving with simplex with updated active inds steepest descent...
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.017009973526000977
#
# Iteration 0
# Objective: 671734.1100278501
# Steepness: -1093.3333333333335
# Step length: 1.492387497139124
#
# Iteration 1
# Objective: 670102.4330309781
# Steepness: -608.695652173913
# Step length: 14.047128014198497
# Total time for steepest-descent scheme: 0.04811573028564453
#
# Finish solving with simplex with initial active inds steepest descent...
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0019381046295166016
#
# Iteration 0
# Objective: 671734.1100278501
# Steepness: -1093.3333333333335
# Step length: 1.492387497139124
#
# Iteration 1
# Objective: 670102.4330309781
# Steepness: -608.695652173913
# Step length: 14.047128014198497
# Total time for steepest-descent scheme: 0.04559588432312012
#
#
#
# Working on problem 2 of 78: netlib_lp_subset\afiro
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -464.75314285714285
# Total solve time: 0.0
# Number of iterations: 19.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0
#
# Iteration 0
# Objective: 440.0
# Steepness: -3.333333333333334
# Step length: 131.99999999999997
#
# Iteration 1
# Objective: 7.105427357601002e-14
# Steepness: -0.14049832478346544
# Step length: 3245.3160714285714
# Total time for steepest-descent scheme: 0.016640901565551758
#
# Solving with circuit aug with updated active inds steepest descent...
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.002499103546142578
#
# Iteration 0
# Objective: 440.0
# Steepness: -3.333333333333334
# Step length: 131.99999999999997
#
# Iteration 1
# Objective: 7.105427357601002e-14
# Steepness: -0.14049832478346544
# Step length: 3245.3160714285714
# Total time for steepest-descent scheme: 0.0
#
# Solving with circuit aug with initial active inds steepest descent...
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.009514331817626953
#
# Iteration 0
# Objective: 440.0
# Steepness: -3.333333333333334
# Step length: 131.99999999999997
#
# Iteration 1
# Objective: 7.105427357601002e-14
# Steepness: -0.14049832478346544
# Step length: 3245.3160714285714
# Total time for steepest-descent scheme: 0.0026350021362304688
#
# Finish solving with simplex with updated active inds steepest descent...
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0
#
# Iteration 0
# Objective: 440.0
# Steepness: -3.333333333333334
# Step length: 131.99999999999997
#
# Iteration 1
# Objective: 7.105427357601002e-14
# Steepness: -0.14049832478346544
# Step length: 3245.3160714285714
# Total time for steepest-descent scheme: 0.008476972579956055
#
# Finish solving with simplex with initial active inds steepest descent...
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0025086402893066406
#
# Iteration 0
# Objective: 440.0
# Steepness: -3.333333333333334
# Step length: 131.99999999999997
#
# Iteration 1
# Objective: 7.105427357601002e-14
# Steepness: -0.14049832478346544
# Step length: 3245.3160714285714
# Total time for steepest-descent scheme: 0.0036857128143310547
#
#
#
# Working on problem 3 of 78: netlib_lp_subset\agg2
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -20239252.355977118
# Total solve time: 0.009999990463256836
# Number of iterations: 158.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0820767879486084
#
# Iteration 0
# Objective: 109626646.32852079
# Steepness: -83.04516320666386
# Step length: 742.8174157224255
#
# Iteration 1
# Objective: 109564958.93499938
# Steepness: -58.894049681906935
# Step length: 2062.9421267070884
#
# Iteration 50
# Objective: -17812065.089391712
# Steepness: -1.1416934370415128
# Step length: 236890.10620872286
# Total time for steepest-descent scheme: 0.580385684967041
#
# Solving with circuit aug with updated active inds steepest descent...
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.08972859382629395
#
# Iteration 0
# Objective: 109626646.32852079
# Steepness: -83.04516320666386
# Step length: 742.8174157224255
#
# Iteration 1
# Objective: 109564958.93499938
# Steepness: -58.894049681906935
# Step length: 2062.9421267070884
#
# Iteration 50
# Objective: -17812065.089391712
# Steepness: -1.1416934370415128
# Step length: 236890.10620872286
# Total time for steepest-descent scheme: 0.5749073028564453
#
# Solving with circuit aug with initial active inds steepest descent...
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.08359909057617188
#
# Iteration 0
# Objective: 109626646.32852079
# Steepness: -83.04516320666386
# Step length: 742.8174157224255
#
# Iteration 1
# Objective: 109564958.93499938
# Steepness: -58.894049681906935
# Step length: 2062.9421267070884
#
# Iteration 50
# Objective: -17812065.089391712
# Steepness: -1.1416934370415128
# Step length: 236890.10620872286
# Total time for steepest-descent scheme: 0.5696625709533691
#
# Finish solving with simplex with updated active inds steepest descent...
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.08507728576660156
#
# Iteration 0
# Objective: 109626646.32852079
# Steepness: -83.04516320666386
# Step length: 742.8174157224255
#
# Iteration 1
# Objective: 109564958.93499938
# Steepness: -58.894049681906935
# Step length: 2062.9421267070884
#
# Iteration 50
# Objective: -17812065.089391712
# Steepness: -1.1416934370415128
# Step length: 236890.10620872286
# Total time for steepest-descent scheme: 0.5856006145477295
#
# Finish solving with simplex with initial active inds steepest descent...
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.09138655662536621
#
# Iteration 0
# Objective: 109626646.32852079
# Steepness: -83.04516320666386
# Step length: 742.8174157224255
#
# Iteration 1
# Objective: 109564958.93499938
# Steepness: -58.894049681906935
# Step length: 2062.9421267070884
#
# Iteration 50
# Objective: -17812065.089391712
# Steepness: -1.1416934370415128
# Step length: 236890.10620872286
# Total time for steepest-descent scheme: 0.5979719161987305
#
#
#
# Working on problem 4 of 78: netlib_lp_subset\agg3
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 10312115.935089217
# Total solve time: 0.003999948501586914
# Number of iterations: 156.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.08166050910949707
#
# Iteration 0
# Objective: 759202344.1690388
# Steepness: -99.87397600792033
# Step length: 6779195.16351643
#
# Iteration 1
# Objective: 82137169.05498938
# Steepness: -73.94169151062248
# Step length: 2650.7530877042677
#
# Iteration 50
# Objective: 11402989.186213307
# Steepness: -1.0241476605354012
# Step length: 186189.46206288485
# Total time for steepest-descent scheme: 0.5558230876922607
#
# Solving with circuit aug with updated active inds steepest descent...
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.09778571128845215
#
# Iteration 0
# Objective: 759202344.1690388
# Steepness: -99.87397600792033
# Step length: 6779195.16351643
#
# Iteration 1
# Objective: 82137169.05498938
# Steepness: -73.94169151062248
# Step length: 2650.7530877042677
#
# Iteration 50
# Objective: 11402989.186213307
# Steepness: -1.0241476605354012
# Step length: 186189.46206288485
# Total time for steepest-descent scheme: 0.5473015308380127
#
# Solving with circuit aug with initial active inds steepest descent...
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.09746837615966797
#
# Iteration 0
# Objective: 759202344.1690388
# Steepness: -99.87397600792033
# Step length: 6779195.16351643
#
# Iteration 1
# Objective: 82137169.05498938
# Steepness: -73.94169151062248
# Step length: 2650.7530877042677
#
# Iteration 50
# Objective: 11402989.186213307
# Steepness: -1.0241476605354012
# Step length: 186189.46206288485
# Total time for steepest-descent scheme: 0.5395369529724121
#
# Finish solving with simplex with updated active inds steepest descent...
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.09440875053405762
#
# Iteration 0
# Objective: 759202344.1690388
# Steepness: -99.87397600792033
# Step length: 6779195.16351643
#
# Iteration 1
# Objective: 82137169.05498938
# Steepness: -73.94169151062248
# Step length: 2650.7530877042677
#
# Iteration 50
# Objective: 11402989.186213307
# Steepness: -1.0241476605354012
# Step length: 186189.46206288485
# Total time for steepest-descent scheme: 0.531390905380249
#
# Finish solving with simplex with initial active inds steepest descent...
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.08766484260559082
#
# Iteration 0
# Objective: 759202344.1690388
# Steepness: -99.87397600792033
# Step length: 6779195.16351643
#
# Iteration 1
# Objective: 82137169.05498938
# Steepness: -73.94169151062248
# Step length: 2650.7530877042677
#
# Iteration 50
# Objective: 11402989.186213307
# Steepness: -1.0241476605354012
# Step length: 186189.46206288485
# Total time for steepest-descent scheme: 0.5322375297546387
#
#
#
# Working on problem 5 of 78: netlib_lp_subset\agg
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -35991767.2865765
# Total solve time: 0.002000093460083008
# Number of iterations: 75.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.052453041076660156
#
# Iteration 0
# Objective: 703339586.6175559
# Steepness: -99.956349594957
# Step length: 2544092.712901022
#
# Iteration 1
# Objective: 449041366.0048387
# Steepness: -99.63098617323385
# Step length: 622821.068708921
# Total time for steepest-descent scheme: 0.20323586463928223
#
# Solving with circuit aug with updated active inds steepest descent...
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.04624319076538086
#
# Iteration 0
# Objective: 703339586.6175559
# Steepness: -99.956349594957
# Step length: 2544092.712901022
#
# Iteration 1
# Objective: 449041366.0048387
# Steepness: -99.63098617323385
# Step length: 622821.068708921
# Total time for steepest-descent scheme: 0.20259594917297363
#
# Solving with circuit aug with initial active inds steepest descent...
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.05457615852355957
#
# Iteration 0
# Objective: 703339586.6175559
# Steepness: -99.956349594957
# Step length: 2544092.712901022
#
# Iteration 1
# Objective: 449041366.0048387
# Steepness: -99.63098617323385
# Step length: 622821.068708921
# Total time for steepest-descent scheme: 0.20064759254455566
#
# Finish solving with simplex with updated active inds steepest descent...
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.050084590911865234
#
# Iteration 0
# Objective: 703339586.6175559
# Steepness: -99.956349594957
# Step length: 2544092.712901022
#
# Iteration 1
# Objective: 449041366.0048387
# Steepness: -99.63098617323385
# Step length: 622821.068708921
# Total time for steepest-descent scheme: 0.18954896926879883
#
# Finish solving with simplex with initial active inds steepest descent...
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.03667044639587402
#
# Iteration 0
# Objective: 703339586.6175559
# Steepness: -99.956349594957
# Step length: 2544092.712901022
#
# Iteration 1
# Objective: 449041366.0048387
# Steepness: -99.63098617323385
# Step length: 622821.068708921
# Total time for steepest-descent scheme: 0.20311880111694336
#
#
#
# Working on problem 6 of 78: netlib_lp_subset\bandm
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -158.62801845011555
# Total solve time: 0.0019998550415039062
# Number of iterations: 216.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.10984182357788086
#
# Iteration 0
# Objective: 35.17554204866987
# Steepness: -3.0233333333333334
# Step length: 5.4910125
#
# Iteration 1
# Objective: 18.574380923669892
# Steepness: -1.6666666666666665
# Step length: 2.919
#
# Iteration 50
# Objective: -83.89061670032704
# Steepness: -0.10222001817147731
# Step length: 7.878452745717247
#
# Iteration 100
# Objective: -150.8447534442673
# Steepness: -0.022664555281095882
# Step length: 2.8725769410157787
#
# Iteration 150
# Objective: -158.3352099434993
# Steepness: -0.003824671795482795
# Step length: 2.8753848724163946
# Total time for steepest-descent scheme: 0.8911693096160889
#
# Solving with circuit aug with updated active inds steepest descent...
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.16049933433532715
#
# Iteration 0
# Objective: 35.17554204866987
# Steepness: -3.0233333333333334
# Step length: 5.4910125
#
# Iteration 1
# Objective: 18.574380923669892
# Steepness: -1.6666666666666665
# Step length: 2.919
#
# Iteration 50
# Objective: -83.89061670032704
# Steepness: -0.10222001817147731
# Step length: 7.878452745717247
#
# Iteration 100
# Objective: -150.8447534442673
# Steepness: -0.022664555281095882
# Step length: 2.8725769410157787
#
# Iteration 150
# Objective: -158.3352099434993
# Steepness: -0.003824671795482795
# Step length: 2.8753848724163946
# Total time for steepest-descent scheme: 0.8808200359344482
#
# Solving with circuit aug with initial active inds steepest descent...
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.11338973045349121
#
# Iteration 0
# Objective: 35.17554204866987
# Steepness: -3.0233333333333334
# Step length: 5.4910125
#
# Iteration 1
# Objective: 18.574380923669892
# Steepness: -1.6666666666666665
# Step length: 2.919
#
# Iteration 50
# Objective: -83.89061670032704
# Steepness: -0.10222001817147731
# Step length: 7.878452745717247
#
# Iteration 100
# Objective: -150.8447534442673
# Steepness: -0.022664555281095882
# Step length: 2.8725769410157787
#
# Iteration 150
# Objective: -158.3352099434993
# Steepness: -0.003824671795482795
# Step length: 2.8753848724163946
# Total time for steepest-descent scheme: 0.8743009567260742
#
# Finish solving with simplex with updated active inds steepest descent...
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.12573027610778809
#
# Iteration 0
# Objective: 35.17554204866987
# Steepness: -3.0233333333333334
# Step length: 5.4910125
#
# Iteration 1
# Objective: 18.574380923669892
# Steepness: -1.6666666666666665
# Step length: 2.919
#
# Iteration 50
# Objective: -83.89061670032704
# Steepness: -0.10222001817147731
# Step length: 7.878452745717247
#
# Iteration 100
# Objective: -150.8447534442673
# Steepness: -0.022664555281095882
# Step length: 2.8725769410157787
#
# Iteration 150
# Objective: -158.3352099434993
# Steepness: -0.003824671795482795
# Step length: 2.8753848724163946
# Total time for steepest-descent scheme: 0.8894786834716797
#
# Finish solving with simplex with initial active inds steepest descent...
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.1323385238647461
#
# Iteration 0
# Objective: 35.17554204866987
# Steepness: -3.0233333333333334
# Step length: 5.4910125
#
# Iteration 1
# Objective: 18.574380923669892
# Steepness: -1.6666666666666665
# Step length: 2.919
#
# Iteration 50
# Objective: -83.89061670032704
# Steepness: -0.10222001817147731
# Step length: 7.878452745717247
#
# Iteration 100
# Objective: -150.8447534442673
# Steepness: -0.022664555281095882
# Step length: 2.8725769410157787
#
# Iteration 150
# Objective: -158.3352099434993
# Steepness: -0.003824671795482795
# Step length: 2.8753848724163946
# Total time for steepest-descent scheme: 0.8600831031799316
#
#
#
# Working on problem 7 of 78: netlib_lp_subset\beaconfd
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 33592.48580719999
# Total solve time: 0.0
# Number of iterations: 20.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.10013031959533691
#
# Iteration 0
# Objective: 33992.2782842
# Steepness: -0.07985710632678573
# Step length: 1074.2533000000003
#
# Iteration 1
# Objective: 33906.4915242
# Steepness: -0.06030063441259438
# Step length: 10.890871063301619
# Total time for steepest-descent scheme: 0.0646967887878418
#
# Solving with circuit aug with updated active inds steepest descent...
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.03655838966369629
#
# Iteration 0
# Objective: 33992.2782842
# Steepness: -0.07985710632678573
# Step length: 1074.2533000000003
#
# Iteration 1
# Objective: 33906.4915242
# Steepness: -0.06030063441259438
# Step length: 10.890871063301619
# Total time for steepest-descent scheme: 0.06368350982666016
#
# Solving with circuit aug with initial active inds steepest descent...
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.038130998611450195
#
# Iteration 0
# Objective: 33992.2782842
# Steepness: -0.07985710632678573
# Step length: 1074.2533000000003
#
# Iteration 1
# Objective: 33906.4915242
# Steepness: -0.06030063441259438
# Step length: 10.890871063301619
# Total time for steepest-descent scheme: 0.0666203498840332
#
# Finish solving with simplex with updated active inds steepest descent...
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.050278425216674805
#
# Iteration 0
# Objective: 33992.2782842
# Steepness: -0.07985710632678573
# Step length: 1074.2533000000003
#
# Iteration 1
# Objective: 33906.4915242
# Steepness: -0.06030063441259438
# Step length: 10.890871063301619
# Total time for steepest-descent scheme: 0.06361269950866699
#
# Finish solving with simplex with initial active inds steepest descent...
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.04478716850280762
#
# Iteration 0
# Objective: 33992.2782842
# Steepness: -0.07985710632678573
# Step length: 1074.2533000000003
#
# Iteration 1
# Objective: 33906.4915242
# Steepness: -0.06030063441259438
# Step length: 10.890871063301619
# Total time for steepest-descent scheme: 0.0619051456451416
#
#
#
# Working on problem 8 of 78: netlib_lp_subset\blend
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -30.812149845828237
# Total solve time: 0.0
# Number of iterations: 96.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.006002902984619141
#
# Iteration 0
# Objective: 0.0
# Steepness: -0.07995096139551053
# Step length: 204.46220784365894
#
# Iteration 1
# Objective: -16.346950086149228
# Steepness: -0.07507855792833903
# Step length: 11.700432388455038
# Total time for steepest-descent scheme: 0.023453950881958008
#
# Solving with circuit aug with updated active inds steepest descent...
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.01825094223022461
#
# Iteration 0
# Objective: 0.0
# Steepness: -0.07995096139551053
# Step length: 204.46220784365894
#
# Iteration 1
# Objective: -16.346950086149228
# Steepness: -0.07507855792833903
# Step length: 11.700432388455038
# Total time for steepest-descent scheme: 0.028140544891357422
#
# Solving with circuit aug with initial active inds steepest descent...
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.012504100799560547
#
# Iteration 0
# Objective: 0.0
# Steepness: -0.07995096139551053
# Step length: 204.46220784365894
#
# Iteration 1
# Objective: -16.346950086149228
# Steepness: -0.07507855792833903
# Step length: 11.700432388455038
# Total time for steepest-descent scheme: 0.0340120792388916
#
# Finish solving with simplex with updated active inds steepest descent...
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0
#
# Iteration 0
# Objective: 0.0
# Steepness: -0.07995096139551053
# Step length: 204.46220784365894
#
# Iteration 1
# Objective: -16.346950086149228
# Steepness: -0.07507855792833903
# Step length: 11.700432388455038
# Total time for steepest-descent scheme: 0.02564859390258789
#
# Finish solving with simplex with initial active inds steepest descent...
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.007696628570556641
#
# Iteration 0
# Objective: 0.0
# Steepness: -0.07995096139551053
# Step length: 204.46220784365894
#
# Iteration 1
# Objective: -16.346950086149228
# Steepness: -0.07507855792833903
# Step length: 11.700432388455038
# Total time for steepest-descent scheme: 0.019260168075561523
#
#
#
# Working on problem 9 of 78: netlib_lp_subset\bnl1
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 1977.629561522889
# Total solve time: 0.018000125885009766
# Number of iterations: 418.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.6502962112426758
#
# Iteration 0
# Objective: 2108.241973450449
# Steepness: -0.7838325324871562
# Step length: 4.856190808556725
#
# Iteration 1
# Objective: 2104.4355331107377
# Steepness: -0.6354513698630138
# Step length: 2.99269911829352
#
# Iteration 50
# Objective: 2043.545568881475
# Steepness: -0.08612423856809902
# Step length: 5.70826107383492
#
# Iteration 100
# Objective: 2022.0571831451566
# Steepness: -0.020279165658631113
# Step length: 1.4363708520740728
#
# Iteration 150
# Objective: 1995.7276129810098
# Steepness: -0.004485204050821907
# Step length: 20.53110302270434
#
# Iteration 200
# Objective: 1977.641840780525
# Steepness: -0.00019217177943730638
# Step length: 64.24983037808491
# Total time for steepest-descent scheme: 2.761603593826294
#
# Solving with circuit aug with updated active inds steepest descent...
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.6391551494598389
#
# Iteration 0
# Objective: 2108.241973450449
# Steepness: -0.7838325324871562
# Step length: 4.856190808556725
#
# Iteration 1
# Objective: 2104.4355331107377
# Steepness: -0.6354513698630138
# Step length: 2.99269911829352
#
# Iteration 50
# Objective: 2043.545568881475
# Steepness: -0.08612423856809902
# Step length: 5.70826107383492
#
# Iteration 100
# Objective: 2022.0571831451566
# Steepness: -0.020279165658631113
# Step length: 1.4363708520740728
#
# Iteration 150
# Objective: 1995.7276129810098
# Steepness: -0.004485204050821907
# Step length: 20.53110302270434
#
# Iteration 200
# Objective: 1977.641840780525
# Steepness: -0.00019217177943730638
# Step length: 64.24983037808491
# Total time for steepest-descent scheme: 2.856569528579712
#
# Solving with circuit aug with initial active inds steepest descent...
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.7148914337158203
#
# Iteration 0
# Objective: 2108.241973450449
# Steepness: -0.7838325324871562
# Step length: 4.856190808556725
#
# Iteration 1
# Objective: 2104.4355331107377
# Steepness: -0.6354513698630138
# Step length: 2.99269911829352
#
# Iteration 50
# Objective: 2043.545568881475
# Steepness: -0.08612423856809902
# Step length: 5.70826107383492
#
# Iteration 100
# Objective: 2022.0571831451566
# Steepness: -0.020279165658631113
# Step length: 1.4363708520740728
#
# Iteration 150
# Objective: 1995.7276129810098
# Steepness: -0.004485204050821907
# Step length: 20.53110302270434
#
# Iteration 200
# Objective: 1977.641840780525
# Steepness: -0.00019217177943730638
# Step length: 64.24983037808491
# Total time for steepest-descent scheme: 3.0142009258270264
#
# Finish solving with simplex with updated active inds steepest descent...
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.6615655422210693
#
# Iteration 0
# Objective: 2108.241973450449
# Steepness: -0.7838325324871562
# Step length: 4.856190808556725
#
# Iteration 1
# Objective: 2104.4355331107377
# Steepness: -0.6354513698630138
# Step length: 2.99269911829352
#
# Iteration 50
# Objective: 2043.545568881475
# Steepness: -0.08612423856809902
# Step length: 5.70826107383492
#
# Iteration 100
# Objective: 2022.0571831451566
# Steepness: -0.020279165658631113
# Step length: 1.4363708520740728
#
# Iteration 150
# Objective: 1995.7276129810098
# Steepness: -0.004485204050821907
# Step length: 20.53110302270434
#
# Iteration 200
# Objective: 1977.641840780525
# Steepness: -0.00019217177943730638
# Step length: 64.24983037808491
# Total time for steepest-descent scheme: 2.841200828552246
#
# Finish solving with simplex with initial active inds steepest descent...
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.6501710414886475
#
# Iteration 0
# Objective: 2108.241973450449
# Steepness: -0.7838325324871562
# Step length: 4.856190808556725
#
# Iteration 1
# Objective: 2104.4355331107377
# Steepness: -0.6354513698630138
# Step length: 2.99269911829352
#
# Iteration 50
# Objective: 2043.545568881475
# Steepness: -0.08612423856809902
# Step length: 5.70826107383492
#
# Iteration 100
# Objective: 2022.0571831451566
# Steepness: -0.020279165658631113
# Step length: 1.4363708520740728
#
# Iteration 150
# Objective: 1995.7276129810098
# Steepness: -0.004485204050821907
# Step length: 20.53110302270434
#
# Iteration 200
# Objective: 1977.641840780525
# Steepness: -0.00019217177943730638
# Step length: 64.24983037808491
# Total time for steepest-descent scheme: 2.7862329483032227
#
#
#
# Working on problem 10 of 78: netlib_lp_subset\boeing1
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -335.2135675071269
# Total solve time: 0.0019998550415039062
# Number of iterations: 489.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.13029265403747559
#
# Iteration 0
# Objective: 185.3449154488552
# Steepness: -0.04583250627946371
# Step length: 25.020530715655763
#
# Iteration 1
# Objective: 184.19816181771438
# Steepness: -0.04562063710694408
# Step length: 2.6145797978557512
#
# Iteration 50
# Objective: 139.54470532839713
# Steepness: -0.011809188377272494
# Step length: 18.347500606060603
#
# Iteration 100
# Objective: 44.144078111970586
# Steepness: -0.007734463866938159
# Step length: 16.87172322888511
#
# Iteration 150
# Objective: -181.3181480752378
# Steepness: -0.005574989948692791
# Step length: 205.30346449428785
#
# Iteration 200
# Objective: -282.48169717286777
# Steepness: -0.002848129479120891
# Step length: 282.23204812842454
#
# Iteration 250
# Objective: -322.4790636131133
# Steepness: -0.0013605947055824793
# Step length: 253.98658316440697
#
# Iteration 300
# Objective: -330.6687738769457
# Steepness: -0.0006404787701682962
# Step length: 108.82814413224426
#
# Iteration 350
# Objective: -335.0442400516968
# Steepness: -5.897976000898025e-05
# Step length: 49.10070024957276
# Total time for steepest-descent scheme: 2.808025598526001
#
# Solving with circuit aug with updated active inds steepest descent...
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.18567728996276855
#
# Iteration 0
# Objective: 185.3449154488552
# Steepness: -0.04583250627946371
# Step length: 25.020530715655763
#
# Iteration 1
# Objective: 184.19816181771438
# Steepness: -0.04562063710694408
# Step length: 2.6145797978557512
#
# Iteration 50
# Objective: 139.54470532839713
# Steepness: -0.011809188377272494
# Step length: 18.347500606060603
#
# Iteration 100
# Objective: 44.144078111970586
# Steepness: -0.007734463866938159
# Step length: 16.87172322888511
#
# Iteration 150
# Objective: -181.3181480752378
# Steepness: -0.005574989948692791
# Step length: 205.30346449428785
#
# Iteration 200
# Objective: -282.48169717286777
# Steepness: -0.002848129479120891
# Step length: 282.23204812842454
#
# Iteration 250
# Objective: -322.4790636131133
# Steepness: -0.0013605947055824793
# Step length: 253.98658316440697
#
# Iteration 300
# Objective: -330.6687738769457
# Steepness: -0.0006404787701682962
# Step length: 108.82814413224426
#
# Iteration 350
# Objective: -335.0442400516968
# Steepness: -5.897976000898025e-05
# Step length: 49.10070024957276
# Total time for steepest-descent scheme: 2.8223536014556885
#
# Solving with circuit aug with initial active inds steepest descent...
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.12977123260498047
#
# Iteration 0
# Objective: 185.3449154488552
# Steepness: -0.04583250627946371
# Step length: 25.020530715655763
#
# Iteration 1
# Objective: 184.19816181771438
# Steepness: -0.04562063710694408
# Step length: 2.6145797978557512
#
# Iteration 50
# Objective: 139.54470532839713
# Steepness: -0.011809188377272494
# Step length: 18.347500606060603
#
# Iteration 100
# Objective: 44.144078111970586
# Steepness: -0.007734463866938159
# Step length: 16.87172322888511
#
# Iteration 150
# Objective: -181.3181480752378
# Steepness: -0.005574989948692791
# Step length: 205.30346449428785
#
# Iteration 200
# Objective: -282.48169717286777
# Steepness: -0.002848129479120891
# Step length: 282.23204812842454
#
# Iteration 250
# Objective: -322.4790636131133
# Steepness: -0.0013605947055824793
# Step length: 253.98658316440697
#
# Iteration 300
# Objective: -330.6687738769457
# Steepness: -0.0006404787701682962
# Step length: 108.82814413224426
#
# Iteration 350
# Objective: -335.0442400516968
# Steepness: -5.897976000898025e-05
# Step length: 49.10070024957276
# Total time for steepest-descent scheme: 2.8199570178985596
#
# Finish solving with simplex with updated active inds steepest descent...
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.12686491012573242
#
# Iteration 0
# Objective: 185.3449154488552
# Steepness: -0.04583250627946371
# Step length: 25.020530715655763
#
# Iteration 1
# Objective: 184.19816181771438
# Steepness: -0.04562063710694408
# Step length: 2.6145797978557512
#
# Iteration 50
# Objective: 139.54470532839713
# Steepness: -0.011809188377272494
# Step length: 18.347500606060603
#
# Iteration 100
# Objective: 44.144078111970586
# Steepness: -0.007734463866938159
# Step length: 16.87172322888511
#
# Iteration 150
# Objective: -181.3181480752378
# Steepness: -0.005574989948692791
# Step length: 205.30346449428785
#
# Iteration 200
# Objective: -282.48169717286777
# Steepness: -0.002848129479120891
# Step length: 282.23204812842454
#
# Iteration 250
# Objective: -322.4790636131133
# Steepness: -0.0013605947055824793
# Step length: 253.98658316440697
#
# Iteration 300
# Objective: -330.6687738769457
# Steepness: -0.0006404787701682962
# Step length: 108.82814413224426
#
# Iteration 350
# Objective: -335.0442400516968
# Steepness: -5.897976000898025e-05
# Step length: 49.10070024957276
# Total time for steepest-descent scheme: 3.1065523624420166
#
# Finish solving with simplex with initial active inds steepest descent...
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.12505054473876953
#
# Iteration 0
# Objective: 185.3449154488552
# Steepness: -0.04583250627946371
# Step length: 25.020530715655763
#
# Iteration 1
# Objective: 184.19816181771438
# Steepness: -0.04562063710694408
# Step length: 2.6145797978557512
#
# Iteration 50
# Objective: 139.54470532839713
# Steepness: -0.011809188377272494
# Step length: 18.347500606060603
#
# Iteration 100
# Objective: 44.144078111970586
# Steepness: -0.007734463866938159
# Step length: 16.87172322888511
#
# Iteration 150
# Objective: -181.3181480752378
# Steepness: -0.005574989948692791
# Step length: 205.30346449428785
#
# Iteration 200
# Objective: -282.48169717286777
# Steepness: -0.002848129479120891
# Step length: 282.23204812842454
#
# Iteration 250
# Objective: -322.4790636131133
# Steepness: -0.0013605947055824793
# Step length: 253.98658316440697
#
# Iteration 300
# Objective: -330.6687738769457
# Steepness: -0.0006404787701682962
# Step length: 108.82814413224426
#
# Iteration 350
# Objective: -335.0442400516968
# Steepness: -5.897976000898025e-05
# Step length: 49.10070024957276
# Total time for steepest-descent scheme: 2.828887462615967
#
#
#
# Working on problem 11 of 78: netlib_lp_subset\boeing2
# Reading netlib_lp_subset\boeing2...
# removing redundant constraint 'LF1013B1'
# removing redundant constraint 'LF1013B2'
# removing redundant constraint 'LF1015B1'
# removing redundant constraint 'LF1017B1'
# removing redundant constraint 'LF1019B1'
# removing redundant constraint 'LF1019B2'
# removing redundant constraint 'LF1004B1'
# removing redundant constraint 'LF1008B1'
# removing redundant constraint 'LF1008B2'
# removing redundant constraint 'LF1010B1'
# removing redundant constraint 'LF1010B2'
# removing redundant constraint 'LF1010B3'
# removing redundant constraint 'LF1012B1'
# removing redundant constraint 'LF1014B1'
# removing redundant constraint 'LF1014B2'
# removing redundant constraint 'LF1100B1'
# removing redundant constraint 'LF1100B2'
# removing redundant constraint 'LF1100B3'
# removing redundant constraint 'LF1100B4'
# removing redundant constraint 'LF1100B5'
# removing redundant constraint 'LF1102B1'
# ...
# removing redundant constraint 'BB625'
# removing redundant constraint 'BB641'
# removing redundant constraint 'BB642'
# removing redundant constraint 'BB643'
# removing redundant constraint 'BB644'
# removing redundant constraint 'BB645'
# removing redundant constraint 'BB651'
# removing redundant constraint 'BB652'
# removing redundant constraint 'BB653'
# removing redundant constraint 'BB654'
# removing redundant constraint 'BB655'
# removing redundant constraint 'BB661'
# removing redundant constraint 'BB662'
# removing redundant constraint 'BB663'
# removing redundant constraint 'BB664'
# removing redundant constraint 'BB665'
# removing redundant constraint 'BB671'
# removing redundant constraint 'BB672'
# removing redundant constraint 'BB673'
# removing redundant constraint 'BB674'
# removing redundant constraint 'BB675'
# Building polyhedron...
# Problem size: n = 3678,  m_B = 6411,  m_A = 253
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 7.509808778762817
#
# Iteration 0
# Objective: 32856322.132818617
# Steepness: -641.175149629028
# Step length: 76.52537363399388
#
# Iteration 1
# Objective: 32807255.964928426
# Steepness: -425.13585916570986
# Step length: 31.949427744533757
#
# Iteration 50
# Objective: 30093658.59119859
# Steepness: -153.99039199416424
# Step length: 707.2010738974151
#
# Iteration 100
# Objective: 28579870.42759521
# Steepness: -119.88397964970855
# Step length: 554.6582535296625
#
# Iteration 150
# Objective: 27339468.62048316
# Steepness: -79.0705638779644
# Step length: 0.9113640963276649
#
# Iteration 200
# Objective: 26384897.9552865
# Steepness: -58.666666666666664
# Step length: 282.00000000000017
#
# Iteration 250
# Objective: 25678050.533281334
# Steepness: -58.666666666666664
# Step length: 35.40673286690165
#
# Iteration 300
# Objective: 25437168.35141155
# Steepness: -32.29501974765054
# Step length: 107.46591511778134
#
# Iteration 350
# Objective: 25365491.157584675
# Steepness: -12.328980785735567
# Step length: 255.16314424810633
#
# Iteration 400
# Objective: 25296082.478848033
# Steepness: -5.500405611759259
# Step length: 248.9160454896174
#
# Iteration 450
# Objective: 25276214.568782903
# Steepness: -0.6719805377749887
# Step length: 1060.3974416869762
# Total time for steepest-descent scheme: 28.844150066375732
#
# Finish solving with simplex with updated active inds steepest descent...
# Reading netlib_lp_subset\cre-c...
# removing redundant constraint 'BB013'
# removing redundant constraint 'BB023'
# removing redundant constraint 'BB031'
# removing redundant constraint 'BB032'
# removing redundant constraint 'BB033'
# removing redundant constraint 'BB034'
# removing redundant constraint 'BB035'
# removing redundant constraint 'BB043'
# removing redundant constraint 'BB053'
# removing redundant constraint 'BB063'
# removing redundant constraint 'BB073'
# removing redundant constraint 'BB083'
# removing redundant constraint 'BB093'
# removing redundant constraint 'BB123'
# removing redundant constraint 'BB133'
# removing redundant constraint 'BB141'
# removing redundant constraint 'BB142'
# removing redundant constraint 'BB143'
# removing redundant constraint 'BB144'
# removing redundant constraint 'BB145'
# removing redundant constraint 'BB163'
# removing redundant constraint 'BB173'
# removing redundant constraint 'BB213'
# removing redundant constraint 'BB231'
# removing redundant constraint 'BB232'
# removing redundant constraint 'BB233'
# removing redundant constraint 'BB234'
# removing redundant constraint 'BB235'
# removing redundant constraint 'BB303'
# removing redundant constraint 'BB384'
# removing redundant constraint 'BB414'
# removing redundant constraint 'BB424'
# removing redundant constraint 'BB434'
# removing redundant constraint 'BB444'
# removing redundant constraint 'BB454'
# removing redundant constraint 'BB484'
# removing redundant constraint 'BB551'
# removing redundant constraint 'BB552'
# removing redundant constraint 'BB553'
# removing redundant constraint 'BB554'
# removing redundant constraint 'BB555'
# removing redundant constraint 'BB571'
# removing redundant constraint 'BB572'
# removing redundant constraint 'BB573'
# removing redundant constraint 'BB574'
# removing redundant constraint 'BB575'
# removing redundant constraint 'BB584'
# removing redundant constraint 'BB601'
# removing redundant constraint 'BB602'
# removing redundant constraint 'BB603'
# removing redundant constraint 'BB604'
# removing redundant constraint 'BB605'
# removing redundant constraint 'BB611'
# removing redundant constraint 'BB612'
# removing redundant constraint 'BB613'
# removing redundant constraint 'BB614'
# removing redundant constraint 'BB615'
# removing redundant constraint 'BB621'
# removing redundant constraint 'BB622'
# removing redundant constraint 'BB623'
# removing redundant constraint 'BB624'
# removing redundant constraint 'BB625'
# removing redundant constraint 'BB641'
# removing redundant constraint 'BB642'
# removing redundant constraint 'BB643'
# removing redundant constraint 'BB644'
# removing redundant constraint 'BB645'
# removing redundant constraint 'BB651'
# removing redundant constraint 'BB652'
# removing redundant constraint 'BB653'
# removing redundant constraint 'BB654'
# removing redundant constraint 'BB655'
# removing redundant constraint 'BB661'
# removing redundant constraint 'BB662'
# removing redundant constraint 'BB663'
# removing redundant constraint 'BB664'
# removing redundant constraint 'BB665'
# removing redundant constraint 'BB671'
# removing redundant constraint 'BB672'
# removing redundant constraint 'BB673'
# removing redundant constraint 'BB674'
# removing redundant constraint 'BB675'
# Building polyhedron...
# Problem size: n = 3678,  m_B = 6411,  m_A = 253
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 7.798617839813232
#
# Iteration 0
# Objective: 32856322.132818617
# Steepness: -641.175149629028
# Step length: 76.52537363399388
#
# Iteration 1
# Objective: 32807255.964928426
# Steepness: -425.13585916570986
# Step length: 31.949427744533757
#
# Iteration 50
# Objective: 30093658.59119859
# Steepness: -153.99039199416424
# Step length: 707.2010738974151
#
# Iteration 100
# Objective: 28579870.42759521
# Steepness: -119.88397964970855
# Step length: 554.6582535296625
#
# Iteration 150
# Objective: 27339468.62048316
# Steepness: -79.0705638779644
# Step length: 0.9113640963276649
#
# Iteration 200
# Objective: 26384897.9552865
# Steepness: -58.666666666666664
# Step length: 282.00000000000017
#
# Iteration 250
# Objective: 25678050.533281334
# Steepness: -58.666666666666664
# Step length: 35.40673286690165
#
# Iteration 300
# Objective: 25437168.35141155
# Steepness: -32.29501974765054
# Step length: 107.46591511778134
#
# Iteration 350
# Objective: 25365491.157584675
# Steepness: -12.328980785735567
# Step length: 255.16314424810633
#
# Iteration 400
# Objective: 25296082.478848033
# Steepness: -5.500405611759259
# Step length: 248.9160454896174
#
# Iteration 450
# Objective: 25276214.568782903
# Steepness: -0.6719805377749887
# Step length: 1060.3974416869762
# Total time for steepest-descent scheme: 28.994990825653076
#
# Finish solving with simplex with initial active inds steepest descent...
# Reading netlib_lp_subset\cre-c...
# removing redundant constraint 'BB013'
# removing redundant constraint 'BB023'
# removing redundant constraint 'BB031'
# removing redundant constraint 'BB032'
# removing redundant constraint 'BB033'
# removing redundant constraint 'BB034'
# removing redundant constraint 'BB035'
# removing redundant constraint 'BB043'
# removing redundant constraint 'BB053'
# removing redundant constraint 'BB063'
# removing redundant constraint 'BB073'
# removing redundant constraint 'BB083'
# removing redundant constraint 'BB093'
# removing redundant constraint 'BB123'
# removing redundant constraint 'BB133'
# removing redundant constraint 'BB141'
# removing redundant constraint 'BB142'
# removing redundant constraint 'BB143'
# removing redundant constraint 'BB144'
# removing redundant constraint 'BB145'
# removing redundant constraint 'BB163'
# removing redundant constraint 'BB173'
# removing redundant constraint 'BB213'
# removing redundant constraint 'BB231'
# removing redundant constraint 'BB232'
# removing redundant constraint 'BB233'
# removing redundant constraint 'BB234'
# removing redundant constraint 'BB235'
# removing redundant constraint 'BB303'
# removing redundant constraint 'BB384'
# removing redundant constraint 'BB414'
# removing redundant constraint 'BB424'
# removing redundant constraint 'BB434'
# removing redundant constraint 'BB444'
# removing redundant constraint 'BB454'
# removing redundant constraint 'BB484'
# removing redundant constraint 'BB551'
# removing redundant constraint 'BB552'
# removing redundant constraint 'BB553'
# removing redundant constraint 'BB554'
# removing redundant constraint 'BB555'
# removing redundant constraint 'BB571'
# removing redundant constraint 'BB572'
# removing redundant constraint 'BB573'
# removing redundant constraint 'BB574'
# removing redundant constraint 'BB575'
# removing redundant constraint 'BB584'
# removing redundant constraint 'BB601'
# removing redundant constraint 'BB602'
# removing redundant constraint 'BB603'
# removing redundant constraint 'BB604'
# removing redundant constraint 'BB605'
# removing redundant constraint 'BB611'
# removing redundant constraint 'BB612'
# removing redundant constraint 'BB613'
# removing redundant constraint 'BB614'
# removing redundant constraint 'BB615'
# removing redundant constraint 'BB621'
# removing redundant constraint 'BB622'
# removing redundant constraint 'BB623'
# removing redundant constraint 'BB624'
# removing redundant constraint 'BB625'
# removing redundant constraint 'BB641'
# removing redundant constraint 'BB642'
# removing redundant constraint 'BB643'
# removing redundant constraint 'BB644'
# removing redundant constraint 'BB645'
# removing redundant constraint 'BB651'
# removing redundant constraint 'BB652'
# removing redundant constraint 'BB653'
# removing redundant constraint 'BB654'
# removing redundant constraint 'BB655'
# removing redundant constraint 'BB661'
# removing redundant constraint 'BB662'
# removing redundant constraint 'BB663'
# removing redundant constraint 'BB664'
# removing redundant constraint 'BB665'
# removing redundant constraint 'BB671'
# removing redundant constraint 'BB672'
# removing redundant constraint 'BB673'
# removing redundant constraint 'BB674'
# removing redundant constraint 'BB675'
# Building polyhedron...
# Problem size: n = 3678,  m_B = 6411,  m_A = 253
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 8.181124925613403
#
# Iteration 0
# Objective: 32856322.132818617
# Steepness: -641.175149629028
# Step length: 76.52537363399388
#
# Iteration 1
# Objective: 32807255.964928426
# Steepness: -425.13585916570986
# Step length: 31.949427744533757
#
# Iteration 50
# Objective: 30093658.59119859
# Steepness: -153.99039199416424
# Step length: 707.2010738974151
#
# Iteration 100
# Objective: 28579870.42759521
# Steepness: -119.88397964970855
# Step length: 554.6582535296625
#
# Iteration 150
# Objective: 27339468.62048316
# Steepness: -79.0705638779644
# Step length: 0.9113640963276649
#
# Iteration 200
# Objective: 26384897.9552865
# Steepness: -58.666666666666664
# Step length: 282.00000000000017
#
# Iteration 250
# Objective: 25678050.533281334
# Steepness: -58.666666666666664
# Step length: 35.40673286690165
#
# Iteration 300
# Objective: 25437168.35141155
# Steepness: -32.29501974765054
# Step length: 107.46591511778134
#
# Iteration 350
# Objective: 25365491.157584675
# Steepness: -12.328980785735567
# Step length: 255.16314424810633
#
# Iteration 400
# Objective: 25296082.478848033
# Steepness: -5.500405611759259
# Step length: 248.9160454896174
#
# Iteration 450
# Objective: 25276214.568782903
# Steepness: -0.6719805377749887
# Step length: 1060.3974416869762
# Total time for steepest-descent scheme: 29.683830499649048
#
#
#
# Working on problem 78 of 78: netlib_lp_subset\modszk1
# Reading netlib_lp_subset\modszk1...
# removing redundant constraint 'ROW0147'
# Building polyhedron...
# Problem size: n = 1620,  m_B = 1618,  m_A = 686
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 320.6197290648233
# Total solve time: 0.032000064849853516
# Number of iterations: 1233.0
#
# Solving with original steepest descent...
# Reading netlib_lp_subset\modszk1...
# removing redundant constraint 'ROW0147'
# Building polyhedron...
# Problem size: n = 1620,  m_B = 1618,  m_A = 686
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.0649385452270508
#
# Iteration 0
# Objective: 699998.447478
# Steepness: -0.07001241293244018
# Step length: 3143467.2427973496
#
# Iteration 1
# Objective: 479916.7208356728
# Steepness: -0.06813450045722237
# Step length: 994453.6074015652
#
# Iteration 50
# Objective: 546.1423394468627
# Steepness: -0.01625016448093732
# Step length: 2617.1582900835015
# Total time for steepest-descent scheme: 1.0537660121917725
#
# Solving with circuit aug with updated active inds steepest descent...
# Reading netlib_lp_subset\modszk1...
# removing redundant constraint 'ROW0147'
# Building polyhedron...
# Problem size: n = 1620,  m_B = 1618,  m_A = 686
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.0771677494049072
#
# Iteration 0
# Objective: 699998.447478
# Steepness: -0.07001241293244018
# Step length: 3143467.2427973496
#
# Iteration 1
# Objective: 479916.7208356728
# Steepness: -0.06813450045722237
# Step length: 994453.6074015652
#
# Iteration 50
# Objective: 546.1423394468627
# Steepness: -0.01625016448093732
# Step length: 2617.1582900835015
# Total time for steepest-descent scheme: 1.0219695568084717
#
# Solving with circuit aug with initial active inds steepest descent...
# Reading netlib_lp_subset\modszk1...
# removing redundant constraint 'ROW0147'
# Building polyhedron...
# Problem size: n = 1620,  m_B = 1618,  m_A = 686
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.1437029838562012
#
# Iteration 0
# Objective: 699998.447478
# Steepness: -0.07001241293244018
# Step length: 3143467.2427973496
#
# Iteration 1
# Objective: 479916.7208356728
# Steepness: -0.06813450045722237
# Step length: 994453.6074015652
#
# Iteration 50
# Objective: 546.1423394468627
# Steepness: -0.01625016448093732
# Step length: 2617.1582900835015
# Total time for steepest-descent scheme: 1.0065550804138184
#
# Finish solving with simplex with updated active inds steepest descent...
# Reading netlib_lp_subset\modszk1...
# removing redundant constraint 'ROW0147'
# Building polyhedron...
# Problem size: n = 1620,  m_B = 1618,  m_A = 686
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.0977251529693604
#
# Iteration 0
# Objective: 699998.447478
# Steepness: -0.07001241293244018
# Step length: 3143467.2427973496
#
# Iteration 1
# Objective: 479916.7208356728
# Steepness: -0.06813450045722237
# Step length: 994453.6074015652
#
# Iteration 50
# Objective: 546.1423394468627
# Steepness: -0.01625016448093732
# Step length: 2617.1582900835015
# Total time for steepest-descent scheme: 1.0493226051330566
#
# Finish solving with simplex with initial active inds steepest descent...
# Reading netlib_lp_subset\modszk1...
# removing redundant constraint 'ROW0147'
# Building polyhedron...
# Problem size: n = 1620,  m_B = 1618,  m_A = 686
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.1297328472137451
#
# Iteration 0
# Objective: 699998.447478
# Steepness: -0.07001241293244018
# Step length: 3143467.2427973496
#
# Iteration 1
# Objective: 479916.7208356728
# Steepness: -0.06813450045722237
# Step length: 994453.6074015652
#
# Iteration 50
# Objective: 546.1423394468627
# Steepness: -0.01625016448093732
# Step length: 2617.1582900835015
# Total time for steepest-descent scheme: 1.0329499244689941

# %% [markdown]
# ## View Results

# %%
results_dir = 'results'
problems = ['adlittle', 'afiro', 'agg2','agg3','agg', 'bandm',
 'beaconfd', 'blend', 'bnl1', 'boeing1', 'boeing2', 'bore3d', 'brandy', 'capri',
 'cycle', 'degen2', 'degen3', 'e226', 'etamacro', 'fffff800', 'finnis',
 'fit1d', 'fit1p', 'forplan', 'ganges', 'gfrd-pnc', 'grow15', 'grow22', 'grow7',
 'israel', 'kb2', 'ken-07', 'lotfi', 'maros', 'pds-02', 'perold',
 'pilotnov', 'qap08', 'recipe', 'sc105', 'sc205', 'sc50a',
 'sc50b', 'scagr25', 'scagr7', 'scfxm1', 'scfxm2', 'scfxm3', 'scorpion', 'scrs8',
 'scsd1', 'scsd6', 'scsd8', 'sctap1', 'sctap2', 'sctap3', 'seba', 'share1b',
 'share2b', 'shell', 'ship04l', 'ship04s', 'ship08l', 'ship08s', 'ship12l', 'ship12s',
 'sierra', 'stair', 'standata', 'standgub', 'standmps', 'stocfor1', 'stocfor2', 'tuff',
 'vtp_base', 'wood1p', 'cre-c', 'modszk1']
 # 'pilot4',

avgs = {'lp_time': [], 'old_sd_time': [], 'old_avg_sd': [],
        'circ_up_act_sd_time': [], 'circ_up_act_avg_sd': [], 
        'circ_init_act_sd_time': [],'circ_init_act_avg_sd': [],
        'simp_up_act_sd_time': [], 'simp_up_act_avg_sd': [], 
        'simp_init_act_sd_time': [],'simp_init_act_avg_sd': [],
        'lp_iters': [], 'old_sd_iters': [], 
        'circ_up_act_sd_iters': [], 'circ_init_act_sd_iters': [],
       'simp_up_act_sd_iters': [], 'simp_init_act_sd_iters': []}
from statistics import median

figure_dir = 'figures'
if not os.path.exists(figure_dir): os.mkdir(figure_dir)
for problem in problems:
    lp_fn = os.path.join(results_dir, problem + '_lp.p')
    old_sd_fn = os.path.join(results_dir, problem + '_old_sd.p')
    if not os.path.exists(old_sd_fn): continue
    circ_up_act_sd_fn = os.path.join(results_dir, problem + '_circ_up_act_sd.p')
    if not os.path.exists(circ_up_act_sd_fn): continue
    circ_init_act_sd_fn = os.path.join(results_dir, problem + '_circ_init_act_sd.p')
    if not os.path.exists(circ_init_act_sd_fn): continue
    simp_up_act_sd_fn = os.path.join(results_dir, problem + '_simp_up_act_sd.p')
    if not os.path.exists(simp_up_act_sd_fn): continue
    simp_init_act_sd_fn = os.path.join(results_dir, problem + '_simp_init_act_sd.p')
    if not os.path.exists(simp_init_act_sd_fn): continue
    
    
    with open(lp_fn, 'rb') as f:
        lp_results = pickle.load(f)
    with open(old_sd_fn, 'rb') as f:
        old_sd_results = pickle.load(f)
    with open(circ_up_act_sd_fn, 'rb') as f:
        circ_up_act_sd_result = pickle.load(f)
    with open(circ_init_act_sd_fn, 'rb') as f:
        circ_init_act_sd_result = pickle.load(f)
    with open(simp_up_act_sd_fn, 'rb') as f:
        simp_up_act_sd_result = pickle.load(f)
    with open(simp_init_act_sd_fn, 'rb') as f:
        simp_init_act_sd_result = pickle.load(f)
        
    try: 
        avgs['old_avg_sd'].append(avg(old_sd_results['solve_times'][1:]))
        avgs['circ_up_act_avg_sd'].append(avg(circ_up_act_sd_result['solve_times'][1:]))
        avgs['circ_init_act_avg_sd'].append(avg(circ_init_act_sd_result['solve_times'][1:]))
        avgs['simp_up_act_avg_sd'].append(avg(simp_up_act_sd_result['solve_times'][1:]))
        avgs['simp_init_act_avg_sd'].append(avg(simp_init_act_sd_result['solve_times'][1:]))
        avgs['lp_time'].append(lp_results['solve_time_total'])
        avgs['old_sd_time'].append(old_sd_results['solve_time_total'])
        avgs['circ_up_act_sd_time'].append(circ_up_act_sd_result['solve_time_total'])
        avgs['circ_init_act_sd_time'].append(circ_init_act_sd_result['solve_time_total'])
        avgs['simp_up_act_sd_time'].append(simp_up_act_sd_result['solve_time_total'])
        avgs['simp_init_act_sd_time'].append(simp_init_act_sd_result['solve_time_total'])
        avgs['lp_iters'].append(lp_results['n_iters'])
        avgs['old_sd_iters'].append(old_sd_results['n_iters'])
        avgs['circ_up_act_sd_iters'].append(circ_up_act_sd_result['n_iters'])
        avgs['circ_init_act_sd_iters'].append(circ_init_act_sd_result['n_iters'])
        avgs['simp_up_act_sd_iters'].append(simp_up_act_sd_result['n_iters'])
        avgs['simp_init_act_sd_iters'].append(simp_init_act_sd_result['n_iters'])
    except KeyError:
        print('skipping {}'.format(problem))
        continue
        
for metric in avgs:
    print(metric)
    print('Average {}: {}'.format(metric, avg(avgs[metric])))
    print('Median {}: {}'.format(metric, median(avgs[metric])))
# Out:
# lp_time
# Average lp_time: 0.016115384224133614
# Median lp_time: 0.001999974250793457
# old_sd_time
# Average old_sd_time: 4.79521928078089
# Median old_sd_time: 1.0113153457641602
# old_avg_sd
# Average old_avg_sd: 0.0030320642304725656
# Median old_avg_sd: 0.00165951418618154
# circ_up_act_sd_time
# Average circ_up_act_sd_time: 4.961198388001858
# Median circ_up_act_sd_time: 0.9742875099182129
# circ_up_act_avg_sd
# Average circ_up_act_avg_sd: 0.00296973343706275
# Median circ_up_act_avg_sd: 0.0017139142273342241
# circ_init_act_sd_time
# Average circ_init_act_sd_time: 4.990241176042801
# Median circ_init_act_sd_time: 0.9832018613815308
# circ_init_act_avg_sd
# Average circ_init_act_avg_sd: 0.00297287226120004
# Median circ_init_act_avg_sd: 0.001613231619002688
# simp_up_act_sd_time
# Average simp_up_act_sd_time: 4.943192280255831
# Median simp_up_act_sd_time: 1.0127726793289185
# simp_up_act_avg_sd
# Average simp_up_act_avg_sd: 0.0029868320891377476
# Median simp_up_act_avg_sd: 0.0015990891309143212
# simp_init_act_sd_time
# Average simp_init_act_sd_time: 4.801544351455493
# Median simp_init_act_sd_time: 0.9733142852783203
# simp_init_act_avg_sd
# Average simp_init_act_avg_sd: 0.0029914629526927162
# Median simp_init_act_avg_sd: 0.0017074701167333855
# lp_iters
# Average lp_iters: 463.12820512820514
# Median lp_iters: 284.0
# old_sd_iters
# Average old_sd_iters: 212.30769230769232
# Median old_sd_iters: 123.5
# circ_up_act_sd_iters
# Average circ_up_act_sd_iters: 212.30769230769232
# Median circ_up_act_sd_iters: 123.5
# circ_init_act_sd_iters
# Average circ_init_act_sd_iters: 212.30769230769232
# Median circ_init_act_sd_iters: 123.5
# simp_up_act_sd_iters
# Average simp_up_act_sd_iters: 246.93589743589743
# Median simp_up_act_sd_iters: 123.5
# simp_init_act_sd_iters
# Average simp_init_act_sd_iters: 246.93589743589743
# Median simp_init_act_sd_iters: 123.5
