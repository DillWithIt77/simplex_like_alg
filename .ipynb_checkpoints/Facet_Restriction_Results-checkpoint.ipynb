# %% [markdown]
# # Warm Start Results

# %% [markdown]
# ## Import Statements

# %%
import os
import pickle
import subprocess

from main import main

from glob import glob
import numpy as np
import random
from matplotlib import pyplot as plt
# %matplotlib inline

from utils import avg

# %% [markdown]
# ## Run Tests

# %%
problems = ['adlittle', 'afiro', 'agg2','agg3','agg', 'bandm',
 'beaconfd', 'blend', 'bnl1', 'boeing1', 'boeing2', 'bore3d', 'brandy', 'capri',
 'cycle', 'degen2', 'degen3', 'e226', 'etamacro', 'fffff800', 'finnis',
 'fit1d', 'fit1p', 'forplan', 'ganges', 'gfrd-pnc', 'grow15', 'grow22', 'grow7',
 'israel', 'kb2', 'ken-07', 'lotfi', 'maros', 'pds-02', 'perold',
 'pilot4', 'pilotnov', 'qap08', 'recipe', 'sc105', 'sc205', 'sc50a',
 'sc50b', 'scagr25', 'scagr7', 'scfxm1', 'scfxm2', 'scfxm3', 'scorpion', 'scrs8',
 'scsd1', 'scsd6', 'scsd8', 'sctap1', 'sctap2', 'sctap3', 'seba', 'share1b',
 'share2b', 'shell', 'ship04l', 'ship04s', 'ship08l', 'ship08s', 'ship12l', 'ship12s',
 'sierra', 'stair', 'standata', 'standgub', 'standmps', 'stocfor1', 'stocfor2', 'tuff',
 'vtp_base', 'wood1p', 'cre-c', 'modszk1']     
# 'shell','modszk1'
# 'cre-c', 'modszk1',
    
results_dir = 'results'
problem_dir = 'netlib_lp_subset'
max_time = 300
reset = False
sd_method = 'dual_simplex'

for i, problem in enumerate(problems):
    mps_fn = os.path.join(problem_dir, problem)
    print('\n\n\nWorking on problem {} of {}: {}'.format(i+1, len(problems), mps_fn))    
    main(mps_fn=mps_fn, results_dir=results_dir, max_time=max_time, reset=reset, sd_method=sd_method)
# Out:
# Working on problem 1 of 79: netlib_lp_subset\adlittle
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-01
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.021169662475585938
# trivial warm start
#
#
#
# Working on problem 2 of 79: netlib_lp_subset\afiro
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.004742860794067383
# trivial warm start
#
#
#
# Working on problem 3 of 79: netlib_lp_subset\agg2
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.2139749526977539
# trivial warm start
#
#
#
# Working on problem 4 of 79: netlib_lp_subset\agg3
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.21813130378723145
# trivial warm start
#
#
#
# Working on problem 5 of 79: netlib_lp_subset\agg
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.10468816757202148
# trivial warm start
#
#
#
# Working on problem 6 of 79: netlib_lp_subset\bandm
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.2696375846862793
# trivial warm start
#
#
#
# Working on problem 7 of 79: netlib_lp_subset\beaconfd
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.09684348106384277
# trivial warm start
#
#
#
# Working on problem 8 of 79: netlib_lp_subset\blend
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.01685953140258789
# trivial warm start
#
#
#
# Working on problem 9 of 79: netlib_lp_subset\bnl1
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.5045630931854248
# trivial warm start
#
#
#
# Working on problem 10 of 79: netlib_lp_subset\boeing1
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.3542656898498535
# trivial warm start
#
#
#
# Working on problem 11 of 79: netlib_lp_subset\boeing2
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\boeing2...
# removing redundant constraint 'LF1013B1'
# removing redundant constraint 'LF1013B2'
# removing redundant constraint 'LF1015B1'
# removing redundant constraint 'LF1017B1'
# removing redundant constraint 'LF1019B1'
# removing redundant constraint 'LF1019B2'
# removing redundant constraint 'LF1004B1'
# removing redundant constraint 'LF1008B1'
# removing redundant constraint 'LF1008B2'
# removing redundant constraint 'LF1010B1'
# removing redundant constraint 'LF1010B2'
# removing redundant constraint 'LF1010B3'
# removing redundant constraint 'LF1012B1'
# removing redundant constraint 'LF1014B1'
# removing redundant constraint 'LF1014B2'
# removing redundant constraint 'LF1100B1'
# removing redundant constraint 'LF1100B2'
# removing redundant constraint 'LF1100B3'
# removing redundant constraint 'LF1100B4'
# removing redundant constraint 'LF1100B5'
# removing redundant constraint 'LF1102B1'
# removing redundant constraint 'LF1102B2'
# removing redundant constraint 'LF1102B3'
# removing redundant constraint 'LF1102B4'
# removing redundant constraint 'LF1200B1'
# removing redundant constraint 'LF1201B1'
# Building polyhedron...
# Problem size: n = 143,  m_B = 352,  m_A = 4
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.06278610229492188
# trivial warm start
#
#
#
# Working on problem 12 of 79: netlib_lp_subset\bore3d
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\bore3d...
# Building polyhedron...
# Problem size: n = 315,  m_B = 344,  m_A = 215
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.15365171432495117
# trivial warm start
#
#
#
# Working on problem 13 of 79: netlib_lp_subset\brandy
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\brandy...
# removing redundant constraint '10178A'
# removing redundant constraint '10179A'
# removing redundant constraint '10180A'
# removing redundant constraint '10181A'
# removing redundant constraint '10182A'
# removing redundant constraint '10184A'
# removing redundant constraint '10185A'
# removing redundant constraint '10186A'
# removing redundant constraint '10187A'
# removing redundant constraint '10188A'
# removing redundant constraint '10189A'
# removing redundant constraint '10002A'
# removing redundant constraint '10003A'
# removing redundant constraint '10004A'
# removing redundant constraint '10067A'
# removing redundant constraint '10077A'
# removing redundant constraint '10079A'
# removing redundant constraint '10088A'
# removing redundant constraint '10099A'
# removing redundant constraint '10103A'
# removing redundant constraint '10109A'
# removing redundant constraint '10111A'
# removing redundant constraint '10112A'
# removing redundant constraint '10113A'
# removing redundant constraint '10114A'
# removing redundant constraint '10115A'
# removing redundant constraint '10155A'
# removing redundant constraint '10157A'
# removing redundant constraint '10161A'
# removing redundant constraint '10165A'
# removing redundant constraint '10166A'
# removing redundant constraint '10174A'
# removing redundant constraint '10205A'
# removing redundant constraint '10206A'
# removing redundant constraint '10212A'
# removing redundant constraint '10213A'
# removing redundant constraint '10214A'
# removing redundant constraint '10221A'
# Building polyhedron...
# Problem size: n = 249,  m_B = 292,  m_A = 139
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.09782290458679199
# trivial warm start
#
#
#
# Working on problem 14 of 79: netlib_lp_subset\capri
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\capri...
# Building polyhedron...
# Problem size: n = 353,  m_B = 583,  m_A = 158
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.20011138916015625
# trivial warm start
#
#
#
# Working on problem 15 of 79: netlib_lp_subset\cycle
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\cycle...
# removing redundant constraint 'GHF...EB'
# removing redundant constraint 'GHH...EB'
# removing redundant constraint 'GHT...EB'
# removing redundant constraint 'GHX...EB'
# removing redundant constraint 'BGL...AA'
# removing redundant constraint 'BGL...AC'
# removing redundant constraint 'BOA...AC'
# removing redundant constraint 'BOB...AC'
# removing redundant constraint 'BGL...AE'
# removing redundant constraint 'BOA...AE'
# removing redundant constraint 'BOF...BD'
# removing redundant constraint 'BGL...CF'
# removing redundant constraint 'BOB...CF'
# removing redundant constraint 'BOX...CF'
# removing redundant constraint 'BGL...DD'
# removing redundant constraint 'BDN...EF'
# removing redundant constraint 'BOB...EF'
# Building polyhedron...
# Problem size: n = 2857,  m_B = 3437,  m_A = 1376
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 8.67955470085144
# trivial warm start
#
#
#
# Working on problem 16 of 79: netlib_lp_subset\degen2
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\degen2...
# Building polyhedron...
# Problem size: n = 534,  m_B = 757,  m_A = 221
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.379166841506958
# trivial warm start
#
#
#
# Working on problem 17 of 79: netlib_lp_subset\degen3
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\degen3...
# Building polyhedron...
# Problem size: n = 1818,  m_B = 2604,  m_A = 717
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 4.035407304763794
# trivial warm start
#
#
#
# Working on problem 18 of 79: netlib_lp_subset\e226
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\e226...
# Building polyhedron...
# Problem size: n = 282,  m_B = 472,  m_A = 33
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.12641501426696777
# trivial warm start
#
#
#
# Working on problem 19 of 79: netlib_lp_subset\etamacro
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\etamacro...
# Building polyhedron...
# Problem size: n = 688,  m_B = 869,  m_A = 354
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.6489467620849609
# trivial warm start
#
#
#
# Working on problem 20 of 79: netlib_lp_subset\fffff800
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\fffff800...
# Building polyhedron...
# Problem size: n = 854,  m_B = 1028,  m_A = 350
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.8914101123809814
# trivial warm start
#
#
#
# Working on problem 21 of 79: netlib_lp_subset\finnis
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\finnis...
# Building polyhedron...
# Problem size: n = 614,  m_B = 1055,  m_A = 92
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.5223009586334229
# trivial warm start
#
#
#
# Working on problem 22 of 79: netlib_lp_subset\fit1d
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\fit1d...
# Building polyhedron...
# Problem size: n = 1026,  m_B = 2075,  m_A = 1
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.5954093933105469
# trivial warm start
#
#
#
# Working on problem 23 of 79: netlib_lp_subset\fit1p
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\fit1p...
# Building polyhedron...
# Problem size: n = 1677,  m_B = 2076,  m_A = 627
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 3.1902449131011963
# trivial warm start
#
#
#
# Working on problem 24 of 79: netlib_lp_subset\forplan
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\forplan...
# removing redundant constraint 'BR   1 1'
# removing redundant constraint 'BR   2 2'
# removing redundant constraint 'BR   2 3'
# removing redundant constraint 'BHVL 2'
# removing redundant constraint 'BHVL 3'
# removing redundant constraint 'BHVL 4'
# removing redundant constraint 'BHVL 5'
# removing redundant constraint 'BHVL 6'
# removing redundant constraint 'BHVL 7'
# removing redundant constraint 'BHVL 8'
# removing redundant constraint 'BHVL 9'
# removing redundant constraint 'BHVL10'
# removing redundant constraint 'BHVL11'
# removing redundant constraint 'BHVL12'
# removing redundant constraint 'BHVL13'
# removing redundant constraint 'BHVL14'
# removing redundant constraint 'BHVL15'
# removing redundant constraint 'BHVL16'
# removing redundant constraint 'BHVL17'
# removing redundant constraint 'BHVL18'
# removing redundant constraint 'BHVL19'
# removing redundant constraint 'BHVL20'
# removing redundant constraint 'A$ 4-8 1'
# removing redundant constraint 'A$ 4-8 2'
# removing redundant constraint 'A$ 4-8 3'
# removing redundant constraint 'A$ 4-8 4'
# Building polyhedron...
# Problem size: n = 421,  m_B = 485,  m_A = 93
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.2318706512451172
# trivial warm start
#
#
#
# Working on problem 25 of 79: netlib_lp_subset\ganges
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\ganges...
# Building polyhedron...
# Problem size: n = 1681,  m_B = 2103,  m_A = 1284
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 4.03973126411438
# trivial warm start
#
#
#
# Working on problem 26 of 79: netlib_lp_subset\gfrd-pnc
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\gfrd-pnc...
# Building polyhedron...
# Problem size: n = 1092,  m_B = 1418,  m_A = 548
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.5180740356445312
# trivial warm start
#
#
#
# Working on problem 27 of 79: netlib_lp_subset\grow15
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\grow15...
# Building polyhedron...
# Problem size: n = 645,  m_B = 1245,  m_A = 300
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.7236590385437012
# trivial warm start
#
#
#
# Working on problem 28 of 79: netlib_lp_subset\grow22
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\grow22...
# Building polyhedron...
# Problem size: n = 946,  m_B = 1826,  m_A = 440
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.4857511520385742
# trivial warm start
#
#
#
# Working on problem 29 of 79: netlib_lp_subset\grow7
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\grow7...
# Building polyhedron...
# Problem size: n = 301,  m_B = 581,  m_A = 140
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.17521095275878906
# trivial warm start
#
#
#
# Working on problem 30 of 79: netlib_lp_subset\israel
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\israel...
# Building polyhedron...
# Problem size: n = 142,  m_B = 316,  m_A = 0
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.05508899688720703
# trivial warm start
#
#
#
# Working on problem 31 of 79: netlib_lp_subset\kb2
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\kb2...
# Building polyhedron...
# Problem size: n = 41,  m_B = 77,  m_A = 16
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.00843048095703125
# trivial warm start
#
#
#
# Working on problem 32 of 79: netlib_lp_subset\ken-07
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\ken-07...
# Building polyhedron...
# Problem size: n = 3602,  m_B = 7204,  m_A = 2426
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 22.122032165527344
# trivial warm start
#
#
#
# Working on problem 33 of 79: netlib_lp_subset\lotfi
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\lotfi...
# Building polyhedron...
# Problem size: n = 308,  m_B = 366,  m_A = 95
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.11250782012939453
# trivial warm start
#
#
#
# Working on problem 34 of 79: netlib_lp_subset\maros
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\maros...
# removing redundant constraint 'S0117601'
# Building polyhedron...
# Problem size: n = 1443,  m_B = 1930,  m_A = 358
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 2.207550525665283
# trivial warm start
#
#
#
# Working on problem 35 of 79: netlib_lp_subset\pds-02
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\pds-02...
# Building polyhedron...
# Problem size: n = 7535,  m_B = 9850,  m_A = 2772
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 60.94706106185913
# trivial warm start
#
#
#
# Working on problem 36 of 79: netlib_lp_subset\perold
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\perold...
# Building polyhedron...
# Problem size: n = 1376,  m_B = 1620,  m_A = 559
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.9882233142852783
# trivial warm start
#
#
#
# Working on problem 37 of 79: netlib_lp_subset\pilot4
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\pilot4...
# Building polyhedron...
# Problem size: n = 1000,  m_B = 1252,  m_A = 317
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.1070513725280762
# trivial warm start
#
#
#
# Working on problem 38 of 79: netlib_lp_subset\pilotnov
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\pilotnov...
# Building polyhedron...
# Problem size: n = 2172,  m_B = 2582,  m_A = 905
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 5.038367748260498
# trivial warm start
#
#
#
# Working on problem 39 of 79: netlib_lp_subset\qap08
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\qap08...
# Building polyhedron...
# Problem size: n = 1632,  m_B = 1632,  m_A = 912
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 2.776780605316162
# trivial warm start
#
#
#
# Working on problem 40 of 79: netlib_lp_subset\recipe
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\recipe...
# Building polyhedron...
# Problem size: n = 180,  m_B = 247,  m_A = 93
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.047194480895996094
# trivial warm start
#
#
#
# Working on problem 41 of 79: netlib_lp_subset\sc105
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\sc105...
# removing redundant constraint 'ROW00003'
# Building polyhedron...
# Problem size: n = 103,  m_B = 162,  m_A = 45
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.018128156661987305
# trivial warm start
#
#
#
# Working on problem 42 of 79: netlib_lp_subset\sc205
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\sc205...
# removing redundant constraint 'ROW00003'
# Building polyhedron...
# Problem size: n = 203,  m_B = 316,  m_A = 91
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.07757306098937988
# trivial warm start
#
#
#
# Working on problem 43 of 79: netlib_lp_subset\sc50a
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\sc50a...
# removing redundant constraint 'ROW00003'
# Building polyhedron...
# Problem size: n = 48,  m_B = 77,  m_A = 20
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.0049741268157958984
# trivial warm start
#
#
#
# Working on problem 44 of 79: netlib_lp_subset\sc50b
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\sc50b...
# removing redundant constraint 'ROW00002'
# removing redundant constraint 'ROW00003'
# Building polyhedron...
# Problem size: n = 48,  m_B = 76,  m_A = 20
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.012037515640258789
# trivial warm start
#
#
#
# Working on problem 45 of 79: netlib_lp_subset\scagr25
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\scagr25...
# Building polyhedron...
# Problem size: n = 500,  m_B = 671,  m_A = 300
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.3493521213531494
# trivial warm start
#
#
#
# Working on problem 46 of 79: netlib_lp_subset\scagr7
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\scagr7...
# Building polyhedron...
# Problem size: n = 140,  m_B = 185,  m_A = 84
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.029451847076416016
# trivial warm start
#
#
#
# Working on problem 47 of 79: netlib_lp_subset\scfxm1
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\scfxm1...
# Building polyhedron...
# Problem size: n = 457,  m_B = 600,  m_A = 187
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.2584195137023926
# trivial warm start
#
#
#
# Working on problem 48 of 79: netlib_lp_subset\scfxm2
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\scfxm2...
# Building polyhedron...
# Problem size: n = 914,  m_B = 1200,  m_A = 374
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.974541425704956
# trivial warm start
#
#
#
# Working on problem 49 of 79: netlib_lp_subset\scfxm3
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\scfxm3...
# Building polyhedron...
# Problem size: n = 1371,  m_B = 1800,  m_A = 561
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 2.147672414779663
# trivial warm start
#
#
#
# Working on problem 50 of 79: netlib_lp_subset\scorpion
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\scorpion...
# Building polyhedron...
# Problem size: n = 358,  m_B = 466,  m_A = 280
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.24004912376403809
# trivial warm start
#
#
#
# Working on problem 51 of 79: netlib_lp_subset\scrs8
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\scrs8...
# Building polyhedron...
# Problem size: n = 1169,  m_B = 1275,  m_A = 384
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.3549787998199463
# trivial warm start
#
#
#
# Working on problem 52 of 79: netlib_lp_subset\scsd1
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\scsd1...
# Building polyhedron...
# Problem size: n = 760,  m_B = 760,  m_A = 77
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.4616384506225586
# trivial warm start
#
#
#
# Working on problem 53 of 79: netlib_lp_subset\scsd6
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\scsd6...
# Building polyhedron...
# Problem size: n = 1350,  m_B = 1350,  m_A = 147
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.437201976776123
# trivial warm start
#
#
#
# Working on problem 54 of 79: netlib_lp_subset\scsd8
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\scsd8...
# Building polyhedron...
# Problem size: n = 2750,  m_B = 2750,  m_A = 397
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 5.696399688720703
# trivial warm start
#
#
#
# Working on problem 55 of 79: netlib_lp_subset\sctap1
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\sctap1...
# Building polyhedron...
# Problem size: n = 480,  m_B = 660,  m_A = 120
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.26708388328552246
# trivial warm start
#
#
#
# Working on problem 56 of 79: netlib_lp_subset\sctap2
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\sctap2...
# Building polyhedron...
# Problem size: n = 1880,  m_B = 2500,  m_A = 470
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 3.7173850536346436
# trivial warm start
#
#
#
# Working on problem 57 of 79: netlib_lp_subset\sctap3
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\sctap3...
# Building polyhedron...
# Problem size: n = 2480,  m_B = 3340,  m_A = 620
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 7.089886665344238
# trivial warm start
#
#
#
# Working on problem 58 of 79: netlib_lp_subset\seba
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\seba...
# Building polyhedron...
# Problem size: n = 1028,  m_B = 1550,  m_A = 507
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.3994779586791992
# trivial warm start
#
#
#
# Working on problem 59 of 79: netlib_lp_subset\share1b
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\share1b...
# Building polyhedron...
# Problem size: n = 225,  m_B = 253,  m_A = 89
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.06973385810852051
# trivial warm start
#
#
#
# Working on problem 60 of 79: netlib_lp_subset\share2b
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\share2b...
# Building polyhedron...
# Problem size: n = 79,  m_B = 162,  m_A = 13
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.013865947723388672
# trivial warm start
#
#
#
# Working on problem 61 of 79: netlib_lp_subset\shell
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\shell...
# Building polyhedron...
# Problem size: n = 1775,  m_B = 1644,  m_A = 784
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 2.9602410793304443
# trivial warm start
#
#
#
# Working on problem 62 of 79: netlib_lp_subset\ship04l
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\ship04l...
# removing redundant constraint 'REGMIN03'
# removing redundant constraint 'REGMIN05'
# removing redundant constraint 'REGMIN06'
# removing redundant constraint 'REGMIN07'
# removing redundant constraint 'REGMIN08'
# removing redundant constraint 'OVRMIN03'
# removing redundant constraint 'OVRMIN05'
# removing redundant constraint 'OVRMIN06'
# removing redundant constraint 'OVRMIN07'
# removing redundant constraint 'OVRMIN08'
# removing redundant constraint 'BAL0113'
# removing redundant constraint 'BAL0124'
# removing redundant constraint 'BAL0161'
# removing redundant constraint 'BAL0162'
# removing redundant constraint 'BAL0170'
# removing redundant constraint 'BAL0181'
# removing redundant constraint 'BAL0185'
# removing redundant constraint 'BAL0186'
# removing redundant constraint 'BAL0213'
# removing redundant constraint 'BAL0224'
# removing redundant constraint 'BAL0261'
# removing redundant constraint 'BAL0262'
# removing redundant constraint 'BAL0270'
# removing redundant constraint 'BAL0281'
# removing redundant constraint 'BAL0285'
# removing redundant constraint 'BAL0286'
# removing redundant constraint 'BAL0313'
# removing redundant constraint 'BAL0324'
# removing redundant constraint 'BAL0361'
# removing redundant constraint 'BAL0362'
# removing redundant constraint 'BAL0370'
# removing redundant constraint 'BAL0381'
# removing redundant constraint 'BAL0385'
# removing redundant constraint 'BAL0386'
# removing redundant constraint 'BAL0413'
# removing redundant constraint 'BAL0424'
# removing redundant constraint 'BAL0461'
# removing redundant constraint 'BAL0462'
# removing redundant constraint 'BAL0470'
# removing redundant constraint 'BAL0481'
# removing redundant constraint 'BAL0485'
# removing redundant constraint 'BAL0486'
# Building polyhedron...
# Problem size: n = 2118,  m_B = 2166,  m_A = 312
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 3.5844764709472656
# trivial warm start
#
#
#
# Working on problem 63 of 79: netlib_lp_subset\ship04s
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\ship04s...
# removing redundant constraint 'REGMIN03'
# removing redundant constraint 'REGMIN05'
# removing redundant constraint 'REGMIN06'
# removing redundant constraint 'REGMIN07'
# removing redundant constraint 'REGMIN08'
# removing redundant constraint 'OVRMIN03'
# removing redundant constraint 'OVRMIN05'
# removing redundant constraint 'OVRMIN06'
# removing redundant constraint 'OVRMIN07'
# removing redundant constraint 'OVRMIN08'
# removing redundant constraint 'BAL0113'
# removing redundant constraint 'BAL0124'
# removing redundant constraint 'BAL0161'
# removing redundant constraint 'BAL0162'
# removing redundant constraint 'BAL0170'
# removing redundant constraint 'BAL0181'
# removing redundant constraint 'BAL0185'
# removing redundant constraint 'BAL0186'
# removing redundant constraint 'BAL0213'
# removing redundant constraint 'BAL0224'
# removing redundant constraint 'BAL0261'
# removing redundant constraint 'BAL0262'
# removing redundant constraint 'BAL0270'
# removing redundant constraint 'BAL0281'
# removing redundant constraint 'BAL0285'
# removing redundant constraint 'BAL0286'
# removing redundant constraint 'BAL0313'
# removing redundant constraint 'BAL0324'
# removing redundant constraint 'BAL0361'
# removing redundant constraint 'BAL0362'
# removing redundant constraint 'BAL0370'
# removing redundant constraint 'BAL0381'
# removing redundant constraint 'BAL0385'
# removing redundant constraint 'BAL0386'
# removing redundant constraint 'BAL0413'
# removing redundant constraint 'BAL0424'
# removing redundant constraint 'BAL0461'
# removing redundant constraint 'BAL0462'
# removing redundant constraint 'BAL0470'
# removing redundant constraint 'BAL0481'
# removing redundant constraint 'BAL0485'
# removing redundant constraint 'BAL0486'
# Building polyhedron...
# Problem size: n = 1458,  m_B = 1506,  m_A = 312
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.7308146953582764
# trivial warm start
#
#
#
# Working on problem 64 of 79: netlib_lp_subset\ship08l
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\ship08l...
# removing redundant constraint 'REGMIN03'
# removing redundant constraint 'REGMIN05'
# removing redundant constraint 'REGMIN06'
# removing redundant constraint 'REGMIN07'
# removing redundant constraint 'REGMIN08'
# removing redundant constraint 'OVRMIN03'
# removing redundant constraint 'OVRMIN05'
# removing redundant constraint 'OVRMIN06'
# removing redundant constraint 'OVRMIN07'
# removing redundant constraint 'OVRMIN08'
# removing redundant constraint 'BAL0113'
# removing redundant constraint 'BAL0161'
# removing redundant constraint 'BAL0162'
# removing redundant constraint 'BAL0170'
# removing redundant constraint 'BAL0181'
# removing redundant constraint 'BAL0185'
# removing redundant constraint 'BAL0186'
# removing redundant constraint 'BAL0213'
# removing redundant constraint 'BAL0261'
# removing redundant constraint 'BAL0262'
# removing redundant constraint 'BAL0270'
# removing redundant constraint 'BAL0281'
# removing redundant constraint 'BAL0285'
# removing redundant constraint 'BAL0286'
# removing redundant constraint 'BAL0313'
# removing redundant constraint 'BAL0361'
# removing redundant constraint 'BAL0362'
# removing redundant constraint 'BAL0370'
# removing redundant constraint 'BAL0381'
# removing redundant constraint 'BAL0385'
# removing redundant constraint 'BAL0386'
# removing redundant constraint 'BAL0413'
# removing redundant constraint 'BAL0461'
# removing redundant constraint 'BAL0462'
# removing redundant constraint 'BAL0470'
# removing redundant constraint 'BAL0481'
# removing redundant constraint 'BAL0485'
# removing redundant constraint 'BAL0486'
# removing redundant constraint 'BAL0513'
# removing redundant constraint 'BAL0561'
# removing redundant constraint 'BAL0562'
# removing redundant constraint 'BAL0570'
# removing redundant constraint 'BAL0581'
# removing redundant constraint 'BAL0585'
# removing redundant constraint 'BAL0586'
# removing redundant constraint 'BAL0613'
# removing redundant constraint 'BAL0661'
# removing redundant constraint 'BAL0662'
# removing redundant constraint 'BAL0670'
# removing redundant constraint 'BAL0681'
# removing redundant constraint 'BAL0685'
# removing redundant constraint 'BAL0686'
# removing redundant constraint 'BAL0713'
# removing redundant constraint 'BAL0761'
# removing redundant constraint 'BAL0762'
# removing redundant constraint 'BAL0770'
# removing redundant constraint 'BAL0781'
# removing redundant constraint 'BAL0785'
# removing redundant constraint 'BAL0786'
# removing redundant constraint 'BAL0813'
# removing redundant constraint 'BAL0861'
# removing redundant constraint 'BAL0862'
# removing redundant constraint 'BAL0870'
# removing redundant constraint 'BAL0881'
# removing redundant constraint 'BAL0885'
# removing redundant constraint 'BAL0886'
# Building polyhedron...
# Problem size: n = 4283,  m_B = 4363,  m_A = 632
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 15.047021389007568
# trivial warm start
#
#
#
# Working on problem 65 of 79: netlib_lp_subset\ship08s
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\ship08s...
# removing redundant constraint 'REGMIN03'
# removing redundant constraint 'REGMIN05'
# removing redundant constraint 'REGMIN06'
# removing redundant constraint 'REGMIN07'
# removing redundant constraint 'REGMIN08'
# removing redundant constraint 'OVRMIN03'
# removing redundant constraint 'OVRMIN05'
# removing redundant constraint 'OVRMIN06'
# removing redundant constraint 'OVRMIN07'
# removing redundant constraint 'OVRMIN08'
# removing redundant constraint 'BAL0113'
# removing redundant constraint 'BAL0161'
# removing redundant constraint 'BAL0162'
# removing redundant constraint 'BAL0170'
# removing redundant constraint 'BAL0181'
# removing redundant constraint 'BAL0185'
# removing redundant constraint 'BAL0186'
# removing redundant constraint 'BAL0213'
# removing redundant constraint 'BAL0261'
# removing redundant constraint 'BAL0262'
# removing redundant constraint 'BAL0270'
# removing redundant constraint 'BAL0281'
# removing redundant constraint 'BAL0285'
# removing redundant constraint 'BAL0286'
# removing redundant constraint 'BAL0313'
# removing redundant constraint 'BAL0361'
# removing redundant constraint 'BAL0362'
# removing redundant constraint 'BAL0370'
# removing redundant constraint 'BAL0381'
# removing redundant constraint 'BAL0385'
# removing redundant constraint 'BAL0386'
# removing redundant constraint 'BAL0413'
# removing redundant constraint 'BAL0461'
# removing redundant constraint 'BAL0462'
# removing redundant constraint 'BAL0470'
# removing redundant constraint 'BAL0481'
# removing redundant constraint 'BAL0485'
# removing redundant constraint 'BAL0486'
# removing redundant constraint 'BAL0513'
# removing redundant constraint 'BAL0561'
# removing redundant constraint 'BAL0562'
# removing redundant constraint 'BAL0570'
# removing redundant constraint 'BAL0581'
# removing redundant constraint 'BAL0585'
# removing redundant constraint 'BAL0586'
# removing redundant constraint 'BAL0613'
# removing redundant constraint 'BAL0661'
# removing redundant constraint 'BAL0662'
# removing redundant constraint 'BAL0670'
# removing redundant constraint 'BAL0681'
# removing redundant constraint 'BAL0685'
# removing redundant constraint 'BAL0686'
# removing redundant constraint 'BAL0713'
# removing redundant constraint 'BAL0761'
# removing redundant constraint 'BAL0762'
# removing redundant constraint 'BAL0770'
# removing redundant constraint 'BAL0781'
# removing redundant constraint 'BAL0785'
# removing redundant constraint 'BAL0786'
# removing redundant constraint 'BAL0813'
# removing redundant constraint 'BAL0861'
# removing redundant constraint 'BAL0862'
# removing redundant constraint 'BAL0870'
# removing redundant constraint 'BAL0881'
# removing redundant constraint 'BAL0885'
# removing redundant constraint 'BAL0886'
# Building polyhedron...
# Problem size: n = 2387,  m_B = 2467,  m_A = 632
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 5.035373210906982
# trivial warm start
#
#
#
# Working on problem 66 of 79: netlib_lp_subset\ship12l
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\ship12l...
# removing redundant constraint 'REGMIN01'
# removing redundant constraint 'REGMIN02'
# removing redundant constraint 'REGMIN03'
# removing redundant constraint 'REGMIN06'
# removing redundant constraint 'REGMIN07'
# removing redundant constraint 'REGMIN08'
# removing redundant constraint 'OVRMIN01'
# removing redundant constraint 'OVRMIN02'
# removing redundant constraint 'OVRMIN03'
# removing redundant constraint 'OVRMIN05'
# removing redundant constraint 'OVRMIN06'
# removing redundant constraint 'OVRMIN07'
# removing redundant constraint 'OVRMIN08'
# removing redundant constraint 'BAL0113'
# removing redundant constraint 'BAL0124'
# removing redundant constraint 'BAL0161'
# removing redundant constraint 'BAL0162'
# removing redundant constraint 'BAL0170'
# removing redundant constraint 'BAL0181'
# removing redundant constraint 'BAL0185'
# removing redundant constraint 'BAL0186'
# removing redundant constraint 'BAL0213'
# removing redundant constraint 'BAL0224'
# removing redundant constraint 'BAL0261'
# removing redundant constraint 'BAL0262'
# removing redundant constraint 'BAL0270'
# removing redundant constraint 'BAL0281'
# removing redundant constraint 'BAL0285'
# removing redundant constraint 'BAL0286'
# removing redundant constraint 'BAL0313'
# removing redundant constraint 'BAL0324'
# removing redundant constraint 'BAL0361'
# removing redundant constraint 'BAL0362'
# removing redundant constraint 'BAL0370'
# removing redundant constraint 'BAL0381'
# removing redundant constraint 'BAL0385'
# removing redundant constraint 'BAL0386'
# removing redundant constraint 'BAL0413'
# removing redundant constraint 'BAL0424'
# removing redundant constraint 'BAL0461'
# removing redundant constraint 'BAL0462'
# removing redundant constraint 'BAL0470'
# removing redundant constraint 'BAL0481'
# removing redundant constraint 'BAL0485'
# removing redundant constraint 'BAL0486'
# removing redundant constraint 'BAL0513'
# removing redundant constraint 'BAL0524'
# removing redundant constraint 'BAL0561'
# removing redundant constraint 'BAL0562'
# removing redundant constraint 'BAL0570'
# removing redundant constraint 'BAL0581'
# removing redundant constraint 'BAL0585'
# removing redundant constraint 'BAL0586'
# removing redundant constraint 'BAL0613'
# removing redundant constraint 'BAL0624'
# removing redundant constraint 'BAL0661'
# removing redundant constraint 'BAL0662'
# removing redundant constraint 'BAL0670'
# removing redundant constraint 'BAL0681'
# removing redundant constraint 'BAL0685'
# removing redundant constraint 'BAL0686'
# removing redundant constraint 'BAL0713'
# removing redundant constraint 'BAL0724'
# removing redundant constraint 'BAL0761'
# removing redundant constraint 'BAL0762'
# removing redundant constraint 'BAL0770'
# removing redundant constraint 'BAL0781'
# removing redundant constraint 'BAL0785'
# removing redundant constraint 'BAL0786'
# removing redundant constraint 'BAL0813'
# removing redundant constraint 'BAL0824'
# removing redundant constraint 'BAL0861'
# removing redundant constraint 'BAL0862'
# removing redundant constraint 'BAL0870'
# removing redundant constraint 'BAL0881'
# removing redundant constraint 'BAL0885'
# removing redundant constraint 'BAL0886'
# removing redundant constraint 'BAL0913'
# removing redundant constraint 'BAL0924'
# removing redundant constraint 'BAL0961'
# removing redundant constraint 'BAL0962'
# removing redundant constraint 'BAL0970'
# removing redundant constraint 'BAL0981'
# removing redundant constraint 'BAL0985'
# removing redundant constraint 'BAL0986'
# removing redundant constraint 'BAL1013'
# removing redundant constraint 'BAL1024'
# removing redundant constraint 'BAL1061'
# removing redundant constraint 'BAL1062'
# removing redundant constraint 'BAL1070'
# removing redundant constraint 'BAL1081'
# removing redundant constraint 'BAL1085'
# removing redundant constraint 'BAL1086'
# removing redundant constraint 'BAL1113'
# removing redundant constraint 'BAL1124'
# removing redundant constraint 'BAL1161'
# removing redundant constraint 'BAL1162'
# removing redundant constraint 'BAL1170'
# removing redundant constraint 'BAL1181'
# removing redundant constraint 'BAL1185'
# removing redundant constraint 'BAL1186'
# removing redundant constraint 'BAL1213'
# removing redundant constraint 'BAL1224'
# removing redundant constraint 'BAL1261'
# removing redundant constraint 'BAL1262'
# removing redundant constraint 'BAL1270'
# removing redundant constraint 'BAL1281'
# removing redundant constraint 'BAL1285'
# removing redundant constraint 'BAL1286'
# Building polyhedron...
# Problem size: n = 5427,  m_B = 5533,  m_A = 936
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 22.35936164855957
# trivial warm start
#
#
#
# Working on problem 67 of 79: netlib_lp_subset\ship12s
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\ship12s...
# removing redundant constraint 'REGMIN01'
# removing redundant constraint 'REGMIN02'
# removing redundant constraint 'REGMIN03'
# removing redundant constraint 'REGMIN06'
# removing redundant constraint 'REGMIN07'
# removing redundant constraint 'REGMIN08'
# removing redundant constraint 'OVRMIN01'
# removing redundant constraint 'OVRMIN02'
# removing redundant constraint 'OVRMIN03'
# removing redundant constraint 'OVRMIN05'
# removing redundant constraint 'OVRMIN06'
# removing redundant constraint 'OVRMIN07'
# removing redundant constraint 'OVRMIN08'
# removing redundant constraint 'BAL0113'
# removing redundant constraint 'BAL0124'
# removing redundant constraint 'BAL0161'
# removing redundant constraint 'BAL0162'
# removing redundant constraint 'BAL0170'
# removing redundant constraint 'BAL0181'
# removing redundant constraint 'BAL0185'
# removing redundant constraint 'BAL0186'
# removing redundant constraint 'BAL0213'
# removing redundant constraint 'BAL0224'
# removing redundant constraint 'BAL0261'
# removing redundant constraint 'BAL0262'
# removing redundant constraint 'BAL0270'
# removing redundant constraint 'BAL0281'
# removing redundant constraint 'BAL0285'
# removing redundant constraint 'BAL0286'
# removing redundant constraint 'BAL0313'
# removing redundant constraint 'BAL0324'
# removing redundant constraint 'BAL0361'
# removing redundant constraint 'BAL0362'
# removing redundant constraint 'BAL0370'
# removing redundant constraint 'BAL0381'
# removing redundant constraint 'BAL0385'
# removing redundant constraint 'BAL0386'
# removing redundant constraint 'BAL0413'
# removing redundant constraint 'BAL0424'
# removing redundant constraint 'BAL0461'
# removing redundant constraint 'BAL0462'
# removing redundant constraint 'BAL0470'
# removing redundant constraint 'BAL0481'
# removing redundant constraint 'BAL0485'
# removing redundant constraint 'BAL0486'
# removing redundant constraint 'BAL0513'
# removing redundant constraint 'BAL0524'
# removing redundant constraint 'BAL0561'
# removing redundant constraint 'BAL0562'
# removing redundant constraint 'BAL0570'
# removing redundant constraint 'BAL0581'
# removing redundant constraint 'BAL0585'
# removing redundant constraint 'BAL0586'
# removing redundant constraint 'BAL0613'
# removing redundant constraint 'BAL0624'
# removing redundant constraint 'BAL0661'
# removing redundant constraint 'BAL0662'
# removing redundant constraint 'BAL0670'
# removing redundant constraint 'BAL0681'
# removing redundant constraint 'BAL0685'
# removing redundant constraint 'BAL0686'
# removing redundant constraint 'BAL0713'
# removing redundant constraint 'BAL0724'
# removing redundant constraint 'BAL0761'
# removing redundant constraint 'BAL0762'
# removing redundant constraint 'BAL0770'
# removing redundant constraint 'BAL0781'
# removing redundant constraint 'BAL0785'
# removing redundant constraint 'BAL0786'
# removing redundant constraint 'BAL0813'
# removing redundant constraint 'BAL0824'
# removing redundant constraint 'BAL0861'
# removing redundant constraint 'BAL0862'
# removing redundant constraint 'BAL0870'
# removing redundant constraint 'BAL0881'
# removing redundant constraint 'BAL0885'
# removing redundant constraint 'BAL0886'
# removing redundant constraint 'BAL0913'
# removing redundant constraint 'BAL0924'
# removing redundant constraint 'BAL0961'
# removing redundant constraint 'BAL0962'
# removing redundant constraint 'BAL0970'
# removing redundant constraint 'BAL0981'
# removing redundant constraint 'BAL0985'
# removing redundant constraint 'BAL0986'
# removing redundant constraint 'BAL1013'
# removing redundant constraint 'BAL1024'
# removing redundant constraint 'BAL1061'
# removing redundant constraint 'BAL1062'
# removing redundant constraint 'BAL1070'
# removing redundant constraint 'BAL1081'
# removing redundant constraint 'BAL1085'
# removing redundant constraint 'BAL1086'
# removing redundant constraint 'BAL1113'
# removing redundant constraint 'BAL1124'
# removing redundant constraint 'BAL1161'
# removing redundant constraint 'BAL1162'
# removing redundant constraint 'BAL1170'
# removing redundant constraint 'BAL1181'
# removing redundant constraint 'BAL1185'
# removing redundant constraint 'BAL1186'
# removing redundant constraint 'BAL1213'
# removing redundant constraint 'BAL1224'
# removing redundant constraint 'BAL1261'
# removing redundant constraint 'BAL1262'
# removing redundant constraint 'BAL1270'
# removing redundant constraint 'BAL1281'
# removing redundant constraint 'BAL1285'
# removing redundant constraint 'BAL1286'
# Building polyhedron...
# Problem size: n = 2763,  m_B = 2869,  m_A = 936
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 6.9972405433654785
# trivial warm start
#
#
#
# Working on problem 68 of 79: netlib_lp_subset\sierra
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\sierra...
# Building polyhedron...
# Problem size: n = 2036,  m_B = 4731,  m_A = 548
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 7.201693534851074
# trivial warm start
#
#
#
# Working on problem 69 of 79: netlib_lp_subset\stair
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\stair...
# Building polyhedron...
# Problem size: n = 467,  m_B = 532,  m_A = 291
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.28347301483154297
# trivial warm start
#
#
#
# Working on problem 70 of 79: netlib_lp_subset\standata
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\standata...
# Building polyhedron...
# Problem size: n = 1075,  m_B = 1362,  m_A = 176
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.1100034713745117
# trivial warm start
#
#
#
# Working on problem 71 of 79: netlib_lp_subset\standgub
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\standgub...
# Building polyhedron...
# Problem size: n = 1184,  m_B = 1471,  m_A = 178
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.3088634014129639
# trivial warm start
#
#
#
# Working on problem 72 of 79: netlib_lp_subset\standmps
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\standmps...
# Building polyhedron...
# Problem size: n = 1075,  m_B = 1362,  m_A = 284
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 1.2028987407684326
# trivial warm start
#
#
#
# Working on problem 73 of 79: netlib_lp_subset\stocfor1
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\stocfor1...
# Building polyhedron...
# Problem size: n = 111,  m_B = 165,  m_A = 63
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.028681039810180664
# trivial warm start
#
#
#
# Working on problem 74 of 79: netlib_lp_subset\stocfor2
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\stocfor2...
# Building polyhedron...
# Problem size: n = 2031,  m_B = 3045,  m_A = 1143
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 5.614935398101807
# trivial warm start
#
#
#
# Working on problem 75 of 79: netlib_lp_subset\tuff
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\tuff...
# removing redundant constraint 'GOI...BW'
# removing redundant constraint 'NOI.G0BW'
# removing redundant constraint 'NOI.G1BW'
# removing redundant constraint 'NOI.G3BW'
# removing redundant constraint 'NOI.G5BW'
# removing redundant constraint 'NOI.G6BW'
# removing redundant constraint 'NOI.G7BW'
# removing redundant constraint 'NOI.G9BW'
# removing redundant constraint 'BBI...BW'
# removing redundant constraint 'BXV...BW'
# removing redundant constraint 'BXW...BW'
# removing redundant constraint 'BXZ...BW'
# removing redundant constraint 'BX5...BW'
# removing redundant constraint 'B3A...BW'
# removing redundant constraint 'B3B...BW'
# removing redundant constraint 'B3C...BW'
# removing redundant constraint 'B3D...BW'
# removing redundant constraint 'B3G...BW'
# removing redundant constraint 'B3H...BW'
# removing redundant constraint 'B3I...BW'
# removing redundant constraint 'B3J...BW'
# removing redundant constraint 'B3K...BW'
# removing redundant constraint 'B3L...BW'
# removing redundant constraint 'B3M...BW'
# removing redundant constraint 'B3N...BW'
# removing redundant constraint 'B3O...BW'
# removing redundant constraint 'B4A...BW'
# removing redundant constraint 'B4B...BW'
# removing redundant constraint 'B4C...BW'
# removing redundant constraint 'B4D...BW'
# removing redundant constraint 'B4G...BW'
# removing redundant constraint 'B4H...BW'
# removing redundant constraint 'B4I...BW'
# removing redundant constraint 'B4J...BW'
# removing redundant constraint 'B4K...BW'
# removing redundant constraint 'B4L...BW'
# removing redundant constraint 'B4M...BW'
# removing redundant constraint 'B4N...BW'
# removing redundant constraint 'B4O...BW'
# Building polyhedron...
# Problem size: n = 587,  m_B = 641,  m_A = 264
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.452531099319458
# trivial warm start
#
#
#
# Working on problem 76 of 79: netlib_lp_subset\vtp_base
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\vtp_base...
# Building polyhedron...
# Problem size: n = 203,  m_B = 392,  m_A = 73
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 0.07372164726257324
# trivial warm start
#
#
#
# Working on problem 77 of 79: netlib_lp_subset\wood1p
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\wood1p...
# Building polyhedron...
# Problem size: n = 2594,  m_B = 2595,  m_A = 243
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 4.914421558380127
# trivial warm start
#
#
#
# Working on problem 78 of 79: netlib_lp_subset\cre-c
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\cre-c...
# removing redundant constraint 'BB013'
# removing redundant constraint 'BB023'
# removing redundant constraint 'BB031'
# removing redundant constraint 'BB032'
# removing redundant constraint 'BB033'
# removing redundant constraint 'BB034'
# removing redundant constraint 'BB035'
# removing redundant constraint 'BB043'
# removing redundant constraint 'BB053'
# removing redundant constraint 'BB063'
# removing redundant constraint 'BB073'
# removing redundant constraint 'BB083'
# removing redundant constraint 'BB093'
# removing redundant constraint 'BB123'
# removing redundant constraint 'BB133'
# removing redundant constraint 'BB141'
# removing redundant constraint 'BB142'
# removing redundant constraint 'BB143'
# removing redundant constraint 'BB144'
# removing redundant constraint 'BB145'
# removing redundant constraint 'BB163'
# removing redundant constraint 'BB173'
# removing redundant constraint 'BB213'
# removing redundant constraint 'BB231'
# removing redundant constraint 'BB232'
# removing redundant constraint 'BB233'
# removing redundant constraint 'BB234'
# removing redundant constraint 'BB235'
# removing redundant constraint 'BB303'
# removing redundant constraint 'BB384'
# removing redundant constraint 'BB414'
# removing redundant constraint 'BB424'
# removing redundant constraint 'BB434'
# removing redundant constraint 'BB444'
# removing redundant constraint 'BB454'
# removing redundant constraint 'BB484'
# removing redundant constraint 'BB551'
# removing redundant constraint 'BB552'
# removing redundant constraint 'BB553'
# removing redundant constraint 'BB554'
# removing redundant constraint 'BB555'
# removing redundant constraint 'BB571'
# removing redundant constraint 'BB572'
# removing redundant constraint 'BB573'
# removing redundant constraint 'BB574'
# removing redundant constraint 'BB575'
# removing redundant constraint 'BB584'
# removing redundant constraint 'BB601'
# removing redundant constraint 'BB602'
# removing redundant constraint 'BB603'
# removing redundant constraint 'BB604'
# removing redundant constraint 'BB605'
# removing redundant constraint 'BB611'
# removing redundant constraint 'BB612'
# removing redundant constraint 'BB613'
# removing redundant constraint 'BB614'
# removing redundant constraint 'BB615'
# removing redundant constraint 'BB621'
# removing redundant constraint 'BB622'
# removing redundant constraint 'BB623'
# removing redundant constraint 'BB624'
# removing redundant constraint 'BB625'
# removing redundant constraint 'BB641'
# removing redundant constraint 'BB642'
# removing redundant constraint 'BB643'
# removing redundant constraint 'BB644'
# removing redundant constraint 'BB645'
# removing redundant constraint 'BB651'
# removing redundant constraint 'BB652'
# removing redundant constraint 'BB653'
# removing redundant constraint 'BB654'
# removing redundant constraint 'BB655'
# removing redundant constraint 'BB661'
# removing redundant constraint 'BB662'
# removing redundant constraint 'BB663'
# removing redundant constraint 'BB664'
# removing redundant constraint 'BB665'
# removing redundant constraint 'BB671'
# removing redundant constraint 'BB672'
# removing redundant constraint 'BB673'
# removing redundant constraint 'BB674'
# removing redundant constraint 'BB675'
# Building polyhedron...
# Problem size: n = 3678,  m_B = 6411,  m_A = 253
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 16.022170782089233
# trivial warm start
#
#
#
# Working on problem 79 of 79: netlib_lp_subset\modszk1
#
# Solving with trivial steepest descent...
# Reading netlib_lp_subset\modszk1...
# removing redundant constraint 'ROW0147'
# Building polyhedron...
# Problem size: n = 1620,  m_B = 1618,  m_A = 686
# Finding feasible solution...
# Building polyhedral model. Solve method: dual_simplex
# Set parameter Method to value 1
# Polyhedral model built!
# Polyhedral model build time: 2.4192698001861572
# trivial warm start

# %% [markdown]
# ## View Results

# %%
results_dir = 'results'
problems = ['adlittle', 'afiro', 'agg2','agg3','agg', 'bandm',
 'beaconfd', 'blend', 'bnl1', 'boeing1', 'boeing2', 'bore3d', 'brandy', 'capri',
 'cycle', 'degen2', 'degen3', 'e226', 'etamacro', 'fffff800', 'finnis',
 'fit1d', 'fit1p', 'forplan', 'ganges', 'gfrd-pnc', 'grow15', 'grow22', 'grow7',
 'israel', 'kb2', 'ken-07', 'lotfi', 'maros', 'pds-02', 'perold',
 'pilot4', 'pilotnov', 'qap08', 'recipe', 'sc105', 'sc205', 'sc50a',
 'sc50b', 'scagr25', 'scagr7', 'scfxm1', 'scfxm2', 'scfxm3', 'scorpion', 'scrs8',
 'scsd1', 'scsd6', 'scsd8', 'sctap1', 'sctap2', 'sctap3', 'seba', 'share1b',
 'share2b', 'shell', 'ship04l', 'ship04s', 'ship08l', 'ship08s', 'ship12l', 'ship12s',
 'sierra', 'stair', 'standata', 'standgub', 'standmps', 'stocfor1', 'stocfor2', 'tuff',
 'vtp_base', 'wood1p', 'cre-c', 'modszk1']

# 'maros', 'pilot4', 'shell', 'modszk1'

# 'cre-c','modszk1',
# avgs = {'lp_time': [], 'old_first_sd': [], 'new_first_sd': [], #'old_avg_sd': [], 'new_avg_sd': [],
#         'lp_iters': []} #, 'old_sd_iters': [], 'new_sd_iters': []}
avgs = {'trivial_first_sd': []}
# 'old_sd_time': [], 'new_sd_time': [],
from statistics import median

figure_dir = 'figures'
if not os.path.exists(figure_dir): os.mkdir(figure_dir)
for problem in problems:
    lp_fn = os.path.join(results_dir, problem + '_lp.p')
    old_sd_fn = os.path.join(results_dir, problem + '_old_sd.p')
    if not os.path.exists(old_sd_fn): continue
    new_sd_fn = os.path.join(results_dir, problem + '_new_sd.p')
    if not os.path.exists(new_sd_fn): continue
    trivial_sd_fn = os.path.join(results_dir, problem + '_trivial_sd.p')
    if not os.path.exists(trivial_sd_fn): continue
    
    
    with open(lp_fn, 'rb') as f:
        lp_results = pickle.load(f)
    with open(old_sd_fn, 'rb') as f:
        old_sd_results = pickle.load(f)
    with open(new_sd_fn, 'rb') as f:
        new_sd_results = pickle.load(f)
    with open(trivial_sd_fn, 'rb') as f:
        trivial_sd_results = pickle.load(f)
        
    try: 
        # avgs['old_first_sd'].append(old_sd_results['solve_times'][0])
        # avgs['old_avg_sd'].append(avg(old_sd_results['solve_times'][1:]))
        # avgs['new_first_sd'].append(new_sd_results['solve_times'][0])
        # avgs['new_avg_sd'].append(avg(new_sd_results['solve_times'][1:]))
        avgs['trivial_first_sd'].append(trivial_sd_results['solve_times'][0])
        # avgs['lp_time'].append(lp_results['solve_time_total'])
        # avgs['old_sd_time'].append(old_sd_results['solve_time_total'])
        # avgs['new_sd_time'].append(new_sd_results['solve_time_total'])
        # avgs['lp_iters'].append(lp_results['n_iters'])
        # avgs['old_sd_iters'].append(old_sd_results['n_iters'])
        # avgs['new_sd_iters'].append(new_sd_results['n_iters'])
    except KeyError:
        print('skipping {}'.format(problem))
        continue
        
for metric in avgs:
    print(metric)
    print('Average {}: {}'.format(metric, avg(avgs[metric])))
    print('Median {}: {}'.format(metric, median(avgs[metric])))
# Out:
# trivial_first_sd
# Average trivial_first_sd: 0.051367086700246305
# Median trivial_first_sd: 0.03000020980834961

# %%
problems = ['stocfor2', 'cycle', 'standmps', 'shell',
            'scagr25', 'scfxm2', 'etamacro', 'qap08', 'share1b',
            'grow15', 'grow22', 'grow7', 'degen3', 'cycle']
# 'modszk1', 'cre-c',
problems = ['cycle', 'degen3', 'modszk1']
# 'modszk1',


results_dir = 'results_dual_simplex_phase1'
figure_dir = 'figs_final'
save_figs = True

if not os.path.exists(figure_dir): os.mkdir(figure_dir)
for problem in problems:
    lp_fn = os.path.join(results_dir, problem + '_lp.p')
    old_sd_fn = os.path.join(results_dir, problem + '_old_sd.p')
    if not os.path.exists(old_sd_fn): continue
    new_sd_fn = os.path.join(results_dir, problem + '_new_sd.p')
    if not os.path.exists(new_sd_fn): continue
    problem_name = problem
    
    with open(lp_fn, 'rb') as f:
        lp_results = pickle.load(f)
    with open(old_sd_fn, 'rb') as f:
        old_sd_results = pickle.load(f)
    with open(new_sd_fn, 'rb') as f:
        new_sd_results = pickle.load(f)
        
    lp_results['obj_values'].append(lp_results['obj'])  
    lp_results['iter_times'].append(lp_results['solve_time_total'])  
    plt.figure(figsize=(10,5))
    plt.title('Simplex Objective for {}'.format(problem_name))
    plt.xlabel('Iteration')
    plt.ylabel('Obj. Value')
    plt.plot(list(range(len(lp_results['obj_values']))), lp_results['obj_values'], 'go-')
    fn = os.path.join(figure_dir, '{}_{}_lp_iter.png'.format(problem, results_dir))
    if save_figs: plt.savefig(fname=fn)
    plt.show()
    
    plt.figure(figsize=(10,5))
    plt.title('SD Objective for {}'.format(problem_name))
    plt.xlabel('Iteration')
    plt.ylabel('Obj. Value')
    plt.plot(list(range(len(old_sd_results['obj_values']))), old_sd_results['obj_values'], 'bo-')
    fn = os.path.join(figure_dir, '{}_{}_sd_iter.png'.format(problem, results_dir))
    if save_figs: plt.savefig(fname=fn)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('SD Objective for {}'.format(problem_name))
    plt.xlabel('Iteration')
    plt.ylabel('Obj. Value')
    plt.plot(list(range(len(new_sd_results['obj_values']))), new_sd_results['obj_values'], 'bo-')
    fn = os.path.join(figure_dir, '{}_{}_sd_iter.png'.format(problem, results_dir))
    if save_figs: plt.savefig(fname=fn)
    plt.show()
    
    times = {}
    times['sd total'] = sd_results['solve_time_total']
    times['simplex total'] = lp_results['solve_time_total']
    times['first old SD step time'] = old_sd_results['solve_times'][0]
    times['average old SD step time'] = avg(old_sd_results['solve_times'][1:])
    times['first old SD step time'] = new_sd_results['solve_times'][0]
    times['average old SD step time'] = avg(new_sd_results['solve_times'][1:])
    times['first SD Phase1 time'] = sd_results['sub_times']['phase1_times'][0]
    old_phase1_time = old_sd_results['sub_times']['phase1_times'][0]
    old_phase1_times = [0, old_phase1_time, 0]
    new_phase1_time = new_sd_results['sub_times']['phase1_times'][0]
    new_phase1_times = [0, new_phase1_time, 0]
    times['first old SD step time'] -= old_phase1_time
    times['first new SD step time'] -= new_phase1_time
    
    time_types = [key for key in times]

    #f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,5))
    plt.figure(figsize=(6,5))
    plt.title('Time breakdown for {}'.format(problem_name))
    plt.ylabel('Time (s)')
    x_pos = np.arange(len(time_types))
    plt.xticks(x_pos, time_types)
    values = [times[key] for key in times]
    p2 = plt.bar(x_pos, values, align='center', alpha=0.8)
    p1 = plt.bar(x_pos, phase1_times, bottom=values, align='center', alpha=0.8)
    fn = os.path.join(figure_dir, '{}_{}_time_breakdown.png'.format(problem, results_dir))
    plt.legend((p1[0], p2[0]), ('Phase I', 'Phase II'))
    plt.ylim(top=times['simplex total']*1.05)
    if save_figs: plt.savefig(fname=fn)
    plt.show()

    #ax2.set_title('Step breakdown for {}'.format(problem_name))
    #ax2.set_ylabel('Time (s)')
    #x_pos = np.arange(len(subtime_types))
    #ax2.set_xticks(x_pos)
    #ax2.set_xticklabels(subtime_types)
    #values = [subtimes[key] for key in subtimes]
    #ax2.bar(x_pos, values, align='center', alpha=0.8, color='m')
    #f.show()  
    
    plt.figure(figsize=(10,5))
    plt.title('Time comparison for {}'.format(problem_name))
    plt.xlabel('Time (s)')
    plt.ylabel('Obj. Value')
    plt.plot(lp_results['iter_times'], lp_results['obj_values'], 'go-', label='simplex')
    plt.plot(old_sd_results['iter_times'], old_sd_results['obj_values'], 'bo-', label='steepest-descent')
    plt.plot(new_sd_results['iter_times'], new_sd_results['obj_values'], 'bo-', label='steepest-descent')
    plt.legend(loc='upper right')
    fn = os.path.join(figure_dir, '{}_{}_time_comp.png'.format(problem, results_dir))
    if save_figs: plt.savefig(fname=fn)
    plt.show()
